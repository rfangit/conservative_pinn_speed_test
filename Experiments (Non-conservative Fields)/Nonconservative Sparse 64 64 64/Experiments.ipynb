# %% [markdown]
# # Imports

# %%
import torch
import sys
import numpy as np
import os
import shutil
from pathlib import Path
# Add parent directory to sys.path
parent_dir = Path.cwd().parent.parent
sys.path.append(str(parent_dir))
# Import modules
from train import train_test_multiple_networks, train_network_with_test_loss, train_grad_network_with_test_loss, save_plot_test_train

# %% [markdown]
# # Network Parameters

# %%
# Training hyperparameters
num_trials = 10
neurons = [64, 64, 64]
num_epochs = 200

# %% [markdown]
# # Running Experiments

# %%
# Folder containing datasets
dataset_folder = "datasets"

# Output folder for plots
output_folder = "loss_plots"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

for subfolder in os.listdir(dataset_folder):
    subfolder_path = os.path.join(dataset_folder, subfolder)
    
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")

        output_subfolder = os.path.join(output_folder, subfolder)
        os.makedirs(output_subfolder, exist_ok=True)
        
        train_folder = os.path.join(subfolder_path, "train")
        test_folder = os.path.join(subfolder_path, "test")
        
        for filename in os.listdir(train_folder):
            if filename.endswith("_train.txt"):
                base_name = filename.replace("_train.txt", "")
                
                # Load train data
                train_filepath = os.path.join(train_folder, filename)
                train_data = np.loadtxt(train_filepath)

                dimension = (int)(train_data.shape[1]/2)

                train_points = torch.tensor(train_data[:, :dimension], dtype=torch.float32)
                train_values = torch.tensor(train_data[:, dimension:], dtype=torch.float32)

                
                # Load test data
                test_filename = f"{base_name}_test.txt"
                test_filepath = os.path.join(test_folder, test_filename)
                test_data = np.loadtxt(test_filepath)
                test_points = torch.tensor(test_data[:, :dimension], dtype=torch.float32)
                test_values = torch.tensor(test_data[:, dimension:], dtype=torch.float32)
                
                print(f"Loaded preprocessed data for dimension {dimension}")
                
                # Train the normal network
                mean_loss, variance_loss, mean_test_loss, variance_test_loss = train_test_multiple_networks(
                    train_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the normal network!")
        
                # Train the conservative network
                mean_loss_grad, variance_loss_grad, mean_test_loss_grad, variance_test_loss_grad = train_test_multiple_networks(
                    train_grad_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the conservative network!")

                # Calculate standard deviations for the normal network
                std_loss = np.sqrt(variance_loss)
                std_test_loss = np.sqrt(variance_test_loss)
                std_loss_grad = np.sqrt(variance_loss_grad)
                std_test_loss_grad = np.sqrt(variance_test_loss_grad)
        
                # Print the minimum loss
                print(f"The minimum loss was {mean_loss[-1]}, conservative {mean_loss_grad[-1]}")
                print(f"The minimum test loss was {mean_test_loss[-1]}, conservative {mean_test_loss_grad[-1]}")
                # Comparison Plot
                epochs = np.arange(num_epochs)
                save_plot_test_train(epochs, mean_loss, std_loss, mean_loss_grad, std_loss_grad,
                      mean_test_loss, std_test_loss, mean_test_loss_grad, std_test_loss_grad,
                      dimension, neurons, num_epochs, output_subfolder)

                # Save the losses to .txt files
                losses_filename = os.path.join(output_subfolder, f"{dimension}D_losses.txt")
                np.savetxt(
                    losses_filename,
                    np.column_stack((
                        epochs,
                        mean_loss, std_loss,  # Training loss and std for normal network
                        mean_test_loss, std_test_loss,  # Test loss and std for normal network
                        mean_loss_grad, std_loss_grad,  # Training loss and std for conservative network
                        mean_test_loss_grad, std_test_loss_grad  # Test loss and std for conservative network
                    )),
                    fmt='%.6f',
                    header='epochs mean_loss std_loss mean_test_loss std_test_loss mean_loss_grad std_loss_grad mean_test_loss_grad std_test_loss_grad'
                )
                print(f"Losses saved to {losses_filename}")
        
print ("Done!!!")
# Out:
# Using device: cuda
# Processing folder: dataset_1
# Loaded preprocessed data for dimension 10
# The network training took 8.48 seconds.
# Done training the normal network!
# The network training took 11.49 seconds.
# Done training the conservative network!
# The minimum loss was 0.0034854775760322807, conservative 0.3531446009874344
# The minimum test loss was 0.003604167536832392, conservative 0.36558887660503386
# Plot saved to loss_plots\dataset_1\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.43 seconds.
# Done training the normal network!
# The network training took 11.74 seconds.
# Done training the conservative network!
# The minimum loss was 0.002247288450598717, conservative 0.3162265092134476
# The minimum test loss was 0.0023765353951603176, conservative 0.3262887239456177
# Plot saved to loss_plots\dataset_1\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.97 seconds.
# Done training the normal network!
# The network training took 11.72 seconds.
# Done training the conservative network!
# The minimum loss was 0.0009375431924127043, conservative 0.049507638067007066
# The minimum test loss was 0.0010210436943452806, conservative 0.05065168216824532
# Plot saved to loss_plots\dataset_1\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.45 seconds.
# Done training the normal network!
# The network training took 11.98 seconds.
# Done training the conservative network!
# The minimum loss was 0.0005522778548765928, conservative 0.01123528452590108
# The minimum test loss was 0.0005900146614294499, conservative 0.011409619171172381
# Plot saved to loss_plots\dataset_1\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.45 seconds.
# Done training the normal network!
# The network training took 11.56 seconds.
# Done training the conservative network!
# The minimum loss was 0.0005365123099181802, conservative 0.018828975223004817
# The minimum test loss was 0.0006032168515957892, conservative 0.01927577443420887
# Plot saved to loss_plots\dataset_1\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.29 seconds.
# Done training the normal network!
# The network training took 12.07 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001439713974832557, conservative 0.4367365151643753
# The minimum test loss was 0.00014742550192750059, conservative 0.4283000320196152
# Plot saved to loss_plots\dataset_1\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.66 seconds.
# Done training the normal network!
# The network training took 11.87 seconds.
# Done training the conservative network!
# The minimum loss was 0.0026186354691162704, conservative 5.0011208057403564
# The minimum test loss was 0.002632920444011688, conservative 5.093327951431275
# Plot saved to loss_plots\dataset_1\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.17 seconds.
# Done training the normal network!
# The network training took 11.58 seconds.
# Done training the conservative network!
# The minimum loss was 0.015520071610808372, conservative 1.6117806315422059
# The minimum test loss was 0.015998293552547692, conservative 1.6281825304031372
# Plot saved to loss_plots\dataset_1\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.32 seconds.
# Done training the normal network!
# The network training took 11.55 seconds.
# Done training the conservative network!
# The minimum loss was 0.003727329708635807, conservative 0.49836980402469633
# The minimum test loss was 0.003927893843501807, conservative 0.5076851546764374
# Plot saved to loss_plots\dataset_1\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\8D_losses.txt
# Processing folder: dataset_10
# Loaded preprocessed data for dimension 10
# The network training took 6.53 seconds.
# Done training the normal network!
# The network training took 12.27 seconds.
# Done training the conservative network!
# The minimum loss was 0.0029288480523973703, conservative 0.32612830996513364
# The minimum test loss was 0.003193414187990129, conservative 0.33543260395526886
# Plot saved to loss_plots\dataset_10\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.19 seconds.
# Done training the normal network!
# The network training took 11.62 seconds.
# Done training the conservative network!
# The minimum loss was 0.0020484923617914317, conservative 0.16783767193555832
# The minimum test loss was 0.0021865553222596644, conservative 0.17344234138727188
# Plot saved to loss_plots\dataset_10\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.87 seconds.
# Done training the normal network!
# The network training took 13.03 seconds.
# Done training the conservative network!
# The minimum loss was 0.0010479235206730664, conservative 0.04450225532054901
# The minimum test loss was 0.0012086880393326282, conservative 0.0464709933847189
# Plot saved to loss_plots\dataset_10\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.31 seconds.
# Done training the normal network!
# The network training took 11.92 seconds.
# Done training the conservative network!
# The minimum loss was 0.0006765155936591327, conservative 0.019857960380613805
# The minimum test loss was 0.0007190758420620114, conservative 0.020254310965538026
# Plot saved to loss_plots\dataset_10\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.78 seconds.
# Done training the normal network!
# The network training took 11.79 seconds.
# Done training the conservative network!
# The minimum loss was 0.0004609546856954694, conservative 0.017564688622951508
# The minimum test loss was 0.0005294677917845547, conservative 0.01823615487664938
# Plot saved to loss_plots\dataset_10\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.12 seconds.
# Done training the normal network!
# The network training took 11.47 seconds.
# Done training the conservative network!
# The minimum loss was 0.00035870093706762417, conservative 0.5823682188987732
# The minimum test loss was 0.00036139329022262247, conservative 0.5796891152858734
# Plot saved to loss_plots\dataset_10\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.29 seconds.
# Done training the normal network!
# The network training took 11.73 seconds.
# Done training the conservative network!
# The minimum loss was 0.005408446863293647, conservative 5.9329931259155275
# The minimum test loss was 0.005463475827127695, conservative 6.014523458480835
# Plot saved to loss_plots\dataset_10\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.22 seconds.
# Done training the normal network!
# The network training took 12.22 seconds.
# Done training the conservative network!
# The minimum loss was 0.016321747004985808, conservative 2.265098547935486
# The minimum test loss was 0.017024504952132702, conservative 2.2602999925613405
# Plot saved to loss_plots\dataset_10\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.92 seconds.
# Done training the normal network!
# The network training took 11.41 seconds.
# Done training the conservative network!
# The minimum loss was 0.005502482503652572, conservative 0.29110087454319
# The minimum test loss was 0.006063559604808688, conservative 0.29459879398345945
# Plot saved to loss_plots\dataset_10\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\8D_losses.txt
# Processing folder: dataset_2
# Loaded preprocessed data for dimension 10
# The network training took 6.21 seconds.
# Done training the normal network!
# The network training took 11.70 seconds.
# Done training the conservative network!
# The minimum loss was 0.003402054589241743, conservative 0.16854689866304398
# The minimum test loss was 0.0036860744934529067, conservative 0.1746116101741791
# Plot saved to loss_plots\dataset_2\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.12 seconds.
# Done training the normal network!
# The network training took 11.57 seconds.
# Done training the conservative network!
# The minimum loss was 0.0015047144144773484, conservative 0.07761338800191879
# The minimum test loss was 0.001633771602064371, conservative 0.08060144260525703
# Plot saved to loss_plots\dataset_2\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.31 seconds.
# Done training the normal network!
# The network training took 13.65 seconds.
# Done training the conservative network!
# The minimum loss was 0.0008928594761528075, conservative 0.03392025381326676
# The minimum test loss was 0.0009865578904282302, conservative 0.034775656461715695
# Plot saved to loss_plots\dataset_2\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.55 seconds.
# Done training the normal network!
# The network training took 11.52 seconds.
# Done training the conservative network!
# The minimum loss was 0.0008207677223253995, conservative 0.027319881692528726
# The minimum test loss was 0.0009069082327187062, conservative 0.028605947270989418
# Plot saved to loss_plots\dataset_2\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.84 seconds.
# Done training the normal network!
# The network training took 12.03 seconds.
# Done training the conservative network!
# The minimum loss was 0.0004527196317212656, conservative 0.01732249725610018
# The minimum test loss was 0.0004967196844518184, conservative 0.017756987363100052
# Plot saved to loss_plots\dataset_2\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.53 seconds.
# Done training the normal network!
# The network training took 12.47 seconds.
# Done training the conservative network!
# The minimum loss was 0.0007806375040672719, conservative 0.47082830369472506
# The minimum test loss was 0.0007611405395437032, conservative 0.4651020377874374
# Plot saved to loss_plots\dataset_2\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.94 seconds.
# Done training the normal network!
# The network training took 12.50 seconds.
# Done training the conservative network!
# The minimum loss was 0.003730719722807407, conservative 5.705993223190307
# The minimum test loss was 0.0036690297536551954, conservative 5.748020458221435
# Plot saved to loss_plots\dataset_2\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.41 seconds.
# Done training the normal network!
# The network training took 11.66 seconds.
# Done training the conservative network!
# The minimum loss was 0.00808379976078868, conservative 2.119252848625183
# The minimum test loss was 0.008356535527855157, conservative 2.121614861488342
# Plot saved to loss_plots\dataset_2\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.23 seconds.
# Done training the normal network!
# The network training took 11.53 seconds.
# Done training the conservative network!
# The minimum loss was 0.004041097103618085, conservative 0.5061335444450379
# The minimum test loss was 0.004136389144696296, conservative 0.5130884408950805
# Plot saved to loss_plots\dataset_2\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\8D_losses.txt
# Processing folder: dataset_3
# Loaded preprocessed data for dimension 10
# The network training took 6.69 seconds.
# Done training the normal network!
# The network training took 11.89 seconds.
# Done training the conservative network!
# The minimum loss was 0.003751777741126716, conservative 0.4201879292726517
# The minimum test loss was 0.004007882066071033, conservative 0.43063574433326723
# Plot saved to loss_plots\dataset_3\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 7.83 seconds.
# Done training the normal network!
# The network training took 13.18 seconds.
# Done training the conservative network!
# The minimum loss was 0.0018810981418937445, conservative 0.07901179268956185
# The minimum test loss was 0.0020535390707664193, conservative 0.08205953463912011
# Plot saved to loss_plots\dataset_3\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.91 seconds.
# Done training the normal network!
# The network training took 12.19 seconds.
# Done training the conservative network!
# The minimum loss was 0.0012960510328412056, conservative 0.07457557618618012
# The minimum test loss was 0.0014284795965068043, conservative 0.07669401466846466
# Plot saved to loss_plots\dataset_3\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.79 seconds.
# Done training the normal network!
# The network training took 12.25 seconds.
# Done training the conservative network!
# The minimum loss was 0.0006503480195533484, conservative 0.025642899982631206
# The minimum test loss was 0.0007008117798250168, conservative 0.0263152115046978
# Plot saved to loss_plots\dataset_3\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.45 seconds.
# Done training the normal network!
# The network training took 12.95 seconds.
# Done training the conservative network!
# The minimum loss was 0.0004267548181815073, conservative 0.011286968365311623
# The minimum test loss was 0.000497970322612673, conservative 0.011939075030386447
# Plot saved to loss_plots\dataset_3\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.42 seconds.
# Done training the normal network!
# The network training took 12.42 seconds.
# Done training the conservative network!
# The minimum loss was 0.00016311649305862376, conservative 0.4765724688768387
# The minimum test loss was 0.00015601298509864135, conservative 0.4725048065185547
# Plot saved to loss_plots\dataset_3\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.42 seconds.
# Done training the normal network!
# The network training took 12.77 seconds.
# Done training the conservative network!
# The minimum loss was 0.003505349881015718, conservative 6.791262149810791
# The minimum test loss was 0.0035549569176509975, conservative 6.922087526321411
# Plot saved to loss_plots\dataset_3\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.38 seconds.
# Done training the normal network!
# The network training took 12.50 seconds.
# Done training the conservative network!
# The minimum loss was 0.016580852027982474, conservative 2.032034230232239
# The minimum test loss was 0.017138334456831217, conservative 2.058642935752869
# Plot saved to loss_plots\dataset_3\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.98 seconds.
# Done training the normal network!
# The network training took 12.31 seconds.
# Done training the conservative network!
# The minimum loss was 0.004297092463821173, conservative 0.6751744151115417
# The minimum test loss was 0.004414701601490378, conservative 0.6880544185638428
# Plot saved to loss_plots\dataset_3\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\8D_losses.txt
# Processing folder: dataset_4
# Loaded preprocessed data for dimension 10
# The network training took 6.52 seconds.
# Done training the normal network!
# The network training took 11.89 seconds.
# Done training the conservative network!
# The minimum loss was 0.003344407770782709, conservative 0.29937317967414856
# The minimum test loss was 0.003483344707638025, conservative 0.30628812611103057
# Plot saved to loss_plots\dataset_4\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.38 seconds.
# Done training the normal network!
# The network training took 11.93 seconds.
# Done training the conservative network!
# The minimum loss was 0.0021617169259116054, conservative 0.16434997767210008
# The minimum test loss was 0.002333842497318983, conservative 0.17201535254716874
# Plot saved to loss_plots\dataset_4\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.52 seconds.
# Done training the normal network!
# The network training took 12.58 seconds.
# Done training the conservative network!
# The minimum loss was 0.0008710748516023159, conservative 0.024837863631546497
# The minimum test loss was 0.0009469713317230344, conservative 0.025569187849760054
# Plot saved to loss_plots\dataset_4\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 7.01 seconds.
# Done training the normal network!
# The network training took 12.09 seconds.
# Done training the conservative network!
# The minimum loss was 0.0014841922675259411, conservative 0.12160085663199424
# The minimum test loss was 0.0016571453539654612, conservative 0.12595451921224593
# Plot saved to loss_plots\dataset_4\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.48 seconds.
# Done training the normal network!
# The network training took 12.00 seconds.
# Done training the conservative network!
# The minimum loss was 0.000490754607017152, conservative 0.014624867588281631
# The minimum test loss was 0.0005499308870639652, conservative 0.015298090502619743
# Plot saved to loss_plots\dataset_4\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.56 seconds.
# Done training the normal network!
# The network training took 12.17 seconds.
# Done training the conservative network!
# The minimum loss was 0.00021956433192826807, conservative 0.6398665606975555
# The minimum test loss was 0.00021425172017188742, conservative 0.6376678168773651
# Plot saved to loss_plots\dataset_4\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.72 seconds.
# Done training the normal network!
# The network training took 13.96 seconds.
# Done training the conservative network!
# The minimum loss was 0.0032189330318942665, conservative 5.738991451263428
# The minimum test loss was 0.0032186678843572738, conservative 5.812474155426026
# Plot saved to loss_plots\dataset_4\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.49 seconds.
# Done training the normal network!
# The network training took 12.38 seconds.
# Done training the conservative network!
# The minimum loss was 0.007870781514793635, conservative 1.5692639231681824
# The minimum test loss was 0.007668727030977607, conservative 1.582953190803528
# Plot saved to loss_plots\dataset_4\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.51 seconds.
# Done training the normal network!
# The network training took 11.90 seconds.
# Done training the conservative network!
# The minimum loss was 0.0045844792854040865, conservative 0.374108824133873
# The minimum test loss was 0.004574244283139706, conservative 0.37970456182956697
# Plot saved to loss_plots\dataset_4\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\8D_losses.txt
# Processing folder: dataset_5
# Loaded preprocessed data for dimension 10
# The network training took 6.50 seconds.
# Done training the normal network!
# The network training took 12.42 seconds.
# Done training the conservative network!
# The minimum loss was 0.0029434412717819214, conservative 0.34512337744235994
# The minimum test loss was 0.0030900855781510472, conservative 0.35397962629795077
# Plot saved to loss_plots\dataset_5\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.98 seconds.
# Done training the normal network!
# The network training took 12.05 seconds.
# Done training the conservative network!
# The minimum loss was 0.0018626292585395277, conservative 0.14138128459453583
# The minimum test loss was 0.0019469428807497025, conservative 0.1455454483628273
# Plot saved to loss_plots\dataset_5\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 8.39 seconds.
# Done training the normal network!
# The network training took 12.32 seconds.
# Done training the conservative network!
# The minimum loss was 0.0010977890458889305, conservative 0.06655747219920158
# The minimum test loss was 0.0012017767643556, conservative 0.06911199986934662
# Plot saved to loss_plots\dataset_5\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.83 seconds.
# Done training the normal network!
# The network training took 12.01 seconds.
# Done training the conservative network!
# The minimum loss was 0.0007075049972627312, conservative 0.03128440901637077
# The minimum test loss was 0.0007726094976533204, conservative 0.03225082419812679
# Plot saved to loss_plots\dataset_5\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 7.16 seconds.
# Done training the normal network!
# The network training took 12.76 seconds.
# Done training the conservative network!
# The minimum loss was 0.0004790878214407712, conservative 0.012284927908331156
# The minimum test loss was 0.0005311438377248124, conservative 0.01241585360839963
# Plot saved to loss_plots\dataset_5\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.54 seconds.
# Done training the normal network!
# The network training took 12.20 seconds.
# Done training the conservative network!
# The minimum loss was 0.00023301120672840624, conservative 0.2554908573627472
# The minimum test loss was 0.00023964431748026981, conservative 0.25424974858760835
# Plot saved to loss_plots\dataset_5\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.61 seconds.
# Done training the normal network!
# The network training took 13.76 seconds.
# Done training the conservative network!
# The minimum loss was 0.0031490473775193095, conservative 5.398003721237183
# The minimum test loss was 0.0031311438186094167, conservative 5.5650835037231445
# Plot saved to loss_plots\dataset_5\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.65 seconds.
# Done training the normal network!
# The network training took 13.11 seconds.
# Done training the conservative network!
# The minimum loss was 0.01612177286297083, conservative 1.479093849658966
# The minimum test loss was 0.01671622972935438, conservative 1.47745840549469
# Plot saved to loss_plots\dataset_5\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 7.26 seconds.
# Done training the normal network!
# The network training took 12.34 seconds.
# Done training the conservative network!
# The minimum loss was 0.0047313996590673925, conservative 0.7216806054115296
# The minimum test loss was 0.0047723299358040094, conservative 0.7337108850479126
# Plot saved to loss_plots\dataset_5\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\8D_losses.txt
# Processing folder: dataset_6
# Loaded preprocessed data for dimension 10
# The network training took 6.45 seconds.
# Done training the normal network!
# The network training took 12.15 seconds.
# Done training the conservative network!
# The minimum loss was 0.0028223993722349405, conservative 0.26052072942256926
# The minimum test loss was 0.0031676214653998612, conservative 0.26956635117530825
# Plot saved to loss_plots\dataset_6\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.66 seconds.
# Done training the normal network!
# The network training took 13.76 seconds.
# Done training the conservative network!
# The minimum loss was 0.002365211118012667, conservative 0.20939337760210036
# The minimum test loss was 0.002431037137284875, conservative 0.2162175729870796
# Plot saved to loss_plots\dataset_6\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 7.17 seconds.
# Done training the normal network!
# The network training took 13.05 seconds.
# Done training the conservative network!
# The minimum loss was 0.0013259243103675544, conservative 0.08048942908644677
# The minimum test loss was 0.0015237757936120034, conservative 0.08391555845737457
# Plot saved to loss_plots\dataset_6\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.63 seconds.
# Done training the normal network!
# The network training took 12.88 seconds.
# Done training the conservative network!
# The minimum loss was 0.0008406010863836854, conservative 0.03772938847541809
# The minimum test loss was 0.00089751934283413, conservative 0.039085383713245395
# Plot saved to loss_plots\dataset_6\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.46 seconds.
# Done training the normal network!
# The network training took 12.00 seconds.
# Done training the conservative network!
# The minimum loss was 0.00045122723095119, conservative 0.018229050375521184
# The minimum test loss was 0.0004942016879795119, conservative 0.018684524483978747
# Plot saved to loss_plots\dataset_6\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.57 seconds.
# Done training the normal network!
# The network training took 12.54 seconds.
# Done training the conservative network!
# The minimum loss was 0.0004759439791087061, conservative 0.26836430132389066
# The minimum test loss was 0.0004759505740366876, conservative 0.26243823766708374
# Plot saved to loss_plots\dataset_6\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 7.01 seconds.
# Done training the normal network!
# The network training took 13.25 seconds.
# Done training the conservative network!
# The minimum loss was 0.007637034030631184, conservative 3.2694756269454954
# The minimum test loss was 0.0078373315744102, conservative 3.353434681892395
# Plot saved to loss_plots\dataset_6\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.49 seconds.
# Done training the normal network!
# The network training took 12.15 seconds.
# Done training the conservative network!
# The minimum loss was 0.017247153259813786, conservative 1.8679146647453309
# The minimum test loss was 0.01740918904542923, conservative 1.8628199219703674
# Plot saved to loss_plots\dataset_6\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.58 seconds.
# Done training the normal network!
# The network training took 12.19 seconds.
# Done training the conservative network!
# The minimum loss was 0.0052187465596944095, conservative 0.28110007345676424
# The minimum test loss was 0.005607030214741826, conservative 0.28776961863040923
# Plot saved to loss_plots\dataset_6\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\8D_losses.txt
# Processing folder: dataset_7
# Loaded preprocessed data for dimension 10
# The network training took 6.53 seconds.
# Done training the normal network!
# The network training took 12.83 seconds.
# Done training the conservative network!
# The minimum loss was 0.003320728801190853, conservative 0.46084312796592714
# The minimum test loss was 0.0033855997724458577, conservative 0.4746423035860062
# Plot saved to loss_plots\dataset_7\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 7.17 seconds.
# Done training the normal network!
# The network training took 12.17 seconds.
# Done training the conservative network!
# The minimum loss was 0.0020792279858142136, conservative 0.18719337731599808
# The minimum test loss was 0.002357916394248605, conservative 0.1952779084444046
# Plot saved to loss_plots\dataset_7\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.45 seconds.
# Done training the normal network!
# The network training took 12.05 seconds.
# Done training the conservative network!
# The minimum loss was 0.0013460582820698618, conservative 0.0979205310344696
# The minimum test loss was 0.0014067623880691827, conservative 0.1019152656197548
# Plot saved to loss_plots\dataset_7\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.65 seconds.
# Done training the normal network!
# The network training took 12.13 seconds.
# Done training the conservative network!
# The minimum loss was 0.0004960015619872137, conservative 0.02849716171622276
# The minimum test loss was 0.0005422353511676193, conservative 0.029141688346862794
# Plot saved to loss_plots\dataset_7\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 7.09 seconds.
# Done training the normal network!
# The network training took 12.57 seconds.
# Done training the conservative network!
# The minimum loss was 0.0008154010749422014, conservative 0.030983488261699676
# The minimum test loss was 0.0009164074901491404, conservative 0.03191420175135136
# Plot saved to loss_plots\dataset_7\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.77 seconds.
# Done training the normal network!
# The network training took 12.50 seconds.
# Done training the conservative network!
# The minimum loss was 0.000728030625032261, conservative 0.26872020959854126
# The minimum test loss was 0.0006918332132045179, conservative 0.26667464673519137
# Plot saved to loss_plots\dataset_7\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.69 seconds.
# Done training the normal network!
# The network training took 14.03 seconds.
# Done training the conservative network!
# The minimum loss was 0.0026917100185528398, conservative 4.808321714401245
# The minimum test loss was 0.002671832451596856, conservative 4.884489965438843
# Plot saved to loss_plots\dataset_7\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.41 seconds.
# Done training the normal network!
# The network training took 12.52 seconds.
# Done training the conservative network!
# The minimum loss was 0.009024998126551508, conservative 2.7522501230239866
# The minimum test loss was 0.00932432054542005, conservative 2.7848912715911864
# Plot saved to loss_plots\dataset_7\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 7.07 seconds.
# Done training the normal network!
# The network training took 11.85 seconds.
# Done training the conservative network!
# The minimum loss was 0.00492675406858325, conservative 0.4887363016605377
# The minimum test loss was 0.00509332693181932, conservative 0.49721071124076843
# Plot saved to loss_plots\dataset_7\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\8D_losses.txt
# Processing folder: dataset_8
# Loaded preprocessed data for dimension 10
# The network training took 6.24 seconds.
# Done training the normal network!
# The network training took 12.00 seconds.
# Done training the conservative network!
# The minimum loss was 0.003305387659929693, conservative 0.25760368406772616
# The minimum test loss was 0.0036055091302841904, conservative 0.26487345099449155
# Plot saved to loss_plots\dataset_8\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.44 seconds.
# Done training the normal network!
# The network training took 12.00 seconds.
# Done training the conservative network!
# The minimum loss was 0.001657819957472384, conservative 0.08133459240198135
# The minimum test loss was 0.0016758587560616433, conservative 0.08315457478165626
# Plot saved to loss_plots\dataset_8\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.89 seconds.
# Done training the normal network!
# The network training took 12.88 seconds.
# Done training the conservative network!
# The minimum loss was 0.0013358195894397796, conservative 0.07933231815695763
# The minimum test loss was 0.0014684849767945707, conservative 0.08162275329232216
# Plot saved to loss_plots\dataset_8\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.86 seconds.
# Done training the normal network!
# The network training took 12.23 seconds.
# Done training the conservative network!
# The minimum loss was 0.001081138022709638, conservative 0.07981797978281975
# The minimum test loss was 0.0011834828648716212, conservative 0.0833236150443554
# Plot saved to loss_plots\dataset_8\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.60 seconds.
# Done training the normal network!
# The network training took 12.02 seconds.
# Done training the conservative network!
# The minimum loss was 0.0007042443263344467, conservative 0.027415907569229604
# The minimum test loss was 0.0007870771980378777, conservative 0.028081238083541394
# Plot saved to loss_plots\dataset_8\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.56 seconds.
# Done training the normal network!
# The network training took 13.69 seconds.
# Done training the conservative network!
# The minimum loss was 0.00016432754127890803, conservative 0.6782434999942779
# The minimum test loss was 0.00016897959139896556, conservative 0.6814296960830688
# Plot saved to loss_plots\dataset_8\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 7.13 seconds.
# Done training the normal network!
# The network training took 12.36 seconds.
# Done training the conservative network!
# The minimum loss was 0.007628257153555751, conservative 5.11285719871521
# The minimum test loss was 0.007472815085202455, conservative 5.194054508209229
# Plot saved to loss_plots\dataset_8\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.36 seconds.
# Done training the normal network!
# The network training took 12.13 seconds.
# Done training the conservative network!
# The minimum loss was 0.012612513080239297, conservative 2.8246003150939942
# The minimum test loss was 0.013083455618470907, conservative 2.828925371170044
# Plot saved to loss_plots\dataset_8\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.45 seconds.
# Done training the normal network!
# The network training took 11.90 seconds.
# Done training the conservative network!
# The minimum loss was 0.006647238181903959, conservative 0.3558747559785843
# The minimum test loss was 0.007294212281703949, conservative 0.359603026509285
# Plot saved to loss_plots\dataset_8\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\8D_losses.txt
# Processing folder: dataset_9
# Loaded preprocessed data for dimension 10
# The network training took 6.45 seconds.
# Done training the normal network!
# The network training took 12.70 seconds.
# Done training the conservative network!
# The minimum loss was 0.003133485116995871, conservative 0.2999542385339737
# The minimum test loss was 0.003501819144003093, conservative 0.3129451036453247
# Plot saved to loss_plots\dataset_9\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.47 seconds.
# Done training the normal network!
# The network training took 11.94 seconds.
# Done training the conservative network!
# The minimum loss was 0.0020845001214183866, conservative 0.22682340145111085
# The minimum test loss was 0.002218994661234319, conservative 0.2337011605501175
# Plot saved to loss_plots\dataset_9\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.41 seconds.
# Done training the normal network!
# The network training took 12.07 seconds.
# Done training the conservative network!
# The minimum loss was 0.0010271209583152085, conservative 0.05893368199467659
# The minimum test loss was 0.001095375674776733, conservative 0.06026884354650974
# Plot saved to loss_plots\dataset_9\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.46 seconds.
# Done training the normal network!
# The network training took 12.06 seconds.
# Done training the conservative network!
# The minimum loss was 0.0009256884572096169, conservative 0.044702285155653956
# The minimum test loss was 0.0009744201495777815, conservative 0.046060816198587415
# Plot saved to loss_plots\dataset_9\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.90 seconds.
# Done training the normal network!
# The network training took 12.40 seconds.
# Done training the conservative network!
# The minimum loss was 0.0005548659129999578, conservative 0.018048926442861556
# The minimum test loss was 0.0005908536200877279, conservative 0.018227287195622922
# Plot saved to loss_plots\dataset_9\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.56 seconds.
# Done training the normal network!
# The network training took 12.09 seconds.
# Done training the conservative network!
# The minimum loss was 0.00037614421744365246, conservative 0.34308035373687745
# The minimum test loss was 0.00039866644656285646, conservative 0.3364652514457703
# Plot saved to loss_plots\dataset_9\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.52 seconds.
# Done training the normal network!
# The network training took 12.31 seconds.
# Done training the conservative network!
# The minimum loss was 0.0038256583036854865, conservative 4.8002687931060795
# The minimum test loss was 0.0038786946330219506, conservative 4.886333894729614
# Plot saved to loss_plots\dataset_9\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 8.04 seconds.
# Done training the normal network!
# The network training took 12.59 seconds.
# Done training the conservative network!
# The minimum loss was 0.0067123327869921924, conservative 3.046735978126526
# The minimum test loss was 0.006821865495294332, conservative 3.0309197187423704
# Plot saved to loss_plots\dataset_9\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.59 seconds.
# Done training the normal network!
# The network training took 12.11 seconds.
# Done training the conservative network!
# The minimum loss was 0.0039061490446329118, conservative 0.4795008093118668
# The minimum test loss was 0.004180776048451662, conservative 0.49074633717536925
# Plot saved to loss_plots\dataset_9\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\8D_losses.txt
# Done!!!

# %% [markdown]
# # Organizing Data

# %%
# Folder containing the loss plots and text files
loss_folder = "loss_plots"

# Output folders for consolidated images and text files
output_image_folder = "consolidated_images"
output_text_folder = "consolidated_text_files"

# Create output folders if they don't exist
os.makedirs(output_image_folder, exist_ok=True)
os.makedirs(output_text_folder, exist_ok=True)

# Iterate through all subfolders in the loss_folder
for subfolder in os.listdir(loss_folder):
    subfolder_path = os.path.join(loss_folder, subfolder)
    
    # Check if it's a directory (e.g., dataset_1, dataset_2, etc.)
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")
        
        # Extract the dataset number (e.g., "1" from "dataset_1")
        dataset_number = subfolder.split("_")[-1]
        
        # Process images
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".png"):  # Process only .png files
                # Construct the new filename (e.g., 2D_Conservative_NN_1.png)
                new_filename = filename.replace(".png", f"_{dataset_number}.png")
                
                # Copy the image to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_image_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied image: {src_path} -> {dest_path}")
        
        # Process text files
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".txt"):  # Process only .txt files
                # Construct the new filename (e.g., 8D_losses_1.txt)
                new_filename = filename.replace(".txt", f"_{dataset_number}.txt")
                
                # Copy the text file to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_text_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied text file: {src_path} -> {dest_path}")

print("All files have been consolidated.")
# Out:
# Processing folder: dataset_1
# Processing folder: dataset_10
# Processing folder: dataset_2
# Processing folder: dataset_3
# Processing folder: dataset_4
# Processing folder: dataset_5
# Processing folder: dataset_6
# Processing folder: dataset_7
# Processing folder: dataset_8
# Processing folder: dataset_9
# All files have been consolidated.
