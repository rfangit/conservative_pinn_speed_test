# %% [markdown]
# # Imports

# %%
import torch
import sys
import numpy as np
import os
import shutil
from pathlib import Path
# Add parent directory to sys.path
parent_dir = Path.cwd().parent.parent
sys.path.append(str(parent_dir))
# Import modules
from train import train_test_multiple_networks, train_network_with_test_loss, train_grad_network_with_test_loss, save_plot_test_train

# %% [markdown]
# # Network Parameters

# %%
# Training hyperparameters
num_trials = 10
neurons = [64, 64, 64]
num_epochs = 200

# %% [markdown]
# # Running Experiments

# %%
# Folder containing datasets
dataset_folder = "datasets"

# Output folder for plots
output_folder = "loss_plots"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

for subfolder in os.listdir(dataset_folder):
    subfolder_path = os.path.join(dataset_folder, subfolder)
    
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")

        output_subfolder = os.path.join(output_folder, subfolder)
        os.makedirs(output_subfolder, exist_ok=True)
        
        train_folder = os.path.join(subfolder_path, "train")
        test_folder = os.path.join(subfolder_path, "test")
        
        for filename in os.listdir(train_folder):
            if filename.endswith("_train.txt"):
                base_name = filename.replace("_train.txt", "")
                
                # Load train data
                train_filepath = os.path.join(train_folder, filename)
                train_data = np.loadtxt(train_filepath)

                dimension = (int)(train_data.shape[1]/2)

                train_points = torch.tensor(train_data[:, :dimension], dtype=torch.float32)
                train_values = torch.tensor(train_data[:, dimension:], dtype=torch.float32)

                
                # Load test data
                test_filename = f"{base_name}_test.txt"
                test_filepath = os.path.join(test_folder, test_filename)
                test_data = np.loadtxt(test_filepath)
                test_points = torch.tensor(test_data[:, :dimension], dtype=torch.float32)
                test_values = torch.tensor(test_data[:, dimension:], dtype=torch.float32)
                
                print(f"Loaded preprocessed data for dimension {dimension}")
                
                # Train the normal network
                mean_loss, variance_loss, mean_test_loss, variance_test_loss = train_test_multiple_networks(
                    train_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the normal network!")
        
                # Train the conservative network
                mean_loss_grad, variance_loss_grad, mean_test_loss_grad, variance_test_loss_grad = train_test_multiple_networks(
                    train_grad_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the conservative network!")

                # Calculate standard deviations for the normal network
                std_loss = np.sqrt(variance_loss)
                std_test_loss = np.sqrt(variance_test_loss)
                std_loss_grad = np.sqrt(variance_loss_grad)
                std_test_loss_grad = np.sqrt(variance_test_loss_grad)
        
                # Print the minimum loss
                print(f"The minimum loss was {mean_loss[-1]}, conservative {mean_loss_grad[-1]}")
                print(f"The minimum test loss was {mean_test_loss[-1]}, conservative {mean_test_loss_grad[-1]}")
                # Comparison Plot
                epochs = np.arange(num_epochs)
                save_plot_test_train(epochs, mean_loss, std_loss, mean_loss_grad, std_loss_grad,
                      mean_test_loss, std_test_loss, mean_test_loss_grad, std_test_loss_grad,
                      dimension, neurons, num_epochs, output_subfolder)

                # Save the losses to .txt files
                losses_filename = os.path.join(output_subfolder, f"{dimension}D_losses.txt")
                np.savetxt(
                    losses_filename,
                    np.column_stack((
                        epochs,
                        mean_loss, std_loss,  # Training loss and std for normal network
                        mean_test_loss, std_test_loss,  # Test loss and std for normal network
                        mean_loss_grad, std_loss_grad,  # Training loss and std for conservative network
                        mean_test_loss_grad, std_test_loss_grad  # Test loss and std for conservative network
                    )),
                    fmt='%.6f',
                    header='epochs mean_loss std_loss mean_test_loss std_test_loss mean_loss_grad std_loss_grad mean_test_loss_grad std_test_loss_grad'
                )
                print(f"Losses saved to {losses_filename}")
        
print ("Done!!!")
# Out:
# Using device: cuda
# Processing folder: dataset_1
# Loaded preprocessed data for dimension 10
# The network training took 8.97 seconds.
# Done training the normal network!
# The network training took 11.57 seconds.
# Done training the conservative network!
# The minimum loss was 2126.1505859375, conservative 23375.573046875
# The minimum test loss was 2173.8132934570312, conservative 24021.480859375
# Plot saved to loss_plots\dataset_1\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.39 seconds.
# Done training the normal network!
# The network training took 11.65 seconds.
# Done training the conservative network!
# The minimum loss was 277137.1671875, conservative 1077508.5
# The minimum test loss was 279231.9546875, conservative 1101165.4625
# Plot saved to loss_plots\dataset_1\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.58 seconds.
# Done training the normal network!
# The network training took 11.88 seconds.
# Done training the conservative network!
# The minimum loss was 4.644305158763018e-06, conservative 0.02488869372755289
# The minimum test loss was 4.680408164858818e-06, conservative 0.02512982189655304
# Plot saved to loss_plots\dataset_1\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.84 seconds.
# Done training the normal network!
# The network training took 12.25 seconds.
# Done training the conservative network!
# The minimum loss was 0.0009123975178226829, conservative 1.6755988121032714
# The minimum test loss was 0.0009013902163133025, conservative 1.6998066306114197
# Plot saved to loss_plots\dataset_1\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.26 seconds.
# Done training the normal network!
# The network training took 11.84 seconds.
# Done training the conservative network!
# The minimum loss was 0.004831440839916467, conservative 0.8559560656547547
# The minimum test loss was 0.004730280581861734, conservative 0.868772280216217
# Plot saved to loss_plots\dataset_1\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.37 seconds.
# Done training the normal network!
# The network training took 11.86 seconds.
# Done training the conservative network!
# The minimum loss was 0.044904709234833716, conservative 8.988626670837402
# The minimum test loss was 0.04481876716017723, conservative 8.95872230529785
# Plot saved to loss_plots\dataset_1\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.54 seconds.
# Done training the normal network!
# The network training took 12.55 seconds.
# Done training the conservative network!
# The minimum loss was 9.782666397094726, conservative 638.9855041503906
# The minimum test loss was 10.081886768341064, conservative 648.454296875
# Plot saved to loss_plots\dataset_1\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\8D_losses.txt
# Processing folder: dataset_10
# Loaded preprocessed data for dimension 10
# The network training took 6.99 seconds.
# Done training the normal network!
# The network training took 11.88 seconds.
# Done training the conservative network!
# The minimum loss was 2054.4918579101563, conservative 22640.77890625
# The minimum test loss was 2102.702526855469, conservative 23312.9501953125
# Plot saved to loss_plots\dataset_10\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 7.01 seconds.
# Done training the normal network!
# The network training took 12.43 seconds.
# Done training the conservative network!
# The minimum loss was 263437.0109375, conservative 1049260.50625
# The minimum test loss was 265496.0796875, conservative 1072225.8125
# Plot saved to loss_plots\dataset_10\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.61 seconds.
# Done training the normal network!
# The network training took 12.21 seconds.
# Done training the conservative network!
# The minimum loss was 1.4160713908495381e-05, conservative 0.02304038666188717
# The minimum test loss was 1.3955418762634508e-05, conservative 0.022712339460849763
# Plot saved to loss_plots\dataset_10\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.74 seconds.
# Done training the normal network!
# The network training took 12.88 seconds.
# Done training the conservative network!
# The minimum loss was 0.004007053445093334, conservative 1.0807654142379761
# The minimum test loss was 0.003910583420656621, conservative 1.1041959404945374
# Plot saved to loss_plots\dataset_10\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.42 seconds.
# Done training the normal network!
# The network training took 11.82 seconds.
# Done training the conservative network!
# The minimum loss was 0.007797284191474319, conservative 1.0141023755073548
# The minimum test loss was 0.007802010141313076, conservative 1.025068986415863
# Plot saved to loss_plots\dataset_10\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.33 seconds.
# Done training the normal network!
# The network training took 11.95 seconds.
# Done training the conservative network!
# The minimum loss was 0.053017765283584595, conservative 15.966628551483154
# The minimum test loss was 0.053677904233336446, conservative 16.267849731445313
# Plot saved to loss_plots\dataset_10\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.53 seconds.
# Done training the normal network!
# The network training took 12.23 seconds.
# Done training the conservative network!
# The minimum loss was 11.051302719116212, conservative 702.2823364257813
# The minimum test loss was 11.304401874542236, conservative 714.7546142578125
# Plot saved to loss_plots\dataset_10\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\8D_losses.txt
# Processing folder: dataset_2
# Loaded preprocessed data for dimension 10
# The network training took 6.82 seconds.
# Done training the normal network!
# The network training took 12.13 seconds.
# Done training the conservative network!
# The minimum loss was 1951.2052490234375, conservative 22585.353125
# The minimum test loss was 2000.1313842773438, conservative 23249.855078125
# Plot saved to loss_plots\dataset_2\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.53 seconds.
# Done training the normal network!
# The network training took 12.13 seconds.
# Done training the conservative network!
# The minimum loss was 280987.646875, conservative 1067899.2125
# The minimum test loss was 283475.625, conservative 1090911.4125
# Plot saved to loss_plots\dataset_2\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.52 seconds.
# Done training the normal network!
# The network training took 11.96 seconds.
# Done training the conservative network!
# The minimum loss was 4.224775639158906e-05, conservative 0.009653407149016857
# The minimum test loss was 4.366121156635927e-05, conservative 0.009972896054387092
# Plot saved to loss_plots\dataset_2\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.58 seconds.
# Done training the normal network!
# The network training took 12.78 seconds.
# Done training the conservative network!
# The minimum loss was 0.0008468801272101701, conservative 2.0208996772766112
# The minimum test loss was 0.0008477073453832418, conservative 2.052925443649292
# Plot saved to loss_plots\dataset_2\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.66 seconds.
# Done training the normal network!
# The network training took 12.32 seconds.
# Done training the conservative network!
# The minimum loss was 0.004800382209941745, conservative 1.0750212907791137
# The minimum test loss was 0.00470281473826617, conservative 1.0806045055389404
# Plot saved to loss_plots\dataset_2\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.58 seconds.
# Done training the normal network!
# The network training took 12.09 seconds.
# Done training the conservative network!
# The minimum loss was 0.04464716650545597, conservative 14.8524658203125
# The minimum test loss was 0.044993848726153376, conservative 15.046564483642578
# Plot saved to loss_plots\dataset_2\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.56 seconds.
# Done training the normal network!
# The network training took 12.27 seconds.
# Done training the conservative network!
# The minimum loss was 8.759260272979736, conservative 610.4721923828125
# The minimum test loss was 8.917792367935181, conservative 618.081201171875
# Plot saved to loss_plots\dataset_2\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\8D_losses.txt
# Processing folder: dataset_3
# Loaded preprocessed data for dimension 10
# The network training took 7.03 seconds.
# Done training the normal network!
# The network training took 12.55 seconds.
# Done training the conservative network!
# The minimum loss was 2055.4729125976564, conservative 23256.7671875
# The minimum test loss was 2106.6392211914062, conservative 23925.4955078125
# Plot saved to loss_plots\dataset_3\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.44 seconds.
# Done training the normal network!
# The network training took 11.72 seconds.
# Done training the conservative network!
# The minimum loss was 272674.84375, conservative 1079784.1125
# The minimum test loss was 275125.390625, conservative 1102671.925
# Plot saved to loss_plots\dataset_3\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.45 seconds.
# Done training the normal network!
# The network training took 12.12 seconds.
# Done training the conservative network!
# The minimum loss was 1.1534936129464768e-05, conservative 0.05673680491745472
# The minimum test loss was 1.164348318525299e-05, conservative 0.056664508581161496
# Plot saved to loss_plots\dataset_3\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.55 seconds.
# Done training the normal network!
# The network training took 12.65 seconds.
# Done training the conservative network!
# The minimum loss was 0.00368480016477406, conservative 1.0211401343345643
# The minimum test loss was 0.0037378938402980568, conservative 1.044219982624054
# Plot saved to loss_plots\dataset_3\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 7.09 seconds.
# Done training the normal network!
# The network training took 11.96 seconds.
# Done training the conservative network!
# The minimum loss was 0.0063316939864307645, conservative 0.8921554386615753
# The minimum test loss was 0.006468731025233865, conservative 0.90655357837677
# Plot saved to loss_plots\dataset_3\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.27 seconds.
# Done training the normal network!
# The network training took 11.85 seconds.
# Done training the conservative network!
# The minimum loss was 0.053005162999033927, conservative 12.225847625732422
# The minimum test loss was 0.053265698999166486, conservative 12.136571598052978
# Plot saved to loss_plots\dataset_3\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.44 seconds.
# Done training the normal network!
# The network training took 12.03 seconds.
# Done training the conservative network!
# The minimum loss was 9.795055532455445, conservative 649.3753723144531
# The minimum test loss was 10.057177829742432, conservative 659.9196594238281
# Plot saved to loss_plots\dataset_3\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\8D_losses.txt
# Processing folder: dataset_4
# Loaded preprocessed data for dimension 10
# The network training took 6.55 seconds.
# Done training the normal network!
# The network training took 12.86 seconds.
# Done training the conservative network!
# The minimum loss was 2241.3028076171877, conservative 24069.4314453125
# The minimum test loss was 2292.0229248046876, conservative 24791.326171875
# Plot saved to loss_plots\dataset_4\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.88 seconds.
# Done training the normal network!
# The network training took 11.98 seconds.
# Done training the conservative network!
# The minimum loss was 275618.9640625, conservative 1067202.85
# The minimum test loss was 277826.9265625, conservative 1090930.6375
# Plot saved to loss_plots\dataset_4\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.62 seconds.
# Done training the normal network!
# The network training took 12.10 seconds.
# Done training the conservative network!
# The minimum loss was 1.7049609687092017e-05, conservative 0.051328082010149954
# The minimum test loss was 1.705019058135804e-05, conservative 0.050918664410710336
# Plot saved to loss_plots\dataset_4\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.57 seconds.
# Done training the normal network!
# The network training took 12.22 seconds.
# Done training the conservative network!
# The minimum loss was 0.0011252214491833002, conservative 1.838249433040619
# The minimum test loss was 0.0011522734712343663, conservative 1.8633231401443482
# Plot saved to loss_plots\dataset_4\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 7.22 seconds.
# Done training the normal network!
# The network training took 12.44 seconds.
# Done training the conservative network!
# The minimum loss was 0.008100203238427639, conservative 0.8504284143447876
# The minimum test loss was 0.008097952930256724, conservative 0.86020929813385
# Plot saved to loss_plots\dataset_4\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.34 seconds.
# Done training the normal network!
# The network training took 11.76 seconds.
# Done training the conservative network!
# The minimum loss was 0.0474808044731617, conservative 18.234288597106932
# The minimum test loss was 0.04818470478057861, conservative 18.310090827941895
# Plot saved to loss_plots\dataset_4\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.46 seconds.
# Done training the normal network!
# The network training took 11.90 seconds.
# Done training the conservative network!
# The minimum loss was 9.578722143173218, conservative 634.2719543457031
# The minimum test loss was 9.824927043914794, conservative 644.23671875
# Plot saved to loss_plots\dataset_4\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\8D_losses.txt
# Processing folder: dataset_5
# Loaded preprocessed data for dimension 10
# The network training took 6.32 seconds.
# Done training the normal network!
# The network training took 12.74 seconds.
# Done training the conservative network!
# The minimum loss was 2151.970751953125, conservative 23549.4947265625
# The minimum test loss was 2206.9964233398437, conservative 24249.7765625
# Plot saved to loss_plots\dataset_5\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 7.04 seconds.
# Done training the normal network!
# The network training took 12.31 seconds.
# Done training the conservative network!
# The minimum loss was 275735.915625, conservative 1070176.2375
# The minimum test loss was 278084.359375, conservative 1092862.1625
# Plot saved to loss_plots\dataset_5\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.65 seconds.
# Done training the normal network!
# The network training took 12.08 seconds.
# Done training the conservative network!
# The minimum loss was 8.400319984502858e-06, conservative 0.023762698471546172
# The minimum test loss was 8.448669450444869e-06, conservative 0.022672736272215843
# Plot saved to loss_plots\dataset_5\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.60 seconds.
# Done training the normal network!
# The network training took 12.12 seconds.
# Done training the conservative network!
# The minimum loss was 0.0010860161681193858, conservative 1.0993668675422668
# The minimum test loss was 0.001100031251553446, conservative 1.1029649138450623
# Plot saved to loss_plots\dataset_5\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.68 seconds.
# Done training the normal network!
# The network training took 13.08 seconds.
# Done training the conservative network!
# The minimum loss was 0.00798729071393609, conservative 0.5057742357254028
# The minimum test loss was 0.007821164978668093, conservative 0.5126450419425964
# Plot saved to loss_plots\dataset_5\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.52 seconds.
# Done training the normal network!
# The network training took 12.37 seconds.
# Done training the conservative network!
# The minimum loss was 0.05918487347662449, conservative 10.016194248199463
# The minimum test loss was 0.06061576791107655, conservative 10.053432750701905
# Plot saved to loss_plots\dataset_5\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.60 seconds.
# Done training the normal network!
# The network training took 12.13 seconds.
# Done training the conservative network!
# The minimum loss was 9.596456050872803, conservative 636.7916015625
# The minimum test loss was 9.861418628692627, conservative 646.5620422363281
# Plot saved to loss_plots\dataset_5\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\8D_losses.txt
# Processing folder: dataset_6
# Loaded preprocessed data for dimension 10
# The network training took 6.57 seconds.
# Done training the normal network!
# The network training took 12.28 seconds.
# Done training the conservative network!
# The minimum loss was 2124.9853271484376, conservative 23753.0005859375
# The minimum test loss was 2176.0058715820314, conservative 24420.025390625
# Plot saved to loss_plots\dataset_6\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 7.09 seconds.
# Done training the normal network!
# The network training took 12.32 seconds.
# Done training the conservative network!
# The minimum loss was 282726.0640625, conservative 1076435.6375
# The minimum test loss was 284954.0703125, conservative 1099692.95
# Plot saved to loss_plots\dataset_6\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.49 seconds.
# Done training the normal network!
# The network training took 12.29 seconds.
# Done training the conservative network!
# The minimum loss was 9.30956946376682e-06, conservative 0.021853527612984182
# The minimum test loss was 9.260619049200613e-06, conservative 0.021708367951214315
# Plot saved to loss_plots\dataset_6\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.50 seconds.
# Done training the normal network!
# The network training took 12.10 seconds.
# Done training the conservative network!
# The minimum loss was 0.0014219932549167425, conservative 0.8965043246746063
# The minimum test loss was 0.0014377062558196484, conservative 0.9216647982597351
# Plot saved to loss_plots\dataset_6\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.37 seconds.
# Done training the normal network!
# The network training took 12.61 seconds.
# Done training the conservative network!
# The minimum loss was 0.005353158945217729, conservative 0.9574024379253387
# The minimum test loss was 0.0054702259134501215, conservative 0.9701220154762268
# Plot saved to loss_plots\dataset_6\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.81 seconds.
# Done training the normal network!
# The network training took 11.97 seconds.
# Done training the conservative network!
# The minimum loss was 0.04036582447588444, conservative 15.828115749359132
# The minimum test loss was 0.040475040674209595, conservative 15.884944820404053
# Plot saved to loss_plots\dataset_6\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.41 seconds.
# Done training the normal network!
# The network training took 11.84 seconds.
# Done training the conservative network!
# The minimum loss was 8.711146783828735, conservative 598.7433837890625
# The minimum test loss was 8.94157166481018, conservative 607.7825134277343
# Plot saved to loss_plots\dataset_6\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\8D_losses.txt
# Processing folder: dataset_7
# Loaded preprocessed data for dimension 10
# The network training took 6.36 seconds.
# Done training the normal network!
# The network training took 11.81 seconds.
# Done training the conservative network!
# The minimum loss was 2144.467736816406, conservative 23492.344140625
# The minimum test loss was 2197.8960205078124, conservative 24206.594140625
# Plot saved to loss_plots\dataset_7\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.71 seconds.
# Done training the normal network!
# The network training took 12.53 seconds.
# Done training the conservative network!
# The minimum loss was 272953.7046875, conservative 1075185.225
# The minimum test loss was 275260.4828125, conservative 1098410.2625
# Plot saved to loss_plots\dataset_7\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.45 seconds.
# Done training the normal network!
# The network training took 12.04 seconds.
# Done training the conservative network!
# The minimum loss was 6.593066846107831e-05, conservative 0.04844323620200157
# The minimum test loss was 6.501461393781938e-05, conservative 0.048350611329078676
# Plot saved to loss_plots\dataset_7\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.52 seconds.
# Done training the normal network!
# The network training took 12.04 seconds.
# Done training the conservative network!
# The minimum loss was 0.0007755217578960582, conservative 1.6104418992996217
# The minimum test loss was 0.0007804385968483984, conservative 1.6411579966545105
# Plot saved to loss_plots\dataset_7\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.33 seconds.
# Done training the normal network!
# The network training took 12.06 seconds.
# Done training the conservative network!
# The minimum loss was 0.007937573874369264, conservative 0.8987284302711487
# The minimum test loss was 0.008151823654770851, conservative 0.9076403021812439
# Plot saved to loss_plots\dataset_7\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 7.00 seconds.
# Done training the normal network!
# The network training took 12.13 seconds.
# Done training the conservative network!
# The minimum loss was 0.0534303892403841, conservative 14.44617280960083
# The minimum test loss was 0.056689944863319394, conservative 14.668696880340576
# Plot saved to loss_plots\dataset_7\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.57 seconds.
# Done training the normal network!
# The network training took 12.13 seconds.
# Done training the conservative network!
# The minimum loss was 10.210282802581787, conservative 651.0229736328125
# The minimum test loss was 10.462524604797363, conservative 661.3932434082031
# Plot saved to loss_plots\dataset_7\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\8D_losses.txt
# Processing folder: dataset_8
# Loaded preprocessed data for dimension 10
# The network training took 6.55 seconds.
# Done training the normal network!
# The network training took 12.07 seconds.
# Done training the conservative network!
# The minimum loss was 2080.7338134765623, conservative 23028.765625
# The minimum test loss was 2131.6558471679687, conservative 23739.6814453125
# Plot saved to loss_plots\dataset_8\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.57 seconds.
# Done training the normal network!
# The network training took 12.95 seconds.
# Done training the conservative network!
# The minimum loss was 271180.340625, conservative 1067436.375
# The minimum test loss was 273430.6140625, conservative 1089839.9625
# Plot saved to loss_plots\dataset_8\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.77 seconds.
# Done training the normal network!
# The network training took 12.25 seconds.
# Done training the conservative network!
# The minimum loss was 2.25412166400929e-05, conservative 0.035525408759713176
# The minimum test loss was 2.2613996407017112e-05, conservative 0.03532702885568142
# Plot saved to loss_plots\dataset_8\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.59 seconds.
# Done training the normal network!
# The network training took 12.13 seconds.
# Done training the conservative network!
# The minimum loss was 0.0020028144354000688, conservative 1.5498246550559998
# The minimum test loss was 0.001941479032393545, conservative 1.5774661302566528
# Plot saved to loss_plots\dataset_8\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.57 seconds.
# Done training the normal network!
# The network training took 12.14 seconds.
# Done training the conservative network!
# The minimum loss was 0.0047175372950732705, conservative 1.1647136092185975
# The minimum test loss was 0.0049325509928166865, conservative 1.179293727874756
# Plot saved to loss_plots\dataset_8\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.97 seconds.
# Done training the normal network!
# The network training took 12.60 seconds.
# Done training the conservative network!
# The minimum loss was 0.049271632358431815, conservative 13.919000339508056
# The minimum test loss was 0.049326327815651896, conservative 14.072992420196533
# Plot saved to loss_plots\dataset_8\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.44 seconds.
# Done training the normal network!
# The network training took 12.07 seconds.
# Done training the conservative network!
# The minimum loss was 8.872398185729981, conservative 586.0774108886719
# The minimum test loss was 9.12035813331604, conservative 595.4825622558594
# Plot saved to loss_plots\dataset_8\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\8D_losses.txt
# Processing folder: dataset_9
# Loaded preprocessed data for dimension 10
# The network training took 6.40 seconds.
# Done training the normal network!
# The network training took 11.84 seconds.
# Done training the conservative network!
# The minimum loss was 2184.913220214844, conservative 24239.3845703125
# The minimum test loss was 2237.6259521484376, conservative 24931.6390625
# Plot saved to loss_plots\dataset_9\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.47 seconds.
# Done training the normal network!
# The network training took 12.61 seconds.
# Done training the conservative network!
# The minimum loss was 279806.5125, conservative 1073282.35
# The minimum test loss was 282172.6375, conservative 1097361.625
# Plot saved to loss_plots\dataset_9\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 7.35 seconds.
# Done training the normal network!
# The network training took 12.37 seconds.
# Done training the conservative network!
# The minimum loss was 1.7167813166452105e-05, conservative 0.0734514370560646
# The minimum test loss was 1.7350197776977438e-05, conservative 0.07341035157442093
# Plot saved to loss_plots\dataset_9\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.67 seconds.
# Done training the normal network!
# The network training took 12.52 seconds.
# Done training the conservative network!
# The minimum loss was 0.0012104073888622225, conservative 1.9671224713325501
# The minimum test loss was 0.0012479267665185035, conservative 2.0127685546875
# Plot saved to loss_plots\dataset_9\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.72 seconds.
# Done training the normal network!
# The network training took 12.28 seconds.
# Done training the conservative network!
# The minimum loss was 0.005009559821337462, conservative 0.7509707033634185
# The minimum test loss was 0.005034704832360149, conservative 0.7613649189472198
# Plot saved to loss_plots\dataset_9\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.70 seconds.
# Done training the normal network!
# The network training took 13.23 seconds.
# Done training the conservative network!
# The minimum loss was 0.049291495233774185, conservative 14.854617404937745
# The minimum test loss was 0.049567239731550215, conservative 14.949156761169434
# Plot saved to loss_plots\dataset_9\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.56 seconds.
# Done training the normal network!
# The network training took 12.21 seconds.
# Done training the conservative network!
# The minimum loss was 9.366299104690551, conservative 616.9191467285157
# The minimum test loss was 9.647073698043823, conservative 626.32294921875
# Plot saved to loss_plots\dataset_9\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\8D_losses.txt
# Done!!!

# %% [markdown]
# # Organizing Data

# %%
# Folder containing the loss plots and text files
loss_folder = "loss_plots"

# Output folders for consolidated images and text files
output_image_folder = "consolidated_images"
output_text_folder = "consolidated_text_files"

# Create output folders if they don't exist
os.makedirs(output_image_folder, exist_ok=True)
os.makedirs(output_text_folder, exist_ok=True)

# Iterate through all subfolders in the loss_folder
for subfolder in os.listdir(loss_folder):
    subfolder_path = os.path.join(loss_folder, subfolder)
    
    # Check if it's a directory (e.g., dataset_1, dataset_2, etc.)
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")
        
        # Extract the dataset number (e.g., "1" from "dataset_1")
        dataset_number = subfolder.split("_")[-1]
        
        # Process images
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".png"):  # Process only .png files
                # Construct the new filename (e.g., 2D_Conservative_NN_1.png)
                new_filename = filename.replace(".png", f"_{dataset_number}.png")
                
                # Copy the image to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_image_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied image: {src_path} -> {dest_path}")
        
        # Process text files
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".txt"):  # Process only .txt files
                # Construct the new filename (e.g., 8D_losses_1.txt)
                new_filename = filename.replace(".txt", f"_{dataset_number}.txt")
                
                # Copy the text file to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_text_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied text file: {src_path} -> {dest_path}")

print("All files have been consolidated.")
# Out:
# Processing folder: dataset_1
# Processing folder: dataset_10
# Processing folder: dataset_2
# Processing folder: dataset_3
# Processing folder: dataset_4
# Processing folder: dataset_5
# Processing folder: dataset_6
# Processing folder: dataset_7
# Processing folder: dataset_8
# Processing folder: dataset_9
# All files have been consolidated.
