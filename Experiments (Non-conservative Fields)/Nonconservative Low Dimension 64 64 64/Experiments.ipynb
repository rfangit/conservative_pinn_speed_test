# %% [markdown]
# # Imports

# %%
import torch
import sys
import numpy as np
import os
import shutil
from pathlib import Path
# Add parent directory to sys.path
parent_dir = Path.cwd().parent.parent
sys.path.append(str(parent_dir))
# Import modules
from train import train_test_multiple_networks, train_network_with_test_loss, train_grad_network_with_test_loss, save_plot_test_train

# %% [markdown]
# # Network Parameters

# %%
# Training hyperparameters
num_trials = 10
neurons = [64, 64, 64]
num_epochs = 200

# %% [markdown]
# # Running Experiments

# %%
# Folder containing datasets
dataset_folder = "datasets"

# Output folder for plots
output_folder = "loss_plots"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

for subfolder in os.listdir(dataset_folder):
    subfolder_path = os.path.join(dataset_folder, subfolder)
    
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")

        output_subfolder = os.path.join(output_folder, subfolder)
        os.makedirs(output_subfolder, exist_ok=True)
        
        train_folder = os.path.join(subfolder_path, "train")
        test_folder = os.path.join(subfolder_path, "test")
        
        for filename in os.listdir(train_folder):
            if filename.endswith("_train.txt"):
                base_name = filename.replace("_train.txt", "")
                
                # Load train data
                train_filepath = os.path.join(train_folder, filename)
                train_data = np.loadtxt(train_filepath)

                dimension = (int)(train_data.shape[1]/2)

                train_points = torch.tensor(train_data[:, :dimension], dtype=torch.float32)
                train_values = torch.tensor(train_data[:, dimension:], dtype=torch.float32)

                
                # Load test data
                test_filename = f"{base_name}_test.txt"
                test_filepath = os.path.join(test_folder, test_filename)
                test_data = np.loadtxt(test_filepath)
                test_points = torch.tensor(test_data[:, :dimension], dtype=torch.float32)
                test_values = torch.tensor(test_data[:, dimension:], dtype=torch.float32)
                
                print(f"Loaded preprocessed data for dimension {dimension}")
                
                # Train the normal network
                mean_loss, variance_loss, mean_test_loss, variance_test_loss = train_test_multiple_networks(
                    train_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the normal network!")
        
                # Train the conservative network
                mean_loss_grad, variance_loss_grad, mean_test_loss_grad, variance_test_loss_grad = train_test_multiple_networks(
                    train_grad_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the conservative network!")

                # Calculate standard deviations for the normal network
                std_loss = np.sqrt(variance_loss)
                std_test_loss = np.sqrt(variance_test_loss)
                std_loss_grad = np.sqrt(variance_loss_grad)
                std_test_loss_grad = np.sqrt(variance_test_loss_grad)
        
                # Print the minimum loss
                print(f"The minimum loss was {mean_loss[-1]}, conservative {mean_loss_grad[-1]}")
                print(f"The minimum test loss was {mean_test_loss[-1]}, conservative {mean_test_loss_grad[-1]}")
                # Comparison Plot
                epochs = np.arange(num_epochs)
                save_plot_test_train(epochs, mean_loss, std_loss, mean_loss_grad, std_loss_grad,
                      mean_test_loss, std_test_loss, mean_test_loss_grad, std_test_loss_grad,
                      dimension, neurons, num_epochs, output_subfolder)

                # Save the losses to .txt files
                losses_filename = os.path.join(output_subfolder, f"{dimension}D_losses.txt")
                np.savetxt(
                    losses_filename,
                    np.column_stack((
                        epochs,
                        mean_loss, std_loss,  # Training loss and std for normal network
                        mean_test_loss, std_test_loss,  # Test loss and std for normal network
                        mean_loss_grad, std_loss_grad,  # Training loss and std for conservative network
                        mean_test_loss_grad, std_test_loss_grad  # Test loss and std for conservative network
                    )),
                    fmt='%.6f',
                    header='epochs mean_loss std_loss mean_test_loss std_test_loss mean_loss_grad std_loss_grad mean_test_loss_grad std_test_loss_grad'
                )
                print(f"Losses saved to {losses_filename}")
        
print ("Done!!!")
# Out:
# Using device: cuda
# Processing folder: dataset_1
# Loaded preprocessed data for dimension 10
# The network training took 9.61 seconds.
# Done training the normal network!
# The network training took 11.31 seconds.
# Done training the conservative network!
# The minimum loss was 6.991920563450548e-05, conservative 0.006529934052377939
# The minimum test loss was 8.30393320939038e-05, conservative 0.006746710976585746
# Plot saved to loss_plots\dataset_1\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.96 seconds.
# Done training the normal network!
# The network training took 11.02 seconds.
# Done training the conservative network!
# The minimum loss was 6.853459271951578e-05, conservative 0.003516662330366671
# The minimum test loss was 7.350794403464534e-05, conservative 0.003560469555668533
# Plot saved to loss_plots\dataset_1\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.02 seconds.
# Done training the normal network!
# The network training took 11.34 seconds.
# Done training the conservative network!
# The minimum loss was 4.7657159666414375e-05, conservative 0.0028653501300141214
# The minimum test loss was 5.317526120052207e-05, conservative 0.003072705049999058
# Plot saved to loss_plots\dataset_1\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.12 seconds.
# Done training the normal network!
# The network training took 11.15 seconds.
# Done training the conservative network!
# The minimum loss was 3.5043825482716785e-05, conservative 0.0004433748807059601
# The minimum test loss was 4.79460577480495e-05, conservative 0.0005134995270054787
# Plot saved to loss_plots\dataset_1\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 10.96 seconds.
# Done training the conservative network!
# The minimum loss was 3.546638345142128e-05, conservative 0.0012126897694543005
# The minimum test loss was 4.312730252422625e-05, conservative 0.0012872334336861968
# Plot saved to loss_plots\dataset_1\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.86 seconds.
# Done training the normal network!
# The network training took 11.08 seconds.
# Done training the conservative network!
# The minimum loss was 5.744140207752935e-06, conservative 0.010228645894676447
# The minimum test loss was 5.855202107341029e-06, conservative 0.010349986236542463
# Plot saved to loss_plots\dataset_1\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.91 seconds.
# Done training the normal network!
# The network training took 11.06 seconds.
# Done training the conservative network!
# The minimum loss was 0.00012753094561048783, conservative 0.13076121509075164
# The minimum test loss was 0.00012605488591361792, conservative 0.1315419927239418
# Plot saved to loss_plots\dataset_1\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.66 seconds.
# Done training the normal network!
# The network training took 11.69 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001418176674633287, conservative 0.17427187860012056
# The minimum test loss was 0.0001426991875632666, conservative 0.17582642585039138
# Plot saved to loss_plots\dataset_1\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.71 seconds.
# Done training the normal network!
# The network training took 11.01 seconds.
# Done training the conservative network!
# The minimum loss was 8.023236005101353e-05, conservative 0.008883456513285638
# The minimum test loss was 0.00011116072855656966, conservative 0.009045102726668119
# Plot saved to loss_plots\dataset_1\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\8D_losses.txt
# Processing folder: dataset_10
# Loaded preprocessed data for dimension 10
# The network training took 5.78 seconds.
# Done training the normal network!
# The network training took 10.87 seconds.
# Done training the conservative network!
# The minimum loss was 0.00022516025928780435, conservative 0.007300900481641293
# The minimum test loss was 0.000252836816071067, conservative 0.007704775547608733
# Plot saved to loss_plots\dataset_10\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.72 seconds.
# Done training the normal network!
# The network training took 11.23 seconds.
# Done training the conservative network!
# The minimum loss was 4.96097607538104e-05, conservative 0.003207520139403641
# The minimum test loss was 6.401304635801352e-05, conservative 0.003682990022934973
# Plot saved to loss_plots\dataset_10\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.81 seconds.
# Done training the normal network!
# The network training took 10.84 seconds.
# Done training the conservative network!
# The minimum loss was 7.750099102850072e-05, conservative 0.00941160200163722
# The minimum test loss was 8.650208474136889e-05, conservative 0.009684202261269093
# Plot saved to loss_plots\dataset_10\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.80 seconds.
# Done training the normal network!
# The network training took 11.00 seconds.
# Done training the conservative network!
# The minimum loss was 5.03825558553217e-05, conservative 0.004720216197893023
# The minimum test loss was 5.4007002836442554e-05, conservative 0.004772166395559907
# Plot saved to loss_plots\dataset_10\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.75 seconds.
# Done training the normal network!
# The network training took 10.86 seconds.
# Done training the conservative network!
# The minimum loss was 5.432020298030693e-05, conservative 0.0010858858586288989
# The minimum test loss was 6.002572627039626e-05, conservative 0.001117039448581636
# Plot saved to loss_plots\dataset_10\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.81 seconds.
# Done training the normal network!
# The network training took 11.03 seconds.
# Done training the conservative network!
# The minimum loss was 6.069939672670444e-07, conservative 0.003948101587593555
# The minimum test loss was 6.069313201351178e-07, conservative 0.0039048588834702967
# Plot saved to loss_plots\dataset_10\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.77 seconds.
# Done training the normal network!
# The network training took 10.86 seconds.
# Done training the conservative network!
# The minimum loss was 5.203624605201185e-05, conservative 0.056992626190185545
# The minimum test loss was 5.4087797070678786e-05, conservative 0.05643072016537189
# Plot saved to loss_plots\dataset_10\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.75 seconds.
# Done training the normal network!
# The network training took 10.90 seconds.
# Done training the conservative network!
# The minimum loss was 4.793376356246881e-05, conservative 0.04612804651260376
# The minimum test loss was 4.844862014579121e-05, conservative 0.04744009040296078
# Plot saved to loss_plots\dataset_10\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.60 seconds.
# Done training the normal network!
# The network training took 10.65 seconds.
# Done training the conservative network!
# The minimum loss was 9.521954198135063e-05, conservative 0.017447849921882152
# The minimum test loss was 0.00011948465835303068, conservative 0.01760023757815361
# Plot saved to loss_plots\dataset_10\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\8D_losses.txt
# Processing folder: dataset_2
# Loaded preprocessed data for dimension 10
# The network training took 5.73 seconds.
# Done training the normal network!
# The network training took 10.78 seconds.
# Done training the conservative network!
# The minimum loss was 0.00015137894661165774, conservative 0.009361505135893821
# The minimum test loss was 0.00017722016345942393, conservative 0.009932176023721696
# Plot saved to loss_plots\dataset_2\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.58 seconds.
# Done training the normal network!
# The network training took 11.87 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001855863054515794, conservative 0.006010584626346826
# The minimum test loss was 0.00015388520114356652, conservative 0.006176457274705172
# Plot saved to loss_plots\dataset_2\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.18 seconds.
# Done training the normal network!
# The network training took 11.69 seconds.
# Done training the conservative network!
# The minimum loss was 6.484540826932062e-05, conservative 0.0021431833505630494
# The minimum test loss was 6.995166222623084e-05, conservative 0.002252568653784692
# Plot saved to loss_plots\dataset_2\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.38 seconds.
# Done training the normal network!
# The network training took 11.53 seconds.
# Done training the conservative network!
# The minimum loss was 5.0247916806256396e-05, conservative 0.0014322325470857323
# The minimum test loss was 5.7778184418566526e-05, conservative 0.0015178953879512846
# Plot saved to loss_plots\dataset_2\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.16 seconds.
# Done training the normal network!
# The network training took 10.81 seconds.
# Done training the conservative network!
# The minimum loss was 4.1239361235057007e-05, conservative 0.002214698609896004
# The minimum test loss was 4.936680161335971e-05, conservative 0.0022810918744653463
# Plot saved to loss_plots\dataset_2\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.92 seconds.
# Done training the normal network!
# The network training took 11.11 seconds.
# Done training the conservative network!
# The minimum loss was 1.5044284828036325e-05, conservative 0.030328698642551898
# The minimum test loss was 1.4878794081596424e-05, conservative 0.030345693230628967
# Plot saved to loss_plots\dataset_2\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.66 seconds.
# Done training the normal network!
# The network training took 11.03 seconds.
# Done training the conservative network!
# The minimum loss was 0.0003800700869760476, conservative 0.11964339688420296
# The minimum test loss was 0.00038218512054299936, conservative 0.11959056332707405
# Plot saved to loss_plots\dataset_2\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.02 seconds.
# Done training the normal network!
# The network training took 10.97 seconds.
# Done training the conservative network!
# The minimum loss was 0.00012365093716653063, conservative 0.06095004267990589
# The minimum test loss was 0.0001316731642873492, conservative 0.06144757233560085
# Plot saved to loss_plots\dataset_2\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.26 seconds.
# Done training the normal network!
# The network training took 11.11 seconds.
# Done training the conservative network!
# The minimum loss was 5.403550931077916e-05, conservative 0.007963456399738788
# The minimum test loss was 5.9901128042838533e-05, conservative 0.008115172013640403
# Plot saved to loss_plots\dataset_2\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\8D_losses.txt
# Processing folder: dataset_3
# Loaded preprocessed data for dimension 10
# The network training took 6.03 seconds.
# Done training the normal network!
# The network training took 11.16 seconds.
# Done training the conservative network!
# The minimum loss was 0.00012727745342999697, conservative 0.016209510900080205
# The minimum test loss was 0.00015283298926078716, conservative 0.01637907363474369
# Plot saved to loss_plots\dataset_3\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.01 seconds.
# Done training the normal network!
# The network training took 11.44 seconds.
# Done training the conservative network!
# The minimum loss was 5.254787902231328e-05, conservative 0.0005840049125254154
# The minimum test loss was 7.443593131029047e-05, conservative 0.0008782959601376205
# Plot saved to loss_plots\dataset_3\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.30 seconds.
# Done training the normal network!
# The network training took 10.78 seconds.
# Done training the conservative network!
# The minimum loss was 4.806969700439367e-05, conservative 0.0019906793255358934
# The minimum test loss was 5.529151421796996e-05, conservative 0.002102427533827722
# Plot saved to loss_plots\dataset_3\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.44 seconds.
# Done training the normal network!
# The network training took 10.93 seconds.
# Done training the conservative network!
# The minimum loss was 4.4946624620934016e-05, conservative 0.0009074719215277583
# The minimum test loss was 5.0806334547814914e-05, conservative 0.0009848780755419284
# Plot saved to loss_plots\dataset_3\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.44 seconds.
# Done training the normal network!
# The network training took 11.26 seconds.
# Done training the conservative network!
# The minimum loss was 4.00645803892985e-05, conservative 0.00042451940244063734
# The minimum test loss was 4.7398090464412236e-05, conservative 0.0004817249602638185
# Plot saved to loss_plots\dataset_3\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.83 seconds.
# Done training the normal network!
# The network training took 11.34 seconds.
# Done training the conservative network!
# The minimum loss was 2.0450898659873928e-06, conservative 0.004344601882621646
# The minimum test loss was 2.097992546623573e-06, conservative 0.004260915191844105
# Plot saved to loss_plots\dataset_3\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.88 seconds.
# Done training the normal network!
# The network training took 11.26 seconds.
# Done training the conservative network!
# The minimum loss was 6.223901182238478e-05, conservative 0.10277786627411842
# The minimum test loss was 6.262131173571107e-05, conservative 0.10379156470298767
# Plot saved to loss_plots\dataset_3\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.73 seconds.
# Done training the normal network!
# The network training took 10.85 seconds.
# Done training the conservative network!
# The minimum loss was 0.0002652349736308679, conservative 0.08275052681565284
# The minimum test loss was 0.00027834001230075955, conservative 0.08434612974524498
# Plot saved to loss_plots\dataset_3\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.69 seconds.
# Done training the normal network!
# The network training took 11.01 seconds.
# Done training the conservative network!
# The minimum loss was 8.847694261930883e-05, conservative 0.02571928407996893
# The minimum test loss was 9.27032386243809e-05, conservative 0.025749942660331725
# Plot saved to loss_plots\dataset_3\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\8D_losses.txt
# Processing folder: dataset_4
# Loaded preprocessed data for dimension 10
# The network training took 5.85 seconds.
# Done training the normal network!
# The network training took 11.17 seconds.
# Done training the conservative network!
# The minimum loss was 0.00012463964449125343, conservative 0.02360721379518509
# The minimum test loss was 0.00013162983013899067, conservative 0.023920120857656
# Plot saved to loss_plots\dataset_4\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.94 seconds.
# Done training the normal network!
# The network training took 11.71 seconds.
# Done training the conservative network!
# The minimum loss was 3.65962325304281e-05, conservative 0.000339357866323553
# The minimum test loss was 7.092341511452104e-05, conservative 0.00061088593211025
# Plot saved to loss_plots\dataset_4\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.17 seconds.
# Done training the normal network!
# The network training took 11.18 seconds.
# Done training the conservative network!
# The minimum loss was 4.704077000496909e-05, conservative 0.003341451962478459
# The minimum test loss was 5.208906113693956e-05, conservative 0.003440107381902635
# Plot saved to loss_plots\dataset_4\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.96 seconds.
# Done training the normal network!
# The network training took 11.32 seconds.
# Done training the conservative network!
# The minimum loss was 6.798066788178403e-05, conservative 0.0037133541190996766
# The minimum test loss was 7.964580145198852e-05, conservative 0.0040505215059965845
# Plot saved to loss_plots\dataset_4\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.69 seconds.
# Done training the normal network!
# The network training took 12.70 seconds.
# Done training the conservative network!
# The minimum loss was 5.374260726966895e-05, conservative 0.0008634127269033342
# The minimum test loss was 5.774916207883507e-05, conservative 0.0009193805395625532
# Plot saved to loss_plots\dataset_4\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.51 seconds.
# Done training the normal network!
# The network training took 12.30 seconds.
# Done training the conservative network!
# The minimum loss was 6.8211389134376075e-06, conservative 0.006528149405494332
# The minimum test loss was 6.605371618206846e-06, conservative 0.0065706932451576
# Plot saved to loss_plots\dataset_4\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.42 seconds.
# Done training the normal network!
# The network training took 12.63 seconds.
# Done training the conservative network!
# The minimum loss was 9.265617300115991e-05, conservative 0.17048100233078003
# The minimum test loss was 9.553288873576093e-05, conservative 0.18130687028169631
# Plot saved to loss_plots\dataset_4\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.56 seconds.
# Done training the normal network!
# The network training took 12.10 seconds.
# Done training the conservative network!
# The minimum loss was 7.456065541191492e-05, conservative 0.10201822221279144
# The minimum test loss was 7.850926122046075e-05, conservative 0.10459675565361977
# Plot saved to loss_plots\dataset_4\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.31 seconds.
# Done training the normal network!
# The network training took 11.10 seconds.
# Done training the conservative network!
# The minimum loss was 0.00010615387800498866, conservative 0.012043590005487204
# The minimum test loss was 0.00012130177419749089, conservative 0.012140951864421368
# Plot saved to loss_plots\dataset_4\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\8D_losses.txt
# Processing folder: dataset_5
# Loaded preprocessed data for dimension 10
# The network training took 5.87 seconds.
# Done training the normal network!
# The network training took 10.84 seconds.
# Done training the conservative network!
# The minimum loss was 0.00010948580311378464, conservative 0.019247402809560298
# The minimum test loss was 0.00013765088660875336, conservative 0.020333513244986536
# Plot saved to loss_plots\dataset_5\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.97 seconds.
# Done training the normal network!
# The network training took 11.56 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001070379868906457, conservative 0.006238812347874045
# The minimum test loss was 0.00011296413213131018, conservative 0.006329151382669806
# Plot saved to loss_plots\dataset_5\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.12 seconds.
# Done training the normal network!
# The network training took 11.02 seconds.
# Done training the conservative network!
# The minimum loss was 7.190853575593792e-05, conservative 0.00016982203524094076
# The minimum test loss was 9.769619719008915e-05, conservative 0.00035447164555080235
# Plot saved to loss_plots\dataset_5\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.78 seconds.
# Done training the normal network!
# The network training took 10.88 seconds.
# Done training the conservative network!
# The minimum loss was 7.256950229930225e-05, conservative 0.002975407266058028
# The minimum test loss was 7.166343784774654e-05, conservative 0.0029158668126910924
# Plot saved to loss_plots\dataset_5\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.73 seconds.
# Done training the normal network!
# The network training took 11.94 seconds.
# Done training the conservative network!
# The minimum loss was 6.30330374406185e-05, conservative 6.662901323579717e-05
# The minimum test loss was 6.40854468656471e-05, conservative 8.981006685644388e-05
# Plot saved to loss_plots\dataset_5\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.05 seconds.
# Done training the normal network!
# The network training took 11.12 seconds.
# Done training the conservative network!
# The minimum loss was 2.185567791457288e-06, conservative 0.008448747172951698
# The minimum test loss was 2.297614832968975e-06, conservative 0.008332208078354598
# Plot saved to loss_plots\dataset_5\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.97 seconds.
# Done training the normal network!
# The network training took 11.42 seconds.
# Done training the conservative network!
# The minimum loss was 6.101058497733902e-05, conservative 0.2776375949382782
# The minimum test loss was 6.160348930279724e-05, conservative 0.2834951639175415
# Plot saved to loss_plots\dataset_5\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.95 seconds.
# Done training the normal network!
# The network training took 11.37 seconds.
# Done training the conservative network!
# The minimum loss was 0.00011139579873997718, conservative 0.055747051164507865
# The minimum test loss was 0.00011706355580827221, conservative 0.05571903176605701
# Plot saved to loss_plots\dataset_5\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.63 seconds.
# Done training the normal network!
# The network training took 11.12 seconds.
# Done training the conservative network!
# The minimum loss was 7.957139860081952e-05, conservative 0.014047462400048972
# The minimum test loss was 8.0375086326967e-05, conservative 0.014470259938389064
# Plot saved to loss_plots\dataset_5\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\8D_losses.txt
# Processing folder: dataset_6
# Loaded preprocessed data for dimension 10
# The network training took 5.96 seconds.
# Done training the normal network!
# The network training took 12.41 seconds.
# Done training the conservative network!
# The minimum loss was 3.686234194901772e-05, conservative 0.007543735858052969
# The minimum test loss was 4.2049152762047014e-05, conservative 0.0078870490193367
# Plot saved to loss_plots\dataset_6\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.91 seconds.
# Done training the normal network!
# The network training took 12.82 seconds.
# Done training the conservative network!
# The minimum loss was 5.9083755695610306e-05, conservative 0.011431987397372723
# The minimum test loss was 6.737955736753065e-05, conservative 0.011746266391128302
# Plot saved to loss_plots\dataset_6\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.85 seconds.
# Done training the normal network!
# The network training took 12.59 seconds.
# Done training the conservative network!
# The minimum loss was 4.3344447476556525e-05, conservative 0.0005110339378006756
# The minimum test loss was 5.9312186931492763e-05, conservative 0.0007849902380257845
# Plot saved to loss_plots\dataset_6\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.45 seconds.
# Done training the normal network!
# The network training took 10.98 seconds.
# Done training the conservative network!
# The minimum loss was 5.2795778901781884e-05, conservative 0.0031613658647984266
# The minimum test loss was 6.576956657227129e-05, conservative 0.0033675883896648884
# Plot saved to loss_plots\dataset_6\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.75 seconds.
# Done training the normal network!
# The network training took 11.41 seconds.
# Done training the conservative network!
# The minimum loss was 5.355406210583169e-05, conservative 0.0017803843715228141
# The minimum test loss was 6.362354542943649e-05, conservative 0.0019195567234419285
# Plot saved to loss_plots\dataset_6\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.01 seconds.
# Done training the normal network!
# The network training took 11.84 seconds.
# Done training the conservative network!
# The minimum loss was 3.6963417142033e-05, conservative 0.0037195282988250256
# The minimum test loss was 3.644916505436413e-05, conservative 0.003687751921825111
# Plot saved to loss_plots\dataset_6\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.05 seconds.
# Done training the normal network!
# The network training took 11.33 seconds.
# Done training the conservative network!
# The minimum loss was 0.00015735728811705485, conservative 0.09396726787090301
# The minimum test loss was 0.00015690502332290634, conservative 0.09499420300126075
# Plot saved to loss_plots\dataset_6\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.80 seconds.
# Done training the normal network!
# The network training took 11.41 seconds.
# Done training the conservative network!
# The minimum loss was 0.00014299395625130273, conservative 0.07879403829574586
# The minimum test loss was 0.00014750836926396004, conservative 0.07749049216508866
# Plot saved to loss_plots\dataset_6\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.22 seconds.
# Done training the normal network!
# The network training took 10.98 seconds.
# Done training the conservative network!
# The minimum loss was 0.00017352007562294603, conservative 0.01647685207426548
# The minimum test loss was 0.0001949372235685587, conservative 0.016832592897117138
# Plot saved to loss_plots\dataset_6\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\8D_losses.txt
# Processing folder: dataset_7
# Loaded preprocessed data for dimension 10
# The network training took 6.59 seconds.
# Done training the normal network!
# The network training took 11.16 seconds.
# Done training the conservative network!
# The minimum loss was 8.189352629415226e-05, conservative 0.011359439231455326
# The minimum test loss was 8.962569772847928e-05, conservative 0.011846683919429779
# Plot saved to loss_plots\dataset_7\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.92 seconds.
# Done training the normal network!
# The network training took 10.84 seconds.
# Done training the conservative network!
# The minimum loss was 7.415443324134685e-05, conservative 0.01369087491184473
# The minimum test loss was 8.353129123861436e-05, conservative 0.014285883121192455
# Plot saved to loss_plots\dataset_7\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.44 seconds.
# Done training the normal network!
# The network training took 11.05 seconds.
# Done training the conservative network!
# The minimum loss was 5.444192611321341e-05, conservative 0.0029302338836714624
# The minimum test loss was 5.285872648528311e-05, conservative 0.002906329301185906
# Plot saved to loss_plots\dataset_7\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.02 seconds.
# Done training the normal network!
# The network training took 11.00 seconds.
# Done training the conservative network!
# The minimum loss was 3.527771023073001e-05, conservative 0.0020339117152616383
# The minimum test loss was 5.143268972460646e-05, conservative 0.0020527102053165434
# Plot saved to loss_plots\dataset_7\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 10.86 seconds.
# Done training the conservative network!
# The minimum loss was 4.5698963367613034e-05, conservative 0.0006358855462167412
# The minimum test loss was 5.962116665614303e-05, conservative 0.0007367658778093755
# Plot saved to loss_plots\dataset_7\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.83 seconds.
# Done training the normal network!
# The network training took 11.01 seconds.
# Done training the conservative network!
# The minimum loss was 6.574600899966754e-06, conservative 0.010638599935919046
# The minimum test loss was 6.710855973324214e-06, conservative 0.010546600818634034
# Plot saved to loss_plots\dataset_7\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.84 seconds.
# Done training the normal network!
# The network training took 11.11 seconds.
# Done training the conservative network!
# The minimum loss was 2.424574995529838e-05, conservative 0.11108431592583656
# The minimum test loss was 2.4399497669946867e-05, conservative 0.11318827122449875
# Plot saved to loss_plots\dataset_7\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.73 seconds.
# Done training the normal network!
# The network training took 10.75 seconds.
# Done training the conservative network!
# The minimum loss was 5.2408410556381566e-05, conservative 0.08907933160662651
# The minimum test loss was 5.339894087228458e-05, conservative 0.08966045081615448
# Plot saved to loss_plots\dataset_7\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.71 seconds.
# Done training the normal network!
# The network training took 10.69 seconds.
# Done training the conservative network!
# The minimum loss was 9.45296858844813e-05, conservative 0.030520696192979813
# The minimum test loss was 9.967757650883869e-05, conservative 0.031080965138971805
# Plot saved to loss_plots\dataset_7\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\8D_losses.txt
# Processing folder: dataset_8
# Loaded preprocessed data for dimension 10
# The network training took 5.71 seconds.
# Done training the normal network!
# The network training took 10.72 seconds.
# Done training the conservative network!
# The minimum loss was 6.82007481373148e-05, conservative 0.005055958917364478
# The minimum test loss was 8.458211086690426e-05, conservative 0.005555314524099231
# Plot saved to loss_plots\dataset_8\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.88 seconds.
# Done training the normal network!
# The network training took 10.86 seconds.
# Done training the conservative network!
# The minimum loss was 3.7182859341555743e-05, conservative 0.0012780778226442635
# The minimum test loss was 5.427326614153572e-05, conservative 0.0016624285257421435
# Plot saved to loss_plots\dataset_8\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.83 seconds.
# Done training the normal network!
# The network training took 10.84 seconds.
# Done training the conservative network!
# The minimum loss was 6.477235219790601e-05, conservative 0.0033749724738299848
# The minimum test loss was 7.103382449713536e-05, conservative 0.0033658151281997562
# Plot saved to loss_plots\dataset_8\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.00 seconds.
# Done training the normal network!
# The network training took 11.25 seconds.
# Done training the conservative network!
# The minimum loss was 3.730367025127635e-05, conservative 0.0034958893433213235
# The minimum test loss was 4.363819352874998e-05, conservative 0.003626775718294084
# Plot saved to loss_plots\dataset_8\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.73 seconds.
# Done training the normal network!
# The network training took 10.82 seconds.
# Done training the conservative network!
# The minimum loss was 3.513095052767312e-05, conservative 0.0015363904996775091
# The minimum test loss was 4.505498545768205e-05, conservative 0.0016453678952530026
# Plot saved to loss_plots\dataset_8\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.72 seconds.
# Done training the normal network!
# The network training took 10.78 seconds.
# Done training the conservative network!
# The minimum loss was 8.935096161621914e-06, conservative 0.00400200723670423
# The minimum test loss was 9.023708071254077e-06, conservative 0.003836887190118432
# Plot saved to loss_plots\dataset_8\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.29 seconds.
# Done training the normal network!
# The network training took 12.79 seconds.
# Done training the conservative network!
# The minimum loss was 7.97171305748634e-05, conservative 0.10966864675283432
# The minimum test loss was 7.83116298407549e-05, conservative 0.11393106132745742
# Plot saved to loss_plots\dataset_8\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.48 seconds.
# Done training the normal network!
# The network training took 12.43 seconds.
# Done training the conservative network!
# The minimum loss was 0.00013829955496476033, conservative 0.1412202775478363
# The minimum test loss was 0.00014412616001209245, conservative 0.14350022226572037
# Plot saved to loss_plots\dataset_8\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.84 seconds.
# Done training the normal network!
# The network training took 12.66 seconds.
# Done training the conservative network!
# The minimum loss was 0.00011230275267735124, conservative 0.012182624079287052
# The minimum test loss was 0.00014513842979795298, conservative 0.012552991975098848
# Plot saved to loss_plots\dataset_8\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\8D_losses.txt
# Processing folder: dataset_9
# Loaded preprocessed data for dimension 10
# The network training took 6.53 seconds.
# Done training the normal network!
# The network training took 12.36 seconds.
# Done training the conservative network!
# The minimum loss was 0.00015223250593408011, conservative 0.0052350312005728485
# The minimum test loss was 0.0001636519213207066, conservative 0.005327920150011778
# Plot saved to loss_plots\dataset_9\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.04 seconds.
# Done training the normal network!
# The network training took 10.75 seconds.
# Done training the conservative network!
# The minimum loss was 0.00011992932704742997, conservative 0.0029302465030923487
# The minimum test loss was 0.00010522799275349825, conservative 0.0029732976341620087
# Plot saved to loss_plots\dataset_9\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.87 seconds.
# Done training the normal network!
# The network training took 11.05 seconds.
# Done training the conservative network!
# The minimum loss was 3.3722475200193004e-05, conservative 2.78034192888299e-05
# The minimum test loss was 5.226782122917939e-05, conservative 5.728914838982746e-05
# Plot saved to loss_plots\dataset_9\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.83 seconds.
# Done training the normal network!
# The network training took 11.04 seconds.
# Done training the conservative network!
# The minimum loss was 6.366004308802075e-05, conservative 0.0044968054629862305
# The minimum test loss was 7.682018331252038e-05, conservative 0.004924462456256151
# Plot saved to loss_plots\dataset_9\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.15 seconds.
# Done training the normal network!
# The network training took 11.09 seconds.
# Done training the conservative network!
# The minimum loss was 3.6916886529070325e-05, conservative 0.0008277055167127401
# The minimum test loss was 4.401515980134718e-05, conservative 0.0008591038524173201
# Plot saved to loss_plots\dataset_9\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.81 seconds.
# Done training the normal network!
# The network training took 12.71 seconds.
# Done training the conservative network!
# The minimum loss was 2.809128318403964e-05, conservative 0.0022983097704127433
# The minimum test loss was 2.8857850384156337e-05, conservative 0.0022285318002104757
# Plot saved to loss_plots\dataset_9\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.88 seconds.
# Done training the normal network!
# The network training took 12.71 seconds.
# Done training the conservative network!
# The minimum loss was 4.223061187076382e-05, conservative 0.056519830226898195
# The minimum test loss was 4.240732250764268e-05, conservative 0.05646659955382347
# Plot saved to loss_plots\dataset_9\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.58 seconds.
# Done training the normal network!
# The network training took 12.51 seconds.
# Done training the conservative network!
# The minimum loss was 0.00015634458759450354, conservative 0.052288918197155
# The minimum test loss was 0.00016178077130462042, conservative 0.05391669124364853
# Plot saved to loss_plots\dataset_9\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.74 seconds.
# Done training the normal network!
# The network training took 12.13 seconds.
# Done training the conservative network!
# The minimum loss was 9.035392431542278e-05, conservative 0.021551181562244892
# The minimum test loss was 9.235444085788913e-05, conservative 0.021856827288866044
# Plot saved to loss_plots\dataset_9\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\8D_losses.txt
# Done!!!

# %% [markdown]
# # Organizing Data

# %%
# Folder containing the loss plots and text files
loss_folder = "loss_plots"

# Output folders for consolidated images and text files
output_image_folder = "consolidated_images"
output_text_folder = "consolidated_text_files"

# Create output folders if they don't exist
os.makedirs(output_image_folder, exist_ok=True)
os.makedirs(output_text_folder, exist_ok=True)

# Iterate through all subfolders in the loss_folder
for subfolder in os.listdir(loss_folder):
    subfolder_path = os.path.join(loss_folder, subfolder)
    
    # Check if it's a directory (e.g., dataset_1, dataset_2, etc.)
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")
        
        # Extract the dataset number (e.g., "1" from "dataset_1")
        dataset_number = subfolder.split("_")[-1]
        
        # Process images
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".png"):  # Process only .png files
                # Construct the new filename (e.g., 2D_Conservative_NN_1.png)
                new_filename = filename.replace(".png", f"_{dataset_number}.png")
                
                # Copy the image to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_image_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied image: {src_path} -> {dest_path}")
        
        # Process text files
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".txt"):  # Process only .txt files
                # Construct the new filename (e.g., 8D_losses_1.txt)
                new_filename = filename.replace(".txt", f"_{dataset_number}.txt")
                
                # Copy the text file to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_text_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied text file: {src_path} -> {dest_path}")

print("All files have been consolidated.")
# Out:
# Processing folder: dataset_1
# Processing folder: dataset_10
# Processing folder: dataset_2
# Processing folder: dataset_3
# Processing folder: dataset_4
# Processing folder: dataset_5
# Processing folder: dataset_6
# Processing folder: dataset_7
# Processing folder: dataset_8
# Processing folder: dataset_9
# All files have been consolidated.
