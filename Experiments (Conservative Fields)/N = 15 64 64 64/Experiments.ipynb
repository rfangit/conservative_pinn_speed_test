# %% [markdown]
# # Imports

# %%
import torch
import sys
import numpy as np
import os
import shutil
from pathlib import Path
# Add parent directory to sys.path
parent_dir = Path.cwd().parent.parent
sys.path.append(str(parent_dir))
# Import modules
from train import train_test_multiple_networks, train_network_with_test_loss, train_grad_network_with_test_loss, save_plot_test_train

# %% [markdown]
# # Network Parameters

# %%
# Training hyperparameters
num_trials = 10
neurons = [64, 64, 64]
num_epochs = 200

# %% [markdown]
# # Running Experiments

# %%
# Folder containing datasets
dataset_folder = "datasets"

# Output folder for plots
output_folder = "loss_plots"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

for subfolder in os.listdir(dataset_folder):
    subfolder_path = os.path.join(dataset_folder, subfolder)
    
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")

        output_subfolder = os.path.join(output_folder, subfolder)
        os.makedirs(output_subfolder, exist_ok=True)
        
        train_folder = os.path.join(subfolder_path, "train")
        test_folder = os.path.join(subfolder_path, "test")
        
        for filename in os.listdir(train_folder):
            if filename.endswith("_train.txt"):
                base_name = filename.replace("_train.txt", "")
                
                # Load train data
                train_filepath = os.path.join(train_folder, filename)
                train_data = np.loadtxt(train_filepath)

                dimension = (int)(train_data.shape[1]/2)

                train_points = torch.tensor(train_data[:, :dimension], dtype=torch.float32)
                train_values = torch.tensor(train_data[:, dimension:], dtype=torch.float32)

                
                # Load test data
                test_filename = f"{base_name}_test.txt"
                test_filepath = os.path.join(test_folder, test_filename)
                test_data = np.loadtxt(test_filepath)
                test_points = torch.tensor(test_data[:, :dimension], dtype=torch.float32)
                test_values = torch.tensor(test_data[:, dimension:], dtype=torch.float32)
                
                print(f"Loaded preprocessed data for dimension {dimension}")
                
                # Train the normal network
                mean_loss, variance_loss, mean_test_loss, variance_test_loss = train_test_multiple_networks(
                    train_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the normal network!")
        
                # Train the conservative network
                mean_loss_grad, variance_loss_grad, mean_test_loss_grad, variance_test_loss_grad = train_test_multiple_networks(
                    train_grad_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the conservative network!")

                # Calculate standard deviations for the normal network
                std_loss = np.sqrt(variance_loss)
                std_test_loss = np.sqrt(variance_test_loss)
                std_loss_grad = np.sqrt(variance_loss_grad)
                std_test_loss_grad = np.sqrt(variance_test_loss_grad)
        
                # Print the minimum loss
                print(f"The minimum loss was {mean_loss[-1]}, conservative {mean_loss_grad[-1]}")
                print(f"The minimum test loss was {mean_test_loss[-1]}, conservative {mean_test_loss_grad[-1]}")
                # Comparison Plot
                epochs = np.arange(num_epochs)
                save_plot_test_train(epochs, mean_loss, std_loss, mean_loss_grad, std_loss_grad,
                      mean_test_loss, std_test_loss, mean_test_loss_grad, std_test_loss_grad,
                      dimension, neurons, num_epochs, output_subfolder)

                # Save the losses to .txt files
                losses_filename = os.path.join(output_subfolder, f"{dimension}D_losses.txt")
                np.savetxt(
                    losses_filename,
                    np.column_stack((
                        epochs,
                        mean_loss, std_loss,  # Training loss and std for normal network
                        mean_test_loss, std_test_loss,  # Test loss and std for normal network
                        mean_loss_grad, std_loss_grad,  # Training loss and std for conservative network
                        mean_test_loss_grad, std_test_loss_grad  # Test loss and std for conservative network
                    )),
                    fmt='%.6f',
                    header='epochs mean_loss std_loss mean_test_loss std_test_loss mean_loss_grad std_loss_grad mean_test_loss_grad std_test_loss_grad'
                )
                print(f"Losses saved to {losses_filename}")
        
print ("Done!!!")
# Out:
# Using device: cuda
# Processing folder: dataset_1
# Loaded preprocessed data for dimension 10
# The network training took 7.25 seconds.
# Done training the normal network!
# The network training took 10.80 seconds.
# Done training the conservative network!
# The minimum loss was 0.0009774827514775098, conservative 0.0009939622832462192
# The minimum test loss was 0.0011068209889344871, conservative 0.0010718080506194384
# Plot saved to loss_plots\dataset_1\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.74 seconds.
# Done training the normal network!
# The network training took 10.45 seconds.
# Done training the conservative network!
# The minimum loss was 0.0004855671839322895, conservative 0.00044952581520192326
# The minimum test loss was 0.0005387769953813404, conservative 0.00047750374651513996
# Plot saved to loss_plots\dataset_1\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.63 seconds.
# Done training the normal network!
# The network training took 10.62 seconds.
# Done training the conservative network!
# The minimum loss was 0.00019671607296913862, conservative 0.00017431335290893913
# The minimum test loss was 0.00021702011144952849, conservative 0.00018285341066075488
# Plot saved to loss_plots\dataset_1\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.97 seconds.
# Done training the normal network!
# The network training took 11.01 seconds.
# Done training the conservative network!
# The minimum loss was 0.00011120649360236712, conservative 0.00010154926203540527
# The minimum test loss was 0.00012499127187766136, conservative 0.00010710887727327645
# Plot saved to loss_plots\dataset_1\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.68 seconds.
# Done training the normal network!
# The network training took 10.53 seconds.
# Done training the conservative network!
# The minimum loss was 8.461973775411024e-05, conservative 5.53062269318616e-05
# The minimum test loss was 8.689186579431407e-05, conservative 5.3406132064992565e-05
# Plot saved to loss_plots\dataset_1\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.71 seconds.
# Done training the normal network!
# The network training took 10.78 seconds.
# Done training the conservative network!
# The minimum loss was 0.003693169017788023, conservative 0.001664559863274917
# The minimum test loss was 0.003683771938085556, conservative 0.0016799507837276905
# Plot saved to loss_plots\dataset_1\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.22 seconds.
# Done training the normal network!
# The network training took 11.16 seconds.
# Done training the conservative network!
# The minimum loss was 0.0021933873882517218, conservative 0.0013312179886270314
# The minimum test loss was 0.002236563735641539, conservative 0.0013074480986688286
# Plot saved to loss_plots\dataset_1\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.25 seconds.
# Done training the normal network!
# The network training took 11.77 seconds.
# Done training the conservative network!
# The minimum loss was 0.0034009757451713084, conservative 0.0019584896857850254
# The minimum test loss was 0.003413011389784515, conservative 0.0019083983381278813
# Plot saved to loss_plots\dataset_1\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 7.26 seconds.
# Done training the normal network!
# The network training took 13.61 seconds.
# Done training the conservative network!
# The minimum loss was 0.0013987568439915777, conservative 0.0015946489875204861
# The minimum test loss was 0.0014175101299770177, conservative 0.0015651692519895732
# Plot saved to loss_plots\dataset_1\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\8D_losses.txt
# Processing folder: dataset_10
# Loaded preprocessed data for dimension 10
# The network training took 6.33 seconds.
# Done training the normal network!
# The network training took 11.12 seconds.
# Done training the conservative network!
# The minimum loss was 0.0007943655829876662, conservative 0.0008799953327979892
# The minimum test loss was 0.0008388320624362677, conservative 0.0008736704709008336
# Plot saved to loss_plots\dataset_10\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 12.10 seconds.
# Done training the conservative network!
# The minimum loss was 0.0005537183256819844, conservative 0.0004472862696275115
# The minimum test loss was 0.0005891403998248279, conservative 0.00045253153948578986
# Plot saved to loss_plots\dataset_10\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.36 seconds.
# Done training the normal network!
# The network training took 11.31 seconds.
# Done training the conservative network!
# The minimum loss was 0.00020368789555504918, conservative 0.00014419803410419262
# The minimum test loss was 0.00021687323605874554, conservative 0.0001449392169888597
# Plot saved to loss_plots\dataset_10\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.35 seconds.
# Done training the normal network!
# The network training took 11.43 seconds.
# Done training the conservative network!
# The minimum loss was 0.00014173467789078132, conservative 0.00016059002664405852
# The minimum test loss was 0.0001474840028095059, conservative 0.0001543942969874479
# Plot saved to loss_plots\dataset_10\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.81 seconds.
# Done training the normal network!
# The network training took 11.11 seconds.
# Done training the conservative network!
# The minimum loss was 7.84795316576492e-05, conservative 6.681454397039488e-05
# The minimum test loss was 8.443281840300187e-05, conservative 6.752210174454376e-05
# Plot saved to loss_plots\dataset_10\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.65 seconds.
# Done training the normal network!
# The network training took 13.09 seconds.
# Done training the conservative network!
# The minimum loss was 0.0033537360723130405, conservative 0.0009553554031299427
# The minimum test loss was 0.003650872886646539, conservative 0.0010022889444371685
# Plot saved to loss_plots\dataset_10\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.94 seconds.
# Done training the normal network!
# The network training took 13.44 seconds.
# Done training the conservative network!
# The minimum loss was 0.002711988496594131, conservative 0.003074667532928288
# The minimum test loss was 0.0026674844673834743, conservative 0.0030633925925940275
# Plot saved to loss_plots\dataset_10\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 7.20 seconds.
# Done training the normal network!
# The network training took 14.94 seconds.
# Done training the conservative network!
# The minimum loss was 0.003202144568786025, conservative 0.003218532586470246
# The minimum test loss was 0.0031510685803368688, conservative 0.003182224067859352
# Plot saved to loss_plots\dataset_10\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.75 seconds.
# Done training the normal network!
# The network training took 11.83 seconds.
# Done training the conservative network!
# The minimum loss was 0.0024924634722992777, conservative 0.0019034866127185524
# The minimum test loss was 0.002635003486648202, conservative 0.0019876795471645893
# Plot saved to loss_plots\dataset_10\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\8D_losses.txt
# Processing folder: dataset_2
# Loaded preprocessed data for dimension 10
# The network training took 6.28 seconds.
# Done training the normal network!
# The network training took 11.44 seconds.
# Done training the conservative network!
# The minimum loss was 0.001150881010107696, conservative 0.0008692053845152259
# The minimum test loss was 0.0012606460135430098, conservative 0.0008932328666560352
# Plot saved to loss_plots\dataset_2\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.16 seconds.
# Done training the normal network!
# The network training took 11.25 seconds.
# Done training the conservative network!
# The minimum loss was 0.0004429142776643857, conservative 0.0004705722793005407
# The minimum test loss was 0.00046836437832098454, conservative 0.0004737359267892316
# Plot saved to loss_plots\dataset_2\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.84 seconds.
# Done training the normal network!
# The network training took 10.35 seconds.
# Done training the conservative network!
# The minimum loss was 0.00018447077309247106, conservative 0.00017899447557283564
# The minimum test loss was 0.0001979271793970838, conservative 0.00018160895706387237
# Plot saved to loss_plots\dataset_2\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.70 seconds.
# Done training the normal network!
# The network training took 10.50 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001343994721537456, conservative 0.00013076090690447017
# The minimum test loss was 0.0001435130470781587, conservative 0.00013129555954947137
# Plot saved to loss_plots\dataset_2\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.63 seconds.
# Done training the normal network!
# The network training took 11.32 seconds.
# Done training the conservative network!
# The minimum loss was 8.081058476818725e-05, conservative 6.375268385454547e-05
# The minimum test loss was 8.546371755073779e-05, conservative 6.390914968505968e-05
# Plot saved to loss_plots\dataset_2\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.26 seconds.
# Done training the normal network!
# The network training took 10.72 seconds.
# Done training the conservative network!
# The minimum loss was 0.0034733097767457367, conservative 0.001458904065657407
# The minimum test loss was 0.0036282429937273264, conservative 0.001473555958364159
# Plot saved to loss_plots\dataset_2\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.01 seconds.
# Done training the normal network!
# The network training took 10.49 seconds.
# Done training the conservative network!
# The minimum loss was 0.0020396742038428783, conservative 0.0021893692668527366
# The minimum test loss was 0.0020405778894200923, conservative 0.002213668986223638
# Plot saved to loss_plots\dataset_2\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.46 seconds.
# Done training the normal network!
# The network training took 10.52 seconds.
# Done training the conservative network!
# The minimum loss was 0.0027645263355225323, conservative 0.0031156240263953807
# The minimum test loss was 0.0027822489850223065, conservative 0.003051652479916811
# Plot saved to loss_plots\dataset_2\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.42 seconds.
# Done training the normal network!
# The network training took 11.49 seconds.
# Done training the conservative network!
# The minimum loss was 0.001387512416113168, conservative 0.0014389604330062866
# The minimum test loss was 0.001456204627174884, conservative 0.0014372452045790852
# Plot saved to loss_plots\dataset_2\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\8D_losses.txt
# Processing folder: dataset_3
# Loaded preprocessed data for dimension 10
# The network training took 5.77 seconds.
# Done training the normal network!
# The network training took 10.43 seconds.
# Done training the conservative network!
# The minimum loss was 0.0009414393338374793, conservative 0.0011217284598387777
# The minimum test loss was 0.0010874896310269833, conservative 0.0012315926840528845
# Plot saved to loss_plots\dataset_3\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.44 seconds.
# Done training the normal network!
# The network training took 10.17 seconds.
# Done training the conservative network!
# The minimum loss was 0.0004723751830169931, conservative 0.0004420546203618869
# The minimum test loss was 0.0005133158701937646, conservative 0.00044507663988042624
# Plot saved to loss_plots\dataset_3\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.58 seconds.
# Done training the normal network!
# The network training took 10.93 seconds.
# Done training the conservative network!
# The minimum loss was 0.00028579845966305586, conservative 0.00023492696782341228
# The minimum test loss was 0.0003143578564049676, conservative 0.000245155073935166
# Plot saved to loss_plots\dataset_3\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.34 seconds.
# Done training the normal network!
# The network training took 12.84 seconds.
# Done training the conservative network!
# The minimum loss was 7.5590968481265e-05, conservative 5.3569274314213544e-05
# The minimum test loss was 7.48941492929589e-05, conservative 5.019854834245052e-05
# Plot saved to loss_plots\dataset_3\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.86 seconds.
# Done training the normal network!
# The network training took 11.05 seconds.
# Done training the conservative network!
# The minimum loss was 8.062652850640006e-05, conservative 7.595174829475582e-05
# The minimum test loss was 9.150452897301875e-05, conservative 8.11716032330878e-05
# Plot saved to loss_plots\dataset_3\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.73 seconds.
# Done training the normal network!
# The network training took 10.87 seconds.
# Done training the conservative network!
# The minimum loss was 0.002339241362642497, conservative 0.0008668248279718682
# The minimum test loss was 0.0022976779611781238, conservative 0.0008614556398242712
# Plot saved to loss_plots\dataset_3\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.89 seconds.
# Done training the normal network!
# The network training took 11.01 seconds.
# Done training the conservative network!
# The minimum loss was 0.004781461600214243, conservative 0.003300302743446082
# The minimum test loss was 0.004766673082485795, conservative 0.0033395415055565538
# Plot saved to loss_plots\dataset_3\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.61 seconds.
# Done training the normal network!
# The network training took 11.45 seconds.
# Done training the conservative network!
# The minimum loss was 0.004722750186920166, conservative 0.00465408933814615
# The minimum test loss was 0.004639515094459057, conservative 0.004567968402989208
# Plot saved to loss_plots\dataset_3\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.37 seconds.
# Done training the normal network!
# The network training took 10.82 seconds.
# Done training the conservative network!
# The minimum loss was 0.0012907200609333814, conservative 0.001461938431020826
# The minimum test loss was 0.0013744564261287452, conservative 0.001502066303510219
# Plot saved to loss_plots\dataset_3\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\8D_losses.txt
# Processing folder: dataset_4
# Loaded preprocessed data for dimension 10
# The network training took 5.72 seconds.
# Done training the normal network!
# The network training took 12.00 seconds.
# Done training the conservative network!
# The minimum loss was 0.0007550664944574237, conservative 0.0008710263762623071
# The minimum test loss was 0.0008094212098512799, conservative 0.0008898354542907327
# Plot saved to loss_plots\dataset_4\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.08 seconds.
# Done training the normal network!
# The network training took 10.95 seconds.
# Done training the conservative network!
# The minimum loss was 0.0005948900943621993, conservative 0.000505123267066665
# The minimum test loss was 0.0006256683147512377, conservative 0.0005193408520426601
# Plot saved to loss_plots\dataset_4\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.88 seconds.
# Done training the normal network!
# The network training took 11.50 seconds.
# Done training the conservative network!
# The minimum loss was 0.00020205036707920954, conservative 0.00022723340807715431
# The minimum test loss was 0.00020634231623262167, conservative 0.00021991983521729708
# Plot saved to loss_plots\dataset_4\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.86 seconds.
# Done training the normal network!
# The network training took 11.04 seconds.
# Done training the conservative network!
# The minimum loss was 0.00018612995045259596, conservative 0.00024798822705633937
# The minimum test loss was 0.00020183451124466956, conservative 0.0002510437698219903
# Plot saved to loss_plots\dataset_4\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.05 seconds.
# Done training the normal network!
# The network training took 10.97 seconds.
# Done training the conservative network!
# The minimum loss was 0.00010076343824039213, conservative 0.00010809120285557584
# The minimum test loss was 0.00011183090027770959, conservative 0.00011277131270617246
# Plot saved to loss_plots\dataset_4\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.83 seconds.
# Done training the normal network!
# The network training took 10.79 seconds.
# Done training the conservative network!
# The minimum loss was 0.002631601027678698, conservative 0.0010011065867729485
# The minimum test loss was 0.0028931988636031747, conservative 0.0010579175665043294
# Plot saved to loss_plots\dataset_4\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.75 seconds.
# Done training the normal network!
# The network training took 11.54 seconds.
# Done training the conservative network!
# The minimum loss was 0.003223425522446632, conservative 0.0023337533115409315
# The minimum test loss was 0.003140868619084358, conservative 0.0023157813819125296
# Plot saved to loss_plots\dataset_4\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.82 seconds.
# Done training the normal network!
# The network training took 10.72 seconds.
# Done training the conservative network!
# The minimum loss was 0.0036873117554932834, conservative 0.002597410511225462
# The minimum test loss was 0.0034025862812995912, conservative 0.002464039041660726
# Plot saved to loss_plots\dataset_4\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.22 seconds.
# Done training the normal network!
# The network training took 10.50 seconds.
# Done training the conservative network!
# The minimum loss was 0.0016195907373912632, conservative 0.001614759222138673
# The minimum test loss was 0.0016484420746564865, conservative 0.0015799052547663451
# Plot saved to loss_plots\dataset_4\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\8D_losses.txt
# Processing folder: dataset_5
# Loaded preprocessed data for dimension 10
# The network training took 5.60 seconds.
# Done training the normal network!
# The network training took 10.75 seconds.
# Done training the conservative network!
# The minimum loss was 0.0009146762313321233, conservative 0.000980631005950272
# The minimum test loss was 0.0010068192437756806, conservative 0.00103632501559332
# Plot saved to loss_plots\dataset_5\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.69 seconds.
# Done training the normal network!
# The network training took 11.21 seconds.
# Done training the conservative network!
# The minimum loss was 0.00042174631089437754, conservative 0.00046019107394386084
# The minimum test loss was 0.00046962655906099824, conservative 0.000493556703440845
# Plot saved to loss_plots\dataset_5\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.02 seconds.
# Done training the normal network!
# The network training took 10.99 seconds.
# Done training the conservative network!
# The minimum loss was 0.00026000877987826244, conservative 0.00025680907419882714
# The minimum test loss was 0.0002805235591949895, conservative 0.0002604919514851645
# Plot saved to loss_plots\dataset_5\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.80 seconds.
# Done training the normal network!
# The network training took 10.69 seconds.
# Done training the conservative network!
# The minimum loss was 0.00010344501279178076, conservative 8.743588405195624e-05
# The minimum test loss was 0.00011589981440920382, conservative 9.42712249525357e-05
# Plot saved to loss_plots\dataset_5\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.09 seconds.
# Done training the normal network!
# The network training took 10.86 seconds.
# Done training the conservative network!
# The minimum loss was 8.446183492196723e-05, conservative 3.793985888478346e-05
# The minimum test loss was 8.56264479807578e-05, conservative 3.675817042676499e-05
# Plot saved to loss_plots\dataset_5\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.77 seconds.
# Done training the normal network!
# The network training took 12.92 seconds.
# Done training the conservative network!
# The minimum loss was 0.003974132251460105, conservative 0.0016793610760942102
# The minimum test loss was 0.00431139450520277, conservative 0.0017688938474748283
# Plot saved to loss_plots\dataset_5\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.57 seconds.
# Done training the normal network!
# The network training took 11.40 seconds.
# Done training the conservative network!
# The minimum loss was 0.002999948593787849, conservative 0.001288503414252773
# The minimum test loss was 0.0030715622939169406, conservative 0.0012803767167497426
# Plot saved to loss_plots\dataset_5\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.41 seconds.
# Done training the normal network!
# The network training took 10.83 seconds.
# Done training the conservative network!
# The minimum loss was 0.004865131201222539, conservative 0.002747888746671379
# The minimum test loss was 0.004997342126443982, conservative 0.0027825755765661596
# Plot saved to loss_plots\dataset_5\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.89 seconds.
# Done training the normal network!
# The network training took 10.97 seconds.
# Done training the conservative network!
# The minimum loss was 0.0016575680929236114, conservative 0.0020056154811754824
# The minimum test loss was 0.0016801692312583328, conservative 0.0019684618338942526
# Plot saved to loss_plots\dataset_5\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\8D_losses.txt
# Processing folder: dataset_6
# Loaded preprocessed data for dimension 10
# The network training took 5.87 seconds.
# Done training the normal network!
# The network training took 11.40 seconds.
# Done training the conservative network!
# The minimum loss was 0.0009450575162190944, conservative 0.0009083034237846732
# The minimum test loss was 0.001067267870530486, conservative 0.000994745729258284
# Plot saved to loss_plots\dataset_6\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.16 seconds.
# Done training the normal network!
# The network training took 11.53 seconds.
# Done training the conservative network!
# The minimum loss was 0.000567066646181047, conservative 0.0005714378610718995
# The minimum test loss was 0.000608695187838748, conservative 0.0005782342457678169
# Plot saved to loss_plots\dataset_6\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.04 seconds.
# Done training the normal network!
# The network training took 11.01 seconds.
# Done training the conservative network!
# The minimum loss was 0.00026091584004461765, conservative 0.00022733336954843252
# The minimum test loss was 0.0003051133855478838, conservative 0.0002504458272596821
# Plot saved to loss_plots\dataset_6\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.95 seconds.
# Done training the normal network!
# The network training took 10.82 seconds.
# Done training the conservative network!
# The minimum loss was 0.00012228238774696364, conservative 0.00013109676146996207
# The minimum test loss was 0.00013185816787881778, conservative 0.00013529856078093873
# Plot saved to loss_plots\dataset_6\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.81 seconds.
# Done training the normal network!
# The network training took 11.41 seconds.
# Done training the conservative network!
# The minimum loss was 8.87906615389511e-05, conservative 8.274693391285837e-05
# The minimum test loss was 9.683373937150464e-05, conservative 8.435905110673047e-05
# Plot saved to loss_plots\dataset_6\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 7.26 seconds.
# Done training the normal network!
# The network training took 11.10 seconds.
# Done training the conservative network!
# The minimum loss was 0.0019078316981904209, conservative 0.0007119485002476722
# The minimum test loss was 0.0018907116842456161, conservative 0.0007117227301932872
# Plot saved to loss_plots\dataset_6\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.32 seconds.
# Done training the normal network!
# The network training took 11.09 seconds.
# Done training the conservative network!
# The minimum loss was 0.0026786404429003595, conservative 0.0016572119435295462
# The minimum test loss was 0.0027278726920485497, conservative 0.0016676881816238165
# Plot saved to loss_plots\dataset_6\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.21 seconds.
# Done training the normal network!
# The network training took 10.64 seconds.
# Done training the conservative network!
# The minimum loss was 0.0039498076075688004, conservative 0.004865308338776231
# The minimum test loss was 0.003929200279526412, conservative 0.004874945688061416
# Plot saved to loss_plots\dataset_6\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.78 seconds.
# Done training the normal network!
# The network training took 10.96 seconds.
# Done training the conservative network!
# The minimum loss was 0.0019601447507739066, conservative 0.0019054921343922616
# The minimum test loss was 0.0020422777510248125, conservative 0.0019263375550508499
# Plot saved to loss_plots\dataset_6\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\8D_losses.txt
# Processing folder: dataset_7
# Loaded preprocessed data for dimension 10
# The network training took 6.08 seconds.
# Done training the normal network!
# The network training took 10.70 seconds.
# Done training the conservative network!
# The minimum loss was 0.000840580026851967, conservative 0.0009371200518216938
# The minimum test loss was 0.0008963674248661846, conservative 0.0009499213541857898
# Plot saved to loss_plots\dataset_7\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.79 seconds.
# Done training the normal network!
# The network training took 10.48 seconds.
# Done training the conservative network!
# The minimum loss was 0.0004789009224623442, conservative 0.0004599023028276861
# The minimum test loss was 0.0005300435004755855, conservative 0.00048120465944521127
# Plot saved to loss_plots\dataset_7\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.72 seconds.
# Done training the normal network!
# The network training took 10.65 seconds.
# Done training the conservative network!
# The minimum loss was 0.00025666123401606454, conservative 0.0003290790948085487
# The minimum test loss was 0.0002747637307038531, conservative 0.0003302181925391778
# Plot saved to loss_plots\dataset_7\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.79 seconds.
# Done training the normal network!
# The network training took 11.13 seconds.
# Done training the conservative network!
# The minimum loss was 9.191412318614312e-05, conservative 0.00012037515043630264
# The minimum test loss was 9.914922047755681e-05, conservative 0.00012106910726288334
# Plot saved to loss_plots\dataset_7\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.13 seconds.
# Done training the normal network!
# The network training took 11.07 seconds.
# Done training the conservative network!
# The minimum loss was 0.00010494818561710418, conservative 0.00011233060067752376
# The minimum test loss was 0.00011576727411011234, conservative 0.00011712948762578889
# Plot saved to loss_plots\dataset_7\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.84 seconds.
# Done training the normal network!
# The network training took 10.89 seconds.
# Done training the conservative network!
# The minimum loss was 0.003677033958956599, conservative 0.0028074761852622033
# The minimum test loss was 0.003942702757194638, conservative 0.002863170695491135
# Plot saved to loss_plots\dataset_7\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.74 seconds.
# Done training the normal network!
# The network training took 11.13 seconds.
# Done training the conservative network!
# The minimum loss was 0.004360063187777996, conservative 0.0031654799124225972
# The minimum test loss was 0.0043567725457251075, conservative 0.003172060614451766
# Plot saved to loss_plots\dataset_7\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.85 seconds.
# Done training the normal network!
# The network training took 11.12 seconds.
# Done training the conservative network!
# The minimum loss was 0.0031586079159751533, conservative 0.0019189170212484895
# The minimum test loss was 0.003242160240188241, conservative 0.0019057153491303324
# Plot saved to loss_plots\dataset_7\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.99 seconds.
# Done training the normal network!
# The network training took 11.09 seconds.
# Done training the conservative network!
# The minimum loss was 0.0013231557211838662, conservative 0.0015549745759926737
# The minimum test loss was 0.0013997350353747607, conservative 0.0015982130193151534
# Plot saved to loss_plots\dataset_7\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\8D_losses.txt
# Processing folder: dataset_8
# Loaded preprocessed data for dimension 10
# The network training took 5.93 seconds.
# Done training the normal network!
# The network training took 10.69 seconds.
# Done training the conservative network!
# The minimum loss was 0.0009335757233202458, conservative 0.0010320673580281436
# The minimum test loss was 0.0009785051865037532, conservative 0.0010229752399027348
# Plot saved to loss_plots\dataset_8\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.95 seconds.
# Done training the normal network!
# The network training took 10.90 seconds.
# Done training the conservative network!
# The minimum loss was 0.0005641482654027641, conservative 0.0005056583293480798
# The minimum test loss was 0.0006169601459987461, conservative 0.0005229889618931338
# Plot saved to loss_plots\dataset_8\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.22 seconds.
# Done training the normal network!
# The network training took 11.29 seconds.
# Done training the conservative network!
# The minimum loss was 0.0002830543788149953, conservative 0.00028834474505856633
# The minimum test loss was 0.00031670641037635506, conservative 0.00030299479694804175
# Plot saved to loss_plots\dataset_8\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.44 seconds.
# Done training the normal network!
# The network training took 10.91 seconds.
# Done training the conservative network!
# The minimum loss was 0.00018426493188599123, conservative 0.0002678052536793984
# The minimum test loss was 0.00020104631257709116, conservative 0.00027054407692048696
# Plot saved to loss_plots\dataset_8\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.99 seconds.
# Done training the normal network!
# The network training took 10.62 seconds.
# Done training the conservative network!
# The minimum loss was 0.00010819661983987316, conservative 0.0001140850319643505
# The minimum test loss was 0.00011747770840884187, conservative 0.00011819417413789779
# Plot saved to loss_plots\dataset_8\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.86 seconds.
# Done training the normal network!
# The network training took 10.64 seconds.
# Done training the conservative network!
# The minimum loss was 0.0029631483484990895, conservative 0.0009506140166195109
# The minimum test loss was 0.0029817638569511473, conservative 0.0009580729762092233
# Plot saved to loss_plots\dataset_8\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.83 seconds.
# Done training the normal network!
# The network training took 11.75 seconds.
# Done training the conservative network!
# The minimum loss was 0.001999009819701314, conservative 0.0030308478279039265
# The minimum test loss was 0.0020565234939567746, conservative 0.003033901797607541
# Plot saved to loss_plots\dataset_8\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.42 seconds.
# Done training the normal network!
# The network training took 11.07 seconds.
# Done training the conservative network!
# The minimum loss was 0.0034452401800081135, conservative 0.0024994861567392947
# The minimum test loss was 0.003503479133360088, conservative 0.0024552309536375106
# Plot saved to loss_plots\dataset_8\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.14 seconds.
# Done training the normal network!
# The network training took 11.58 seconds.
# Done training the conservative network!
# The minimum loss was 0.0017000633873976768, conservative 0.0020325898309238254
# The minimum test loss was 0.0017961883451789618, conservative 0.002043571090325713
# Plot saved to loss_plots\dataset_8\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\8D_losses.txt
# Processing folder: dataset_9
# Loaded preprocessed data for dimension 10
# The network training took 5.95 seconds.
# Done training the normal network!
# The network training took 10.57 seconds.
# Done training the conservative network!
# The minimum loss was 0.001017853891244158, conservative 0.0011412655701860785
# The minimum test loss was 0.0009684898483101279, conservative 0.001035517011769116
# Plot saved to loss_plots\dataset_9\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.65 seconds.
# Done training the normal network!
# The network training took 10.91 seconds.
# Done training the conservative network!
# The minimum loss was 0.0005065214965725318, conservative 0.0006027343799360097
# The minimum test loss was 0.0005155910243047401, conservative 0.000585580209735781
# Plot saved to loss_plots\dataset_9\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.99 seconds.
# Done training the normal network!
# The network training took 10.58 seconds.
# Done training the conservative network!
# The minimum loss was 0.00017083723214454948, conservative 0.00014904510244377888
# The minimum test loss was 0.0001754937635269016, conservative 0.00014602054943679832
# Plot saved to loss_plots\dataset_9\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.70 seconds.
# Done training the normal network!
# The network training took 10.53 seconds.
# Done training the conservative network!
# The minimum loss was 0.00015103542391443626, conservative 0.00020149944903096183
# The minimum test loss was 0.00015923413448035718, conservative 0.0001982525471248664
# Plot saved to loss_plots\dataset_9\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.59 seconds.
# Done training the normal network!
# The network training took 10.40 seconds.
# Done training the conservative network!
# The minimum loss was 8.903180860215798e-05, conservative 6.810668674006592e-05
# The minimum test loss was 9.791565607883968e-05, conservative 7.092106206982863e-05
# Plot saved to loss_plots\dataset_9\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.67 seconds.
# Done training the normal network!
# The network training took 10.94 seconds.
# Done training the conservative network!
# The minimum loss was 0.002946712216362357, conservative 0.001140972931170836
# The minimum test loss was 0.003094204911030829, conservative 0.0011231967189814895
# Plot saved to loss_plots\dataset_9\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.24 seconds.
# Done training the normal network!
# The network training took 11.53 seconds.
# Done training the conservative network!
# The minimum loss was 0.0027294839965179563, conservative 0.002661633212119341
# The minimum test loss was 0.0027852709987200796, conservative 0.0026704626507125795
# Plot saved to loss_plots\dataset_9\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.76 seconds.
# Done training the normal network!
# The network training took 10.77 seconds.
# Done training the conservative network!
# The minimum loss was 0.001511167164426297, conservative 0.0019902525003999473
# The minimum test loss was 0.0015320000471547245, conservative 0.0020302624790929256
# Plot saved to loss_plots\dataset_9\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.74 seconds.
# Done training the normal network!
# The network training took 10.71 seconds.
# Done training the conservative network!
# The minimum loss was 0.001460556243546307, conservative 0.0017330323345959187
# The minimum test loss was 0.0015798158943653106, conservative 0.0018278681440278889
# Plot saved to loss_plots\dataset_9\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\8D_losses.txt
# Done!!!

# %% [markdown]
# # Organizing Data

# %%
# Folder containing the loss plots and text files
loss_folder = "loss_plots"

# Output folders for consolidated images and text files
output_image_folder = "consolidated_images"
output_text_folder = "consolidated_text_files"

# Create output folders if they don't exist
os.makedirs(output_image_folder, exist_ok=True)
os.makedirs(output_text_folder, exist_ok=True)

# Iterate through all subfolders in the loss_folder
for subfolder in os.listdir(loss_folder):
    subfolder_path = os.path.join(loss_folder, subfolder)
    
    # Check if it's a directory (e.g., dataset_1, dataset_2, etc.)
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")
        
        # Extract the dataset number (e.g., "1" from "dataset_1")
        dataset_number = subfolder.split("_")[-1]
        
        # Process images
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".png"):  # Process only .png files
                # Construct the new filename (e.g., 2D_Conservative_NN_1.png)
                new_filename = filename.replace(".png", f"_{dataset_number}.png")
                
                # Copy the image to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_image_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied image: {src_path} -> {dest_path}")
        
        # Process text files
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".txt"):  # Process only .txt files
                # Construct the new filename (e.g., 8D_losses_1.txt)
                new_filename = filename.replace(".txt", f"_{dataset_number}.txt")
                
                # Copy the text file to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_text_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied text file: {src_path} -> {dest_path}")

print("All files have been consolidated.")
# Out:
# Processing folder: dataset_1
# Processing folder: dataset_10
# Processing folder: dataset_2
# Processing folder: dataset_3
# Processing folder: dataset_4
# Processing folder: dataset_5
# Processing folder: dataset_6
# Processing folder: dataset_7
# Processing folder: dataset_8
# Processing folder: dataset_9
# All files have been consolidated.
