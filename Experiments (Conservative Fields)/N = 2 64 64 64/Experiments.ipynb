# %% [markdown]
# # Imports

# %%
import torch
import sys
import numpy as np
import os
import shutil
from pathlib import Path
# Add parent directory to sys.path
parent_dir = Path.cwd().parent.parent
sys.path.append(str(parent_dir))
# Import modules
from train import train_test_multiple_networks, train_network_with_test_loss, train_grad_network_with_test_loss, save_plot_test_train

# %% [markdown]
# # Network Parameters

# %%
# Training hyperparameters
num_trials = 10
neurons = [64, 64, 64]
num_epochs = 200

# %% [markdown]
# # Running Experiments

# %%
# Folder containing datasets
dataset_folder = "datasets"

# Output folder for plots
output_folder = "loss_plots"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

for subfolder in os.listdir(dataset_folder):
    subfolder_path = os.path.join(dataset_folder, subfolder)
    
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")

        output_subfolder = os.path.join(output_folder, subfolder)
        os.makedirs(output_subfolder, exist_ok=True)
        
        train_folder = os.path.join(subfolder_path, "train")
        test_folder = os.path.join(subfolder_path, "test")
        
        for filename in os.listdir(train_folder):
            if filename.endswith("_train.txt"):
                base_name = filename.replace("_train.txt", "")
                
                # Load train data
                train_filepath = os.path.join(train_folder, filename)
                train_data = np.loadtxt(train_filepath)

                dimension = (int)(train_data.shape[1]/2)

                train_points = torch.tensor(train_data[:, :dimension], dtype=torch.float32)
                train_values = torch.tensor(train_data[:, dimension:], dtype=torch.float32)

                
                # Load test data
                test_filename = f"{base_name}_test.txt"
                test_filepath = os.path.join(test_folder, test_filename)
                test_data = np.loadtxt(test_filepath)
                test_points = torch.tensor(test_data[:, :dimension], dtype=torch.float32)
                test_values = torch.tensor(test_data[:, dimension:], dtype=torch.float32)
                
                print(f"Loaded preprocessed data for dimension {dimension}")
                
                # Train the normal network
                mean_loss, variance_loss, mean_test_loss, variance_test_loss = train_test_multiple_networks(
                    train_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the normal network!")
        
                # Train the conservative network
                mean_loss_grad, variance_loss_grad, mean_test_loss_grad, variance_test_loss_grad = train_test_multiple_networks(
                    train_grad_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the conservative network!")

                # Calculate standard deviations for the normal network
                std_loss = np.sqrt(variance_loss)
                std_test_loss = np.sqrt(variance_test_loss)
                std_loss_grad = np.sqrt(variance_loss_grad)
                std_test_loss_grad = np.sqrt(variance_test_loss_grad)
        
                # Print the minimum loss
                print(f"The minimum loss was {mean_loss[-1]}, conservative {mean_loss_grad[-1]}")
                print(f"The minimum test loss was {mean_test_loss[-1]}, conservative {mean_test_loss_grad[-1]}")
                # Comparison Plot
                epochs = np.arange(num_epochs)
                save_plot_test_train(epochs, mean_loss, std_loss, mean_loss_grad, std_loss_grad,
                      mean_test_loss, std_test_loss, mean_test_loss_grad, std_test_loss_grad,
                      dimension, neurons, num_epochs, output_subfolder)

                # Save the losses to .txt files
                losses_filename = os.path.join(output_subfolder, f"{dimension}D_losses.txt")
                np.savetxt(
                    losses_filename,
                    np.column_stack((
                        epochs,
                        mean_loss, std_loss,  # Training loss and std for normal network
                        mean_test_loss, std_test_loss,  # Test loss and std for normal network
                        mean_loss_grad, std_loss_grad,  # Training loss and std for conservative network
                        mean_test_loss_grad, std_test_loss_grad  # Test loss and std for conservative network
                    )),
                    fmt='%.6f',
                    header='epochs mean_loss std_loss mean_test_loss std_test_loss mean_loss_grad std_loss_grad mean_test_loss_grad std_test_loss_grad'
                )
                print(f"Losses saved to {losses_filename}")
        
print ("Done!!!")
# Out:
# Using device: cuda
# Processing folder: dataset_1
# Loaded preprocessed data for dimension 10
# The network training took 6.45 seconds.
# Done training the normal network!
# The network training took 7.60 seconds.
# Done training the conservative network!
# The minimum loss was 4.1423206494073386e-05, conservative 8.353283737960737e-06
# The minimum test loss was 4.5803111061104576e-05, conservative 8.32079258543672e-06
# Plot saved to loss_plots\dataset_1\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 3.80 seconds.
# Done training the normal network!
# The network training took 8.04 seconds.
# Done training the conservative network!
# The minimum loss was 2.2299320335150696e-05, conservative 3.933459652216698e-06
# The minimum test loss was 2.5975828430091495e-05, conservative 4.2083808466486515e-06
# Plot saved to loss_plots\dataset_1\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 4.18 seconds.
# Done training the normal network!
# The network training took 7.88 seconds.
# Done training the conservative network!
# The minimum loss was 2.390613590250723e-05, conservative 7.384505033769529e-06
# The minimum test loss was 3.0500578759529162e-05, conservative 1.108574019781372e-05
# Plot saved to loss_plots\dataset_1\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 3.52 seconds.
# Done training the normal network!
# The network training took 7.50 seconds.
# Done training the conservative network!
# The minimum loss was 4.4191409870109055e-05, conservative 1.430916302069818e-06
# The minimum test loss was 4.689435500040418e-05, conservative 1.8205892274636425e-06
# Plot saved to loss_plots\dataset_1\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 3.54 seconds.
# Done training the normal network!
# The network training took 9.28 seconds.
# Done training the conservative network!
# The minimum loss was 5.396783781179693e-05, conservative 2.3050689151205008e-06
# The minimum test loss was 5.906851765757892e-05, conservative 2.417677524135797e-06
# Plot saved to loss_plots\dataset_1\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 3.90 seconds.
# Done training the normal network!
# The network training took 7.26 seconds.
# Done training the conservative network!
# The minimum loss was 2.4959451729955616e-05, conservative 2.76093281172507e-05
# The minimum test loss was 2.4870138804544695e-05, conservative 2.725524836932891e-05
# Plot saved to loss_plots\dataset_1\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 3.44 seconds.
# Done training the normal network!
# The network training took 7.03 seconds.
# Done training the conservative network!
# The minimum loss was 8.327526702487376e-05, conservative 3.627670321293408e-05
# The minimum test loss was 8.127926303131971e-05, conservative 3.602735978347482e-05
# Plot saved to loss_plots\dataset_1\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 3.37 seconds.
# Done training the normal network!
# The network training took 9.21 seconds.
# Done training the conservative network!
# The minimum loss was 3.72346825315617e-05, conservative 3.333295826450922e-05
# The minimum test loss was 3.790434311667923e-05, conservative 3.35059909048141e-05
# Plot saved to loss_plots\dataset_1\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 4.07 seconds.
# Done training the normal network!
# The network training took 7.52 seconds.
# Done training the conservative network!
# The minimum loss was 4.17034410929773e-05, conservative 1.3591970946436049e-05
# The minimum test loss was 5.416171443357598e-05, conservative 1.4527284383802907e-05
# Plot saved to loss_plots\dataset_1\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\8D_losses.txt
# Processing folder: dataset_10
# Loaded preprocessed data for dimension 10
# The network training took 4.03 seconds.
# Done training the normal network!
# The network training took 7.53 seconds.
# Done training the conservative network!
# The minimum loss was 3.5951674362877384e-05, conservative 2.550582721596584e-05
# The minimum test loss was 4.545674892142415e-05, conservative 3.15620367473457e-05
# Plot saved to loss_plots\dataset_10\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 3.77 seconds.
# Done training the normal network!
# The network training took 7.66 seconds.
# Done training the conservative network!
# The minimum loss was 3.41464417942916e-05, conservative 4.570355667965487e-06
# The minimum test loss was 3.890117513947189e-05, conservative 4.521200480667176e-06
# Plot saved to loss_plots\dataset_10\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 3.69 seconds.
# Done training the normal network!
# The network training took 7.23 seconds.
# Done training the conservative network!
# The minimum loss was 2.6903249090537428e-05, conservative 6.96895308465173e-06
# The minimum test loss was 2.9564911346824375e-05, conservative 7.1663461994830865e-06
# Plot saved to loss_plots\dataset_10\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 3.47 seconds.
# Done training the normal network!
# The network training took 9.28 seconds.
# Done training the conservative network!
# The minimum loss was 2.019904877670342e-05, conservative 6.198098935783491e-06
# The minimum test loss was 2.156357559215394e-05, conservative 6.331610029519652e-06
# Plot saved to loss_plots\dataset_10\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 3.56 seconds.
# Done training the normal network!
# The network training took 7.23 seconds.
# Done training the conservative network!
# The minimum loss was 2.961809586849995e-05, conservative 1.8402179307486221e-06
# The minimum test loss was 3.120168730674777e-05, conservative 2.0062957787558845e-06
# Plot saved to loss_plots\dataset_10\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 3.33 seconds.
# Done training the normal network!
# The network training took 7.39 seconds.
# Done training the conservative network!
# The minimum loss was 7.76111977529581e-06, conservative 3.392049120520824e-06
# The minimum test loss was 7.566186059193569e-06, conservative 3.3602374628571852e-06
# Plot saved to loss_plots\dataset_10\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 4.14 seconds.
# Done training the normal network!
# The network training took 7.98 seconds.
# Done training the conservative network!
# The minimum loss was 2.355826782149961e-05, conservative 3.0465748204733244e-05
# The minimum test loss was 2.322468044440029e-05, conservative 2.9918388827354646e-05
# Plot saved to loss_plots\dataset_10\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 4.19 seconds.
# Done training the normal network!
# The network training took 9.02 seconds.
# Done training the conservative network!
# The minimum loss was 2.66571430984186e-05, conservative 1.698430814940366e-05
# The minimum test loss was 2.8789572934329043e-05, conservative 1.7494242729299004e-05
# Plot saved to loss_plots\dataset_10\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 4.01 seconds.
# Done training the normal network!
# The network training took 7.56 seconds.
# Done training the conservative network!
# The minimum loss was 3.859568387269974e-05, conservative 1.439804836991243e-05
# The minimum test loss was 4.057458063471131e-05, conservative 1.4498075324809179e-05
# Plot saved to loss_plots\dataset_10\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\8D_losses.txt
# Processing folder: dataset_2
# Loaded preprocessed data for dimension 10
# The network training took 3.55 seconds.
# Done training the normal network!
# The network training took 7.82 seconds.
# Done training the conservative network!
# The minimum loss was 4.983574290235992e-05, conservative 5.739516518588062e-06
# The minimum test loss was 5.4120203640195544e-05, conservative 6.006224793964066e-06
# Plot saved to loss_plots\dataset_2\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 3.39 seconds.
# Done training the normal network!
# The network training took 6.99 seconds.
# Done training the conservative network!
# The minimum loss was 5.36898682184983e-05, conservative 1.5582574451400433e-05
# The minimum test loss was 5.336852627806366e-05, conservative 1.5139116294449196e-05
# Plot saved to loss_plots\dataset_2\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 3.68 seconds.
# Done training the normal network!
# The network training took 7.40 seconds.
# Done training the conservative network!
# The minimum loss was 4.292996927688364e-05, conservative 6.671284836556879e-06
# The minimum test loss was 4.824296702281572e-05, conservative 7.653190391465613e-06
# Plot saved to loss_plots\dataset_2\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 3.56 seconds.
# Done training the normal network!
# The network training took 7.24 seconds.
# Done training the conservative network!
# The minimum loss was 3.475855392025551e-05, conservative 3.7862401200072782e-06
# The minimum test loss was 3.9416168510797435e-05, conservative 4.211451971514179e-06
# Plot saved to loss_plots\dataset_2\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 3.25 seconds.
# Done training the normal network!
# The network training took 7.92 seconds.
# Done training the conservative network!
# The minimum loss was 4.377919867692981e-05, conservative 4.8865936832953595e-06
# The minimum test loss was 4.645658118533902e-05, conservative 4.983242729394988e-06
# Plot saved to loss_plots\dataset_2\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 3.91 seconds.
# Done training the normal network!
# The network training took 8.12 seconds.
# Done training the conservative network!
# The minimum loss was 9.599449731467757e-05, conservative 3.5213603678130315e-05
# The minimum test loss was 0.00010133928844879847, conservative 3.72432429685432e-05
# Plot saved to loss_plots\dataset_2\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 4.70 seconds.
# Done training the normal network!
# The network training took 8.16 seconds.
# Done training the conservative network!
# The minimum loss was 0.00020383906958159058, conservative 0.00017079190402000677
# The minimum test loss was 0.0002102221827954054, conservative 0.00017400100514350925
# Plot saved to loss_plots\dataset_2\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 3.63 seconds.
# Done training the normal network!
# The network training took 7.40 seconds.
# Done training the conservative network!
# The minimum loss was 4.6508889136021024e-05, conservative 5.6118192514986734e-05
# The minimum test loss was 4.816013934032526e-05, conservative 5.6391552152490473e-05
# Plot saved to loss_plots\dataset_2\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 3.41 seconds.
# Done training the normal network!
# The network training took 6.97 seconds.
# Done training the conservative network!
# The minimum loss was 2.872564746212447e-05, conservative 1.9772941050177907e-05
# The minimum test loss was 3.0983395481598565e-05, conservative 2.0123021749895996e-05
# Plot saved to loss_plots\dataset_2\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\8D_losses.txt
# Processing folder: dataset_3
# Loaded preprocessed data for dimension 10
# The network training took 3.38 seconds.
# Done training the normal network!
# The network training took 7.49 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001007055638183374, conservative 4.062334082846064e-05
# The minimum test loss was 0.00011078949246439152, conservative 4.054905839439016e-05
# Plot saved to loss_plots\dataset_3\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 3.37 seconds.
# Done training the normal network!
# The network training took 8.15 seconds.
# Done training the conservative network!
# The minimum loss was 5.398008470365312e-05, conservative 1.6475643860758282e-06
# The minimum test loss was 7.169844830059446e-05, conservative 3.8016120697648146e-06
# Plot saved to loss_plots\dataset_3\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 3.49 seconds.
# Done training the normal network!
# The network training took 6.88 seconds.
# Done training the conservative network!
# The minimum loss was 3.011697517649736e-05, conservative 6.5552752630537725e-06
# The minimum test loss was 3.56944467057474e-05, conservative 7.16652107257687e-06
# Plot saved to loss_plots\dataset_3\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 4.15 seconds.
# Done training the normal network!
# The network training took 7.56 seconds.
# Done training the conservative network!
# The minimum loss was 3.372020673850784e-05, conservative 2.5386465665633297e-06
# The minimum test loss was 3.3000278563122265e-05, conservative 2.307307221371957e-06
# Plot saved to loss_plots\dataset_3\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 3.73 seconds.
# Done training the normal network!
# The network training took 7.25 seconds.
# Done training the conservative network!
# The minimum loss was 3.3053402694349644e-05, conservative 5.960391973758305e-07
# The minimum test loss was 3.7338882975745946e-05, conservative 7.701438732965471e-07
# Plot saved to loss_plots\dataset_3\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 4.47 seconds.
# Done training the normal network!
# The network training took 8.19 seconds.
# Done training the conservative network!
# The minimum loss was 2.533468559704488e-05, conservative 1.4274564455263316e-05
# The minimum test loss was 2.5576971711416264e-05, conservative 1.5004500028226175e-05
# Plot saved to loss_plots\dataset_3\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 3.79 seconds.
# Done training the normal network!
# The network training took 7.87 seconds.
# Done training the conservative network!
# The minimum loss was 6.003370508551597e-05, conservative 4.701718717115e-05
# The minimum test loss was 6.109690475568641e-05, conservative 4.791863138962071e-05
# Plot saved to loss_plots\dataset_3\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 3.80 seconds.
# Done training the normal network!
# The network training took 8.50 seconds.
# Done training the conservative network!
# The minimum loss was 8.69191007950576e-05, conservative 2.1274420305417152e-05
# The minimum test loss was 8.983539373730309e-05, conservative 2.1238075714791193e-05
# Plot saved to loss_plots\dataset_3\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 3.66 seconds.
# Done training the normal network!
# The network training took 6.91 seconds.
# Done training the conservative network!
# The minimum loss was 3.091537873842753e-05, conservative 1.7024492990458384e-05
# The minimum test loss was 3.277076993981609e-05, conservative 1.727619346638676e-05
# Plot saved to loss_plots\dataset_3\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\8D_losses.txt
# Processing folder: dataset_4
# Loaded preprocessed data for dimension 10
# The network training took 3.94 seconds.
# Done training the normal network!
# The network training took 7.37 seconds.
# Done training the conservative network!
# The minimum loss was 4.5574336763820614e-05, conservative 1.611179441169952e-05
# The minimum test loss was 4.5796108315698804e-05, conservative 1.582379609317286e-05
# Plot saved to loss_plots\dataset_4\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 3.65 seconds.
# Done training the normal network!
# The network training took 8.21 seconds.
# Done training the conservative network!
# The minimum loss was 8.424111911153886e-05, conservative 2.1153974898879825e-06
# The minimum test loss was 9.516550999251194e-05, conservative 2.3649406671211183e-06
# Plot saved to loss_plots\dataset_4\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 3.32 seconds.
# Done training the normal network!
# The network training took 7.49 seconds.
# Done training the conservative network!
# The minimum loss was 3.607491034927079e-05, conservative 3.731147330654494e-06
# The minimum test loss was 3.948038865928538e-05, conservative 4.6525135530828265e-06
# Plot saved to loss_plots\dataset_4\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 3.38 seconds.
# Done training the normal network!
# The network training took 7.40 seconds.
# Done training the conservative network!
# The minimum loss was 4.423759310157038e-05, conservative 2.5444827087994783e-06
# The minimum test loss was 4.9282190047961194e-05, conservative 2.754005186034192e-06
# Plot saved to loss_plots\dataset_4\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 3.88 seconds.
# Done training the normal network!
# The network training took 7.45 seconds.
# Done training the conservative network!
# The minimum loss was 4.39075438407599e-05, conservative 1.1009058368927072e-06
# The minimum test loss was 4.4355793579597955e-05, conservative 1.2121451618440914e-06
# Plot saved to loss_plots\dataset_4\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 3.35 seconds.
# Done training the normal network!
# The network training took 8.02 seconds.
# Done training the conservative network!
# The minimum loss was 2.3390249953081366e-05, conservative 1.7145517176686553e-05
# The minimum test loss was 2.3311648874368984e-05, conservative 1.73485205777979e-05
# Plot saved to loss_plots\dataset_4\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 4.33 seconds.
# Done training the normal network!
# The network training took 7.80 seconds.
# Done training the conservative network!
# The minimum loss was 7.128830839064904e-05, conservative 4.8649154541635654e-05
# The minimum test loss was 7.110208971425891e-05, conservative 4.892592260148376e-05
# Plot saved to loss_plots\dataset_4\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 3.93 seconds.
# Done training the normal network!
# The network training took 6.78 seconds.
# Done training the conservative network!
# The minimum loss was 9.807502974581439e-05, conservative 2.8593877505045385e-05
# The minimum test loss was 0.00010154198716918472, conservative 2.94640253741818e-05
# Plot saved to loss_plots\dataset_4\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 3.83 seconds.
# Done training the normal network!
# The network training took 7.93 seconds.
# Done training the conservative network!
# The minimum loss was 2.186275323765585e-05, conservative 1.0280685501129483e-05
# The minimum test loss was 2.316114459972596e-05, conservative 1.0574099223958911e-05
# Plot saved to loss_plots\dataset_4\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\8D_losses.txt
# Processing folder: dataset_5
# Loaded preprocessed data for dimension 10
# The network training took 3.62 seconds.
# Done training the normal network!
# The network training took 6.85 seconds.
# Done training the conservative network!
# The minimum loss was 3.2448458659928293e-05, conservative 9.765703180164564e-06
# The minimum test loss was 3.4529020740592384e-05, conservative 9.848262470768531e-06
# Plot saved to loss_plots\dataset_5\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 3.41 seconds.
# Done training the normal network!
# The network training took 7.92 seconds.
# Done training the conservative network!
# The minimum loss was 5.177985585760325e-05, conservative 1.0965943829432945e-05
# The minimum test loss was 5.034697678638622e-05, conservative 1.0341266352043021e-05
# Plot saved to loss_plots\dataset_5\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 3.70 seconds.
# Done training the normal network!
# The network training took 7.44 seconds.
# Done training the conservative network!
# The minimum loss was 3.7993329897290096e-05, conservative 4.4565488792613906e-07
# The minimum test loss was 3.371474376763217e-05, conservative 5.340004975096235e-07
# Plot saved to loss_plots\dataset_5\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 3.88 seconds.
# Done training the normal network!
# The network training took 7.01 seconds.
# Done training the conservative network!
# The minimum loss was 4.0169178464566355e-05, conservative 3.3243664233850724e-06
# The minimum test loss was 4.3820039718411866e-05, conservative 3.4976757433469174e-06
# Plot saved to loss_plots\dataset_5\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 3.40 seconds.
# Done training the normal network!
# The network training took 6.83 seconds.
# Done training the conservative network!
# The minimum loss was 1.200931519633741e-05, conservative 3.439841975705349e-07
# The minimum test loss was 1.1495776470837882e-05, conservative 3.722994051713613e-07
# Plot saved to loss_plots\dataset_5\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 3.49 seconds.
# Done training the normal network!
# The network training took 8.26 seconds.
# Done training the conservative network!
# The minimum loss was 1.0734709212556481e-05, conservative 7.76754332036944e-06
# The minimum test loss was 1.092752304430178e-05, conservative 8.033574908949959e-06
# Plot saved to loss_plots\dataset_5\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 3.47 seconds.
# Done training the normal network!
# The network training took 6.86 seconds.
# Done training the conservative network!
# The minimum loss was 3.664402829599567e-05, conservative 3.2120937612489796e-05
# The minimum test loss was 3.675855805340689e-05, conservative 3.055504421354271e-05
# Plot saved to loss_plots\dataset_5\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 3.60 seconds.
# Done training the normal network!
# The network training took 7.85 seconds.
# Done training the conservative network!
# The minimum loss was 5.3446860692929474e-05, conservative 3.6233075661584735e-05
# The minimum test loss was 5.6127165589714426e-05, conservative 3.8269231117737947e-05
# Plot saved to loss_plots\dataset_5\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 3.39 seconds.
# Done training the normal network!
# The network training took 7.32 seconds.
# Done training the conservative network!
# The minimum loss was 4.137204614380607e-05, conservative 1.7744362867233577e-05
# The minimum test loss was 4.5441626934916715e-05, conservative 1.806530817702878e-05
# Plot saved to loss_plots\dataset_5\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\8D_losses.txt
# Processing folder: dataset_6
# Loaded preprocessed data for dimension 10
# The network training took 3.68 seconds.
# Done training the normal network!
# The network training took 7.49 seconds.
# Done training the conservative network!
# The minimum loss was 6.703195977024734e-05, conservative 1.4837504659226397e-05
# The minimum test loss was 6.712675676681101e-05, conservative 1.484819158577011e-05
# Plot saved to loss_plots\dataset_6\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 3.57 seconds.
# Done training the normal network!
# The network training took 6.96 seconds.
# Done training the conservative network!
# The minimum loss was 1.5655106653866824e-05, conservative 5.248385605227668e-06
# The minimum test loss was 1.7213493629242292e-05, conservative 5.301195506035583e-06
# Plot saved to loss_plots\dataset_6\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 3.87 seconds.
# Done training the normal network!
# The network training took 7.96 seconds.
# Done training the conservative network!
# The minimum loss was 5.7314826699439435e-05, conservative 8.622351316489585e-07
# The minimum test loss was 5.435766361188144e-05, conservative 8.913358044537745e-07
# Plot saved to loss_plots\dataset_6\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 3.33 seconds.
# Done training the normal network!
# The network training took 7.02 seconds.
# Done training the conservative network!
# The minimum loss was 4.966949436493451e-05, conservative 3.230629272366059e-06
# The minimum test loss was 5.4135225946083664e-05, conservative 3.3316438020847273e-06
# Plot saved to loss_plots\dataset_6\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 3.74 seconds.
# Done training the normal network!
# The network training took 6.94 seconds.
# Done training the conservative network!
# The minimum loss was 6.788273894926533e-05, conservative 3.604241555876797e-06
# The minimum test loss was 7.611306391481776e-05, conservative 3.890327820954553e-06
# Plot saved to loss_plots\dataset_6\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 3.35 seconds.
# Done training the normal network!
# The network training took 6.79 seconds.
# Done training the conservative network!
# The minimum loss was 2.0797642355319114e-05, conservative 3.680757924939826e-06
# The minimum test loss was 2.1219501832092647e-05, conservative 3.7788488270962262e-06
# Plot saved to loss_plots\dataset_6\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 3.67 seconds.
# Done training the normal network!
# The network training took 7.08 seconds.
# Done training the conservative network!
# The minimum loss was 5.285430306685157e-05, conservative 6.521654686366673e-05
# The minimum test loss was 5.369921382225584e-05, conservative 6.492183420050423e-05
# Plot saved to loss_plots\dataset_6\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 3.27 seconds.
# Done training the normal network!
# The network training took 6.98 seconds.
# Done training the conservative network!
# The minimum loss was 5.9716036776080725e-05, conservative 2.923548836406553e-05
# The minimum test loss was 6.104070198489353e-05, conservative 2.8005396416119765e-05
# Plot saved to loss_plots\dataset_6\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 4.50 seconds.
# Done training the normal network!
# The network training took 8.31 seconds.
# Done training the conservative network!
# The minimum loss was 8.145699466695077e-05, conservative 1.715583302939194e-05
# The minimum test loss was 8.456678042421118e-05, conservative 1.6743225751270073e-05
# Plot saved to loss_plots\dataset_6\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\8D_losses.txt
# Processing folder: dataset_7
# Loaded preprocessed data for dimension 10
# The network training took 3.39 seconds.
# Done training the normal network!
# The network training took 6.80 seconds.
# Done training the conservative network!
# The minimum loss was 1.7067548833438194e-05, conservative 6.899642630742164e-06
# The minimum test loss was 1.897652600746369e-05, conservative 7.0587850132142195e-06
# Plot saved to loss_plots\dataset_7\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 3.54 seconds.
# Done training the normal network!
# The network training took 7.04 seconds.
# Done training the conservative network!
# The minimum loss was 1.636025044717826e-05, conservative 4.293457209314511e-06
# The minimum test loss was 2.0295241847634314e-05, conservative 4.862027412855241e-06
# Plot saved to loss_plots\dataset_7\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 3.20 seconds.
# Done training the normal network!
# The network training took 6.93 seconds.
# Done training the conservative network!
# The minimum loss was 2.714416077651549e-05, conservative 8.185307660824036e-06
# The minimum test loss was 3.191137202520622e-05, conservative 1.0615078826958779e-05
# Plot saved to loss_plots\dataset_7\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 3.41 seconds.
# Done training the normal network!
# The network training took 6.64 seconds.
# Done training the conservative network!
# The minimum loss was 3.277842024544953e-05, conservative 2.772206460122106e-06
# The minimum test loss was 3.700822635437362e-05, conservative 3.5391298069953336e-06
# Plot saved to loss_plots\dataset_7\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 3.30 seconds.
# Done training the normal network!
# The network training took 6.63 seconds.
# Done training the conservative network!
# The minimum loss was 5.72801916860044e-05, conservative 6.754372975592559e-07
# The minimum test loss was 5.5277428691624665e-05, conservative 6.910697607054317e-07
# Plot saved to loss_plots\dataset_7\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 3.43 seconds.
# Done training the normal network!
# The network training took 7.29 seconds.
# Done training the conservative network!
# The minimum loss was 3.506910970827448e-05, conservative 3.5580250732891726e-05
# The minimum test loss was 3.6236574396752984e-05, conservative 3.699740354932146e-05
# Plot saved to loss_plots\dataset_7\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 3.28 seconds.
# Done training the normal network!
# The network training took 7.72 seconds.
# Done training the conservative network!
# The minimum loss was 1.4259357340051792e-05, conservative 2.928807971329661e-05
# The minimum test loss was 1.4217743137123762e-05, conservative 2.9184299819462467e-05
# Plot saved to loss_plots\dataset_7\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 3.24 seconds.
# Done training the normal network!
# The network training took 6.77 seconds.
# Done training the conservative network!
# The minimum loss was 1.2147768575232477e-05, conservative 1.4990671661507805e-05
# The minimum test loss was 1.2354957470961381e-05, conservative 1.5073228496476077e-05
# Plot saved to loss_plots\dataset_7\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 3.29 seconds.
# Done training the normal network!
# The network training took 8.81 seconds.
# Done training the conservative network!
# The minimum loss was 3.2722443756938445e-05, conservative 1.6580258397880242e-05
# The minimum test loss was 3.478146354609635e-05, conservative 1.6837949260661844e-05
# Plot saved to loss_plots\dataset_7\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\8D_losses.txt
# Processing folder: dataset_8
# Loaded preprocessed data for dimension 10
# The network training took 3.34 seconds.
# Done training the normal network!
# The network training took 7.02 seconds.
# Done training the conservative network!
# The minimum loss was 5.0952501260326245e-05, conservative 2.276201562381175e-05
# The minimum test loss was 5.590388864220586e-05, conservative 2.3273671740753343e-05
# Plot saved to loss_plots\dataset_8\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 3.33 seconds.
# Done training the normal network!
# The network training took 6.99 seconds.
# Done training the conservative network!
# The minimum loss was 3.85485418519238e-05, conservative 2.618686858113506e-06
# The minimum test loss was 4.3420596557552924e-05, conservative 2.738650562150724e-06
# Plot saved to loss_plots\dataset_8\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 3.42 seconds.
# Done training the normal network!
# The network training took 7.51 seconds.
# Done training the conservative network!
# The minimum loss was 2.4465028764097953e-05, conservative 9.708997640700546e-06
# The minimum test loss was 2.8613120230147614e-05, conservative 1.0432322778797242e-05
# Plot saved to loss_plots\dataset_8\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 3.79 seconds.
# Done training the normal network!
# The network training took 6.73 seconds.
# Done training the conservative network!
# The minimum loss was 4.838245004066266e-05, conservative 3.746286301975488e-06
# The minimum test loss was 5.232675193838077e-05, conservative 3.8108269563963402e-06
# Plot saved to loss_plots\dataset_8\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 3.21 seconds.
# Done training the normal network!
# The network training took 6.93 seconds.
# Done training the conservative network!
# The minimum loss was 8.072678465396166e-05, conservative 2.2121108145256585e-06
# The minimum test loss was 8.673913071106653e-05, conservative 2.395797662302357e-06
# Plot saved to loss_plots\dataset_8\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 3.28 seconds.
# Done training the normal network!
# The network training took 6.61 seconds.
# Done training the conservative network!
# The minimum loss was 5.444550643005641e-05, conservative 1.971707715711091e-05
# The minimum test loss was 5.383713723858818e-05, conservative 2.055539216598845e-05
# Plot saved to loss_plots\dataset_8\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 3.23 seconds.
# Done training the normal network!
# The network training took 6.52 seconds.
# Done training the conservative network!
# The minimum loss was 4.443165271368343e-05, conservative 3.15944565954851e-05
# The minimum test loss was 4.457828963495558e-05, conservative 3.189978324371623e-05
# Plot saved to loss_plots\dataset_8\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 3.40 seconds.
# Done training the normal network!
# The network training took 6.95 seconds.
# Done training the conservative network!
# The minimum loss was 5.93771485000616e-05, conservative 4.5168962606112474e-05
# The minimum test loss was 6.025163202139083e-05, conservative 4.468549414013978e-05
# Plot saved to loss_plots\dataset_8\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 3.30 seconds.
# Done training the normal network!
# The network training took 6.86 seconds.
# Done training the conservative network!
# The minimum loss was 4.880956148554105e-05, conservative 1.2962927257831325e-05
# The minimum test loss was 6.203717384778429e-05, conservative 1.515064791419718e-05
# Plot saved to loss_plots\dataset_8\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\8D_losses.txt
# Processing folder: dataset_9
# Loaded preprocessed data for dimension 10
# The network training took 3.52 seconds.
# Done training the normal network!
# The network training took 6.59 seconds.
# Done training the conservative network!
# The minimum loss was 7.697065520915203e-05, conservative 2.569860125731793e-05
# The minimum test loss was 8.893408012227156e-05, conservative 2.7880997549800668e-05
# Plot saved to loss_plots\dataset_9\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 3.70 seconds.
# Done training the normal network!
# The network training took 7.55 seconds.
# Done training the conservative network!
# The minimum loss was 5.929179278609809e-05, conservative 1.9403544183660414e-05
# The minimum test loss was 4.9343684440827926e-05, conservative 1.7256319188163617e-05
# Plot saved to loss_plots\dataset_9\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 3.58 seconds.
# Done training the normal network!
# The network training took 6.79 seconds.
# Done training the conservative network!
# The minimum loss was 5.61974840820767e-05, conservative 2.1503857169591357e-06
# The minimum test loss was 5.517221834452357e-05, conservative 1.8051466781798808e-06
# Plot saved to loss_plots\dataset_9\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 4.61 seconds.
# Done training the normal network!
# The network training took 8.65 seconds.
# Done training the conservative network!
# The minimum loss was 4.580186796374619e-05, conservative 2.1686032823708955e-06
# The minimum test loss was 5.126303603901761e-05, conservative 2.2756292310077695e-06
# Plot saved to loss_plots\dataset_9\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 3.63 seconds.
# Done training the normal network!
# The network training took 7.56 seconds.
# Done training the conservative network!
# The minimum loss was 6.326816946966574e-05, conservative 3.0146654580676114e-06
# The minimum test loss was 6.891523989907e-05, conservative 3.101924539805623e-06
# Plot saved to loss_plots\dataset_9\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 3.25 seconds.
# Done training the normal network!
# The network training took 6.42 seconds.
# Done training the conservative network!
# The minimum loss was 3.236105458199745e-05, conservative 2.026632701017661e-05
# The minimum test loss was 3.4249157579324674e-05, conservative 2.0925187072862172e-05
# Plot saved to loss_plots\dataset_9\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 3.24 seconds.
# Done training the normal network!
# The network training took 6.97 seconds.
# Done training the conservative network!
# The minimum loss was 4.45849585958058e-05, conservative 4.763618562719785e-05
# The minimum test loss was 4.499472888710443e-05, conservative 4.766438651131466e-05
# Plot saved to loss_plots\dataset_9\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 3.36 seconds.
# Done training the normal network!
# The network training took 7.80 seconds.
# Done training the conservative network!
# The minimum loss was 4.381525232020067e-05, conservative 1.8557170915300957e-05
# The minimum test loss was 4.4837085079052484e-05, conservative 1.8762277431960683e-05
# Plot saved to loss_plots\dataset_9\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 3.67 seconds.
# Done training the normal network!
# The network training took 6.89 seconds.
# Done training the conservative network!
# The minimum loss was 2.7218654395255726e-05, conservative 2.9997096862643958e-05
# The minimum test loss was 2.814697800204158e-05, conservative 2.965258518088376e-05
# Plot saved to loss_plots\dataset_9\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\8D_losses.txt
# Done!!!

# %% [markdown]
# # Organizing Data

# %%
# Folder containing the loss plots and text files
loss_folder = "loss_plots"

# Output folders for consolidated images and text files
output_image_folder = "consolidated_images"
output_text_folder = "consolidated_text_files"

# Create output folders if they don't exist
os.makedirs(output_image_folder, exist_ok=True)
os.makedirs(output_text_folder, exist_ok=True)

# Iterate through all subfolders in the loss_folder
for subfolder in os.listdir(loss_folder):
    subfolder_path = os.path.join(loss_folder, subfolder)
    
    # Check if it's a directory (e.g., dataset_1, dataset_2, etc.)
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")
        
        # Extract the dataset number (e.g., "1" from "dataset_1")
        dataset_number = subfolder.split("_")[-1]
        
        # Process images
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".png"):  # Process only .png files
                # Construct the new filename (e.g., 2D_Conservative_NN_1.png)
                new_filename = filename.replace(".png", f"_{dataset_number}.png")
                
                # Copy the image to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_image_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied image: {src_path} -> {dest_path}")
        
        # Process text files
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".txt"):  # Process only .txt files
                # Construct the new filename (e.g., 8D_losses_1.txt)
                new_filename = filename.replace(".txt", f"_{dataset_number}.txt")
                
                # Copy the text file to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_text_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied text file: {src_path} -> {dest_path}")

print("All files have been consolidated.")
# Out:
# Processing folder: dataset_1
# Processing folder: dataset_10
# Processing folder: dataset_2
# Processing folder: dataset_3
# Processing folder: dataset_4
# Processing folder: dataset_5
# Processing folder: dataset_6
# Processing folder: dataset_7
# Processing folder: dataset_8
# Processing folder: dataset_9
# All files have been consolidated.
