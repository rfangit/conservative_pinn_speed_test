# %% [markdown]
# # Imports

# %%
import torch
import sys
import numpy as np
import os
import shutil
from pathlib import Path
# Add parent directory to sys.path
parent_dir = Path.cwd().parent.parent
sys.path.append(str(parent_dir))
# Import modules
from train import train_test_multiple_networks, train_network_with_test_loss, train_grad_network_with_test_loss, save_plot_test_train

# %% [markdown]
# # Network Parameters

# %%
# Training hyperparameters
num_trials = 10
neurons = [128, 128, 128]
num_epochs = 200

# %% [markdown]
# # Running Experiments

# %%
# Folder containing datasets
dataset_folder = "datasets"

# Output folder for plots
output_folder = "loss_plots"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

for subfolder in os.listdir(dataset_folder):
    subfolder_path = os.path.join(dataset_folder, subfolder)
    
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")

        output_subfolder = os.path.join(output_folder, subfolder)
        os.makedirs(output_subfolder, exist_ok=True)
        
        train_folder = os.path.join(subfolder_path, "train")
        test_folder = os.path.join(subfolder_path, "test")
        
        for filename in os.listdir(train_folder):
            if filename.endswith("_train.txt"):
                base_name = filename.replace("_train.txt", "")
                
                # Load train data
                train_filepath = os.path.join(train_folder, filename)
                train_data = np.loadtxt(train_filepath)

                dimension = (int)(train_data.shape[1]/2)

                train_points = torch.tensor(train_data[:, :dimension], dtype=torch.float32)
                train_values = torch.tensor(train_data[:, dimension:], dtype=torch.float32)

                
                # Load test data
                test_filename = f"{base_name}_test.txt"
                test_filepath = os.path.join(test_folder, test_filename)
                test_data = np.loadtxt(test_filepath)
                test_points = torch.tensor(test_data[:, :dimension], dtype=torch.float32)
                test_values = torch.tensor(test_data[:, dimension:], dtype=torch.float32)
                
                print(f"Loaded preprocessed data for dimension {dimension}")
                
                # Train the normal network
                mean_loss, variance_loss, mean_test_loss, variance_test_loss = train_test_multiple_networks(
                    train_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the normal network!")
        
                # Train the conservative network
                mean_loss_grad, variance_loss_grad, mean_test_loss_grad, variance_test_loss_grad = train_test_multiple_networks(
                    train_grad_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the conservative network!")

                # Calculate standard deviations for the normal network
                std_loss = np.sqrt(variance_loss)
                std_test_loss = np.sqrt(variance_test_loss)
                std_loss_grad = np.sqrt(variance_loss_grad)
                std_test_loss_grad = np.sqrt(variance_test_loss_grad)
        
                # Print the minimum loss
                print(f"The minimum loss was {mean_loss[-1]}, conservative {mean_loss_grad[-1]}")
                print(f"The minimum test loss was {mean_test_loss[-1]}, conservative {mean_test_loss_grad[-1]}")
                # Comparison Plot
                epochs = np.arange(num_epochs)
                save_plot_test_train(epochs, mean_loss, std_loss, mean_loss_grad, std_loss_grad,
                      mean_test_loss, std_test_loss, mean_test_loss_grad, std_test_loss_grad,
                      dimension, neurons, num_epochs, output_subfolder)

                # Save the losses to .txt files
                losses_filename = os.path.join(output_subfolder, f"{dimension}D_losses.txt")
                np.savetxt(
                    losses_filename,
                    np.column_stack((
                        epochs,
                        mean_loss, std_loss,  # Training loss and std for normal network
                        mean_test_loss, std_test_loss,  # Test loss and std for normal network
                        mean_loss_grad, std_loss_grad,  # Training loss and std for conservative network
                        mean_test_loss_grad, std_test_loss_grad  # Test loss and std for conservative network
                    )),
                    fmt='%.6f',
                    header='epochs mean_loss std_loss mean_test_loss std_test_loss mean_loss_grad std_loss_grad mean_test_loss_grad std_test_loss_grad'
                )
                print(f"Losses saved to {losses_filename}")
        
print ("Done!!!")
# Out:
# Using device: cuda
# Processing folder: dataset_1
# Loaded preprocessed data for dimension 10
# The network training took 10.82 seconds.
# Done training the normal network!
# The network training took 12.60 seconds.
# Done training the conservative network!
# The minimum loss was 0.0005302669771481306, conservative 0.000478734981152229
# The minimum test loss was 0.0006445807346608489, conservative 0.0005248952569672838
# Plot saved to loss_plots\dataset_1\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 7.08 seconds.
# Done training the normal network!
# The network training took 12.74 seconds.
# Done training the conservative network!
# The minimum loss was 0.00025754827802302314, conservative 0.00031514347210759297
# The minimum test loss was 0.00030275648459792136, conservative 0.0003322201984701678
# Plot saved to loss_plots\dataset_1\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.60 seconds.
# Done training the normal network!
# The network training took 13.23 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001216246782860253, conservative 8.860821471898817e-05
# The minimum test loss was 0.00014220103184925392, conservative 9.532469339319505e-05
# Plot saved to loss_plots\dataset_1\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.49 seconds.
# Done training the normal network!
# The network training took 13.53 seconds.
# Done training the conservative network!
# The minimum loss was 7.343521210714243e-05, conservative 6.075073943065945e-05
# The minimum test loss was 8.75532379723154e-05, conservative 6.559345420100726e-05
# Plot saved to loss_plots\dataset_1\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.62 seconds.
# Done training the normal network!
# The network training took 12.67 seconds.
# Done training the conservative network!
# The minimum loss was 4.8770991998026145e-05, conservative 3.704145365190925e-05
# The minimum test loss was 5.1826806884491813e-05, conservative 3.640231370809488e-05
# Plot saved to loss_plots\dataset_1\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.50 seconds.
# Done training the normal network!
# The network training took 13.03 seconds.
# Done training the conservative network!
# The minimum loss was 0.0011182429559994489, conservative 0.0008645492314826697
# The minimum test loss was 0.001108680834295228, conservative 0.0008590356126660481
# Plot saved to loss_plots\dataset_1\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.65 seconds.
# Done training the normal network!
# The network training took 12.52 seconds.
# Done training the conservative network!
# The minimum loss was 0.0005293154768878594, conservative 0.0006912359909620136
# The minimum test loss was 0.0005468496412504465, conservative 0.0006766421545762568
# Plot saved to loss_plots\dataset_1\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.50 seconds.
# Done training the normal network!
# The network training took 13.06 seconds.
# Done training the conservative network!
# The minimum loss was 0.0012902202783152462, conservative 0.00047421383205801246
# The minimum test loss was 0.0013239045510999858, conservative 0.00047626567247789354
# Plot saved to loss_plots\dataset_1\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.56 seconds.
# Done training the normal network!
# The network training took 12.79 seconds.
# Done training the conservative network!
# The minimum loss was 0.0007533403928391636, conservative 0.0005885575170395896
# The minimum test loss was 0.000782461476046592, conservative 0.00057829886500258
# Plot saved to loss_plots\dataset_1\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\8D_losses.txt
# Processing folder: dataset_10
# Loaded preprocessed data for dimension 10
# The network training took 6.71 seconds.
# Done training the normal network!
# The network training took 12.50 seconds.
# Done training the conservative network!
# The minimum loss was 0.00044707142224069684, conservative 0.0005009085783967748
# The minimum test loss was 0.0004938418453093619, conservative 0.0005009872867958621
# Plot saved to loss_plots\dataset_10\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.42 seconds.
# Done training the normal network!
# The network training took 12.34 seconds.
# Done training the conservative network!
# The minimum loss was 0.00031104166992008687, conservative 0.0002443730700179003
# The minimum test loss was 0.00034752550709526986, conservative 0.0002523794610169716
# Plot saved to loss_plots\dataset_10\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.47 seconds.
# Done training the normal network!
# The network training took 12.46 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001277544695767574, conservative 7.304004320758395e-05
# The minimum test loss was 0.00014312458952190355, conservative 7.492303775507026e-05
# Plot saved to loss_plots\dataset_10\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.58 seconds.
# Done training the normal network!
# The network training took 12.30 seconds.
# Done training the conservative network!
# The minimum loss was 9.1537775733741e-05, conservative 9.06616282009054e-05
# The minimum test loss was 9.882044105324894e-05, conservative 8.673429438204039e-05
# Plot saved to loss_plots\dataset_10\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.18 seconds.
# Done training the normal network!
# The network training took 13.29 seconds.
# Done training the conservative network!
# The minimum loss was 4.3643598837661556e-05, conservative 5.217049110797234e-05
# The minimum test loss was 4.925022694806103e-05, conservative 5.333068547770381e-05
# Plot saved to loss_plots\dataset_10\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.58 seconds.
# Done training the normal network!
# The network training took 12.28 seconds.
# Done training the conservative network!
# The minimum loss was 0.0011932859546504916, conservative 0.0003356968212756328
# The minimum test loss was 0.001264488563174382, conservative 0.0003589340834878385
# Plot saved to loss_plots\dataset_10\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.30 seconds.
# Done training the normal network!
# The network training took 12.21 seconds.
# Done training the conservative network!
# The minimum loss was 0.0013012297567911446, conservative 0.0009848615241935476
# The minimum test loss was 0.0012699810089543463, conservative 0.0009790358017198741
# Plot saved to loss_plots\dataset_10\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.37 seconds.
# Done training the normal network!
# The network training took 12.61 seconds.
# Done training the conservative network!
# The minimum loss was 0.0015111460932530462, conservative 0.0006928011134732515
# The minimum test loss was 0.0015074356109835208, conservative 0.0006909235671628267
# Plot saved to loss_plots\dataset_10\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.45 seconds.
# Done training the normal network!
# The network training took 12.22 seconds.
# Done training the conservative network!
# The minimum loss was 0.001359113142825663, conservative 0.0007313692214665935
# The minimum test loss was 0.001505736412946135, conservative 0.0007602754572872073
# Plot saved to loss_plots\dataset_10\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\8D_losses.txt
# Processing folder: dataset_2
# Loaded preprocessed data for dimension 10
# The network training took 6.60 seconds.
# Done training the normal network!
# The network training took 12.63 seconds.
# Done training the conservative network!
# The minimum loss was 0.00069593740045093, conservative 0.0005268677952699364
# The minimum test loss was 0.0007984573603607714, conservative 0.0005489196977578103
# Plot saved to loss_plots\dataset_2\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.38 seconds.
# Done training the normal network!
# The network training took 12.42 seconds.
# Done training the conservative network!
# The minimum loss was 0.0002846668707206845, conservative 0.00034550521813798697
# The minimum test loss was 0.0003138189698802307, conservative 0.0003486799687379971
# Plot saved to loss_plots\dataset_2\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.52 seconds.
# Done training the normal network!
# The network training took 12.56 seconds.
# Done training the conservative network!
# The minimum loss was 0.00012285934717510828, conservative 0.00010694400989450515
# The minimum test loss was 0.00013772973470622675, conservative 0.00010996983546647243
# Plot saved to loss_plots\dataset_2\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.58 seconds.
# Done training the normal network!
# The network training took 12.26 seconds.
# Done training the conservative network!
# The minimum loss was 8.223707918659784e-05, conservative 6.251960257941391e-05
# The minimum test loss was 9.239310456905514e-05, conservative 6.365283406921663e-05
# Plot saved to loss_plots\dataset_2\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.41 seconds.
# Done training the normal network!
# The network training took 12.42 seconds.
# Done training the conservative network!
# The minimum loss was 4.1754445555852725e-05, conservative 5.625944286293816e-05
# The minimum test loss was 4.679821395257022e-05, conservative 5.670895097864559e-05
# Plot saved to loss_plots\dataset_2\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.68 seconds.
# Done training the normal network!
# The network training took 12.77 seconds.
# Done training the conservative network!
# The minimum loss was 0.0012011522630928084, conservative 0.00041254661628045144
# The minimum test loss was 0.0012380771455354988, conservative 0.000410373140766751
# Plot saved to loss_plots\dataset_2\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 7.41 seconds.
# Done training the normal network!
# The network training took 13.17 seconds.
# Done training the conservative network!
# The minimum loss was 0.0011291410715784877, conservative 0.0006199602328706532
# The minimum test loss was 0.0011077074042987079, conservative 0.0006257493980228901
# Plot saved to loss_plots\dataset_2\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.87 seconds.
# Done training the normal network!
# The network training took 12.82 seconds.
# Done training the conservative network!
# The minimum loss was 0.0015413579414598644, conservative 0.0008788694336544723
# The minimum test loss was 0.0015683321049436926, conservative 0.000862022940418683
# Plot saved to loss_plots\dataset_2\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.38 seconds.
# Done training the normal network!
# The network training took 12.54 seconds.
# Done training the conservative network!
# The minimum loss was 0.0007576407224405557, conservative 0.0005574650800554082
# The minimum test loss was 0.0008142982667777687, conservative 0.0005569397239014506
# Plot saved to loss_plots\dataset_2\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\8D_losses.txt
# Processing folder: dataset_3
# Loaded preprocessed data for dimension 10
# The network training took 6.35 seconds.
# Done training the normal network!
# The network training took 12.39 seconds.
# Done training the conservative network!
# The minimum loss was 0.0005952326115220785, conservative 0.0008554201514925808
# The minimum test loss was 0.0007303765509277582, conservative 0.0009423625655472278
# Plot saved to loss_plots\dataset_3\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.36 seconds.
# Done training the normal network!
# The network training took 12.40 seconds.
# Done training the conservative network!
# The minimum loss was 0.00031656397914048284, conservative 0.00023970343900145963
# The minimum test loss was 0.00035613893705885855, conservative 0.000241346174152568
# Plot saved to loss_plots\dataset_3\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.37 seconds.
# Done training the normal network!
# The network training took 12.45 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001842236117227003, conservative 0.00012061432498740032
# The minimum test loss was 0.00021361767867347225, conservative 0.00012880980357294903
# Plot saved to loss_plots\dataset_3\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.61 seconds.
# Done training the normal network!
# The network training took 12.55 seconds.
# Done training the conservative network!
# The minimum loss was 4.663763502321672e-05, conservative 4.076466448168503e-05
# The minimum test loss was 4.716235671367031e-05, conservative 3.756613023142563e-05
# Plot saved to loss_plots\dataset_3\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.44 seconds.
# Done training the normal network!
# The network training took 12.79 seconds.
# Done training the conservative network!
# The minimum loss was 4.698916236520745e-05, conservative 7.786360874888487e-05
# The minimum test loss was 5.6214765936601904e-05, conservative 8.110891430987977e-05
# Plot saved to loss_plots\dataset_3\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.54 seconds.
# Done training the normal network!
# The network training took 13.06 seconds.
# Done training the conservative network!
# The minimum loss was 0.000663179811090231, conservative 0.0002743080025538802
# The minimum test loss was 0.0006708468863507733, conservative 0.0002668063127202913
# Plot saved to loss_plots\dataset_3\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.44 seconds.
# Done training the normal network!
# The network training took 12.31 seconds.
# Done training the conservative network!
# The minimum loss was 0.0018518838798627258, conservative 0.0005996388819767163
# The minimum test loss was 0.0018610737170092762, conservative 0.0005982263886835426
# Plot saved to loss_plots\dataset_3\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.73 seconds.
# Done training the normal network!
# The network training took 12.52 seconds.
# Done training the conservative network!
# The minimum loss was 0.002330773894209415, conservative 0.0012608143675606697
# The minimum test loss was 0.0023120860452763735, conservative 0.0012387580471113324
# Plot saved to loss_plots\dataset_3\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.27 seconds.
# Done training the normal network!
# The network training took 12.42 seconds.
# Done training the conservative network!
# The minimum loss was 0.00074729158077389, conservative 0.0008397455618251115
# The minimum test loss was 0.0008132596267387271, conservative 0.0008752943074796348
# Plot saved to loss_plots\dataset_3\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\8D_losses.txt
# Processing folder: dataset_4
# Loaded preprocessed data for dimension 10
# The network training took 6.26 seconds.
# Done training the normal network!
# The network training took 12.49 seconds.
# Done training the conservative network!
# The minimum loss was 0.0004300384811358526, conservative 0.00047239052364602687
# The minimum test loss was 0.0004809853882761672, conservative 0.0004848175216466188
# Plot saved to loss_plots\dataset_4\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.47 seconds.
# Done training the normal network!
# The network training took 12.53 seconds.
# Done training the conservative network!
# The minimum loss was 0.00036216630251146854, conservative 0.00028309373738011345
# The minimum test loss was 0.00040213748579844835, conservative 0.0003032590931979939
# Plot saved to loss_plots\dataset_4\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.55 seconds.
# Done training the normal network!
# The network training took 12.85 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001324411430687178, conservative 0.0001340048824204132
# The minimum test loss was 0.0001390427270962391, conservative 0.0001281328179175034
# Plot saved to loss_plots\dataset_4\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.53 seconds.
# Done training the normal network!
# The network training took 12.44 seconds.
# Done training the conservative network!
# The minimum loss was 0.000105747642373899, conservative 0.00014230021115508863
# The minimum test loss was 0.0001205755710543599, conservative 0.00014586816905648448
# Plot saved to loss_plots\dataset_4\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.40 seconds.
# Done training the normal network!
# The network training took 12.85 seconds.
# Done training the conservative network!
# The minimum loss was 5.699643188563641e-05, conservative 6.153132380859461e-05
# The minimum test loss was 6.731451212544925e-05, conservative 6.523528754769359e-05
# Plot saved to loss_plots\dataset_4\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.40 seconds.
# Done training the normal network!
# The network training took 12.37 seconds.
# Done training the conservative network!
# The minimum loss was 0.0010513396933674811, conservative 0.00034103176149073987
# The minimum test loss was 0.0011258525715675204, conservative 0.0003745354057173245
# Plot saved to loss_plots\dataset_4\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.61 seconds.
# Done training the normal network!
# The network training took 12.56 seconds.
# Done training the conservative network!
# The minimum loss was 0.00131158092408441, conservative 0.0009648431820096448
# The minimum test loss was 0.0012827391445171088, conservative 0.0009536959376418963
# Plot saved to loss_plots\dataset_4\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.25 seconds.
# Done training the normal network!
# The network training took 12.41 seconds.
# Done training the conservative network!
# The minimum loss was 0.0016300571500323714, conservative 0.0006701216829242185
# The minimum test loss was 0.0015430824598297477, conservative 0.0006627449882216751
# Plot saved to loss_plots\dataset_4\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.48 seconds.
# Done training the normal network!
# The network training took 12.89 seconds.
# Done training the conservative network!
# The minimum loss was 0.0010291046346537769, conservative 0.0007759184401948005
# The minimum test loss was 0.0010635309969075023, conservative 0.0007527351030148566
# Plot saved to loss_plots\dataset_4\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\8D_losses.txt
# Processing folder: dataset_5
# Loaded preprocessed data for dimension 10
# The network training took 6.31 seconds.
# Done training the normal network!
# The network training took 12.32 seconds.
# Done training the conservative network!
# The minimum loss was 0.0004914128832751885, conservative 0.00044320564484223723
# The minimum test loss was 0.0005727590003516525, conservative 0.00048448987654410304
# Plot saved to loss_plots\dataset_5\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.31 seconds.
# Done training the normal network!
# The network training took 12.23 seconds.
# Done training the conservative network!
# The minimum loss was 0.00025990606809500605, conservative 0.0002543480979511514
# The minimum test loss was 0.00030621037585660816, conservative 0.0002814706793287769
# Plot saved to loss_plots\dataset_5\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.64 seconds.
# Done training the normal network!
# The network training took 12.54 seconds.
# Done training the conservative network!
# The minimum loss was 0.00015152191772358493, conservative 0.0001686589646851644
# The minimum test loss was 0.00017037944344338029, conservative 0.00017244432383449747
# Plot saved to loss_plots\dataset_5\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.47 seconds.
# Done training the normal network!
# The network training took 12.56 seconds.
# Done training the conservative network!
# The minimum loss was 6.158356663945596e-05, conservative 6.619665000471287e-05
# The minimum test loss was 7.304829414351843e-05, conservative 7.144129594962578e-05
# Plot saved to loss_plots\dataset_5\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.37 seconds.
# Done training the normal network!
# The network training took 12.38 seconds.
# Done training the conservative network!
# The minimum loss was 5.083909927634522e-05, conservative 2.4397974084422457e-05
# The minimum test loss was 5.279138822515961e-05, conservative 2.3828154007787815e-05
# Plot saved to loss_plots\dataset_5\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.33 seconds.
# Done training the normal network!
# The network training took 12.69 seconds.
# Done training the conservative network!
# The minimum loss was 0.0012056445586495102, conservative 0.00070741934760008
# The minimum test loss was 0.001306161773391068, conservative 0.0007531942479545251
# Plot saved to loss_plots\dataset_5\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.56 seconds.
# Done training the normal network!
# The network training took 12.48 seconds.
# Done training the conservative network!
# The minimum loss was 0.0011328994005452842, conservative 0.0003318761519039981
# The minimum test loss was 0.0011519633291754872, conservative 0.0003294230889878236
# Plot saved to loss_plots\dataset_5\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.31 seconds.
# Done training the normal network!
# The network training took 12.27 seconds.
# Done training the conservative network!
# The minimum loss was 0.0026410956401377917, conservative 0.0006383765576174483
# The minimum test loss was 0.002735161874443293, conservative 0.0006452459580032155
# Plot saved to loss_plots\dataset_5\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.31 seconds.
# Done training the normal network!
# The network training took 12.27 seconds.
# Done training the conservative network!
# The minimum loss was 0.0010082326713018118, conservative 0.0011811660253442824
# The minimum test loss was 0.0010506548802368342, conservative 0.0011651569395326078
# Plot saved to loss_plots\dataset_5\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\8D_losses.txt
# Processing folder: dataset_6
# Loaded preprocessed data for dimension 10
# The network training took 6.23 seconds.
# Done training the normal network!
# The network training took 12.32 seconds.
# Done training the conservative network!
# The minimum loss was 0.000534568983130157, conservative 0.00042237551242578774
# The minimum test loss was 0.000645261286990717, conservative 0.0004913000972010195
# Plot saved to loss_plots\dataset_6\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.49 seconds.
# Done training the normal network!
# The network training took 12.34 seconds.
# Done training the conservative network!
# The minimum loss was 0.00029437354241963477, conservative 0.0002998229436343536
# The minimum test loss was 0.00032888753339648246, conservative 0.0003027856233529747
# Plot saved to loss_plots\dataset_6\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.37 seconds.
# Done training the normal network!
# The network training took 12.75 seconds.
# Done training the conservative network!
# The minimum loss was 0.00015241801738739014, conservative 0.00012314102277741768
# The minimum test loss was 0.00019173920736648142, conservative 0.0001412390047335066
# Plot saved to loss_plots\dataset_6\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 7.14 seconds.
# Done training the normal network!
# The network training took 12.32 seconds.
# Done training the conservative network!
# The minimum loss was 7.478293191525154e-05, conservative 7.133774452086072e-05
# The minimum test loss was 8.530217746738344e-05, conservative 7.461066270479933e-05
# Plot saved to loss_plots\dataset_6\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.35 seconds.
# Done training the normal network!
# The network training took 12.34 seconds.
# Done training the conservative network!
# The minimum loss was 4.8862128460314123e-05, conservative 5.289935033943038e-05
# The minimum test loss was 5.607234088529367e-05, conservative 5.4423540495918134e-05
# Plot saved to loss_plots\dataset_6\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.62 seconds.
# Done training the normal network!
# The network training took 12.26 seconds.
# Done training the conservative network!
# The minimum loss was 0.0011583108571358025, conservative 0.00024872212525224314
# The minimum test loss was 0.001123810012359172, conservative 0.0002509759258828126
# Plot saved to loss_plots\dataset_6\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.49 seconds.
# Done training the normal network!
# The network training took 12.22 seconds.
# Done training the conservative network!
# The minimum loss was 0.001287693448830396, conservative 0.0005587623483734206
# The minimum test loss was 0.0013081112527288496, conservative 0.0005695506901247427
# Plot saved to loss_plots\dataset_6\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.22 seconds.
# Done training the normal network!
# The network training took 12.18 seconds.
# Done training the conservative network!
# The minimum loss was 0.0022381234681233763, conservative 0.0011402107542380691
# The minimum test loss was 0.002235017216298729, conservative 0.0011233132448978723
# Plot saved to loss_plots\dataset_6\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.18 seconds.
# Done training the normal network!
# The network training took 12.19 seconds.
# Done training the conservative network!
# The minimum loss was 0.0011342272744514048, conservative 0.0007203597982879728
# The minimum test loss was 0.0012284558149985969, conservative 0.0007358654111158103
# Plot saved to loss_plots\dataset_6\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\8D_losses.txt
# Processing folder: dataset_7
# Loaded preprocessed data for dimension 10
# The network training took 6.32 seconds.
# Done training the normal network!
# The network training took 12.53 seconds.
# Done training the conservative network!
# The minimum loss was 0.00047578599187545476, conservative 0.00046422748710028827
# The minimum test loss was 0.0005216133082285524, conservative 0.0004648212343454361
# Plot saved to loss_plots\dataset_7\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.19 seconds.
# Done training the normal network!
# The network training took 11.96 seconds.
# Done training the conservative network!
# The minimum loss was 0.00025544569798512383, conservative 0.0002890005271183327
# The minimum test loss was 0.00029834074375685305, conservative 0.0003019275041879155
# Plot saved to loss_plots\dataset_7\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.25 seconds.
# Done training the normal network!
# The network training took 12.20 seconds.
# Done training the conservative network!
# The minimum loss was 0.00014809461135882883, conservative 0.00017517297528684138
# The minimum test loss was 0.00016473464638693257, conservative 0.000175022536132019
# Plot saved to loss_plots\dataset_7\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.40 seconds.
# Done training the normal network!
# The network training took 12.14 seconds.
# Done training the conservative network!
# The minimum loss was 5.674135245499201e-05, conservative 8.033006779442075e-05
# The minimum test loss was 6.336894912237768e-05, conservative 8.102312276605516e-05
# Plot saved to loss_plots\dataset_7\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.35 seconds.
# Done training the normal network!
# The network training took 12.67 seconds.
# Done training the conservative network!
# The minimum loss was 6.437702031689697e-05, conservative 7.195827638497576e-05
# The minimum test loss was 7.475392776541412e-05, conservative 7.451558776665479e-05
# Plot saved to loss_plots\dataset_7\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.53 seconds.
# Done training the normal network!
# The network training took 12.62 seconds.
# Done training the conservative network!
# The minimum loss was 0.0011994943721219896, conservative 0.0006904348760144785
# The minimum test loss was 0.0012749108369462191, conservative 0.0007195341488113627
# Plot saved to loss_plots\dataset_7\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.63 seconds.
# Done training the normal network!
# The network training took 12.91 seconds.
# Done training the conservative network!
# The minimum loss was 0.0014298235299065709, conservative 0.0008989521185867489
# The minimum test loss was 0.001425831054802984, conservative 0.0008944676315877587
# Plot saved to loss_plots\dataset_7\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.54 seconds.
# Done training the normal network!
# The network training took 12.54 seconds.
# Done training the conservative network!
# The minimum loss was 0.0018035705201327802, conservative 0.000581244079512544
# The minimum test loss was 0.0018497126060537995, conservative 0.0005765626236097887
# Plot saved to loss_plots\dataset_7\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.43 seconds.
# Done training the normal network!
# The network training took 12.45 seconds.
# Done training the conservative network!
# The minimum loss was 0.0007763077737763524, conservative 0.000813205391750671
# The minimum test loss was 0.0008374066208489239, conservative 0.0008523630356648936
# Plot saved to loss_plots\dataset_7\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\8D_losses.txt
# Processing folder: dataset_8
# Loaded preprocessed data for dimension 10
# The network training took 6.72 seconds.
# Done training the normal network!
# The network training took 12.39 seconds.
# Done training the conservative network!
# The minimum loss was 0.0005854107323102653, conservative 0.0005528638313990087
# The minimum test loss was 0.0006350304058287293, conservative 0.0005495936842635274
# Plot saved to loss_plots\dataset_8\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.50 seconds.
# Done training the normal network!
# The network training took 12.55 seconds.
# Done training the conservative network!
# The minimum loss was 0.0003248074848670512, conservative 0.0002833526465110481
# The minimum test loss was 0.00037702507397625596, conservative 0.00030030585621716456
# Plot saved to loss_plots\dataset_8\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.67 seconds.
# Done training the normal network!
# The network training took 12.73 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001645702650421299, conservative 0.00016430314717581497
# The minimum test loss was 0.00019543667876860128, conservative 0.00017534020735183732
# Plot saved to loss_plots\dataset_8\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.46 seconds.
# Done training the normal network!
# The network training took 13.08 seconds.
# Done training the conservative network!
# The minimum loss was 8.451247631455772e-05, conservative 0.00011989513295702636
# The minimum test loss was 9.699031361378729e-05, conservative 0.00012229771600686946
# Plot saved to loss_plots\dataset_8\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.53 seconds.
# Done training the normal network!
# The network training took 12.66 seconds.
# Done training the conservative network!
# The minimum loss was 6.027746603649575e-05, conservative 7.143907278077677e-05
# The minimum test loss was 6.919441002537497e-05, conservative 7.439104592776857e-05
# Plot saved to loss_plots\dataset_8\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.57 seconds.
# Done training the normal network!
# The network training took 12.60 seconds.
# Done training the conservative network!
# The minimum loss was 0.0012451878341380508, conservative 0.0005933156498940662
# The minimum test loss was 0.0012235559057444333, conservative 0.0005801502557005733
# Plot saved to loss_plots\dataset_8\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.69 seconds.
# Done training the normal network!
# The network training took 12.76 seconds.
# Done training the conservative network!
# The minimum loss was 0.00110897280392237, conservative 0.0011445086100138723
# The minimum test loss was 0.001153078250354156, conservative 0.001147587812738493
# Plot saved to loss_plots\dataset_8\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.45 seconds.
# Done training the normal network!
# The network training took 12.44 seconds.
# Done training the conservative network!
# The minimum loss was 0.0018278022995218634, conservative 0.0006173849396873266
# The minimum test loss was 0.001860222197137773, conservative 0.0006194515473907814
# Plot saved to loss_plots\dataset_8\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.34 seconds.
# Done training the normal network!
# The network training took 12.97 seconds.
# Done training the conservative network!
# The minimum loss was 0.0009547448891680688, conservative 0.0010010578262154013
# The minimum test loss was 0.0010439165751449763, conservative 0.0010157896555028855
# Plot saved to loss_plots\dataset_8\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\8D_losses.txt
# Processing folder: dataset_9
# Loaded preprocessed data for dimension 10
# The network training took 6.44 seconds.
# Done training the normal network!
# The network training took 12.65 seconds.
# Done training the conservative network!
# The minimum loss was 0.0006913662829902024, conservative 0.000658381445100531
# The minimum test loss was 0.0006642902269959449, conservative 0.0005873431131476536
# Plot saved to loss_plots\dataset_9\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.51 seconds.
# Done training the normal network!
# The network training took 12.72 seconds.
# Done training the conservative network!
# The minimum loss was 0.0002898489969084039, conservative 0.00034832782694138587
# The minimum test loss was 0.0003054908389458433, conservative 0.00033133705728687345
# Plot saved to loss_plots\dataset_9\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.64 seconds.
# Done training the normal network!
# The network training took 12.56 seconds.
# Done training the conservative network!
# The minimum loss was 9.968912563635967e-05, conservative 8.028239753912202e-05
# The minimum test loss was 0.0001065552824002225, conservative 7.934137174743227e-05
# Plot saved to loss_plots\dataset_9\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.58 seconds.
# Done training the normal network!
# The network training took 12.63 seconds.
# Done training the conservative network!
# The minimum loss was 8.495547153870575e-05, conservative 0.00013896798409405165
# The minimum test loss was 9.294676201534457e-05, conservative 0.00013630663743242623
# Plot saved to loss_plots\dataset_9\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.41 seconds.
# Done training the normal network!
# The network training took 12.50 seconds.
# Done training the conservative network!
# The minimum loss was 5.2335232248879036e-05, conservative 3.6575705235009084e-05
# The minimum test loss was 6.0698231754940936e-05, conservative 3.808962719631381e-05
# Plot saved to loss_plots\dataset_9\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.50 seconds.
# Done training the normal network!
# The network training took 12.55 seconds.
# Done training the conservative network!
# The minimum loss was 0.0009665941062849015, conservative 0.0006371910654706881
# The minimum test loss was 0.001036757096881047, conservative 0.0006276111816987395
# Plot saved to loss_plots\dataset_9\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.49 seconds.
# Done training the normal network!
# The network training took 12.82 seconds.
# Done training the conservative network!
# The minimum loss was 0.0013021530932746828, conservative 0.0010006862314185128
# The minimum test loss was 0.0013368993881158532, conservative 0.0010016080690547825
# Plot saved to loss_plots\dataset_9\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.65 seconds.
# Done training the normal network!
# The network training took 12.74 seconds.
# Done training the conservative network!
# The minimum loss was 0.000737557269167155, conservative 0.0006313848862191662
# The minimum test loss was 0.000761214696103707, conservative 0.0006382157851476222
# Plot saved to loss_plots\dataset_9\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 7.58 seconds.
# Done training the normal network!
# The network training took 12.75 seconds.
# Done training the conservative network!
# The minimum loss was 0.0007684972952120006, conservative 0.0008632918470539153
# The minimum test loss was 0.0008630892320070416, conservative 0.0009248361922800541
# Plot saved to loss_plots\dataset_9\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\8D_losses.txt
# Done!!!

# %% [markdown]
# # Organizing Data

# %%
# Folder containing the loss plots and text files
loss_folder = "loss_plots"

# Output folders for consolidated images and text files
output_image_folder = "consolidated_images"
output_text_folder = "consolidated_text_files"

# Create output folders if they don't exist
os.makedirs(output_image_folder, exist_ok=True)
os.makedirs(output_text_folder, exist_ok=True)

# Iterate through all subfolders in the loss_folder
for subfolder in os.listdir(loss_folder):
    subfolder_path = os.path.join(loss_folder, subfolder)
    
    # Check if it's a directory (e.g., dataset_1, dataset_2, etc.)
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")
        
        # Extract the dataset number (e.g., "1" from "dataset_1")
        dataset_number = subfolder.split("_")[-1]
        
        # Process images
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".png"):  # Process only .png files
                # Construct the new filename (e.g., 2D_Conservative_NN_1.png)
                new_filename = filename.replace(".png", f"_{dataset_number}.png")
                
                # Copy the image to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_image_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied image: {src_path} -> {dest_path}")
        
        # Process text files
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".txt"):  # Process only .txt files
                # Construct the new filename (e.g., 8D_losses_1.txt)
                new_filename = filename.replace(".txt", f"_{dataset_number}.txt")
                
                # Copy the text file to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_text_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied text file: {src_path} -> {dest_path}")

print("All files have been consolidated.")
# Out:
# Processing folder: dataset_1
# Processing folder: dataset_10
# Processing folder: dataset_2
# Processing folder: dataset_3
# Processing folder: dataset_4
# Processing folder: dataset_5
# Processing folder: dataset_6
# Processing folder: dataset_7
# Processing folder: dataset_8
# Processing folder: dataset_9
# All files have been consolidated.
