# %% [markdown]
# # Imports

# %%
import torch
import sys
import numpy as np
import os
import shutil
from pathlib import Path
# Add parent directory to sys.path
parent_dir = Path.cwd().parent.parent
sys.path.append(str(parent_dir))
# Import modules
from train import train_test_multiple_networks, train_network_with_test_loss, train_grad_network_with_test_loss, save_plot_test_train

# %% [markdown]
# # Network Parameters

# %%
# Training hyperparameters
num_trials = 10
neurons = [128, 128, 128]
num_epochs = 200

# %% [markdown]
# # Running Experiments

# %%
# Folder containing datasets
dataset_folder = "datasets"

# Output folder for plots
output_folder = "loss_plots"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

for subfolder in os.listdir(dataset_folder):
    subfolder_path = os.path.join(dataset_folder, subfolder)
    
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")

        output_subfolder = os.path.join(output_folder, subfolder)
        os.makedirs(output_subfolder, exist_ok=True)
        
        train_folder = os.path.join(subfolder_path, "train")
        test_folder = os.path.join(subfolder_path, "test")
        
        for filename in os.listdir(train_folder):
            if filename.endswith("_train.txt"):
                base_name = filename.replace("_train.txt", "")
                
                # Load train data
                train_filepath = os.path.join(train_folder, filename)
                train_data = np.loadtxt(train_filepath)

                dimension = (int)(train_data.shape[1]/2)

                train_points = torch.tensor(train_data[:, :dimension], dtype=torch.float32)
                train_values = torch.tensor(train_data[:, dimension:], dtype=torch.float32)

                
                # Load test data
                test_filename = f"{base_name}_test.txt"
                test_filepath = os.path.join(test_folder, test_filename)
                test_data = np.loadtxt(test_filepath)
                test_points = torch.tensor(test_data[:, :dimension], dtype=torch.float32)
                test_values = torch.tensor(test_data[:, dimension:], dtype=torch.float32)
                
                print(f"Loaded preprocessed data for dimension {dimension}")
                
                # Train the normal network
                mean_loss, variance_loss, mean_test_loss, variance_test_loss = train_test_multiple_networks(
                    train_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the normal network!")
        
                # Train the conservative network
                mean_loss_grad, variance_loss_grad, mean_test_loss_grad, variance_test_loss_grad = train_test_multiple_networks(
                    train_grad_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the conservative network!")

                # Calculate standard deviations for the normal network
                std_loss = np.sqrt(variance_loss)
                std_test_loss = np.sqrt(variance_test_loss)
                std_loss_grad = np.sqrt(variance_loss_grad)
                std_test_loss_grad = np.sqrt(variance_test_loss_grad)
        
                # Print the minimum loss
                print(f"The minimum loss was {mean_loss[-1]}, conservative {mean_loss_grad[-1]}")
                print(f"The minimum test loss was {mean_test_loss[-1]}, conservative {mean_test_loss_grad[-1]}")
                # Comparison Plot
                epochs = np.arange(num_epochs)
                save_plot_test_train(epochs, mean_loss, std_loss, mean_loss_grad, std_loss_grad,
                      mean_test_loss, std_test_loss, mean_test_loss_grad, std_test_loss_grad,
                      dimension, neurons, num_epochs, output_subfolder)

                # Save the losses to .txt files
                losses_filename = os.path.join(output_subfolder, f"{dimension}D_losses.txt")
                np.savetxt(
                    losses_filename,
                    np.column_stack((
                        epochs,
                        mean_loss, std_loss,  # Training loss and std for normal network
                        mean_test_loss, std_test_loss,  # Test loss and std for normal network
                        mean_loss_grad, std_loss_grad,  # Training loss and std for conservative network
                        mean_test_loss_grad, std_test_loss_grad  # Test loss and std for conservative network
                    )),
                    fmt='%.6f',
                    header='epochs mean_loss std_loss mean_test_loss std_test_loss mean_loss_grad std_loss_grad mean_test_loss_grad std_test_loss_grad'
                )
                print(f"Losses saved to {losses_filename}")
        
print ("Done!!!")
# Out:
# Using device: cuda
# Processing folder: dataset_1
# Loaded preprocessed data for dimension 10
# The network training took 8.04 seconds.
# Done training the normal network!
# The network training took 11.92 seconds.
# Done training the conservative network!
# The minimum loss was 61.9643051147461, conservative 15.369147682189942
# The minimum test loss was 66.20886535644532, conservative 15.534036636352539
# Plot saved to loss_plots\dataset_1\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.44 seconds.
# Done training the normal network!
# The network training took 11.26 seconds.
# Done training the conservative network!
# The minimum loss was 15909.36484375, conservative 1392.10341796875
# The minimum test loss was 16650.44462890625, conservative 1456.8806762695312
# Plot saved to loss_plots\dataset_1\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.11 seconds.
# Done training the normal network!
# The network training took 11.91 seconds.
# Done training the conservative network!
# The minimum loss was 1.671738095865294e-05, conservative 2.0458953895285958e-05
# The minimum test loss was 1.6944032950050314e-05, conservative 2.0899861829093426e-05
# Plot saved to loss_plots\dataset_1\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.07 seconds.
# Done training the normal network!
# The network training took 11.48 seconds.
# Done training the conservative network!
# The minimum loss was 0.0002394387047388591, conservative 0.00013827364782628137
# The minimum test loss was 0.00023430459114024416, conservative 0.0001349071149888914
# Plot saved to loss_plots\dataset_1\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 5.85 seconds.
# Done training the normal network!
# The network training took 11.85 seconds.
# Done training the conservative network!
# The minimum loss was 0.0017271065386012196, conservative 0.0006124589330283925
# The minimum test loss was 0.001696818380150944, conservative 0.000590859359363094
# Plot saved to loss_plots\dataset_1\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.37 seconds.
# Done training the normal network!
# The network training took 11.15 seconds.
# Done training the conservative network!
# The minimum loss was 0.00560031458735466, conservative 0.006158874416723847
# The minimum test loss was 0.005539695639163256, conservative 0.006007554475218058
# Plot saved to loss_plots\dataset_1\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.43 seconds.
# Done training the normal network!
# The network training took 11.65 seconds.
# Done training the conservative network!
# The minimum loss was 0.6571148812770844, conservative 0.29091833233833314
# The minimum test loss was 0.697804582118988, conservative 0.29694396555423735
# Plot saved to loss_plots\dataset_1\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\8D_losses.txt
# Processing folder: dataset_10
# Loaded preprocessed data for dimension 10
# The network training took 6.09 seconds.
# Done training the normal network!
# The network training took 11.54 seconds.
# Done training the conservative network!
# The minimum loss was 60.438838195800784, conservative 15.09580020904541
# The minimum test loss was 64.51839752197266, conservative 15.318325424194336
# Plot saved to loss_plots\dataset_10\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.24 seconds.
# Done training the normal network!
# The network training took 12.47 seconds.
# Done training the conservative network!
# The minimum loss was 15542.58505859375, conservative 1367.8044799804688
# The minimum test loss was 16255.54296875, conservative 1432.0640502929687
# Plot saved to loss_plots\dataset_10\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.10 seconds.
# Done training the normal network!
# The network training took 12.78 seconds.
# Done training the conservative network!
# The minimum loss was 3.112545291514834e-05, conservative 0.00047369412850457594
# The minimum test loss was 3.065104911001981e-05, conservative 0.0004788538543380128
# Plot saved to loss_plots\dataset_10\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.04 seconds.
# Done training the normal network!
# The network training took 11.05 seconds.
# Done training the conservative network!
# The minimum loss was 0.0005055757384980098, conservative 0.00013678175891982392
# The minimum test loss was 0.000500964155071415, conservative 0.00013327108827070332
# Plot saved to loss_plots\dataset_10\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.03 seconds.
# Done training the normal network!
# The network training took 10.97 seconds.
# Done training the conservative network!
# The minimum loss was 0.0025709117762744427, conservative 0.0009241221880074591
# The minimum test loss was 0.0025300542125478386, conservative 0.0009218893537763506
# Plot saved to loss_plots\dataset_10\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.96 seconds.
# Done training the normal network!
# The network training took 11.97 seconds.
# Done training the conservative network!
# The minimum loss was 0.0051949238404631615, conservative 0.007151142414659262
# The minimum test loss was 0.005227128835394978, conservative 0.007086279941722751
# Plot saved to loss_plots\dataset_10\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.78 seconds.
# Done training the normal network!
# The network training took 10.94 seconds.
# Done training the conservative network!
# The minimum loss was 0.7359035193920136, conservative 0.31608074009418485
# The minimum test loss was 0.7826963365077972, conservative 0.32263574600219724
# Plot saved to loss_plots\dataset_10\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\8D_losses.txt
# Processing folder: dataset_2
# Loaded preprocessed data for dimension 10
# The network training took 5.76 seconds.
# Done training the normal network!
# The network training took 11.25 seconds.
# Done training the conservative network!
# The minimum loss was 58.487657165527345, conservative 14.575823879241943
# The minimum test loss was 62.789663314819336, conservative 14.718410015106201
# Plot saved to loss_plots\dataset_2\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.02 seconds.
# Done training the normal network!
# The network training took 11.20 seconds.
# Done training the conservative network!
# The minimum loss was 16019.74228515625, conservative 1398.5599243164063
# The minimum test loss was 16742.50439453125, conservative 1478.3432861328124
# Plot saved to loss_plots\dataset_2\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.08 seconds.
# Done training the normal network!
# The network training took 11.76 seconds.
# Done training the conservative network!
# The minimum loss was 0.00011873791445395909, conservative 6.336473070405191e-05
# The minimum test loss was 0.00012189606568426825, conservative 6.342046262943767e-05
# Plot saved to loss_plots\dataset_2\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.86 seconds.
# Done training the normal network!
# The network training took 10.96 seconds.
# Done training the conservative network!
# The minimum loss was 0.00021058205311419442, conservative 0.00026843173982342704
# The minimum test loss was 0.00020835721952607855, conservative 0.00026208330382360145
# Plot saved to loss_plots\dataset_2\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 5.94 seconds.
# Done training the normal network!
# The network training took 10.75 seconds.
# Done training the conservative network!
# The minimum loss was 0.0010729588335379957, conservative 0.0007844185631256551
# The minimum test loss was 0.0010628605959936976, conservative 0.0007745453069219366
# Plot saved to loss_plots\dataset_2\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.64 seconds.
# Done training the normal network!
# The network training took 10.74 seconds.
# Done training the conservative network!
# The minimum loss was 0.003925644932314754, conservative 0.005551686673425138
# The minimum test loss was 0.0040223724907264115, conservative 0.005573622789233923
# Plot saved to loss_plots\dataset_2\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.75 seconds.
# Done training the normal network!
# The network training took 11.98 seconds.
# Done training the conservative network!
# The minimum loss was 0.6051737129688263, conservative 0.2724117964506149
# The minimum test loss was 0.6445246815681458, conservative 0.2815132811665535
# Plot saved to loss_plots\dataset_2\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\8D_losses.txt
# Processing folder: dataset_3
# Loaded preprocessed data for dimension 10
# The network training took 5.77 seconds.
# Done training the normal network!
# The network training took 10.90 seconds.
# Done training the conservative network!
# The minimum loss was 61.42821426391602, conservative 15.136534500122071
# The minimum test loss was 65.85848426818848, conservative 15.333683681488036
# Plot saved to loss_plots\dataset_3\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.73 seconds.
# Done training the normal network!
# The network training took 10.89 seconds.
# Done training the conservative network!
# The minimum loss was 16020.6609375, conservative 1417.420166015625
# The minimum test loss was 16777.731640625, conservative 1493.0435913085937
# Plot saved to loss_plots\dataset_3\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.81 seconds.
# Done training the normal network!
# The network training took 10.98 seconds.
# Done training the conservative network!
# The minimum loss was 4.5852911716792734e-05, conservative 3.295869064459112e-05
# The minimum test loss was 4.6689596092619465e-05, conservative 3.289077976660337e-05
# Plot saved to loss_plots\dataset_3\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.82 seconds.
# Done training the normal network!
# The network training took 12.04 seconds.
# Done training the conservative network!
# The minimum loss was 0.0009325358201749623, conservative 0.0001529688473965507
# The minimum test loss was 0.0009628230996895582, conservative 0.0001540724842925556
# Plot saved to loss_plots\dataset_3\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.07 seconds.
# Done training the normal network!
# The network training took 11.39 seconds.
# Done training the conservative network!
# The minimum loss was 0.0015796930878423155, conservative 0.0007376770896371454
# The minimum test loss was 0.0016130001051351428, conservative 0.0007406871241983026
# Plot saved to loss_plots\dataset_3\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.71 seconds.
# Done training the normal network!
# The network training took 11.19 seconds.
# Done training the conservative network!
# The minimum loss was 0.005197742767632007, conservative 0.007154833665117622
# The minimum test loss was 0.0052388768643140795, conservative 0.0069937026128172874
# Plot saved to loss_plots\dataset_3\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.97 seconds.
# Done training the normal network!
# The network training took 10.95 seconds.
# Done training the conservative network!
# The minimum loss was 0.6488272428512574, conservative 0.2883554816246033
# The minimum test loss was 0.6912732541561126, conservative 0.29424916952848434
# Plot saved to loss_plots\dataset_3\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\8D_losses.txt
# Processing folder: dataset_4
# Loaded preprocessed data for dimension 10
# The network training took 5.95 seconds.
# Done training the normal network!
# The network training took 12.00 seconds.
# Done training the conservative network!
# The minimum loss was 63.951941299438474, conservative 15.827031993865967
# The minimum test loss was 68.27564582824706, conservative 16.066374015808105
# Plot saved to loss_plots\dataset_4\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.79 seconds.
# Done training the normal network!
# The network training took 11.18 seconds.
# Done training the conservative network!
# The minimum loss was 15722.25126953125, conservative 1394.3290161132813
# The minimum test loss was 16471.17236328125, conservative 1458.7673461914062
# Plot saved to loss_plots\dataset_4\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.52 seconds.
# Done training the normal network!
# The network training took 11.14 seconds.
# Done training the conservative network!
# The minimum loss was 4.688757417170564e-05, conservative 7.079559873091057e-05
# The minimum test loss was 4.920371538901236e-05, conservative 7.762021523376461e-05
# Plot saved to loss_plots\dataset_4\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.17 seconds.
# Done training the normal network!
# The network training took 11.27 seconds.
# Done training the conservative network!
# The minimum loss was 0.00047563995176460596, conservative 0.0004320422845921712
# The minimum test loss was 0.0004759144154377282, conservative 0.00042780602634593377
# Plot saved to loss_plots\dataset_4\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.13 seconds.
# Done training the normal network!
# The network training took 11.77 seconds.
# Done training the conservative network!
# The minimum loss was 0.002472121920436621, conservative 0.001082402456086129
# The minimum test loss was 0.0025096866418607535, conservative 0.0010786933300551027
# Plot saved to loss_plots\dataset_4\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.38 seconds.
# Done training the normal network!
# The network training took 11.11 seconds.
# Done training the conservative network!
# The minimum loss was 0.0038605328416451814, conservative 0.0042789884144440295
# The minimum test loss was 0.004006138513796031, conservative 0.004346246388740838
# Plot saved to loss_plots\dataset_4\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.53 seconds.
# Done training the normal network!
# The network training took 10.93 seconds.
# Done training the conservative network!
# The minimum loss was 0.6587151646614074, conservative 0.29551925510168076
# The minimum test loss was 0.7072966575622559, conservative 0.30057118088006973
# Plot saved to loss_plots\dataset_4\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\8D_losses.txt
# Processing folder: dataset_5
# Loaded preprocessed data for dimension 10
# The network training took 6.19 seconds.
# Done training the normal network!
# The network training took 11.76 seconds.
# Done training the conservative network!
# The minimum loss was 62.70743637084961, conservative 15.278988552093505
# The minimum test loss was 66.96407890319824, conservative 15.497282695770263
# Plot saved to loss_plots\dataset_5\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.38 seconds.
# Done training the normal network!
# The network training took 11.51 seconds.
# Done training the conservative network!
# The minimum loss was 15992.88408203125, conservative 1399.0358276367188
# The minimum test loss was 16716.8505859375, conservative 1475.4119873046875
# Plot saved to loss_plots\dataset_5\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.12 seconds.
# Done training the normal network!
# The network training took 11.41 seconds.
# Done training the conservative network!
# The minimum loss was 4.1827526183624285e-05, conservative 2.0456581751204794e-05
# The minimum test loss was 4.649498077924363e-05, conservative 2.152761107936385e-05
# Plot saved to loss_plots\dataset_5\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.11 seconds.
# Done training the normal network!
# The network training took 11.30 seconds.
# Done training the conservative network!
# The minimum loss was 0.0005507642956217751, conservative 0.00018020311326836236
# The minimum test loss was 0.0005486687790835276, conservative 0.00017664725455688313
# Plot saved to loss_plots\dataset_5\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 5.95 seconds.
# Done training the normal network!
# The network training took 11.07 seconds.
# Done training the conservative network!
# The minimum loss was 0.0023887447081506253, conservative 0.0007484963221941143
# The minimum test loss was 0.00237291119992733, conservative 0.0007342514058109373
# Plot saved to loss_plots\dataset_5\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.28 seconds.
# Done training the normal network!
# The network training took 11.04 seconds.
# Done training the conservative network!
# The minimum loss was 0.006562045123428106, conservative 0.00577571289613843
# The minimum test loss was 0.006775960326194763, conservative 0.005779514578171075
# Plot saved to loss_plots\dataset_5\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.28 seconds.
# Done training the normal network!
# The network training took 11.55 seconds.
# Done training the conservative network!
# The minimum loss was 0.6690650224685669, conservative 0.28119528442621233
# The minimum test loss was 0.7155343770980835, conservative 0.2876040756702423
# Plot saved to loss_plots\dataset_5\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\8D_losses.txt
# Processing folder: dataset_6
# Loaded preprocessed data for dimension 10
# The network training took 5.91 seconds.
# Done training the normal network!
# The network training took 11.07 seconds.
# Done training the conservative network!
# The minimum loss was 62.604500961303714, conservative 15.518200206756593
# The minimum test loss was 66.75355491638183, conservative 15.69974422454834
# Plot saved to loss_plots\dataset_6\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 11.14 seconds.
# Done training the conservative network!
# The minimum loss was 16082.82109375, conservative 1417.3348266601563
# The minimum test loss was 16821.4681640625, conservative 1493.54248046875
# Plot saved to loss_plots\dataset_6\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.27 seconds.
# Done training the normal network!
# The network training took 12.77 seconds.
# Done training the conservative network!
# The minimum loss was 6.5264096519968e-05, conservative 1.747433689160971e-05
# The minimum test loss was 6.554990741278744e-05, conservative 1.7600062346900813e-05
# Plot saved to loss_plots\dataset_6\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.27 seconds.
# Done training the normal network!
# The network training took 11.84 seconds.
# Done training the conservative network!
# The minimum loss was 0.0003974770224886015, conservative 9.58485594310332e-05
# The minimum test loss was 0.00039867887971922755, conservative 9.652610715420451e-05
# Plot saved to loss_plots\dataset_6\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.57 seconds.
# Done training the normal network!
# The network training took 11.47 seconds.
# Done training the conservative network!
# The minimum loss was 0.0016274361754767598, conservative 0.001657701435033232
# The minimum test loss was 0.0016562316799536348, conservative 0.00167122725979425
# Plot saved to loss_plots\dataset_6\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.99 seconds.
# Done training the normal network!
# The network training took 11.54 seconds.
# Done training the conservative network!
# The minimum loss was 0.003032212588004768, conservative 0.005763799976557493
# The minimum test loss was 0.0030391988111659884, conservative 0.005609152792021632
# Plot saved to loss_plots\dataset_6\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.36 seconds.
# Done training the normal network!
# The network training took 11.40 seconds.
# Done training the conservative network!
# The minimum loss was 0.6111827611923217, conservative 0.2716055765748024
# The minimum test loss was 0.6502859175205231, conservative 0.27621163725852965
# Plot saved to loss_plots\dataset_6\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\8D_losses.txt
# Processing folder: dataset_7
# Loaded preprocessed data for dimension 10
# The network training took 6.04 seconds.
# Done training the normal network!
# The network training took 11.39 seconds.
# Done training the conservative network!
# The minimum loss was 62.98144683837891, conservative 15.409267807006836
# The minimum test loss was 67.24530982971191, conservative 15.645118045806885
# Plot saved to loss_plots\dataset_7\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 12.89 seconds.
# Done training the conservative network!
# The minimum loss was 16026.55966796875, conservative 1402.5869262695312
# The minimum test loss was 16778.96982421875, conservative 1467.9280029296874
# Plot saved to loss_plots\dataset_7\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.62 seconds.
# Done training the normal network!
# The network training took 12.04 seconds.
# Done training the conservative network!
# The minimum loss was 6.297835352597758e-05, conservative 3.4493083694542294e-05
# The minimum test loss was 6.339069295790978e-05, conservative 3.573732483346248e-05
# Plot saved to loss_plots\dataset_7\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.17 seconds.
# Done training the normal network!
# The network training took 13.38 seconds.
# Done training the conservative network!
# The minimum loss was 0.00017467233556089923, conservative 0.00011956515154452064
# The minimum test loss was 0.00017715155554469674, conservative 0.00011721975897671655
# Plot saved to loss_plots\dataset_7\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.47 seconds.
# Done training the normal network!
# The network training took 11.80 seconds.
# Done training the conservative network!
# The minimum loss was 0.0023027097107842565, conservative 0.000987233780324459
# The minimum test loss was 0.002359336847439408, conservative 0.0009819573257118463
# Plot saved to loss_plots\dataset_7\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.05 seconds.
# Done training the normal network!
# The network training took 11.39 seconds.
# Done training the conservative network!
# The minimum loss was 0.003918918594717979, conservative 0.004863671795465052
# The minimum test loss was 0.00412806284148246, conservative 0.005132391978986561
# Plot saved to loss_plots\dataset_7\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.47 seconds.
# Done training the normal network!
# The network training took 11.74 seconds.
# Done training the conservative network!
# The minimum loss was 0.7081509530544281, conservative 0.3089011788368225
# The minimum test loss was 0.7562928855419159, conservative 0.3130430802702904
# Plot saved to loss_plots\dataset_7\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\8D_losses.txt
# Processing folder: dataset_8
# Loaded preprocessed data for dimension 10
# The network training took 6.02 seconds.
# Done training the normal network!
# The network training took 11.27 seconds.
# Done training the conservative network!
# The minimum loss was 60.54913177490234, conservative 15.305369186401368
# The minimum test loss was 64.65698165893555, conservative 15.478898429870606
# Plot saved to loss_plots\dataset_8\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 11.29 seconds.
# Done training the conservative network!
# The minimum loss was 15873.99326171875, conservative 1396.1216552734375
# The minimum test loss was 16632.56513671875, conservative 1466.7667358398437
# Plot saved to loss_plots\dataset_8\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.14 seconds.
# Done training the normal network!
# The network training took 11.35 seconds.
# Done training the conservative network!
# The minimum loss was 8.550831553293392e-05, conservative 5.274728282529395e-05
# The minimum test loss was 8.733065587875898e-05, conservative 5.3185189244686626e-05
# Plot saved to loss_plots\dataset_8\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.52 seconds.
# Done training the normal network!
# The network training took 11.77 seconds.
# Done training the conservative network!
# The minimum loss was 0.00034004947374342007, conservative 0.00014827156483079306
# The minimum test loss was 0.00033650978875812145, conservative 0.0001485102911829017
# Plot saved to loss_plots\dataset_8\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.01 seconds.
# Done training the normal network!
# The network training took 11.26 seconds.
# Done training the conservative network!
# The minimum loss was 0.0009974647662602365, conservative 0.0009477478684857488
# The minimum test loss was 0.0010254956840071827, conservative 0.0009630650572944432
# Plot saved to loss_plots\dataset_8\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.08 seconds.
# Done training the normal network!
# The network training took 11.25 seconds.
# Done training the conservative network!
# The minimum loss was 0.0040580577217042444, conservative 0.005795621778815985
# The minimum test loss was 0.004050304461270571, conservative 0.005745948478579521
# Plot saved to loss_plots\dataset_8\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.00 seconds.
# Done training the normal network!
# The network training took 11.48 seconds.
# Done training the conservative network!
# The minimum loss was 0.6206640481948853, conservative 0.2826097935438156
# The minimum test loss was 0.6646308720111846, conservative 0.288515305519104
# Plot saved to loss_plots\dataset_8\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\8D_losses.txt
# Processing folder: dataset_9
# Loaded preprocessed data for dimension 10
# The network training took 6.88 seconds.
# Done training the normal network!
# The network training took 11.43 seconds.
# Done training the conservative network!
# The minimum loss was 64.44046058654786, conservative 15.9511212348938
# The minimum test loss was 68.82255210876465, conservative 16.207990169525146
# Plot saved to loss_plots\dataset_9\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.06 seconds.
# Done training the normal network!
# The network training took 11.28 seconds.
# Done training the conservative network!
# The minimum loss was 16047.0142578125, conservative 1410.89423828125
# The minimum test loss was 16776.6884765625, conservative 1488.678466796875
# Plot saved to loss_plots\dataset_9\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.17 seconds.
# Done training the normal network!
# The network training took 11.40 seconds.
# Done training the conservative network!
# The minimum loss was 4.3463424481160474e-05, conservative 8.83763505044044e-05
# The minimum test loss was 4.3339023432054094e-05, conservative 9.278433881263482e-05
# Plot saved to loss_plots\dataset_9\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.20 seconds.
# Done training the normal network!
# The network training took 11.86 seconds.
# Done training the conservative network!
# The minimum loss was 0.00046212177549023183, conservative 0.00026897390634985643
# The minimum test loss was 0.0004683091363403946, conservative 0.0002630392642458901
# Plot saved to loss_plots\dataset_9\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.47 seconds.
# Done training the normal network!
# The network training took 11.74 seconds.
# Done training the conservative network!
# The minimum loss was 0.0017768044723197817, conservative 0.000748918781755492
# The minimum test loss was 0.0017981410841457547, conservative 0.0007318817835766823
# Plot saved to loss_plots\dataset_9\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.07 seconds.
# Done training the normal network!
# The network training took 11.29 seconds.
# Done training the conservative network!
# The minimum loss was 0.0045928035629913214, conservative 0.0073113332502543925
# The minimum test loss was 0.004626511945389211, conservative 0.0072221077047288414
# Plot saved to loss_plots\dataset_9\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.47 seconds.
# Done training the normal network!
# The network training took 11.99 seconds.
# Done training the conservative network!
# The minimum loss was 0.6279131352901459, conservative 0.27950459271669387
# The minimum test loss was 0.6693138360977173, conservative 0.2841543912887573
# Plot saved to loss_plots\dataset_9\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\8D_losses.txt
# Done!!!

# %% [markdown]
# # Organizing Data

# %%
# Folder containing the loss plots and text files
loss_folder = "loss_plots"

# Output folders for consolidated images and text files
output_image_folder = "consolidated_images"
output_text_folder = "consolidated_text_files"

# Create output folders if they don't exist
os.makedirs(output_image_folder, exist_ok=True)
os.makedirs(output_text_folder, exist_ok=True)

# Iterate through all subfolders in the loss_folder
for subfolder in os.listdir(loss_folder):
    subfolder_path = os.path.join(loss_folder, subfolder)
    
    # Check if it's a directory (e.g., dataset_1, dataset_2, etc.)
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")
        
        # Extract the dataset number (e.g., "1" from "dataset_1")
        dataset_number = subfolder.split("_")[-1]
        
        # Process images
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".png"):  # Process only .png files
                # Construct the new filename (e.g., 2D_Conservative_NN_1.png)
                new_filename = filename.replace(".png", f"_{dataset_number}.png")
                
                # Copy the image to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_image_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied image: {src_path} -> {dest_path}")
        
        # Process text files
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".txt"):  # Process only .txt files
                # Construct the new filename (e.g., 8D_losses_1.txt)
                new_filename = filename.replace(".txt", f"_{dataset_number}.txt")
                
                # Copy the text file to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_text_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied text file: {src_path} -> {dest_path}")

print("All files have been consolidated.")
# Out:
# Processing folder: dataset_1
# Processing folder: dataset_10
# Processing folder: dataset_2
# Processing folder: dataset_3
# Processing folder: dataset_4
# Processing folder: dataset_5
# Processing folder: dataset_6
# Processing folder: dataset_7
# Processing folder: dataset_8
# Processing folder: dataset_9
# All files have been consolidated.
