# %% [markdown]
# # Imports

# %%
import torch
import sys
import numpy as np
import os
import shutil
from pathlib import Path
# Add parent directory to sys.path
parent_dir = Path.cwd().parent.parent
sys.path.append(str(parent_dir))
# Import modules
from train import train_test_multiple_networks, train_network_with_test_loss, train_grad_network_with_test_loss, save_plot_test_train

# %% [markdown]
# # Network Parameters

# %%
# Training hyperparameters
num_trials = 10
neurons = [128, 128, 128]
num_epochs = 200

# %% [markdown]
# # Running Experiments

# %%
# Folder containing datasets
dataset_folder = "datasets"

# Output folder for plots
output_folder = "loss_plots"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

for subfolder in os.listdir(dataset_folder):
    subfolder_path = os.path.join(dataset_folder, subfolder)
    
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")

        output_subfolder = os.path.join(output_folder, subfolder)
        os.makedirs(output_subfolder, exist_ok=True)
        
        train_folder = os.path.join(subfolder_path, "train")
        test_folder = os.path.join(subfolder_path, "test")
        
        for filename in os.listdir(train_folder):
            if filename.endswith("_train.txt"):
                base_name = filename.replace("_train.txt", "")
                
                # Load train data
                train_filepath = os.path.join(train_folder, filename)
                train_data = np.loadtxt(train_filepath)

                dimension = (int)(train_data.shape[1]/2)

                train_points = torch.tensor(train_data[:, :dimension], dtype=torch.float32)
                train_values = torch.tensor(train_data[:, dimension:], dtype=torch.float32)

                
                # Load test data
                test_filename = f"{base_name}_test.txt"
                test_filepath = os.path.join(test_folder, test_filename)
                test_data = np.loadtxt(test_filepath)
                test_points = torch.tensor(test_data[:, :dimension], dtype=torch.float32)
                test_values = torch.tensor(test_data[:, dimension:], dtype=torch.float32)
                
                print(f"Loaded preprocessed data for dimension {dimension}")
                
                # Train the normal network
                mean_loss, variance_loss, mean_test_loss, variance_test_loss = train_test_multiple_networks(
                    train_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the normal network!")
        
                # Train the conservative network
                mean_loss_grad, variance_loss_grad, mean_test_loss_grad, variance_test_loss_grad = train_test_multiple_networks(
                    train_grad_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the conservative network!")

                # Calculate standard deviations for the normal network
                std_loss = np.sqrt(variance_loss)
                std_test_loss = np.sqrt(variance_test_loss)
                std_loss_grad = np.sqrt(variance_loss_grad)
                std_test_loss_grad = np.sqrt(variance_test_loss_grad)
        
                # Print the minimum loss
                print(f"The minimum loss was {mean_loss[-1]}, conservative {mean_loss_grad[-1]}")
                print(f"The minimum test loss was {mean_test_loss[-1]}, conservative {mean_test_loss_grad[-1]}")
                # Comparison Plot
                epochs = np.arange(num_epochs)
                save_plot_test_train(epochs, mean_loss, std_loss, mean_loss_grad, std_loss_grad,
                      mean_test_loss, std_test_loss, mean_test_loss_grad, std_test_loss_grad,
                      dimension, neurons, num_epochs, output_subfolder)

                # Save the losses to .txt files
                losses_filename = os.path.join(output_subfolder, f"{dimension}D_losses.txt")
                np.savetxt(
                    losses_filename,
                    np.column_stack((
                        epochs,
                        mean_loss, std_loss,  # Training loss and std for normal network
                        mean_test_loss, std_test_loss,  # Test loss and std for normal network
                        mean_loss_grad, std_loss_grad,  # Training loss and std for conservative network
                        mean_test_loss_grad, std_test_loss_grad  # Test loss and std for conservative network
                    )),
                    fmt='%.6f',
                    header='epochs mean_loss std_loss mean_test_loss std_test_loss mean_loss_grad std_loss_grad mean_test_loss_grad std_test_loss_grad'
                )
                print(f"Losses saved to {losses_filename}")
        
print ("Done!!!")
# Out:
# Using device: cuda
# Processing folder: dataset_1
# Loaded preprocessed data for dimension 10
# The network training took 8.23 seconds.
# Done training the normal network!
# The network training took 11.71 seconds.
# Done training the conservative network!
# The minimum loss was 3.2782940706965746e-05, conservative 1.5920380815259704e-05
# The minimum test loss was 3.529734422045294e-05, conservative 1.5891661178102368e-05
# Plot saved to loss_plots\dataset_1\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.23 seconds.
# Done training the normal network!
# The network training took 11.66 seconds.
# Done training the conservative network!
# The minimum loss was 3.83839458663715e-05, conservative 3.018325742232264e-06
# The minimum test loss was 4.1271452300861713e-05, conservative 3.287280878794263e-06
# Plot saved to loss_plots\dataset_1\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.60 seconds.
# Done training the normal network!
# The network training took 11.74 seconds.
# Done training the conservative network!
# The minimum loss was 1.2677219729084754e-05, conservative 4.2055838093801866e-06
# The minimum test loss was 1.731219181237975e-05, conservative 7.771311993565178e-06
# Plot saved to loss_plots\dataset_1\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.69 seconds.
# Done training the normal network!
# The network training took 12.11 seconds.
# Done training the conservative network!
# The minimum loss was 4.089001376996748e-05, conservative 1.3083664043733733e-06
# The minimum test loss was 4.417352756718174e-05, conservative 1.6821421354507037e-06
# Plot saved to loss_plots\dataset_1\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.09 seconds.
# Done training the normal network!
# The network training took 11.28 seconds.
# Done training the conservative network!
# The minimum loss was 1.9287365012132797e-05, conservative 3.0602805509261087e-06
# The minimum test loss was 2.161903976229951e-05, conservative 3.1555546570416483e-06
# Plot saved to loss_plots\dataset_1\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.04 seconds.
# Done training the normal network!
# The network training took 11.23 seconds.
# Done training the conservative network!
# The minimum loss was 1.5960641167112045e-05, conservative 1.82946788299887e-05
# The minimum test loss was 1.5574875033053103e-05, conservative 1.84447912943142e-05
# Plot saved to loss_plots\dataset_1\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.07 seconds.
# Done training the normal network!
# The network training took 11.62 seconds.
# Done training the conservative network!
# The minimum loss was 3.2493691287527325e-05, conservative 4.295475118851755e-05
# The minimum test loss was 3.156176662741927e-05, conservative 4.283681982997223e-05
# Plot saved to loss_plots\dataset_1\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.30 seconds.
# Done training the normal network!
# The network training took 11.49 seconds.
# Done training the conservative network!
# The minimum loss was 1.5211521349556278e-05, conservative 1.995730726775946e-05
# The minimum test loss was 1.5467335833818653e-05, conservative 2.0122562364122133e-05
# Plot saved to loss_plots\dataset_1\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.96 seconds.
# Done training the normal network!
# The network training took 11.20 seconds.
# Done training the conservative network!
# The minimum loss was 2.2760057072446215e-05, conservative 1.0761971179817919e-05
# The minimum test loss was 2.968604130728636e-05, conservative 1.1579924830584787e-05
# Plot saved to loss_plots\dataset_1\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\8D_losses.txt
# Processing folder: dataset_10
# Loaded preprocessed data for dimension 10
# The network training took 5.97 seconds.
# Done training the normal network!
# The network training took 11.16 seconds.
# Done training the conservative network!
# The minimum loss was 4.090196780452971e-05, conservative 2.2296442693914287e-05
# The minimum test loss was 4.967823042534292e-05, conservative 2.8086951533623506e-05
# Plot saved to loss_plots\dataset_10\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.36 seconds.
# Done training the normal network!
# The network training took 11.76 seconds.
# Done training the conservative network!
# The minimum loss was 3.391310328879626e-05, conservative 4.523626535046787e-06
# The minimum test loss was 3.748382750927704e-05, conservative 4.4124934902356475e-06
# Plot saved to loss_plots\dataset_10\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.53 seconds.
# Done training the normal network!
# The network training took 11.35 seconds.
# Done training the conservative network!
# The minimum loss was 1.730846115606255e-05, conservative 2.9918122208982824e-06
# The minimum test loss was 1.8862107845052377e-05, conservative 3.1532600132777587e-06
# Plot saved to loss_plots\dataset_10\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.15 seconds.
# Done training the normal network!
# The network training took 11.37 seconds.
# Done training the conservative network!
# The minimum loss was 1.1566482362468377e-05, conservative 6.722542525494646e-06
# The minimum test loss was 1.2370387139526429e-05, conservative 6.755426147719845e-06
# Plot saved to loss_plots\dataset_10\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.90 seconds.
# Done training the normal network!
# The network training took 11.24 seconds.
# Done training the conservative network!
# The minimum loss was 2.2304105914372486e-05, conservative 1.6143723087225226e-06
# The minimum test loss was 2.3938042249938008e-05, conservative 1.7712983890305623e-06
# Plot saved to loss_plots\dataset_10\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 11.93 seconds.
# Done training the conservative network!
# The minimum loss was 7.201661946965032e-06, conservative 2.797896104311803e-06
# The minimum test loss was 7.109413672878873e-06, conservative 2.923559236478468e-06
# Plot saved to loss_plots\dataset_10\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.57 seconds.
# Done training the normal network!
# The network training took 11.80 seconds.
# Done training the conservative network!
# The minimum loss was 1.2507972678577062e-05, conservative 1.647508352107252e-05
# The minimum test loss was 1.2239638090250083e-05, conservative 1.597977134224493e-05
# Plot saved to loss_plots\dataset_10\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.30 seconds.
# Done training the normal network!
# The network training took 11.49 seconds.
# Done training the conservative network!
# The minimum loss was 5.517381714525982e-05, conservative 7.515821653214516e-06
# The minimum test loss was 5.6729073912720195e-05, conservative 7.761635470160399e-06
# Plot saved to loss_plots\dataset_10\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.12 seconds.
# Done training the normal network!
# The network training took 10.91 seconds.
# Done training the conservative network!
# The minimum loss was 2.1716705850849395e-05, conservative 7.933823553685215e-06
# The minimum test loss was 2.2692227139486933e-05, conservative 7.977813129400602e-06
# Plot saved to loss_plots\dataset_10\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\8D_losses.txt
# Processing folder: dataset_2
# Loaded preprocessed data for dimension 10
# The network training took 5.79 seconds.
# Done training the normal network!
# The network training took 11.64 seconds.
# Done training the conservative network!
# The minimum loss was 3.371248058101628e-05, conservative 6.915464769008395e-06
# The minimum test loss was 3.8017367478460075e-05, conservative 6.789129361095547e-06
# Plot saved to loss_plots\dataset_2\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.56 seconds.
# Done training the normal network!
# The network training took 11.08 seconds.
# Done training the conservative network!
# The minimum loss was 4.3957966408925134e-05, conservative 1.961077296073199e-05
# The minimum test loss was 4.4536805216921496e-05, conservative 1.901804780573002e-05
# Plot saved to loss_plots\dataset_2\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.95 seconds.
# Done training the normal network!
# The network training took 11.05 seconds.
# Done training the conservative network!
# The minimum loss was 2.770418159343535e-05, conservative 4.199013665129314e-06
# The minimum test loss was 3.214758235117188e-05, conservative 4.8855845989237425e-06
# Plot saved to loss_plots\dataset_2\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.15 seconds.
# Done training the normal network!
# The network training took 10.98 seconds.
# Done training the conservative network!
# The minimum loss was 4.1848340697470124e-05, conservative 1.9349226818121677e-06
# The minimum test loss was 4.6215219117584636e-05, conservative 2.2344127444284824e-06
# Plot saved to loss_plots\dataset_2\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.81 seconds.
# Done training the normal network!
# The network training took 11.43 seconds.
# Done training the conservative network!
# The minimum loss was 2.567398678365862e-05, conservative 1.668256300035864e-06
# The minimum test loss was 2.7977205354545732e-05, conservative 1.7442507214582292e-06
# Plot saved to loss_plots\dataset_2\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.34 seconds.
# Done training the normal network!
# The network training took 11.00 seconds.
# Done training the conservative network!
# The minimum loss was 3.604457215260482e-05, conservative 1.5201902397166122e-05
# The minimum test loss was 3.776237044803565e-05, conservative 1.5798554613866145e-05
# Plot saved to loss_plots\dataset_2\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.04 seconds.
# Done training the normal network!
# The network training took 11.25 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001100669785955688, conservative 0.0001385962832500809
# The minimum test loss was 0.00011285592372587417, conservative 0.00013912768554291688
# Plot saved to loss_plots\dataset_2\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 11.12 seconds.
# Done training the conservative network!
# The minimum loss was 5.4836678827996366e-05, conservative 8.953373753683991e-06
# The minimum test loss was 5.5769685604900585e-05, conservative 9.026986708704498e-06
# Plot saved to loss_plots\dataset_2\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.76 seconds.
# Done training the normal network!
# The network training took 11.76 seconds.
# Done training the conservative network!
# The minimum loss was 2.4637955357320605e-05, conservative 9.864555931926588e-06
# The minimum test loss was 2.6025109855254412e-05, conservative 9.996881590268459e-06
# Plot saved to loss_plots\dataset_2\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\8D_losses.txt
# Processing folder: dataset_3
# Loaded preprocessed data for dimension 10
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 11.06 seconds.
# Done training the conservative network!
# The minimum loss was 5.048168932262342e-05, conservative 2.7270603914075765e-05
# The minimum test loss was 5.9126323685632086e-05, conservative 2.6555260410532357e-05
# Plot saved to loss_plots\dataset_3\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.88 seconds.
# Done training the normal network!
# The network training took 10.99 seconds.
# Done training the conservative network!
# The minimum loss was 6.896940758451819e-05, conservative 2.808094734518818e-06
# The minimum test loss was 8.561803770135157e-05, conservative 5.736291359426104e-06
# Plot saved to loss_plots\dataset_3\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 10.77 seconds.
# Done training the conservative network!
# The minimum loss was 1.6916082404350164e-05, conservative 4.9005577011485e-06
# The minimum test loss was 2.0644566211558414e-05, conservative 5.325753522811283e-06
# Plot saved to loss_plots\dataset_3\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.16 seconds.
# Done training the normal network!
# The network training took 11.93 seconds.
# Done training the conservative network!
# The minimum loss was 4.416896899783751e-05, conservative 1.1174733174357243e-06
# The minimum test loss was 4.394544721435523e-05, conservative 1.0318558111066522e-06
# Plot saved to loss_plots\dataset_3\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 10.87 seconds.
# Done training the conservative network!
# The minimum loss was 4.826244385185419e-05, conservative 3.086605730118208e-07
# The minimum test loss was 5.294584607327124e-05, conservative 4.3259775566184545e-07
# Plot saved to loss_plots\dataset_3\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.78 seconds.
# Done training the normal network!
# The network training took 11.08 seconds.
# Done training the conservative network!
# The minimum loss was 1.895683753900812e-05, conservative 5.867156187377987e-06
# The minimum test loss was 1.8831938359653577e-05, conservative 6.458013240262517e-06
# Plot saved to loss_plots\dataset_3\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.99 seconds.
# Done training the normal network!
# The network training took 10.91 seconds.
# Done training the conservative network!
# The minimum loss was 3.176026093569817e-05, conservative 3.594986746975337e-05
# The minimum test loss was 3.24630711475038e-05, conservative 3.668547960842261e-05
# Plot saved to loss_plots\dataset_3\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.83 seconds.
# Done training the normal network!
# The network training took 12.04 seconds.
# Done training the conservative network!
# The minimum loss was 4.834794999624137e-05, conservative 2.3799637347110547e-05
# The minimum test loss was 5.005184848414501e-05, conservative 2.317481194040738e-05
# Plot saved to loss_plots\dataset_3\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.01 seconds.
# Done training the normal network!
# The network training took 11.14 seconds.
# Done training the conservative network!
# The minimum loss was 1.954191420736606e-05, conservative 9.015820251079276e-06
# The minimum test loss was 2.058245136140613e-05, conservative 9.29622265175567e-06
# Plot saved to loss_plots\dataset_3\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\8D_losses.txt
# Processing folder: dataset_4
# Loaded preprocessed data for dimension 10
# The network training took 5.86 seconds.
# Done training the normal network!
# The network training took 11.08 seconds.
# Done training the conservative network!
# The minimum loss was 1.976329931494547e-05, conservative 6.7108175244356975e-06
# The minimum test loss was 2.0628399761335457e-05, conservative 6.595692866540048e-06
# Plot saved to loss_plots\dataset_4\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.92 seconds.
# Done training the normal network!
# The network training took 11.12 seconds.
# Done training the conservative network!
# The minimum loss was 9.210360367433168e-05, conservative 1.4439680285249778e-06
# The minimum test loss was 0.00010160382225876674, conservative 1.7386874787916896e-06
# Plot saved to loss_plots\dataset_4\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.25 seconds.
# Done training the normal network!
# The network training took 12.06 seconds.
# Done training the conservative network!
# The minimum loss was 1.7583211229066364e-05, conservative 1.82427342565461e-06
# The minimum test loss was 1.9724399953702233e-05, conservative 2.7544902081899638e-06
# Plot saved to loss_plots\dataset_4\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.06 seconds.
# Done training the normal network!
# The network training took 11.32 seconds.
# Done training the conservative network!
# The minimum loss was 1.829587545216782e-05, conservative 1.8380361552772229e-06
# The minimum test loss was 2.0979845885449322e-05, conservative 2.0352164597170486e-06
# Plot saved to loss_plots\dataset_4\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 10.97 seconds.
# Done training the conservative network!
# The minimum loss was 3.677662989503006e-05, conservative 6.032277781287121e-07
# The minimum test loss was 3.7302907730918375e-05, conservative 7.585795970044274e-07
# Plot saved to loss_plots\dataset_4\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.89 seconds.
# Done training the normal network!
# The network training took 11.43 seconds.
# Done training the conservative network!
# The minimum loss was 1.604883991603856e-05, conservative 8.535575034329668e-06
# The minimum test loss was 1.6293042517645517e-05, conservative 8.846409173202119e-06
# Plot saved to loss_plots\dataset_4\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.19 seconds.
# Done training the normal network!
# The network training took 11.96 seconds.
# Done training the conservative network!
# The minimum loss was 9.603689941286575e-05, conservative 2.632563837323687e-05
# The minimum test loss was 9.257198362320196e-05, conservative 2.589978385003633e-05
# Plot saved to loss_plots\dataset_4\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.94 seconds.
# Done training the normal network!
# The network training took 11.17 seconds.
# Done training the conservative network!
# The minimum loss was 1.346933113381965e-05, conservative 9.18905666367209e-06
# The minimum test loss was 1.3747757293458562e-05, conservative 9.471601970290067e-06
# Plot saved to loss_plots\dataset_4\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.90 seconds.
# Done training the normal network!
# The network training took 11.18 seconds.
# Done training the conservative network!
# The minimum loss was 2.254252049169736e-05, conservative 8.710076940587896e-06
# The minimum test loss was 2.2984560018812772e-05, conservative 8.943125294536003e-06
# Plot saved to loss_plots\dataset_4\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\8D_losses.txt
# Processing folder: dataset_5
# Loaded preprocessed data for dimension 10
# The network training took 6.11 seconds.
# Done training the normal network!
# The network training took 11.02 seconds.
# Done training the conservative network!
# The minimum loss was 1.0959380961139687e-05, conservative 9.39294177442207e-06
# The minimum test loss was 1.268198311663582e-05, conservative 9.466270148550393e-06
# Plot saved to loss_plots\dataset_5\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.18 seconds.
# Done training the normal network!
# The network training took 11.75 seconds.
# Done training the conservative network!
# The minimum loss was 5.001653116778471e-05, conservative 1.0836407227543532e-05
# The minimum test loss was 5.036396541981958e-05, conservative 1.0196359698966263e-05
# Plot saved to loss_plots\dataset_5\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.30 seconds.
# Done training the normal network!
# The network training took 11.26 seconds.
# Done training the conservative network!
# The minimum loss was 3.896077978424728e-05, conservative 1.112810767267547e-06
# The minimum test loss was 3.481693038338562e-05, conservative 1.1390207305339573e-06
# Plot saved to loss_plots\dataset_5\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.07 seconds.
# Done training the normal network!
# The network training took 11.00 seconds.
# Done training the conservative network!
# The minimum loss was 3.3738409092620715e-05, conservative 1.8821734443008608e-06
# The minimum test loss was 3.600327927415492e-05, conservative 2.043885660896194e-06
# Plot saved to loss_plots\dataset_5\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.08 seconds.
# Done training the normal network!
# The network training took 11.12 seconds.
# Done training the conservative network!
# The minimum loss was 1.2241590047779027e-05, conservative 4.5781030451053083e-07
# The minimum test loss was 1.1748119959520409e-05, conservative 4.536860359394268e-07
# Plot saved to loss_plots\dataset_5\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.44 seconds.
# Done training the normal network!
# The network training took 11.53 seconds.
# Done training the conservative network!
# The minimum loss was 7.191593044808542e-06, conservative 3.4382993135295694e-06
# The minimum test loss was 7.099945082700287e-06, conservative 3.5448611924948637e-06
# Plot saved to loss_plots\dataset_5\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.86 seconds.
# Done training the normal network!
# The network training took 11.18 seconds.
# Done training the conservative network!
# The minimum loss was 1.827089836297091e-05, conservative 1.2908612961837208e-05
# The minimum test loss was 1.8145808280678465e-05, conservative 1.2309309613556253e-05
# Plot saved to loss_plots\dataset_5\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 10.97 seconds.
# Done training the conservative network!
# The minimum loss was 1.6650144880259175e-05, conservative 1.203708779939916e-05
# The minimum test loss was 1.7894362736114998e-05, conservative 1.2612358887054143e-05
# Plot saved to loss_plots\dataset_5\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.02 seconds.
# Done training the normal network!
# The network training took 11.06 seconds.
# Done training the conservative network!
# The minimum loss was 1.7457463854952948e-05, conservative 1.2087681170669384e-05
# The minimum test loss was 1.9222257742512737e-05, conservative 1.210626237480028e-05
# Plot saved to loss_plots\dataset_5\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\8D_losses.txt
# Processing folder: dataset_6
# Loaded preprocessed data for dimension 10
# The network training took 6.29 seconds.
# Done training the normal network!
# The network training took 11.63 seconds.
# Done training the conservative network!
# The minimum loss was 2.804651385304169e-05, conservative 1.2971887554158456e-05
# The minimum test loss was 2.907277585109114e-05, conservative 1.2853610360252788e-05
# Plot saved to loss_plots\dataset_6\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.02 seconds.
# Done training the normal network!
# The network training took 10.98 seconds.
# Done training the conservative network!
# The minimum loss was 1.0504045485504321e-05, conservative 6.697346452710917e-06
# The minimum test loss was 1.1492296926007839e-05, conservative 6.651504486399063e-06
# Plot saved to loss_plots\dataset_6\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 11.10 seconds.
# Done training the conservative network!
# The minimum loss was 6.479200492321979e-05, conservative 9.59731534067032e-07
# The minimum test loss was 6.045627196726855e-05, conservative 9.49605632172279e-07
# Plot saved to loss_plots\dataset_6\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.17 seconds.
# Done training the normal network!
# The network training took 11.11 seconds.
# Done training the conservative network!
# The minimum loss was 2.0445518384804017e-05, conservative 1.8678478340916627e-06
# The minimum test loss was 2.245922150905244e-05, conservative 1.939567096087558e-06
# Plot saved to loss_plots\dataset_6\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.44 seconds.
# Done training the normal network!
# The network training took 11.58 seconds.
# Done training the conservative network!
# The minimum loss was 2.1289351661835098e-05, conservative 1.6515744391654153e-06
# The minimum test loss was 2.4462656074319967e-05, conservative 1.8451730397828213e-06
# Plot saved to loss_plots\dataset_6\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.94 seconds.
# Done training the normal network!
# The network training took 11.26 seconds.
# Done training the conservative network!
# The minimum loss was 1.838953212427441e-05, conservative 2.4807470026644294e-06
# The minimum test loss was 1.9197287019778742e-05, conservative 2.608401018733275e-06
# Plot saved to loss_plots\dataset_6\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.06 seconds.
# Done training the normal network!
# The network training took 11.38 seconds.
# Done training the conservative network!
# The minimum loss was 4.38746006693691e-05, conservative 2.0320047588029412e-05
# The minimum test loss was 4.398519631649833e-05, conservative 1.993715723074274e-05
# Plot saved to loss_plots\dataset_6\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.01 seconds.
# Done training the normal network!
# The network training took 11.20 seconds.
# Done training the conservative network!
# The minimum loss was 2.6010717192548327e-05, conservative 1.7303730419371278e-05
# The minimum test loss was 2.721676391956862e-05, conservative 1.6975868402369087e-05
# Plot saved to loss_plots\dataset_6\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 7.36 seconds.
# Done training the normal network!
# The network training took 11.60 seconds.
# Done training the conservative network!
# The minimum loss was 4.472687578527257e-05, conservative 1.4491128695226507e-05
# The minimum test loss was 5.0328495854046194e-05, conservative 1.4211699908628362e-05
# Plot saved to loss_plots\dataset_6\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\8D_losses.txt
# Processing folder: dataset_7
# Loaded preprocessed data for dimension 10
# The network training took 6.23 seconds.
# Done training the normal network!
# The network training took 11.08 seconds.
# Done training the conservative network!
# The minimum loss was 1.823709849304578e-05, conservative 8.23383247734455e-06
# The minimum test loss was 1.9279624393675476e-05, conservative 8.476205630358891e-06
# Plot saved to loss_plots\dataset_7\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.97 seconds.
# Done training the normal network!
# The network training took 11.23 seconds.
# Done training the conservative network!
# The minimum loss was 1.896805420074088e-05, conservative 2.6978520827469767e-05
# The minimum test loss was 2.1710275541408917e-05, conservative 2.742711033079104e-05
# Plot saved to loss_plots\dataset_7\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.03 seconds.
# Done training the normal network!
# The network training took 11.85 seconds.
# Done training the conservative network!
# The minimum loss was 1.2672219963860697e-05, conservative 8.860202206051326e-06
# The minimum test loss was 1.598078661118052e-05, conservative 1.1290862676105463e-05
# Plot saved to loss_plots\dataset_7\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.75 seconds.
# Done training the normal network!
# The network training took 11.81 seconds.
# Done training the conservative network!
# The minimum loss was 1.3552799009630689e-05, conservative 3.0747293976673974e-06
# The minimum test loss was 1.5782251830387394e-05, conservative 3.820372148766182e-06
# Plot saved to loss_plots\dataset_7\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.20 seconds.
# Done training the normal network!
# The network training took 11.43 seconds.
# Done training the conservative network!
# The minimum loss was 4.636408702936023e-05, conservative 5.199902687991198e-07
# The minimum test loss was 4.4488581625046206e-05, conservative 5.282609009782391e-07
# Plot saved to loss_plots\dataset_7\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.20 seconds.
# Done training the normal network!
# The network training took 11.39 seconds.
# Done training the conservative network!
# The minimum loss was 2.1794066196889616e-05, conservative 2.0011290780530543e-05
# The minimum test loss was 2.1807446228194748e-05, conservative 2.067477917080396e-05
# Plot saved to loss_plots\dataset_7\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.28 seconds.
# Done training the normal network!
# The network training took 12.13 seconds.
# Done training the conservative network!
# The minimum loss was 7.464347436325624e-06, conservative 1.279053121834295e-05
# The minimum test loss was 7.487713446607813e-06, conservative 1.281593049498042e-05
# Plot saved to loss_plots\dataset_7\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.85 seconds.
# Done training the normal network!
# The network training took 11.58 seconds.
# Done training the conservative network!
# The minimum loss was 5.31392995526403e-06, conservative 7.063031898724148e-06
# The minimum test loss was 5.287258659336658e-06, conservative 7.1403347192244835e-06
# Plot saved to loss_plots\dataset_7\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.99 seconds.
# Done training the normal network!
# The network training took 11.37 seconds.
# Done training the conservative network!
# The minimum loss was 2.9071974768157816e-05, conservative 1.0146185286430409e-05
# The minimum test loss was 3.014283402080764e-05, conservative 1.0571436632744735e-05
# Plot saved to loss_plots\dataset_7\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\8D_losses.txt
# Processing folder: dataset_8
# Loaded preprocessed data for dimension 10
# The network training took 5.84 seconds.
# Done training the normal network!
# The network training took 10.80 seconds.
# Done training the conservative network!
# The minimum loss was 4.215426106384257e-05, conservative 7.969531316120992e-06
# The minimum test loss was 4.670370108215138e-05, conservative 8.265900146398052e-06
# Plot saved to loss_plots\dataset_8\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.93 seconds.
# Done training the normal network!
# The network training took 12.34 seconds.
# Done training the conservative network!
# The minimum loss was 2.257749738419079e-05, conservative 2.3656917164771583e-06
# The minimum test loss was 2.691392892302247e-05, conservative 2.4600653887318913e-06
# Plot saved to loss_plots\dataset_8\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.91 seconds.
# Done training the normal network!
# The network training took 12.16 seconds.
# Done training the conservative network!
# The minimum loss was 2.7400951057643397e-05, conservative 6.974996449571336e-06
# The minimum test loss was 3.0514620993926657e-05, conservative 7.528134415224486e-06
# Plot saved to loss_plots\dataset_8\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.52 seconds.
# Done training the normal network!
# The network training took 11.43 seconds.
# Done training the conservative network!
# The minimum loss was 1.516649190307362e-05, conservative 3.7427574966386603e-06
# The minimum test loss was 1.6799818695290014e-05, conservative 3.8138908962537245e-06
# Plot saved to loss_plots\dataset_8\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.66 seconds.
# Done training the normal network!
# The network training took 11.72 seconds.
# Done training the conservative network!
# The minimum loss was 4.140181445109192e-05, conservative 1.707136584627733e-06
# The minimum test loss was 4.506469176703831e-05, conservative 1.8230744444736047e-06
# Plot saved to loss_plots\dataset_8\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.80 seconds.
# Done training the normal network!
# The network training took 12.41 seconds.
# Done training the conservative network!
# The minimum loss was 5.640870858769631e-05, conservative 8.697177918293164e-06
# The minimum test loss was 5.468427643791074e-05, conservative 8.795240228209878e-06
# Plot saved to loss_plots\dataset_8\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.27 seconds.
# Done training the normal network!
# The network training took 11.46 seconds.
# Done training the conservative network!
# The minimum loss was 7.555628362752032e-05, conservative 1.939541316460236e-05
# The minimum test loss was 7.46765634175972e-05, conservative 1.969979703062563e-05
# Plot saved to loss_plots\dataset_8\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.41 seconds.
# Done training the normal network!
# The network training took 12.05 seconds.
# Done training the conservative network!
# The minimum loss was 3.226736216674908e-05, conservative 1.77516451003612e-05
# The minimum test loss was 3.24537577398587e-05, conservative 1.7440916599298363e-05
# Plot saved to loss_plots\dataset_8\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.01 seconds.
# Done training the normal network!
# The network training took 11.52 seconds.
# Done training the conservative network!
# The minimum loss was 2.4562514408899005e-05, conservative 2.2070091290515848e-05
# The minimum test loss was 3.3067418735299724e-05, conservative 2.410349943602341e-05
# Plot saved to loss_plots\dataset_8\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\8D_losses.txt
# Processing folder: dataset_9
# Loaded preprocessed data for dimension 10
# The network training took 6.49 seconds.
# Done training the normal network!
# The network training took 12.01 seconds.
# Done training the conservative network!
# The minimum loss was 4.7934489339240825e-05, conservative 2.5802422806009416e-05
# The minimum test loss was 5.831725029565859e-05, conservative 2.7472274496176396e-05
# Plot saved to loss_plots\dataset_9\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.01 seconds.
# Done training the normal network!
# The network training took 11.39 seconds.
# Done training the conservative network!
# The minimum loss was 5.167148556211032e-05, conservative 2.8490909244283102e-05
# The minimum test loss was 4.37543771113269e-05, conservative 2.7464695676826523e-05
# Plot saved to loss_plots\dataset_9\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.01 seconds.
# Done training the normal network!
# The network training took 11.29 seconds.
# Done training the conservative network!
# The minimum loss was 7.139651061152107e-05, conservative 1.7689739365778224e-06
# The minimum test loss was 6.994251161813736e-05, conservative 1.3988098430672835e-06
# Plot saved to loss_plots\dataset_9\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.00 seconds.
# Done training the normal network!
# The network training took 11.58 seconds.
# Done training the conservative network!
# The minimum loss was 1.604120252522989e-05, conservative 1.4194964478519979e-06
# The minimum test loss was 1.8409725817036816e-05, conservative 1.5027464769445943e-06
# Plot saved to loss_plots\dataset_9\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.67 seconds.
# Done training the normal network!
# The network training took 11.46 seconds.
# Done training the conservative network!
# The minimum loss was 1.815362293200451e-05, conservative 2.6650602080735553e-06
# The minimum test loss was 1.9939374578825663e-05, conservative 2.7320431399857627e-06
# Plot saved to loss_plots\dataset_9\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 12.07 seconds.
# Done training the conservative network!
# The minimum loss was 7.421200034514186e-05, conservative 9.648266836848051e-06
# The minimum test loss was 7.336017069974332e-05, conservative 9.840805250860286e-06
# Plot saved to loss_plots\dataset_9\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.21 seconds.
# Done training the normal network!
# The network training took 11.77 seconds.
# Done training the conservative network!
# The minimum loss was 1.9119595435768133e-05, conservative 1.8242404257762247e-05
# The minimum test loss was 1.9510196761984843e-05, conservative 1.8313207783648976e-05
# Plot saved to loss_plots\dataset_9\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.99 seconds.
# Done training the normal network!
# The network training took 11.72 seconds.
# Done training the conservative network!
# The minimum loss was 9.171487399726175e-05, conservative 1.0937289516732562e-05
# The minimum test loss was 9.362528817291604e-05, conservative 1.1266674664511812e-05
# Plot saved to loss_plots\dataset_9\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.44 seconds.
# Done training the normal network!
# The network training took 11.51 seconds.
# Done training the conservative network!
# The minimum loss was 1.2162983512098436e-05, conservative 2.578495168563677e-05
# The minimum test loss was 1.2707461519312346e-05, conservative 2.5353369528602344e-05
# Plot saved to loss_plots\dataset_9\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\8D_losses.txt
# Done!!!

# %% [markdown]
# # Organizing Data

# %%
# Folder containing the loss plots and text files
loss_folder = "loss_plots"

# Output folders for consolidated images and text files
output_image_folder = "consolidated_images"
output_text_folder = "consolidated_text_files"

# Create output folders if they don't exist
os.makedirs(output_image_folder, exist_ok=True)
os.makedirs(output_text_folder, exist_ok=True)

# Iterate through all subfolders in the loss_folder
for subfolder in os.listdir(loss_folder):
    subfolder_path = os.path.join(loss_folder, subfolder)
    
    # Check if it's a directory (e.g., dataset_1, dataset_2, etc.)
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")
        
        # Extract the dataset number (e.g., "1" from "dataset_1")
        dataset_number = subfolder.split("_")[-1]
        
        # Process images
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".png"):  # Process only .png files
                # Construct the new filename (e.g., 2D_Conservative_NN_1.png)
                new_filename = filename.replace(".png", f"_{dataset_number}.png")
                
                # Copy the image to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_image_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied image: {src_path} -> {dest_path}")
        
        # Process text files
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".txt"):  # Process only .txt files
                # Construct the new filename (e.g., 8D_losses_1.txt)
                new_filename = filename.replace(".txt", f"_{dataset_number}.txt")
                
                # Copy the text file to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_text_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied text file: {src_path} -> {dest_path}")

print("All files have been consolidated.")
# Out:
# Processing folder: dataset_1
# Processing folder: dataset_10
# Processing folder: dataset_2
# Processing folder: dataset_3
# Processing folder: dataset_4
# Processing folder: dataset_5
# Processing folder: dataset_6
# Processing folder: dataset_7
# Processing folder: dataset_8
# Processing folder: dataset_9
# All files have been consolidated.
