# %% [markdown]
# # Imports

# %%
import torch
import sys
import numpy as np
import os
import shutil
from pathlib import Path
# Add parent directory to sys.path
parent_dir = Path.cwd().parent.parent
sys.path.append(str(parent_dir))
# Import modules
from train import train_test_multiple_networks, train_network_with_test_loss, train_grad_network_with_test_loss, save_plot_test_train

# %% [markdown]
# # Network Parameters

# %%
# Training hyperparameters
num_trials = 10
neurons = [256, 256, 256]
num_epochs = 200

# %% [markdown]
# # Running Experiments

# %%
# Folder containing datasets
dataset_folder = "datasets"

# Output folder for plots
output_folder = "loss_plots"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

for subfolder in os.listdir(dataset_folder):
    subfolder_path = os.path.join(dataset_folder, subfolder)
    
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")

        output_subfolder = os.path.join(output_folder, subfolder)
        os.makedirs(output_subfolder, exist_ok=True)
        
        train_folder = os.path.join(subfolder_path, "train")
        test_folder = os.path.join(subfolder_path, "test")
        
        for filename in os.listdir(train_folder):
            if filename.endswith("_train.txt"):
                base_name = filename.replace("_train.txt", "")
                
                # Load train data
                train_filepath = os.path.join(train_folder, filename)
                train_data = np.loadtxt(train_filepath)

                dimension = (int)(train_data.shape[1]/2)

                train_points = torch.tensor(train_data[:, :dimension], dtype=torch.float32)
                train_values = torch.tensor(train_data[:, dimension:], dtype=torch.float32)

                
                # Load test data
                test_filename = f"{base_name}_test.txt"
                test_filepath = os.path.join(test_folder, test_filename)
                test_data = np.loadtxt(test_filepath)
                test_points = torch.tensor(test_data[:, :dimension], dtype=torch.float32)
                test_values = torch.tensor(test_data[:, dimension:], dtype=torch.float32)
                
                print(f"Loaded preprocessed data for dimension {dimension}")
                
                # Train the normal network
                mean_loss, variance_loss, mean_test_loss, variance_test_loss = train_test_multiple_networks(
                    train_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the normal network!")
        
                # Train the conservative network
                mean_loss_grad, variance_loss_grad, mean_test_loss_grad, variance_test_loss_grad = train_test_multiple_networks(
                    train_grad_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the conservative network!")

                # Calculate standard deviations for the normal network
                std_loss = np.sqrt(variance_loss)
                std_test_loss = np.sqrt(variance_test_loss)
                std_loss_grad = np.sqrt(variance_loss_grad)
                std_test_loss_grad = np.sqrt(variance_test_loss_grad)
        
                # Print the minimum loss
                print(f"The minimum loss was {mean_loss[-1]}, conservative {mean_loss_grad[-1]}")
                print(f"The minimum test loss was {mean_test_loss[-1]}, conservative {mean_test_loss_grad[-1]}")
                # Comparison Plot
                epochs = np.arange(num_epochs)
                save_plot_test_train(epochs, mean_loss, std_loss, mean_loss_grad, std_loss_grad,
                      mean_test_loss, std_test_loss, mean_test_loss_grad, std_test_loss_grad,
                      dimension, neurons, num_epochs, output_subfolder)

                # Save the losses to .txt files
                losses_filename = os.path.join(output_subfolder, f"{dimension}D_losses.txt")
                np.savetxt(
                    losses_filename,
                    np.column_stack((
                        epochs,
                        mean_loss, std_loss,  # Training loss and std for normal network
                        mean_test_loss, std_test_loss,  # Test loss and std for normal network
                        mean_loss_grad, std_loss_grad,  # Training loss and std for conservative network
                        mean_test_loss_grad, std_test_loss_grad  # Test loss and std for conservative network
                    )),
                    fmt='%.6f',
                    header='epochs mean_loss std_loss mean_test_loss std_test_loss mean_loss_grad std_loss_grad mean_test_loss_grad std_test_loss_grad'
                )
                print(f"Losses saved to {losses_filename}")
        
print ("Done!!!")
# Out:
# Using device: cuda
# Processing folder: dataset_1
# Loaded preprocessed data for dimension 10
# The network training took 9.11 seconds.
# Done training the normal network!
# The network training took 11.81 seconds.
# Done training the conservative network!
# The minimum loss was 8.120043785311281e-05, conservative 2.9159523319322033e-05
# The minimum test loss was 8.419913683610503e-05, conservative 2.8877538716187702e-05
# Plot saved to loss_plots\dataset_1\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.99 seconds.
# Done training the normal network!
# The network training took 10.91 seconds.
# Done training the conservative network!
# The minimum loss was 7.533284879173152e-05, conservative 5.077605351289094e-06
# The minimum test loss was 8.10465426184237e-05, conservative 5.468372705763613e-06
# Plot saved to loss_plots\dataset_1\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.85 seconds.
# Done training the normal network!
# The network training took 11.23 seconds.
# Done training the conservative network!
# The minimum loss was 5.1197271932323926e-05, conservative 2.1321432996046497e-06
# The minimum test loss was 5.9347251044528095e-05, conservative 5.668792209689855e-06
# Plot saved to loss_plots\dataset_1\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.00 seconds.
# Done training the normal network!
# The network training took 10.87 seconds.
# Done training the conservative network!
# The minimum loss was 6.285103190748487e-05, conservative 1.6496063608428813e-06
# The minimum test loss was 6.625197383982595e-05, conservative 2.0769244315488322e-06
# Plot saved to loss_plots\dataset_1\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.22 seconds.
# Done training the normal network!
# The network training took 11.35 seconds.
# Done training the conservative network!
# The minimum loss was 5.3420641779666764e-05, conservative 4.3699553202714014e-06
# The minimum test loss was 5.7777666734182274e-05, conservative 4.50378026926046e-06
# Plot saved to loss_plots\dataset_1\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.85 seconds.
# Done training the normal network!
# The network training took 11.30 seconds.
# Done training the conservative network!
# The minimum loss was 1.763342015692615e-05, conservative 2.529556895751739e-05
# The minimum test loss was 1.7323289284831844e-05, conservative 2.514499981316476e-05
# Plot saved to loss_plots\dataset_1\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.90 seconds.
# Done training the normal network!
# The network training took 11.57 seconds.
# Done training the conservative network!
# The minimum loss was 0.0007569994588266127, conservative 9.068844929061014e-06
# The minimum test loss was 0.0007511939260439249, conservative 9.009880704979878e-06
# Plot saved to loss_plots\dataset_1\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.81 seconds.
# Done training the normal network!
# The network training took 12.35 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001594047272192256, conservative 1.7213833143614465e-05
# The minimum test loss was 0.0001594381172253634, conservative 1.7358611012241453e-05
# Plot saved to loss_plots\dataset_1\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.40 seconds.
# Done training the normal network!
# The network training took 11.35 seconds.
# Done training the conservative network!
# The minimum loss was 8.060119635047158e-05, conservative 2.036971918641939e-05
# The minimum test loss was 9.491051132499706e-05, conservative 2.1938039117230802e-05
# Plot saved to loss_plots\dataset_1\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\8D_losses.txt
# Processing folder: dataset_10
# Loaded preprocessed data for dimension 10
# The network training took 5.89 seconds.
# Done training the normal network!
# The network training took 10.73 seconds.
# Done training the conservative network!
# The minimum loss was 4.2362708336440845e-05, conservative 4.079982627445133e-05
# The minimum test loss was 5.143299604242202e-05, conservative 4.7008490946609526e-05
# Plot saved to loss_plots\dataset_10\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.87 seconds.
# Done training the normal network!
# The network training took 10.73 seconds.
# Done training the conservative network!
# The minimum loss was 0.00012866731340182013, conservative 5.115587418913492e-06
# The minimum test loss was 0.00013586374407168478, conservative 5.09417141074664e-06
# Plot saved to loss_plots\dataset_10\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.83 seconds.
# Done training the normal network!
# The network training took 11.73 seconds.
# Done training the conservative network!
# The minimum loss was 3.535793457558612e-05, conservative 4.759787316288566e-06
# The minimum test loss was 3.8835402847325895e-05, conservative 4.9966810820478715e-06
# Plot saved to loss_plots\dataset_10\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.52 seconds.
# Done training the normal network!
# The network training took 11.03 seconds.
# Done training the conservative network!
# The minimum loss was 2.2823504332336596e-05, conservative 4.030236027574574e-06
# The minimum test loss was 2.4423848117294256e-05, conservative 4.125435157220636e-06
# Plot saved to loss_plots\dataset_10\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.86 seconds.
# Done training the normal network!
# The network training took 11.33 seconds.
# Done training the conservative network!
# The minimum loss was 0.00010560366754361895, conservative 2.732922007453453e-06
# The minimum test loss was 0.0001092248650820693, conservative 2.92991226160666e-06
# Plot saved to loss_plots\dataset_10\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 11.03 seconds.
# Done training the conservative network!
# The minimum loss was 8.502133343881723e-05, conservative 0.00020437207894019593
# The minimum test loss was 8.356627340617706e-05, conservative 0.0002017798824624606
# Plot saved to loss_plots\dataset_10\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.90 seconds.
# Done training the normal network!
# The network training took 11.49 seconds.
# Done training the conservative network!
# The minimum loss was 4.523203333519632e-05, conservative 9.409597150806803e-05
# The minimum test loss was 4.5152976963436234e-05, conservative 9.425156290490122e-05
# Plot saved to loss_plots\dataset_10\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.45 seconds.
# Done training the normal network!
# The network training took 10.85 seconds.
# Done training the conservative network!
# The minimum loss was 1.519945644758991e-05, conservative 1.3584988528236863e-05
# The minimum test loss was 1.5642189646314363e-05, conservative 1.3912886697653448e-05
# Plot saved to loss_plots\dataset_10\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.86 seconds.
# Done training the normal network!
# The network training took 10.85 seconds.
# Done training the conservative network!
# The minimum loss was 6.067249050829559e-05, conservative 9.969254961106344e-05
# The minimum test loss was 6.223417458386393e-05, conservative 0.00010060148579214002
# Plot saved to loss_plots\dataset_10\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\8D_losses.txt
# Processing folder: dataset_2
# Loaded preprocessed data for dimension 10
# The network training took 5.76 seconds.
# Done training the normal network!
# The network training took 10.80 seconds.
# Done training the conservative network!
# The minimum loss was 0.00020017011120216922, conservative 1.1635068358373245e-05
# The minimum test loss was 0.00019092962684226223, conservative 1.1125412015644542e-05
# Plot saved to loss_plots\dataset_2\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.85 seconds.
# Done training the normal network!
# The network training took 10.86 seconds.
# Done training the conservative network!
# The minimum loss was 9.630186214053538e-05, conservative 3.194241171513568e-05
# The minimum test loss was 9.584271283529233e-05, conservative 3.0226059971028006e-05
# Plot saved to loss_plots\dataset_2\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.25 seconds.
# Done training the normal network!
# The network training took 11.81 seconds.
# Done training the conservative network!
# The minimum loss was 4.6492946057696824e-05, conservative 7.565498049189046e-06
# The minimum test loss was 5.220153034315445e-05, conservative 8.50660105697898e-06
# Plot saved to loss_plots\dataset_2\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.07 seconds.
# Done training the normal network!
# The network training took 11.22 seconds.
# Done training the conservative network!
# The minimum loss was 0.00013179247325751932, conservative 3.4332597124375753e-06
# The minimum test loss was 0.0001383854112646077, conservative 3.925413670913258e-06
# Plot saved to loss_plots\dataset_2\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.06 seconds.
# Done training the normal network!
# The network training took 11.21 seconds.
# Done training the conservative network!
# The minimum loss was 5.9698572476918345e-05, conservative 2.3738703703202193e-06
# The minimum test loss was 6.23459207417909e-05, conservative 2.4441304503852735e-06
# Plot saved to loss_plots\dataset_2\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.04 seconds.
# Done training the normal network!
# The network training took 11.01 seconds.
# Done training the conservative network!
# The minimum loss was 0.00013817507860949262, conservative 8.20143468445167e-06
# The minimum test loss was 0.00014256192953325807, conservative 8.269006821137737e-06
# Plot saved to loss_plots\dataset_2\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.34 seconds.
# Done training the normal network!
# The network training took 11.61 seconds.
# Done training the conservative network!
# The minimum loss was 0.00042230005565215836, conservative 9.702428401396901e-05
# The minimum test loss was 0.00042739007585623767, conservative 9.724880983412732e-05
# Plot saved to loss_plots\dataset_2\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.92 seconds.
# Done training the normal network!
# The network training took 11.01 seconds.
# Done training the conservative network!
# The minimum loss was 4.547292410279624e-05, conservative 8.155038476616027e-05
# The minimum test loss was 4.7194458238664085e-05, conservative 8.237202218879247e-05
# Plot saved to loss_plots\dataset_2\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.96 seconds.
# Done training the normal network!
# The network training took 10.81 seconds.
# Done training the conservative network!
# The minimum loss was 6.139643846836407e-05, conservative 8.038758687689551e-06
# The minimum test loss was 6.357010497595183e-05, conservative 8.337178178408066e-06
# Plot saved to loss_plots\dataset_2\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\8D_losses.txt
# Processing folder: dataset_3
# Loaded preprocessed data for dimension 10
# The network training took 5.74 seconds.
# Done training the normal network!
# The network training took 10.65 seconds.
# Done training the conservative network!
# The minimum loss was 0.00014437530480790884, conservative 1.9610390336310956e-05
# The minimum test loss was 0.00015415493544423953, conservative 1.9504127340042033e-05
# Plot saved to loss_plots\dataset_3\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.17 seconds.
# Done training the normal network!
# The network training took 11.33 seconds.
# Done training the conservative network!
# The minimum loss was 0.00021469440616783686, conservative 1.4005468892719364e-05
# The minimum test loss was 0.00022706649760948495, conservative 2.2810945301898756e-05
# Plot saved to loss_plots\dataset_3\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.89 seconds.
# Done training the normal network!
# The network training took 10.91 seconds.
# Done training the conservative network!
# The minimum loss was 7.469829342880985e-05, conservative 9.008934557641624e-06
# The minimum test loss was 8.216450005420484e-05, conservative 9.567150459588448e-06
# Plot saved to loss_plots\dataset_3\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.85 seconds.
# Done training the normal network!
# The network training took 10.89 seconds.
# Done training the conservative network!
# The minimum loss was 5.0335907508269885e-05, conservative 6.592442423425382e-06
# The minimum test loss was 4.92447055876255e-05, conservative 5.557371491704544e-06
# Plot saved to loss_plots\dataset_3\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.85 seconds.
# Done training the normal network!
# The network training took 11.14 seconds.
# Done training the conservative network!
# The minimum loss was 2.9519906820496545e-05, conservative 6.724930898371895e-07
# The minimum test loss was 3.4019898885162546e-05, conservative 9.52086060124202e-07
# Plot saved to loss_plots\dataset_3\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.24 seconds.
# Done training the normal network!
# The network training took 11.38 seconds.
# Done training the conservative network!
# The minimum loss was 1.4176980948832352e-05, conservative 5.783319943475363e-06
# The minimum test loss was 1.4134751290839631e-05, conservative 6.001723136250803e-06
# Plot saved to loss_plots\dataset_3\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.92 seconds.
# Done training the normal network!
# The network training took 10.96 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001252916128578363, conservative 0.0010851593886400223
# The minimum test loss was 0.00012883251492894486, conservative 0.0010787579972202366
# Plot saved to loss_plots\dataset_3\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 7.42 seconds.
# Done training the normal network!
# The network training took 11.25 seconds.
# Done training the conservative network!
# The minimum loss was 0.0003183160923072137, conservative 0.00011626873747445643
# The minimum test loss was 0.000328174664900871, conservative 0.00011411074774514418
# Plot saved to loss_plots\dataset_3\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.93 seconds.
# Done training the normal network!
# The network training took 11.23 seconds.
# Done training the conservative network!
# The minimum loss was 4.925247521896381e-05, conservative 9.179474682241562e-06
# The minimum test loss was 5.054821222074679e-05, conservative 9.581031736161095e-06
# Plot saved to loss_plots\dataset_3\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\8D_losses.txt
# Processing folder: dataset_4
# Loaded preprocessed data for dimension 10
# The network training took 6.02 seconds.
# Done training the normal network!
# The network training took 12.10 seconds.
# Done training the conservative network!
# The minimum loss was 4.386665677884594e-05, conservative 7.475672055079485e-06
# The minimum test loss was 4.535796851996565e-05, conservative 7.384678201560746e-06
# Plot saved to loss_plots\dataset_4\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.10 seconds.
# Done training the normal network!
# The network training took 11.18 seconds.
# Done training the conservative network!
# The minimum loss was 0.00015848140174057335, conservative 5.772745385002054e-06
# The minimum test loss was 0.0001648067933274433, conservative 6.470783750955888e-06
# Plot saved to loss_plots\dataset_4\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.86 seconds.
# Done training the normal network!
# The network training took 11.10 seconds.
# Done training the conservative network!
# The minimum loss was 7.261845894390717e-05, conservative 1.6337358033524651e-06
# The minimum test loss was 7.103676107362844e-05, conservative 2.580121486062126e-06
# Plot saved to loss_plots\dataset_4\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.02 seconds.
# Done training the normal network!
# The network training took 10.96 seconds.
# Done training the conservative network!
# The minimum loss was 5.763017834397033e-05, conservative 3.5672678905029897e-06
# The minimum test loss was 6.286035386438016e-05, conservative 3.872613524436019e-06
# Plot saved to loss_plots\dataset_4\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.38 seconds.
# Done training the normal network!
# The network training took 11.57 seconds.
# Done training the conservative network!
# The minimum loss was 6.186313985381275e-05, conservative 2.8602060979210362e-06
# The minimum test loss was 6.144427043182077e-05, conservative 3.020013798504806e-06
# Plot saved to loss_plots\dataset_4\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.25 seconds.
# Done training the normal network!
# The network training took 11.28 seconds.
# Done training the conservative network!
# The minimum loss was 3.975039471697528e-05, conservative 4.809308052244887e-06
# The minimum test loss was 4.052561143907951e-05, conservative 4.8942859848466466e-06
# Plot saved to loss_plots\dataset_4\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.97 seconds.
# Done training the normal network!
# The network training took 11.11 seconds.
# Done training the conservative network!
# The minimum loss was 4.5763154230371586e-05, conservative 4.5421056711347774e-05
# The minimum test loss was 4.677245997299906e-05, conservative 4.557717966235941e-05
# Plot saved to loss_plots\dataset_4\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.89 seconds.
# Done training the normal network!
# The network training took 10.68 seconds.
# Done training the conservative network!
# The minimum loss was 2.4940542789408938e-05, conservative 8.939671852203901e-06
# The minimum test loss was 2.5536610883136747e-05, conservative 9.097422343984363e-06
# Plot saved to loss_plots\dataset_4\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.14 seconds.
# Done training the normal network!
# The network training took 11.32 seconds.
# Done training the conservative network!
# The minimum loss was 2.4716811640246306e-05, conservative 1.1470882691355655e-05
# The minimum test loss was 2.6055457783513703e-05, conservative 1.1853050727950176e-05
# Plot saved to loss_plots\dataset_4\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\8D_losses.txt
# Processing folder: dataset_5
# Loaded preprocessed data for dimension 10
# The network training took 5.82 seconds.
# Done training the normal network!
# The network training took 12.46 seconds.
# Done training the conservative network!
# The minimum loss was 4.823450908588711e-05, conservative 1.7797529744711936e-05
# The minimum test loss was 5.021552969992626e-05, conservative 1.8097674364980775e-05
# Plot saved to loss_plots\dataset_5\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.07 seconds.
# Done training the normal network!
# The network training took 11.28 seconds.
# Done training the conservative network!
# The minimum loss was 7.096903864294291e-05, conservative 1.1785102060457575e-05
# The minimum test loss was 6.864710012450814e-05, conservative 1.0906243915087543e-05
# Plot saved to loss_plots\dataset_5\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.07 seconds.
# Done training the normal network!
# The network training took 11.19 seconds.
# Done training the conservative network!
# The minimum loss was 4.0963137871585785e-05, conservative 7.49261830605974e-06
# The minimum test loss was 3.58851579221664e-05, conservative 6.717682344969944e-06
# Plot saved to loss_plots\dataset_5\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.47 seconds.
# Done training the normal network!
# The network training took 11.70 seconds.
# Done training the conservative network!
# The minimum loss was 6.922060929355211e-05, conservative 3.273012191584712e-06
# The minimum test loss was 7.204144312709105e-05, conservative 3.471721265668748e-06
# Plot saved to loss_plots\dataset_5\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.86 seconds.
# Done training the normal network!
# The network training took 11.83 seconds.
# Done training the conservative network!
# The minimum loss was 1.2655041882680961e-05, conservative 3.4574942219478545e-06
# The minimum test loss was 1.2118752965761815e-05, conservative 3.1940161306920345e-06
# Plot saved to loss_plots\dataset_5\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.28 seconds.
# Done training the normal network!
# The network training took 11.05 seconds.
# Done training the conservative network!
# The minimum loss was 6.148955708340509e-06, conservative 3.3226337336600407e-06
# The minimum test loss was 6.060226678528125e-06, conservative 3.462007362031727e-06
# Plot saved to loss_plots\dataset_5\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.99 seconds.
# Done training the normal network!
# The network training took 10.98 seconds.
# Done training the conservative network!
# The minimum loss was 0.00012794812946594902, conservative 9.79405645011866e-06
# The minimum test loss was 0.00012549663370009512, conservative 9.44854687077168e-06
# Plot saved to loss_plots\dataset_5\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.33 seconds.
# Done training the normal network!
# The network training took 11.37 seconds.
# Done training the conservative network!
# The minimum loss was 3.686733625727356e-05, conservative 9.756524059412186e-06
# The minimum test loss was 3.854830674754339e-05, conservative 1.027934499688854e-05
# Plot saved to loss_plots\dataset_5\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.83 seconds.
# Done training the normal network!
# The network training took 11.02 seconds.
# Done training the conservative network!
# The minimum loss was 3.407842004889972e-05, conservative 2.6478954532649367e-05
# The minimum test loss was 3.765174769796431e-05, conservative 2.657475420164701e-05
# Plot saved to loss_plots\dataset_5\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\8D_losses.txt
# Processing folder: dataset_6
# Loaded preprocessed data for dimension 10
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 10.85 seconds.
# Done training the conservative network!
# The minimum loss was 2.3906144542706896e-05, conservative 3.2762978344180736e-05
# The minimum test loss was 2.53923954005586e-05, conservative 3.2831296221047526e-05
# Plot saved to loss_plots\dataset_6\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.80 seconds.
# Done training the normal network!
# The network training took 10.90 seconds.
# Done training the conservative network!
# The minimum loss was 1.8615665067045483e-05, conservative 8.855199098434241e-06
# The minimum test loss was 2.0133485759288305e-05, conservative 8.865903350852022e-06
# Plot saved to loss_plots\dataset_6\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.26 seconds.
# Done training the normal network!
# The network training took 11.53 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001030279596307082, conservative 6.566522802131658e-06
# The minimum test loss was 9.838953083090019e-05, conservative 4.872538715972041e-06
# Plot saved to loss_plots\dataset_6\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.99 seconds.
# Done training the normal network!
# The network training took 11.63 seconds.
# Done training the conservative network!
# The minimum loss was 7.93940151197603e-05, conservative 3.033622033399297e-06
# The minimum test loss was 8.360563770111184e-05, conservative 3.1138859526436136e-06
# Plot saved to loss_plots\dataset_6\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.41 seconds.
# Done training the normal network!
# The network training took 11.14 seconds.
# Done training the conservative network!
# The minimum loss was 6.501184725493658e-05, conservative 2.7632928322418594e-06
# The minimum test loss was 7.26514590496663e-05, conservative 3.0084554509812733e-06
# Plot saved to loss_plots\dataset_6\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 11.11 seconds.
# Done training the conservative network!
# The minimum loss was 6.952347234800982e-06, conservative 2.4211428240050736e-06
# The minimum test loss was 7.221674695756519e-06, conservative 2.498968331110518e-06
# Plot saved to loss_plots\dataset_6\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.36 seconds.
# Done training the normal network!
# The network training took 11.58 seconds.
# Done training the conservative network!
# The minimum loss was 3.570452827261761e-05, conservative 0.0001827310413318628
# The minimum test loss was 3.594885492930189e-05, conservative 0.00018120462827937446
# Plot saved to loss_plots\dataset_6\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.00 seconds.
# Done training the normal network!
# The network training took 11.18 seconds.
# Done training the conservative network!
# The minimum loss was 7.26444719475694e-05, conservative 1.7937486063601682e-05
# The minimum test loss was 7.367280559265055e-05, conservative 1.730875205794291e-05
# Plot saved to loss_plots\dataset_6\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.22 seconds.
# Done training the normal network!
# The network training took 11.13 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001534248367534019, conservative 1.3522213339456358e-05
# The minimum test loss was 0.00015958370349835604, conservative 1.4311315226223087e-05
# Plot saved to loss_plots\dataset_6\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\8D_losses.txt
# Processing folder: dataset_7
# Loaded preprocessed data for dimension 10
# The network training took 6.23 seconds.
# Done training the normal network!
# The network training took 11.22 seconds.
# Done training the conservative network!
# The minimum loss was 1.9983559559477727e-05, conservative 7.445134019690158e-06
# The minimum test loss was 2.164856405215687e-05, conservative 7.776453867336385e-06
# Plot saved to loss_plots\dataset_7\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.28 seconds.
# Done training the normal network!
# The network training took 11.68 seconds.
# Done training the conservative network!
# The minimum loss was 3.4965858321811535e-05, conservative 5.08069681472989e-06
# The minimum test loss was 4.269239434506744e-05, conservative 5.491980846272781e-06
# Plot saved to loss_plots\dataset_7\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.83 seconds.
# Done training the normal network!
# The network training took 10.86 seconds.
# Done training the conservative network!
# The minimum loss was 3.095985321124317e-05, conservative 8.8107651208702e-06
# The minimum test loss was 3.5384388138481884e-05, conservative 1.1194894068466964e-05
# Plot saved to loss_plots\dataset_7\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.41 seconds.
# Done training the normal network!
# The network training took 11.08 seconds.
# Done training the conservative network!
# The minimum loss was 4.570622822939185e-05, conservative 1.8306014339941612e-06
# The minimum test loss was 4.9423098062106874e-05, conservative 2.593403337414202e-06
# Plot saved to loss_plots\dataset_7\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.57 seconds.
# Done training the normal network!
# The network training took 12.51 seconds.
# Done training the conservative network!
# The minimum loss was 0.00010213519126409665, conservative 1.6518319625902222e-06
# The minimum test loss was 9.913942049024626e-05, conservative 1.5577271824440685e-06
# Plot saved to loss_plots\dataset_7\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.42 seconds.
# Done training the normal network!
# The network training took 11.68 seconds.
# Done training the conservative network!
# The minimum loss was 1.644738831600989e-05, conservative 6.200116740728845e-06
# The minimum test loss was 1.6978339863271687e-05, conservative 6.61865756228508e-06
# Plot saved to loss_plots\dataset_7\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.96 seconds.
# Done training the normal network!
# The network training took 10.71 seconds.
# Done training the conservative network!
# The minimum loss was 4.558900004667521e-05, conservative 4.5748563661618394e-05
# The minimum test loss was 4.526821803665371e-05, conservative 4.604517848747491e-05
# Plot saved to loss_plots\dataset_7\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.69 seconds.
# Done training the normal network!
# The network training took 10.48 seconds.
# Done training the conservative network!
# The minimum loss was 0.0003872250252243248, conservative 0.00039388640639117514
# The minimum test loss was 0.00038725664257981406, conservative 0.00039107657630665926
# Plot saved to loss_plots\dataset_7\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.98 seconds.
# Done training the normal network!
# The network training took 12.30 seconds.
# Done training the conservative network!
# The minimum loss was 4.780109084094875e-05, conservative 7.330701873797807e-06
# The minimum test loss was 4.904440793325193e-05, conservative 7.745015409454936e-06
# Plot saved to loss_plots\dataset_7\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\8D_losses.txt
# Processing folder: dataset_8
# Loaded preprocessed data for dimension 10
# The network training took 6.87 seconds.
# Done training the normal network!
# The network training took 11.44 seconds.
# Done training the conservative network!
# The minimum loss was 8.434089286311064e-05, conservative 1.4113774113866384e-05
# The minimum test loss was 8.960429331636988e-05, conservative 1.486010046392039e-05
# Plot saved to loss_plots\dataset_8\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.27 seconds.
# Done training the normal network!
# The network training took 11.69 seconds.
# Done training the conservative network!
# The minimum loss was 0.0002117806208843831, conservative 4.068875114171533e-06
# The minimum test loss was 0.00021019383639213628, conservative 4.211009013488365e-06
# Plot saved to loss_plots\dataset_8\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.36 seconds.
# Done training the normal network!
# The network training took 11.65 seconds.
# Done training the conservative network!
# The minimum loss was 6.504040638901642e-05, conservative 4.080748476553709e-06
# The minimum test loss was 6.88531168634654e-05, conservative 4.694210292655043e-06
# Plot saved to loss_plots\dataset_8\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.18 seconds.
# Done training the normal network!
# The network training took 11.77 seconds.
# Done training the conservative network!
# The minimum loss was 6.764408008166355e-05, conservative 2.4659234099999593e-06
# The minimum test loss was 6.968203342694324e-05, conservative 2.5636720806687665e-06
# Plot saved to loss_plots\dataset_8\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.19 seconds.
# Done training the normal network!
# The network training took 11.14 seconds.
# Done training the conservative network!
# The minimum loss was 7.655491717741824e-05, conservative 1.948792237271846e-06
# The minimum test loss was 8.146702202793676e-05, conservative 2.164631632695091e-06
# Plot saved to loss_plots\dataset_8\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.98 seconds.
# Done training the normal network!
# The network training took 11.01 seconds.
# Done training the conservative network!
# The minimum loss was 0.00015256587066687645, conservative 4.259874444869638e-05
# The minimum test loss was 0.00014827142495050795, conservative 4.3100739503643126e-05
# Plot saved to loss_plots\dataset_8\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.16 seconds.
# Done training the normal network!
# The network training took 11.38 seconds.
# Done training the conservative network!
# The minimum loss was 5.154060672794003e-05, conservative 2.3649904051126214e-05
# The minimum test loss was 5.1506249656085855e-05, conservative 2.3675138527323726e-05
# Plot saved to loss_plots\dataset_8\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.08 seconds.
# Done training the normal network!
# The network training took 11.99 seconds.
# Done training the conservative network!
# The minimum loss was 1.624817114134203e-05, conservative 0.00010471375667293614
# The minimum test loss was 1.674317763900035e-05, conservative 0.00010414997163934458
# Plot saved to loss_plots\dataset_8\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.03 seconds.
# Done training the normal network!
# The network training took 11.21 seconds.
# Done training the conservative network!
# The minimum loss was 0.00010024947659985628, conservative 2.2617177455686034e-05
# The minimum test loss was 0.0001149798663391266, conservative 2.4456973460473818e-05
# Plot saved to loss_plots\dataset_8\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\8D_losses.txt
# Processing folder: dataset_9
# Loaded preprocessed data for dimension 10
# The network training took 5.90 seconds.
# Done training the normal network!
# The network training took 10.82 seconds.
# Done training the conservative network!
# The minimum loss was 0.00032247880881186575, conservative 1.7876326774057814e-05
# The minimum test loss was 0.00033534371978021226, conservative 2.0171712549199583e-05
# Plot saved to loss_plots\dataset_9\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.88 seconds.
# Done training the normal network!
# The network training took 10.94 seconds.
# Done training the conservative network!
# The minimum loss was 6.849978926766198e-05, conservative 4.472017262742156e-05
# The minimum test loss was 5.665961471095216e-05, conservative 3.758537641260773e-05
# Plot saved to loss_plots\dataset_9\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.94 seconds.
# Done training the normal network!
# The network training took 11.53 seconds.
# Done training the conservative network!
# The minimum loss was 6.784821453038603e-05, conservative 3.5910795304516798e-06
# The minimum test loss was 6.624001325690187e-05, conservative 3.3734001590346454e-06
# Plot saved to loss_plots\dataset_9\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.95 seconds.
# Done training the normal network!
# The network training took 10.86 seconds.
# Done training the conservative network!
# The minimum loss was 7.418420973408502e-05, conservative 6.24714040213803e-06
# The minimum test loss was 8.133641676977277e-05, conservative 6.510793377856317e-06
# Plot saved to loss_plots\dataset_9\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.93 seconds.
# Done training the normal network!
# The network training took 10.95 seconds.
# Done training the conservative network!
# The minimum loss was 6.750481916242279e-05, conservative 5.951260493475274e-06
# The minimum test loss was 7.085921206453349e-05, conservative 6.086198231969319e-06
# Plot saved to loss_plots\dataset_9\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.86 seconds.
# Done training the normal network!
# The network training took 10.79 seconds.
# Done training the conservative network!
# The minimum loss was 0.00014939568754925858, conservative 0.000563247694663005
# The minimum test loss was 0.00014580877568732832, conservative 0.0005643161999159929
# Plot saved to loss_plots\dataset_9\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.81 seconds.
# Done training the normal network!
# The network training took 11.45 seconds.
# Done training the conservative network!
# The minimum loss was 0.00035712829912881716, conservative 1.3090013680994161e-05
# The minimum test loss was 0.000356663615002617, conservative 1.297081225857255e-05
# Plot saved to loss_plots\dataset_9\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.86 seconds.
# Done training the normal network!
# The network training took 10.77 seconds.
# Done training the conservative network!
# The minimum loss was 7.959448212204733e-05, conservative 0.0001203527742291044
# The minimum test loss was 7.985217471286887e-05, conservative 0.00012205742359583382
# Plot saved to loss_plots\dataset_9\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.83 seconds.
# Done training the normal network!
# The network training took 10.81 seconds.
# Done training the conservative network!
# The minimum loss was 1.572875962665421e-05, conservative 1.2315037884036428e-05
# The minimum test loss was 1.6250651060545352e-05, conservative 1.20426328976464e-05
# Plot saved to loss_plots\dataset_9\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\8D_losses.txt
# Done!!!

# %% [markdown]
# # Organizing Data

# %%
# Folder containing the loss plots and text files
loss_folder = "loss_plots"

# Output folders for consolidated images and text files
output_image_folder = "consolidated_images"
output_text_folder = "consolidated_text_files"

# Create output folders if they don't exist
os.makedirs(output_image_folder, exist_ok=True)
os.makedirs(output_text_folder, exist_ok=True)

# Iterate through all subfolders in the loss_folder
for subfolder in os.listdir(loss_folder):
    subfolder_path = os.path.join(loss_folder, subfolder)
    
    # Check if it's a directory (e.g., dataset_1, dataset_2, etc.)
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")
        
        # Extract the dataset number (e.g., "1" from "dataset_1")
        dataset_number = subfolder.split("_")[-1]
        
        # Process images
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".png"):  # Process only .png files
                # Construct the new filename (e.g., 2D_Conservative_NN_1.png)
                new_filename = filename.replace(".png", f"_{dataset_number}.png")
                
                # Copy the image to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_image_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied image: {src_path} -> {dest_path}")
        
        # Process text files
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".txt"):  # Process only .txt files
                # Construct the new filename (e.g., 8D_losses_1.txt)
                new_filename = filename.replace(".txt", f"_{dataset_number}.txt")
                
                # Copy the text file to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_text_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied text file: {src_path} -> {dest_path}")

print("All files have been consolidated.")
# Out:
# Processing folder: dataset_1
# Processing folder: dataset_10
# Processing folder: dataset_2
# Processing folder: dataset_3
# Processing folder: dataset_4
# Processing folder: dataset_5
# Processing folder: dataset_6
# Processing folder: dataset_7
# Processing folder: dataset_8
# Processing folder: dataset_9
# All files have been consolidated.
