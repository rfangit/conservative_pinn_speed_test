# %% [markdown]
# # Generating High Dimensional Data

# %%
import sys
import numpy as np
from pathlib import Path
# Add parent directory to sys.path
parent_dir = Path.cwd().parent
sys.path.append(str(parent_dir))
# Import modules
from dataset_gen import average_sphere_volume, generate_and_save_datasets, compute_volume_ratios

dimensions = [2, 3, 5, 8, 10, 12, 15, 18, 20]  # List of dimensions to generate datasets for
output_folder = 'datasets'
amplitude = 1.0  # Fixed amplitude for all Gaussians (set to None for random amplitudes)
sigma_range=(0.5, 1.0)
num_sets = 10  # Number of datasets to generate for each dimension
base_seed = 42  # Base seed for reproducibility

num_centers = [int(15) for d in dimensions]
print("Computed num_centers:", num_centers)
generate_and_save_datasets(dimensions, num_centers, output_folder, num_sets, base_seed, amplitude)
# Out:
# Computed num_centers: [15, 15, 15, 15, 15, 15, 15, 15, 15]
# Dataset for dimension 2 with 15 centers saved to 'datasets\dataset_1\dataset_dim_2.txt'
# Dataset for dimension 3 with 15 centers saved to 'datasets\dataset_1\dataset_dim_3.txt'
# Dataset for dimension 5 with 15 centers saved to 'datasets\dataset_1\dataset_dim_5.txt'
# Dataset for dimension 8 with 15 centers saved to 'datasets\dataset_1\dataset_dim_8.txt'
# Dataset for dimension 10 with 15 centers saved to 'datasets\dataset_1\dataset_dim_10.txt'
# Dataset for dimension 12 with 15 centers saved to 'datasets\dataset_1\dataset_dim_12.txt'
# Dataset for dimension 15 with 15 centers saved to 'datasets\dataset_1\dataset_dim_15.txt'
# Dataset for dimension 18 with 15 centers saved to 'datasets\dataset_1\dataset_dim_18.txt'
# Dataset for dimension 20 with 15 centers saved to 'datasets\dataset_1\dataset_dim_20.txt'
# Dataset for dimension 2 with 15 centers saved to 'datasets\dataset_2\dataset_dim_2.txt'
# Dataset for dimension 3 with 15 centers saved to 'datasets\dataset_2\dataset_dim_3.txt'
# Dataset for dimension 5 with 15 centers saved to 'datasets\dataset_2\dataset_dim_5.txt'
# Dataset for dimension 8 with 15 centers saved to 'datasets\dataset_2\dataset_dim_8.txt'
# Dataset for dimension 10 with 15 centers saved to 'datasets\dataset_2\dataset_dim_10.txt'
# Dataset for dimension 12 with 15 centers saved to 'datasets\dataset_2\dataset_dim_12.txt'
# Dataset for dimension 15 with 15 centers saved to 'datasets\dataset_2\dataset_dim_15.txt'
# Dataset for dimension 18 with 15 centers saved to 'datasets\dataset_2\dataset_dim_18.txt'
# Dataset for dimension 20 with 15 centers saved to 'datasets\dataset_2\dataset_dim_20.txt'
# Dataset for dimension 2 with 15 centers saved to 'datasets\dataset_3\dataset_dim_2.txt'
# Dataset for dimension 3 with 15 centers saved to 'datasets\dataset_3\dataset_dim_3.txt'
# Dataset for dimension 5 with 15 centers saved to 'datasets\dataset_3\dataset_dim_5.txt'
# Dataset for dimension 8 with 15 centers saved to 'datasets\dataset_3\dataset_dim_8.txt'
# Dataset for dimension 10 with 15 centers saved to 'datasets\dataset_3\dataset_dim_10.txt'
# Dataset for dimension 12 with 15 centers saved to 'datasets\dataset_3\dataset_dim_12.txt'
# Dataset for dimension 15 with 15 centers saved to 'datasets\dataset_3\dataset_dim_15.txt'
# Dataset for dimension 18 with 15 centers saved to 'datasets\dataset_3\dataset_dim_18.txt'
# Dataset for dimension 20 with 15 centers saved to 'datasets\dataset_3\dataset_dim_20.txt'
# Dataset for dimension 2 with 15 centers saved to 'datasets\dataset_4\dataset_dim_2.txt'
# Dataset for dimension 3 with 15 centers saved to 'datasets\dataset_4\dataset_dim_3.txt'
# Dataset for dimension 5 with 15 centers saved to 'datasets\dataset_4\dataset_dim_5.txt'
# Dataset for dimension 8 with 15 centers saved to 'datasets\dataset_4\dataset_dim_8.txt'
# Dataset for dimension 10 with 15 centers saved to 'datasets\dataset_4\dataset_dim_10.txt'
# Dataset for dimension 12 with 15 centers saved to 'datasets\dataset_4\dataset_dim_12.txt'
# Dataset for dimension 15 with 15 centers saved to 'datasets\dataset_4\dataset_dim_15.txt'
# Dataset for dimension 18 with 15 centers saved to 'datasets\dataset_4\dataset_dim_18.txt'
# Dataset for dimension 20 with 15 centers saved to 'datasets\dataset_4\dataset_dim_20.txt'
# Dataset for dimension 2 with 15 centers saved to 'datasets\dataset_5\dataset_dim_2.txt'
# Dataset for dimension 3 with 15 centers saved to 'datasets\dataset_5\dataset_dim_3.txt'
# Dataset for dimension 5 with 15 centers saved to 'datasets\dataset_5\dataset_dim_5.txt'
# Dataset for dimension 8 with 15 centers saved to 'datasets\dataset_5\dataset_dim_8.txt'
# Dataset for dimension 10 with 15 centers saved to 'datasets\dataset_5\dataset_dim_10.txt'
# Dataset for dimension 12 with 15 centers saved to 'datasets\dataset_5\dataset_dim_12.txt'
# Dataset for dimension 15 with 15 centers saved to 'datasets\dataset_5\dataset_dim_15.txt'
# Dataset for dimension 18 with 15 centers saved to 'datasets\dataset_5\dataset_dim_18.txt'
# Dataset for dimension 20 with 15 centers saved to 'datasets\dataset_5\dataset_dim_20.txt'
# Dataset for dimension 2 with 15 centers saved to 'datasets\dataset_6\dataset_dim_2.txt'
# Dataset for dimension 3 with 15 centers saved to 'datasets\dataset_6\dataset_dim_3.txt'
# Dataset for dimension 5 with 15 centers saved to 'datasets\dataset_6\dataset_dim_5.txt'
# Dataset for dimension 8 with 15 centers saved to 'datasets\dataset_6\dataset_dim_8.txt'
# Dataset for dimension 10 with 15 centers saved to 'datasets\dataset_6\dataset_dim_10.txt'
# Dataset for dimension 12 with 15 centers saved to 'datasets\dataset_6\dataset_dim_12.txt'
# Dataset for dimension 15 with 15 centers saved to 'datasets\dataset_6\dataset_dim_15.txt'
# Dataset for dimension 18 with 15 centers saved to 'datasets\dataset_6\dataset_dim_18.txt'
# Dataset for dimension 20 with 15 centers saved to 'datasets\dataset_6\dataset_dim_20.txt'
# Dataset for dimension 2 with 15 centers saved to 'datasets\dataset_7\dataset_dim_2.txt'
# Dataset for dimension 3 with 15 centers saved to 'datasets\dataset_7\dataset_dim_3.txt'
# Dataset for dimension 5 with 15 centers saved to 'datasets\dataset_7\dataset_dim_5.txt'
# Dataset for dimension 8 with 15 centers saved to 'datasets\dataset_7\dataset_dim_8.txt'
# Dataset for dimension 10 with 15 centers saved to 'datasets\dataset_7\dataset_dim_10.txt'
# Dataset for dimension 12 with 15 centers saved to 'datasets\dataset_7\dataset_dim_12.txt'
# Dataset for dimension 15 with 15 centers saved to 'datasets\dataset_7\dataset_dim_15.txt'
# Dataset for dimension 18 with 15 centers saved to 'datasets\dataset_7\dataset_dim_18.txt'
# Dataset for dimension 20 with 15 centers saved to 'datasets\dataset_7\dataset_dim_20.txt'
# Dataset for dimension 2 with 15 centers saved to 'datasets\dataset_8\dataset_dim_2.txt'
# Dataset for dimension 3 with 15 centers saved to 'datasets\dataset_8\dataset_dim_3.txt'
# Dataset for dimension 5 with 15 centers saved to 'datasets\dataset_8\dataset_dim_5.txt'
# Dataset for dimension 8 with 15 centers saved to 'datasets\dataset_8\dataset_dim_8.txt'
# Dataset for dimension 10 with 15 centers saved to 'datasets\dataset_8\dataset_dim_10.txt'
# Dataset for dimension 12 with 15 centers saved to 'datasets\dataset_8\dataset_dim_12.txt'
# Dataset for dimension 15 with 15 centers saved to 'datasets\dataset_8\dataset_dim_15.txt'
# Dataset for dimension 18 with 15 centers saved to 'datasets\dataset_8\dataset_dim_18.txt'
# Dataset for dimension 20 with 15 centers saved to 'datasets\dataset_8\dataset_dim_20.txt'
# Dataset for dimension 2 with 15 centers saved to 'datasets\dataset_9\dataset_dim_2.txt'
# Dataset for dimension 3 with 15 centers saved to 'datasets\dataset_9\dataset_dim_3.txt'
# Dataset for dimension 5 with 15 centers saved to 'datasets\dataset_9\dataset_dim_5.txt'
# Dataset for dimension 8 with 15 centers saved to 'datasets\dataset_9\dataset_dim_8.txt'
# Dataset for dimension 10 with 15 centers saved to 'datasets\dataset_9\dataset_dim_10.txt'
# Dataset for dimension 12 with 15 centers saved to 'datasets\dataset_9\dataset_dim_12.txt'
# Dataset for dimension 15 with 15 centers saved to 'datasets\dataset_9\dataset_dim_15.txt'
# Dataset for dimension 18 with 15 centers saved to 'datasets\dataset_9\dataset_dim_18.txt'
# Dataset for dimension 20 with 15 centers saved to 'datasets\dataset_9\dataset_dim_20.txt'
# Dataset for dimension 2 with 15 centers saved to 'datasets\dataset_10\dataset_dim_2.txt'
# Dataset for dimension 3 with 15 centers saved to 'datasets\dataset_10\dataset_dim_3.txt'
# Dataset for dimension 5 with 15 centers saved to 'datasets\dataset_10\dataset_dim_5.txt'
# Dataset for dimension 8 with 15 centers saved to 'datasets\dataset_10\dataset_dim_8.txt'
# Dataset for dimension 10 with 15 centers saved to 'datasets\dataset_10\dataset_dim_10.txt'
# Dataset for dimension 12 with 15 centers saved to 'datasets\dataset_10\dataset_dim_12.txt'
# Dataset for dimension 15 with 15 centers saved to 'datasets\dataset_10\dataset_dim_15.txt'
# Dataset for dimension 18 with 15 centers saved to 'datasets\dataset_10\dataset_dim_18.txt'
# Dataset for dimension 20 with 15 centers saved to 'datasets\dataset_10\dataset_dim_20.txt'

# %% [markdown]
# # Training and Test Point Generation
#
# Can be modified to turn on non-conservative vector field generation.

# %%
import os
import sys
import numpy as np
import torch
from pathlib import Path
# Add parent directory to sys.path
parent_dir = Path.cwd().parent
sys.path.append(str(parent_dir))
# Import modules
from dataset_gen import vector_function, random_input_points, generate_random_transform_matrix

# Folder containing datasets
dataset_folder = "datasets"
num_samples = 10000 #Number of test and train data points.

def print_vector_stats(points, values, label):
    """Helper function to calculate and print vector statistics"""
    avg_vector = np.mean(values.numpy(), axis=0)
    vector_magnitude = np.linalg.norm(avg_vector)
    print(f"\n{label} Vector Statistics:")
    print(f"Average vector: {avg_vector}")
    print(f"Vector magnitude: {vector_magnitude:.4f}")
    print(f"Min value: {np.min(values.numpy()):.4f}")
    print(f"Max value: {np.max(values.numpy()):.4f}")
    print(f"Mean absolute value: {np.mean(np.abs(values.numpy())):.4f}")
    return avg_vector

# Iterate through all subfolders in the dataset folder
for subfolder in os.listdir(dataset_folder):
    subfolder_path = os.path.join(dataset_folder, subfolder)
    
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")

        # Create train and test subfolders if they don't exist
        train_folder = os.path.join(subfolder_path, "train")
        test_folder = os.path.join(subfolder_path, "test")
        os.makedirs(train_folder, exist_ok=True)
        os.makedirs(test_folder, exist_ok=True)
        
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".txt"):
                filepath = os.path.join(subfolder_path, filename)
                loaded_data = np.loadtxt(filepath)
        
                dimension = loaded_data.shape[1] - 2
                print(f"Processing {filename} with dimension {dimension}")
                
                # Separate the data
                centers = torch.tensor(loaded_data[:, :dimension], dtype=torch.float32)
                amplitudes = torch.tensor(loaded_data[:, -2], dtype=torch.float32)
                sigmas = torch.tensor(loaded_data[:, -1], dtype=torch.float32)

                # Generate random transformation matrix using dimension as seed
                # Only necessary for testing a non-conservative vector field.
                #transform_matrix = generate_random_transform_matrix(dimension, seed=dimension)
                #print("Generated transformation matrix:")
                #print(transform_matrix)
        
                # Generate points and values
                train_points = random_input_points(num_samples, dimension, seed=dimension)
                test_points = random_input_points(num_samples, dimension, seed=dimension+30)
                train_values = vector_function(train_points, centers, amplitudes, sigmas, center_batch_size=100)# transform_matrix, center_batch_size=100)
                test_values = vector_function(test_points, centers, amplitudes, sigmas, center_batch_size=100)# transform_matrix, center_batch_size=100)

                # Print statistics - Uncomment to see statistics
                #train_avg = print_vector_stats(train_points, train_values, "Training")
                #test_avg = print_vector_stats(test_points, test_values, "Test")
                
                # Save files
                base_name = os.path.splitext(filename)[0]
                
                # Save train data
                train_data = np.column_stack((train_points.numpy(), train_values.numpy()))
                train_filename = os.path.join(train_folder, f"{base_name}_train.txt")
                np.savetxt(train_filename, train_data)
                
                # Save test data
                test_data = np.column_stack((test_points.numpy(), test_values.numpy()))
                test_filename = os.path.join(test_folder, f"{base_name}_test.txt")
                np.savetxt(test_filename, test_data)
                
                print(f"Saved train/test data for {filename}")
print ("Done!")
# Out:
# Processing folder: dataset_1
# Processing dataset_dim_10.txt with dimension 10
#
# Training Vector Statistics:
# Average vector: [ 0.06501458  0.01989115 -0.14391151  0.31267285 -0.0956817  -0.06411502
#  -0.08908417 -0.08562692 -0.10612997 -0.02451727]
# Vector magnitude: 0.4043
# Min value: -1.7199
# Max value: 1.5854
# Mean absolute value: 0.3859
#
# Test Vector Statistics:
# Average vector: [ 0.06043554  0.02266128 -0.13299198  0.314221   -0.1002426  -0.06095902
#  -0.0899049  -0.07712398 -0.10715395 -0.03322079]
# Vector magnitude: 0.4012
# Min value: -1.5680
# Max value: 1.7623
# Mean absolute value: 0.3871
# Saved train/test data for dataset_dim_10.txt
# Processing dataset_dim_12.txt with dimension 12
#
# Training Vector Statistics:
# Average vector: [ 0.04355454 -0.0996571   0.07865205  0.14096478  0.06766164 -0.05106686
#   0.14698052  0.06042635 -0.01467666  0.08204866 -0.01878003 -0.00210348]
# Vector magnitude: 0.2786
# Min value: -1.0851
# Max value: 1.1450
# Mean absolute value: 0.2400
#
# Test Vector Statistics:
# Average vector: [ 0.04111265 -0.09275347  0.07980828  0.14302056  0.06537596 -0.05103117
#   0.15255821  0.05524614 -0.01426402  0.08197118 -0.02263312 -0.00443048]
# Vector magnitude: 0.2789
# Min value: -1.1264
# Max value: 1.1641
# Mean absolute value: 0.2402
# Saved train/test data for dataset_dim_12.txt
# Processing dataset_dim_15.txt with dimension 15
#
# Training Vector Statistics:
# Average vector: [ 0.00570789  0.02030534 -0.01358213  0.00421603 -0.00547628 -0.0460629
#  -0.05164316 -0.11806104 -0.00680069  0.05466795  0.01988843 -0.08563472
#  -0.04185924  0.00968898 -0.08388841]
# Vector magnitude: 0.1976
# Min value: -0.6127
# Max value: 0.6284
# Mean absolute value: 0.1098
#
# Test Vector Statistics:
# Average vector: [ 0.00406155  0.01909425 -0.01181026  0.00395529 -0.00604329 -0.04725389
#  -0.05153176 -0.1141079  -0.00778247  0.05510327  0.02034338 -0.0860924
#  -0.04425638  0.00982186 -0.08334721]
# Vector magnitude: 0.1960
# Min value: -0.6261
# Max value: 0.6895
# Mean absolute value: 0.1103
# Saved train/test data for dataset_dim_15.txt
# Processing dataset_dim_18.txt with dimension 18
#
# Training Vector Statistics:
# Average vector: [ 0.03154102  0.02250683 -0.00316728 -0.02525949 -0.00485994 -0.00605249
#   0.00495938  0.03307797  0.00499076  0.02059053 -0.04372366  0.03500351
#   0.00927343 -0.01849258  0.0302589  -0.00234385 -0.01537281  0.00154228]
# Vector magnitude: 0.0922
# Min value: -0.7008
# Max value: 0.5465
# Mean absolute value: 0.0583
#
# Test Vector Statistics:
# Average vector: [ 0.03040782  0.02267916 -0.00420288 -0.02540429 -0.00563927 -0.00341514
#   0.00565857  0.03199287  0.0072757   0.02115426 -0.04526991  0.03458279
#   0.00853305 -0.01929025  0.0287488  -0.00081904 -0.01605272  0.00064882]
# Vector magnitude: 0.0921
# Min value: -0.5719
# Max value: 0.5395
# Mean absolute value: 0.0583
# Saved train/test data for dataset_dim_18.txt
# Processing dataset_dim_2.txt with dimension 2
#
# Training Vector Statistics:
# Average vector: [ 0.6581259 -0.6585362]
# Vector magnitude: 0.9310
# Min value: -6.7063
# Max value: 5.3031
# Mean absolute value: 3.0780
#
# Test Vector Statistics:
# Average vector: [ 0.59208405 -0.61423415]
# Vector magnitude: 0.8531
# Min value: -6.7056
# Max value: 5.3144
# Mean absolute value: 3.0851
# Saved train/test data for dataset_dim_2.txt
# Processing dataset_dim_20.txt with dimension 20
#
# Training Vector Statistics:
# Average vector: [-0.01917676  0.00474831  0.01522301 -0.01897418  0.00038722  0.03485312
#  -0.00048574 -0.02969907  0.03179315 -0.00583106  0.02833029  0.01256047
#   0.00619939 -0.00384011  0.01492248  0.00944386  0.04609257  0.00490708
#   0.02268436  0.00401728]
# Vector magnitude: 0.0902
# Min value: -0.3200
# Max value: 0.4160
# Mean absolute value: 0.0421
#
# Test Vector Statistics:
# Average vector: [-0.01833279  0.00522444  0.01376322 -0.02024468  0.00054205  0.0335235
#  -0.00120154 -0.0299054   0.03080441 -0.0051163   0.02834205  0.01227119
#   0.00545874 -0.0037306   0.0158751   0.01002313  0.04782819  0.00430834
#   0.02278209  0.00333186]
# Vector magnitude: 0.0902
# Min value: -0.3303
# Max value: 0.3904
# Mean absolute value: 0.0419
# Saved train/test data for dataset_dim_20.txt
# Processing dataset_dim_3.txt with dimension 3
#
# Training Vector Statistics:
# Average vector: [ 0.5250813  -0.19373599  0.46466178]
# Vector magnitude: 0.7274
# Min value: -5.3847
# Max value: 5.0784
# Mean absolute value: 2.3335
#
# Test Vector Statistics:
# Average vector: [ 0.5252848 -0.1446579  0.5177354]
# Vector magnitude: 0.7516
# Min value: -5.3580
# Max value: 5.0654
# Mean absolute value: 2.3367
# Saved train/test data for dataset_dim_3.txt
# Processing dataset_dim_5.txt with dimension 5
#
# Training Vector Statistics:
# Average vector: [ 0.18047303  0.10609136 -0.48874682 -0.21954526  0.08465029]
# Vector magnitude: 0.5814
# Min value: -3.1250
# Max value: 3.3205
# Mean absolute value: 0.8926
#
# Test Vector Statistics:
# Average vector: [ 0.17060384  0.09142742 -0.4807024  -0.20629103  0.07352154]
# Vector magnitude: 0.5626
# Min value: -3.2984
# Max value: 3.0713
# Mean absolute value: 0.8929
# Saved train/test data for dataset_dim_5.txt
# Processing dataset_dim_8.txt with dimension 8
#
# Training Vector Statistics:
# Average vector: [-0.07705981  0.064299   -0.09415349  0.24575491 -0.04131461 -0.14353856
#  -0.2894077   0.2399326 ]
# Vector magnitude: 0.4929
# Min value: -2.1714
# Max value: 2.2018
# Mean absolute value: 0.6503
#
# Test Vector Statistics:
# Average vector: [-0.07632659  0.059411   -0.08044536  0.26341334 -0.03678303 -0.1487041
#  -0.29359552  0.23076524]
# Vector magnitude: 0.4981
# Min value: -2.1637
# Max value: 2.1599
# Mean absolute value: 0.6504
# Saved train/test data for dataset_dim_8.txt
# Processing folder: dataset_10
# Processing dataset_dim_10.txt with dimension 10
#
# Training Vector Statistics:
# Average vector: [ 0.10285283  0.14146905  0.04744787 -0.15128973  0.19833006  0.02811281
#  -0.07607975 -0.09242682  0.16417001  0.095872  ]
# Vector magnitude: 0.3825
# Min value: -1.6344
# Max value: 1.7187
# Mean absolute value: 0.3971
#
# Test Vector Statistics:
# Average vector: [ 0.10118355  0.1482485   0.06335548 -0.14437427  0.19866928  0.03828274
#  -0.07816152 -0.08671281  0.16157433  0.08419272]
# Vector magnitude: 0.3806
# Min value: -1.6072
# Max value: 1.7163
# Mean absolute value: 0.3969
# Saved train/test data for dataset_dim_10.txt
# Processing dataset_dim_12.txt with dimension 12
#
# Training Vector Statistics:
# Average vector: [-0.0433663  -0.05870012 -0.00247118 -0.06561331  0.06015139  0.03602244
#  -0.00215027 -0.04713434 -0.03916069 -0.08441763 -0.01924206 -0.04839906]
# Vector magnitude: 0.1678
# Min value: -1.0488
# Max value: 1.0312
# Mean absolute value: 0.2150
#
# Test Vector Statistics:
# Average vector: [-0.04616258 -0.05558657 -0.00141303 -0.06655736  0.05971425  0.03911724
#   0.00425879 -0.05354356 -0.04047678 -0.08435939 -0.02147151 -0.04968393]
# Vector magnitude: 0.1712
# Min value: -0.9482
# Max value: 0.9316
# Mean absolute value: 0.2152
# Saved train/test data for dataset_dim_12.txt
# Processing dataset_dim_15.txt with dimension 15
#
# Training Vector Statistics:
# Average vector: [-0.03060758 -0.04591    -0.03712931  0.02095008 -0.05455943 -0.05047747
#   0.05436997 -0.03183658  0.01493983 -0.00222507  0.07456899  0.03292428
#   0.05396497 -0.00490422  0.01779884]
# Vector magnitude: 0.1565
# Min value: -0.6335
# Max value: 0.5787
# Mean absolute value: 0.0945
#
# Test Vector Statistics:
# Average vector: [-0.03103688 -0.04564992 -0.03612205  0.02031617 -0.05483577 -0.0500559
#   0.05496012 -0.02702851  0.01422754 -0.00270809  0.07423364  0.03233844
#   0.05215776 -0.00513287  0.01875577]
# Vector magnitude: 0.1546
# Min value: -0.5654
# Max value: 0.5785
# Mean absolute value: 0.0942
# Saved train/test data for dataset_dim_15.txt
# Processing dataset_dim_18.txt with dimension 18
#
# Training Vector Statistics:
# Average vector: [-0.05076164  0.01779997 -0.01310027 -0.03067919  0.02813578 -0.00076107
#   0.04502295  0.06367378  0.04674447 -0.01261584 -0.03403094  0.00694119
#   0.0256204   0.04605513  0.02612482 -0.00081968 -0.05231658 -0.02652462]
# Vector magnitude: 0.1461
# Min value: -0.5825
# Max value: 0.5767
# Mean absolute value: 0.0868
#
# Test Vector Statistics:
# Average vector: [-0.05224636  0.01789879 -0.01389196 -0.03023207  0.02841306  0.00272681
#   0.04598832  0.06217925  0.04837666 -0.01275143 -0.03534584  0.00721863
#   0.0248163   0.0446693   0.02304998  0.00018382 -0.0532371  -0.02725129]
# Vector magnitude: 0.1465
# Min value: -0.5005
# Max value: 0.5473
# Mean absolute value: 0.0862
# Saved train/test data for dataset_dim_18.txt
# Processing dataset_dim_2.txt with dimension 2
#
# Training Vector Statistics:
# Average vector: [ 0.58885217 -0.05305038]
# Vector magnitude: 0.5912
# Min value: -4.7180
# Max value: 5.3291
# Mean absolute value: 2.4120
#
# Test Vector Statistics:
# Average vector: [ 0.5284269  -0.01799646]
# Vector magnitude: 0.5287
# Min value: -4.7258
# Max value: 5.3378
# Mean absolute value: 2.4201
# Saved train/test data for dataset_dim_2.txt
# Processing dataset_dim_20.txt with dimension 20
#
# Training Vector Statistics:
# Average vector: [-0.01412273  0.00451636 -0.00807301  0.02390566  0.00194472  0.01477904
#  -0.04319391 -0.00920182 -0.01181857  0.02573545  0.00079184 -0.02881955
#   0.01038699 -0.02449519 -0.01774497 -0.06192501 -0.04996814 -0.02965605
#   0.03432081  0.00589134]
# Vector magnitude: 0.1188
# Min value: -0.4220
# Max value: 0.3649
# Mean absolute value: 0.0587
#
# Test Vector Statistics:
# Average vector: [-0.01281969  0.00452432 -0.00805167  0.02295492  0.00161272  0.01381142
#  -0.04358355 -0.0096774  -0.01304429  0.02645859  0.00027809 -0.02886658
#   0.0099094  -0.02419224 -0.01638319 -0.06112833 -0.04806234 -0.03004012
#   0.03445213  0.00594851]
# Vector magnitude: 0.1174
# Min value: -0.3953
# Max value: 0.3788
# Mean absolute value: 0.0591
# Saved train/test data for dataset_dim_20.txt
# Processing dataset_dim_3.txt with dimension 3
#
# Training Vector Statistics:
# Average vector: [ 0.30577818 -0.12454243 -0.42599425]
# Vector magnitude: 0.5390
# Min value: -5.2175
# Max value: 4.8339
# Mean absolute value: 2.0539
#
# Test Vector Statistics:
# Average vector: [ 0.29584825 -0.07023502 -0.36424762]
# Vector magnitude: 0.4745
# Min value: -5.2161
# Max value: 4.8710
# Mean absolute value: 2.0509
# Saved train/test data for dataset_dim_3.txt
# Processing dataset_dim_5.txt with dimension 5
#
# Training Vector Statistics:
# Average vector: [-0.24734646 -0.20055802 -0.38081473 -0.07069901 -0.12144697]
# Vector magnitude: 0.5159
# Min value: -2.8487
# Max value: 2.8120
# Mean absolute value: 0.9643
#
# Test Vector Statistics:
# Average vector: [-0.26596564 -0.21084557 -0.36535218 -0.05522667 -0.12765662]
# Vector magnitude: 0.5177
# Min value: -2.8543
# Max value: 2.8129
# Mean absolute value: 0.9650
# Saved train/test data for dataset_dim_5.txt
# Processing dataset_dim_8.txt with dimension 8
#
# Training Vector Statistics:
# Average vector: [ 0.2718206  -0.02804831  0.0187062   0.06249318  0.27635574  0.25079864
#  -0.15421858 -0.08948033]
# Vector magnitude: 0.5000
# Min value: -1.5484
# Max value: 1.7407
# Mean absolute value: 0.4253
#
# Test Vector Statistics:
# Average vector: [ 0.26991394 -0.03343917  0.02828522  0.07301769  0.2784229   0.2510178
#  -0.16033033 -0.0978419 ]
# Vector magnitude: 0.5059
# Min value: -1.6320
# Max value: 2.0265
# Mean absolute value: 0.4238
# Saved train/test data for dataset_dim_8.txt
# Processing folder: dataset_2
# Processing dataset_dim_10.txt with dimension 10
#
# Training Vector Statistics:
# Average vector: [ 0.11496953 -0.0476489  -0.14820142 -0.02413098 -0.05493358 -0.16524532
#  -0.15978676 -0.07514617  0.08517657 -0.11964369]
# Vector magnitude: 0.3480
# Min value: -1.2552
# Max value: 1.1306
# Mean absolute value: 0.2455
#
# Test Vector Statistics:
# Average vector: [ 0.11436581 -0.04446381 -0.14008132 -0.02340831 -0.05705036 -0.16340104
#  -0.16045092 -0.0700591   0.08275663 -0.12576805]
# Vector magnitude: 0.3442
# Min value: -1.1759
# Max value: 1.1443
# Mean absolute value: 0.2466
# Saved train/test data for dataset_dim_10.txt
# Processing dataset_dim_12.txt with dimension 12
#
# Training Vector Statistics:
# Average vector: [ 5.8028411e-02  1.0580216e-01 -1.5804995e-02  4.8760787e-02
#   1.1061437e-01 -7.7610165e-02 -7.4592642e-02 -9.4210608e-03
#  -3.5196483e-02 -1.3643804e-01 -1.1932258e-02 -5.4159231e-05]
# Vector magnitude: 0.2472
# Min value: -1.0813
# Max value: 0.9802
# Mean absolute value: 0.2150
#
# Test Vector Statistics:
# Average vector: [ 0.05777059  0.11061205 -0.01420756  0.04919261  0.10867602 -0.07497601
#  -0.06773946 -0.01352409 -0.03663708 -0.13666613 -0.01771929 -0.00044211]
# Vector magnitude: 0.2464
# Min value: -1.1077
# Max value: 1.0565
# Mean absolute value: 0.2149
# Saved train/test data for dataset_dim_12.txt
# Processing dataset_dim_15.txt with dimension 15
#
# Training Vector Statistics:
# Average vector: [ 0.01085597  0.00900657 -0.09933048  0.05597483 -0.06130486 -0.01174855
#  -0.00864298  0.03886601  0.03655542  0.0119138  -0.01809629 -0.01223559
#  -0.07235552  0.00056386 -0.0177672 ]
# Vector magnitude: 0.1618
# Min value: -0.6196
# Max value: 0.6267
# Mean absolute value: 0.1062
#
# Test Vector Statistics:
# Average vector: [ 0.01040018  0.00742008 -0.09688069  0.05497829 -0.06233079 -0.01258987
#  -0.0074124   0.04374753  0.03581271  0.01255655 -0.01659868 -0.0126336
#  -0.07343102  0.0010047  -0.01605647]
# Vector magnitude: 0.1616
# Min value: -0.7050
# Max value: 0.6706
# Mean absolute value: 0.1060
# Saved train/test data for dataset_dim_15.txt
# Processing dataset_dim_18.txt with dimension 18
#
# Training Vector Statistics:
# Average vector: [ 0.04266666  0.00457136 -0.07333857 -0.02186449  0.04092176 -0.00301668
#   0.01565511 -0.03144423 -0.02177987  0.01119273  0.01695924 -0.05128672
#  -0.01953486  0.03228045  0.02269002  0.00617515  0.00466252 -0.0114389 ]
# Vector magnitude: 0.1275
# Min value: -0.5152
# Max value: 0.4944
# Mean absolute value: 0.0796
#
# Test Vector Statistics:
# Average vector: [ 0.04119535  0.00402288 -0.07538161 -0.02288368  0.04107164 -0.00105261
#   0.01644343 -0.03145155 -0.01981775  0.01171013  0.01688097 -0.05053822
#  -0.01967617  0.03182275  0.0209054   0.00655928  0.00357578 -0.01334582]
# Vector magnitude: 0.1277
# Min value: -0.4715
# Max value: 0.4839
# Mean absolute value: 0.0794
# Saved train/test data for dataset_dim_18.txt
# Processing dataset_dim_2.txt with dimension 2
#
# Training Vector Statistics:
# Average vector: [-0.61496973 -1.2226737 ]
# Vector magnitude: 1.3686
# Min value: -5.7142
# Max value: 4.6038
# Mean absolute value: 2.4802
#
# Test Vector Statistics:
# Average vector: [-0.67714417 -1.1762183 ]
# Vector magnitude: 1.3572
# Min value: -5.7113
# Max value: 4.6302
# Mean absolute value: 2.4815
# Saved train/test data for dataset_dim_2.txt
# Processing dataset_dim_20.txt with dimension 20
#
# Training Vector Statistics:
# Average vector: [ 0.00320266 -0.02603518  0.00827945  0.01651976 -0.04655591 -0.00114287
#   0.01067162  0.00057981  0.04298049 -0.00419177 -0.00022585 -0.02969405
#  -0.00381842 -0.00047694  0.02438421  0.00727943 -0.00695792 -0.02641096
#  -0.00298484  0.03161549]
# Vector magnitude: 0.0921
# Min value: -0.3843
# Max value: 0.4171
# Mean absolute value: 0.0566
#
# Test Vector Statistics:
# Average vector: [ 5.0721285e-03 -2.5310537e-02  7.3446562e-03  1.4448094e-02
#  -4.5893479e-02 -1.4791813e-03  1.0682480e-02 -5.1130954e-04
#   4.1509911e-02 -4.0478939e-03 -8.5812673e-04 -3.0420419e-02
#  -4.8856419e-03  5.6050896e-05  2.4695877e-02  7.8623910e-03
#  -4.9260161e-03 -2.6518365e-02 -4.0444625e-03  3.1246375e-02]
# Vector magnitude: 0.0907
# Min value: -0.3869
# Max value: 0.3944
# Mean absolute value: 0.0565
# Saved train/test data for dataset_dim_20.txt
# Processing dataset_dim_3.txt with dimension 3
#
# Training Vector Statistics:
# Average vector: [0.02150078 0.39115742 1.117937  ]
# Vector magnitude: 1.1846
# Min value: -4.2943
# Max value: 4.7144
# Mean absolute value: 2.0568
#
# Test Vector Statistics:
# Average vector: [0.02802985 0.4254174  1.1488897 ]
# Vector magnitude: 1.2254
# Min value: -4.2949
# Max value: 4.7196
# Mean absolute value: 2.0695
# Saved train/test data for dataset_dim_3.txt
# Processing dataset_dim_5.txt with dimension 5
#
# Training Vector Statistics:
# Average vector: [-0.90749216 -0.02356173  0.31251088  0.11113735 -0.33561552]
# Vector magnitude: 1.0231
# Min value: -3.6090
# Max value: 3.2475
# Mean absolute value: 1.1698
#
# Test Vector Statistics:
# Average vector: [-0.92513144 -0.03516867  0.31997007  0.12953356 -0.3406583 ]
# Vector magnitude: 1.0451
# Min value: -3.5777
# Max value: 3.4294
# Mean absolute value: 1.1711
# Saved train/test data for dataset_dim_5.txt
# Processing dataset_dim_8.txt with dimension 8
#
# Training Vector Statistics:
# Average vector: [-0.2874188  -0.08114811  0.14102428 -0.18581766  0.3183066   0.11219193
#  -0.09376236 -0.01770585]
# Vector magnitude: 0.5164
# Min value: -2.3693
# Max value: 2.3773
# Mean absolute value: 0.6555
#
# Test Vector Statistics:
# Average vector: [-0.28512987 -0.08509132  0.15379721 -0.17192413  0.32124752  0.11165208
#  -0.10109035 -0.02787758]
# Vector magnitude: 0.5181
# Min value: -2.3306
# Max value: 2.3881
# Mean absolute value: 0.6556
# Saved train/test data for dataset_dim_8.txt
# Processing folder: dataset_3
# Processing dataset_dim_10.txt with dimension 10
#
# Training Vector Statistics:
# Average vector: [ 0.16396692 -0.02601182 -0.22905923 -0.19442149 -0.23937605 -0.01676667
#   0.16104345  0.22534524  0.06694325 -0.10550718]
# Vector magnitude: 0.5174
# Min value: -1.7375
# Max value: 1.6414
# Mean absolute value: 0.4077
#
# Test Vector Statistics:
# Average vector: [ 0.16063097 -0.02399103 -0.21448982 -0.19524567 -0.24123469 -0.0129685
#   0.15610906  0.23589724  0.06314371 -0.11879138]
# Vector magnitude: 0.5167
# Min value: -1.7849
# Max value: 1.6509
# Mean absolute value: 0.4075
# Saved train/test data for dataset_dim_10.txt
# Processing dataset_dim_12.txt with dimension 12
#
# Training Vector Statistics:
# Average vector: [-0.06592641  0.10213654  0.06280927  0.08499756  0.05396611  0.04792356
#   0.01786622 -0.1369071   0.10193156  0.03876083 -0.02210546 -0.12793344]
# Vector magnitude: 0.2810
# Min value: -1.1068
# Max value: 1.0802
# Mean absolute value: 0.1625
#
# Test Vector Statistics:
# Average vector: [-0.06968005  0.1044578   0.06322131  0.08302031  0.05237252  0.04743084
#   0.02250201 -0.13985358  0.10022935  0.04218698 -0.02301003 -0.12754595]
# Vector magnitude: 0.2834
# Min value: -1.0700
# Max value: 1.2909
# Mean absolute value: 0.1614
# Saved train/test data for dataset_dim_12.txt
# Processing dataset_dim_15.txt with dimension 15
#
# Training Vector Statistics:
# Average vector: [-0.03927037 -0.00998621  0.02236654  0.00285565 -0.02217217  0.05892484
#  -0.01563344  0.0412218  -0.0044227  -0.02649279  0.02726418 -0.0575853
#  -0.0564762   0.01815202 -0.00223348]
# Vector magnitude: 0.1279
# Min value: -0.7209
# Max value: 0.7115
# Mean absolute value: 0.1245
#
# Test Vector Statistics:
# Average vector: [-0.03974962 -0.01136346  0.02354929  0.00163562 -0.02214437  0.0574187
#  -0.01499615  0.04615128 -0.00515853 -0.02582879  0.02758146 -0.05763667
#  -0.05650879  0.01987645 -0.00080643]
# Vector magnitude: 0.1295
# Min value: -0.6550
# Max value: 0.7343
# Mean absolute value: 0.1236
# Saved train/test data for dataset_dim_15.txt
# Processing dataset_dim_18.txt with dimension 18
#
# Training Vector Statistics:
# Average vector: [ 0.01698564  0.01399735 -0.00492716 -0.00297422 -0.02152795  0.00101546
#   0.02256024 -0.0315371  -0.03935767 -0.02237425 -0.01963423 -0.04117615
#  -0.02506972  0.03879189 -0.02436793 -0.03867396  0.03790975 -0.01054695]
# Vector magnitude: 0.1113
# Min value: -0.4224
# Max value: 0.3999
# Mean absolute value: 0.0617
#
# Test Vector Statistics:
# Average vector: [ 0.01570563  0.01436253 -0.00637689 -0.00283249 -0.02134589  0.00307965
#   0.02326469 -0.03250723 -0.03791985 -0.02213537 -0.02133042 -0.04094575
#  -0.02600621  0.03857771 -0.02553532 -0.03880865  0.03772496 -0.01111308]
# Vector magnitude: 0.1118
# Min value: -0.4171
# Max value: 0.4464
# Mean absolute value: 0.0618
# Saved train/test data for dataset_dim_18.txt
# Processing dataset_dim_2.txt with dimension 2
#
# Training Vector Statistics:
# Average vector: [ 0.68361557 -1.4033022 ]
# Vector magnitude: 1.5610
# Min value: -5.6515
# Max value: 5.8048
# Mean absolute value: 2.9623
#
# Test Vector Statistics:
# Average vector: [ 0.6158794 -1.3490962]
# Vector magnitude: 1.4830
# Min value: -5.6512
# Max value: 5.7926
# Mean absolute value: 2.9530
# Saved train/test data for dataset_dim_2.txt
# Processing dataset_dim_20.txt with dimension 20
#
# Training Vector Statistics:
# Average vector: [-0.0071133   0.00520251  0.00048475 -0.03271144 -0.03665037 -0.03854454
#  -0.01667096  0.00373517 -0.01551493 -0.05997214  0.00757669  0.02625569
#  -0.00061073 -0.03146328 -0.0025433  -0.0526314  -0.03945839 -0.01309453
#   0.01594631  0.01642732]
# Vector magnitude: 0.1220
# Min value: -0.4537
# Max value: 0.3733
# Mean absolute value: 0.0564
#
# Test Vector Statistics:
# Average vector: [-6.2319124e-03  4.7857291e-03  1.7489318e-05 -3.4662209e-02
#  -3.7751250e-02 -3.9861821e-02 -1.6883859e-02  3.5854140e-03
#  -1.7308978e-02 -5.9316650e-02  7.8473995e-03  2.6710708e-02
#  -1.0326765e-03 -3.0820368e-02 -8.5265341e-04 -5.2093849e-02
#  -3.7965044e-02 -1.3231621e-02  1.6700137e-02  1.6358633e-02]
# Vector magnitude: 0.1225
# Min value: -0.5017
# Max value: 0.4602
# Mean absolute value: 0.0567
# Saved train/test data for dataset_dim_20.txt
# Processing dataset_dim_3.txt with dimension 3
#
# Training Vector Statistics:
# Average vector: [1.0190228  0.40898743 0.5923315 ]
# Vector magnitude: 1.2476
# Min value: -5.4079
# Max value: 5.3261
# Mean absolute value: 2.1873
#
# Test Vector Statistics:
# Average vector: [1.017566   0.45428428 0.64052224]
# Vector magnitude: 1.2853
# Min value: -5.3941
# Max value: 5.3257
# Mean absolute value: 2.1890
# Saved train/test data for dataset_dim_3.txt
# Processing dataset_dim_5.txt with dimension 5
#
# Training Vector Statistics:
# Average vector: [-0.33438817 -0.34553707 -0.54588425 -0.7592353  -0.05194365]
# Vector magnitude: 1.0528
# Min value: -3.6797
# Max value: 3.5619
# Mean absolute value: 1.2764
#
# Test Vector Statistics:
# Average vector: [-0.35306266 -0.3636995  -0.52921546 -0.7446002  -0.06811877]
# Vector magnitude: 1.0469
# Min value: -3.7045
# Max value: 3.5036
# Mean absolute value: 1.2796
# Saved train/test data for dataset_dim_5.txt
# Processing dataset_dim_8.txt with dimension 8
#
# Training Vector Statistics:
# Average vector: [ 0.02805617  0.12643163 -0.35030147 -0.19071558 -0.20213866  0.06033635
#  -0.10802494  0.33509398]
# Vector magnitude: 0.5868
# Min value: -1.9750
# Max value: 2.2199
# Mean absolute value: 0.6346
#
# Test Vector Statistics:
# Average vector: [ 0.02883273  0.12134054 -0.3426477  -0.17500263 -0.19691943  0.05684578
#  -0.11073915  0.3218172 ]
# Vector magnitude: 0.5669
# Min value: -2.0604
# Max value: 2.2962
# Mean absolute value: 0.6351
# Saved train/test data for dataset_dim_8.txt
# Processing folder: dataset_4
# Processing dataset_dim_10.txt with dimension 10
#
# Training Vector Statistics:
# Average vector: [ 0.19316645 -0.00195303 -0.16410446 -0.1089346   0.17675439  0.15018539
#   0.10074713 -0.14078024 -0.00657573 -0.00136849]
# Vector magnitude: 0.3999
# Min value: -1.4465
# Max value: 1.5141
# Mean absolute value: 0.3777
#
# Test Vector Statistics:
# Average vector: [ 0.18901297  0.00523529 -0.14965595 -0.10732134  0.1772814   0.15905373
#   0.098262   -0.13640076 -0.01033472 -0.01522214]
# Vector magnitude: 0.3937
# Min value: -1.5924
# Max value: 1.5825
# Mean absolute value: 0.3776
# Saved train/test data for dataset_dim_10.txt
# Processing dataset_dim_12.txt with dimension 12
#
# Training Vector Statistics:
# Average vector: [-0.09387881  0.08986177  0.16741212 -0.0112023  -0.06194152 -0.02389189
#   0.08417839 -0.09562602 -0.19193582 -0.02973508  0.0547471  -0.09039526]
# Vector magnitude: 0.3385
# Min value: -1.1575
# Max value: 1.0454
# Mean absolute value: 0.2087
#
# Test Vector Statistics:
# Average vector: [-0.09641103  0.09274776  0.16653775 -0.01221421 -0.06321301 -0.02068157
#   0.08720425 -0.09967379 -0.18938845 -0.0313281   0.05167743 -0.09046974]
# Vector magnitude: 0.3398
# Min value: -0.9680
# Max value: 0.9947
# Mean absolute value: 0.2073
# Saved train/test data for dataset_dim_12.txt
# Processing dataset_dim_15.txt with dimension 15
#
# Training Vector Statistics:
# Average vector: [ 0.03423858 -0.09354904 -0.04760265  0.02595657 -0.00980198  0.10273626
#   0.06682728 -0.09612046 -0.02148823 -0.00357285 -0.0629845   0.01794842
#   0.03481962 -0.00742178  0.03339909]
# Vector magnitude: 0.2106
# Min value: -0.7352
# Max value: 0.7264
# Mean absolute value: 0.1332
#
# Test Vector Statistics:
# Average vector: [ 0.03325339 -0.09525925 -0.04463371  0.02434918 -0.01032854  0.10316052
#   0.06736368 -0.09102    -0.02259868 -0.00273434 -0.06311961  0.01688906
#   0.03317185 -0.00755599  0.03570832]
# Vector magnitude: 0.2087
# Min value: -0.6838
# Max value: 0.7680
# Mean absolute value: 0.1333
# Saved train/test data for dataset_dim_15.txt
# Processing dataset_dim_18.txt with dimension 18
#
# Training Vector Statistics:
# Average vector: [ 0.02391907  0.04472172 -0.01595972  0.06270288  0.05763259 -0.0420246
#   0.02580611  0.00337767 -0.06108874 -0.00382288 -0.0388656  -0.05313909
#   0.01618235  0.04092909  0.04210788  0.00407485 -0.00348112 -0.0191291 ]
# Vector magnitude: 0.1572
# Min value: -0.6789
# Max value: 0.6752
# Mean absolute value: 0.1281
#
# Test Vector Statistics:
# Average vector: [ 0.02070494  0.04421687 -0.01974994  0.0620653   0.0577548  -0.036408
#   0.02755353  0.00249778 -0.05758143 -0.00351226 -0.04248559 -0.05270909
#   0.01471214  0.04012624  0.0410642   0.00589164 -0.00469111 -0.0208356 ]
# Vector magnitude: 0.1548
# Min value: -0.6186
# Max value: 0.6658
# Mean absolute value: 0.1284
# Saved train/test data for dataset_dim_18.txt
# Processing dataset_dim_2.txt with dimension 2
#
# Training Vector Statistics:
# Average vector: [-0.29232964  0.93253195]
# Vector magnitude: 0.9773
# Min value: -5.2586
# Max value: 5.8554
# Mean absolute value: 2.6111
#
# Test Vector Statistics:
# Average vector: [-0.35828766  0.9694769 ]
# Vector magnitude: 1.0336
# Min value: -5.2561
# Max value: 5.8643
# Mean absolute value: 2.6280
# Saved train/test data for dataset_dim_2.txt
# Processing dataset_dim_20.txt with dimension 20
#
# Training Vector Statistics:
# Average vector: [-0.01132411  0.03333871 -0.01040081  0.00134096 -0.04729662  0.00997864
#   0.00831804 -0.0050475  -0.03000157 -0.05031596  0.07494751 -0.00381171
#   0.0179798   0.06011726  0.01029601  0.01586665  0.02490134  0.03327201
#  -0.0114304   0.02653235]
# Vector magnitude: 0.1404
# Min value: -0.5234
# Max value: 0.4956
# Mean absolute value: 0.0766
#
# Test Vector Statistics:
# Average vector: [-0.01054869  0.03303783 -0.01233408 -0.0014206  -0.04726294  0.00867167
#   0.00793247 -0.00622207 -0.03121306 -0.04935002  0.07503542 -0.0045117
#   0.01729403  0.06015633  0.01245063  0.01673204  0.02840917  0.03263302
#  -0.01131307  0.02609686]
# Vector magnitude: 0.1409
# Min value: -0.4733
# Max value: 0.6058
# Mean absolute value: 0.0767
# Saved train/test data for dataset_dim_20.txt
# Processing dataset_dim_3.txt with dimension 3
#
# Training Vector Statistics:
# Average vector: [-0.34897417  0.36950028  0.2899283 ]
# Vector magnitude: 0.5851
# Min value: -5.3187
# Max value: 5.2044
# Mean absolute value: 2.1653
#
# Test Vector Statistics:
# Average vector: [-0.35237017  0.40182555  0.3275014 ]
# Vector magnitude: 0.6268
# Min value: -5.2590
# Max value: 5.1926
# Mean absolute value: 2.1761
# Saved train/test data for dataset_dim_3.txt
# Processing dataset_dim_5.txt with dimension 5
#
# Training Vector Statistics:
# Average vector: [-0.47891694 -0.3447966   0.11653636  0.283778    0.10379995]
# Vector magnitude: 0.6732
# Min value: -3.1965
# Max value: 3.1521
# Mean absolute value: 1.1202
#
# Test Vector Statistics:
# Average vector: [-0.498631   -0.35608345  0.13179089  0.29269224  0.08811679]
# Vector magnitude: 0.6973
# Min value: -3.1529
# Max value: 3.1722
# Mean absolute value: 1.1215
# Saved train/test data for dataset_dim_5.txt
# Processing dataset_dim_8.txt with dimension 8
#
# Training Vector Statistics:
# Average vector: [-0.20627436 -0.0967216  -0.03344059 -0.11957913 -0.11719906  0.40284336
#  -0.07110231 -0.2820299 ]
# Vector magnitude: 0.5727
# Min value: -1.9313
# Max value: 1.9660
# Mean absolute value: 0.4693
#
# Test Vector Statistics:
# Average vector: [-0.20416495 -0.10228562 -0.02618407 -0.11148906 -0.11540885  0.40068093
#  -0.07481491 -0.29403105]
# Vector magnitude: 0.5755
# Min value: -1.7721
# Max value: 1.9674
# Mean absolute value: 0.4693
# Saved train/test data for dataset_dim_8.txt
# Processing folder: dataset_5
# Processing dataset_dim_10.txt with dimension 10
#
# Training Vector Statistics:
# Average vector: [-0.04911036  0.2315677  -0.02260721 -0.05951196 -0.1445803   0.00818983
#  -0.03980327  0.12016577  0.01724708  0.20415501]
# Vector magnitude: 0.3729
# Min value: -1.6409
# Max value: 1.6934
# Mean absolute value: 0.4082
#
# Test Vector Statistics:
# Average vector: [-0.05150976  0.23847288 -0.00645652 -0.05779919 -0.14996092  0.01733104
#  -0.04599844  0.13011247  0.0150119   0.19299808]
# Vector magnitude: 0.3771
# Min value: -1.6737
# Max value: 1.6321
# Mean absolute value: 0.4081
# Saved train/test data for dataset_dim_10.txt
# Processing dataset_dim_12.txt with dimension 12
#
# Training Vector Statistics:
# Average vector: [-0.11599313 -0.09870426  0.06338765 -0.15423384 -0.00451357 -0.11240261
#  -0.02607347  0.01804092  0.12605561  0.018235    0.1169824  -0.00743393]
# Vector magnitude: 0.3076
# Min value: -1.0183
# Max value: 0.9870
# Mean absolute value: 0.2231
#
# Test Vector Statistics:
# Average vector: [-0.11951622 -0.09071769  0.06807806 -0.153192   -0.00718482 -0.10910392
#  -0.01780124  0.01060962  0.12446057  0.01744963  0.11368731 -0.00944914]
# Vector magnitude: 0.3030
# Min value: -0.9322
# Max value: 0.9791
# Mean absolute value: 0.2229
# Saved train/test data for dataset_dim_12.txt
# Processing dataset_dim_15.txt with dimension 15
#
# Training Vector Statistics:
# Average vector: [-0.01126715 -0.03976762  0.09881577  0.10524938  0.02855572  0.0937852
#  -0.00044834  0.01797904 -0.0966263   0.03618753 -0.02398194  0.04943683
#   0.03770365 -0.01781881  0.04710338]
# Vector magnitude: 0.2238
# Min value: -0.8820
# Max value: 0.7968
# Mean absolute value: 0.1601
#
# Test Vector Statistics:
# Average vector: [-0.01362188 -0.03989057  0.10256562  0.10418097  0.02918392  0.09291981
#   0.00071402  0.02389675 -0.09681016  0.03796702 -0.0239706   0.04968427
#   0.03597908 -0.01823743  0.04878832]
# Vector magnitude: 0.2260
# Min value: -0.8009
# Max value: 0.7726
# Mean absolute value: 0.1595
# Saved train/test data for dataset_dim_15.txt
# Processing dataset_dim_18.txt with dimension 18
#
# Training Vector Statistics:
# Average vector: [ 0.01358999  0.03422874 -0.05656807  0.00115158 -0.04098179 -0.02108317
#   0.01259633  0.00427836  0.02899441 -0.00822485 -0.0271896  -0.0420877
#   0.03619897 -0.06476788 -0.05483912 -0.00704639 -0.0146634   0.01231807]
# Vector magnitude: 0.1386
# Min value: -0.5122
# Max value: 0.3962
# Mean absolute value: 0.0651
#
# Test Vector Statistics:
# Average vector: [ 0.01227942  0.03432405 -0.05762633  0.00090452 -0.04104664 -0.01860492
#   0.01358132  0.00346213  0.03067341 -0.00778641 -0.02833796 -0.04111663
#   0.03532889 -0.06525639 -0.05563447 -0.00617533 -0.01535573  0.01090203]
# Vector magnitude: 0.1392
# Min value: -0.4365
# Max value: 0.4322
# Mean absolute value: 0.0648
# Saved train/test data for dataset_dim_18.txt
# Processing dataset_dim_2.txt with dimension 2
#
# Training Vector Statistics:
# Average vector: [ 0.23457524 -0.10360789]
# Vector magnitude: 0.2564
# Min value: -6.7532
# Max value: 6.1403
# Mean absolute value: 3.0390
#
# Test Vector Statistics:
# Average vector: [ 0.15850277 -0.05522107]
# Vector magnitude: 0.1678
# Min value: -6.7586
# Max value: 6.1479
# Mean absolute value: 3.0534
# Saved train/test data for dataset_dim_2.txt
# Processing dataset_dim_20.txt with dimension 20
#
# Training Vector Statistics:
# Average vector: [-0.01072102  0.01297814  0.03037086  0.02048369 -0.01970105  0.01896412
#   0.01773219 -0.00727409  0.01650411 -0.01135593 -0.00641587 -0.00308537
#  -0.01123146 -0.00818883  0.02755586  0.01896567  0.00103127 -0.00821794
#   0.01632835  0.00600434]
# Vector magnitude: 0.0698
# Min value: -0.3173
# Max value: 0.3148
# Mean absolute value: 0.0324
#
# Test Vector Statistics:
# Average vector: [-0.00990762  0.01298115  0.0299696   0.01929286 -0.01956131  0.01867893
#   0.01774931 -0.00795679  0.01613549 -0.01101978 -0.00676736 -0.00335463
#  -0.01207311 -0.00843693  0.0285095   0.01972252  0.00174516 -0.008974
#   0.01672046  0.00586425]
# Vector magnitude: 0.0700
# Min value: -0.2711
# Max value: 0.3677
# Mean absolute value: 0.0324
# Saved train/test data for dataset_dim_20.txt
# Processing dataset_dim_3.txt with dimension 3
#
# Training Vector Statistics:
# Average vector: [ 0.16323826 -1.0756165  -0.2585892 ]
# Vector magnitude: 1.1182
# Min value: -4.1772
# Max value: 4.3250
# Mean absolute value: 1.8578
#
# Test Vector Statistics:
# Average vector: [ 0.13334745 -1.0711471  -0.21997988]
# Vector magnitude: 1.1016
# Min value: -4.1892
# Max value: 4.1879
# Mean absolute value: 1.8582
# Saved train/test data for dataset_dim_3.txt
# Processing dataset_dim_5.txt with dimension 5
#
# Training Vector Statistics:
# Average vector: [ 0.07330678  0.20563364  0.29475495 -0.4483521  -0.18038142]
# Vector magnitude: 0.6067
# Min value: -3.2080
# Max value: 3.4889
# Mean absolute value: 1.0604
#
# Test Vector Statistics:
# Average vector: [ 0.04986778  0.18786232  0.30746853 -0.43655708 -0.18983755]
# Vector magnitude: 0.5991
# Min value: -3.1705
# Max value: 3.5564
# Mean absolute value: 1.0643
# Saved train/test data for dataset_dim_5.txt
# Processing dataset_dim_8.txt with dimension 8
#
# Training Vector Statistics:
# Average vector: [-0.0128864   0.06250244  0.01742784 -0.01468941  0.08686723  0.08053003
#  -0.0457816   0.20408115]
# Vector magnitude: 0.2497
# Min value: -2.2469
# Max value: 2.0995
# Mean absolute value: 0.5652
#
# Test Vector Statistics:
# Average vector: [-0.01446144  0.06072231  0.02596415 -0.00142066  0.09195844  0.07849518
#  -0.05174116  0.19523658]
# Vector magnitude: 0.2449
# Min value: -2.1165
# Max value: 2.1492
# Mean absolute value: 0.5649
# Saved train/test data for dataset_dim_8.txt
# Processing folder: dataset_6
# Processing dataset_dim_10.txt with dimension 10
#
# Training Vector Statistics:
# Average vector: [ 0.11129431  0.12712269 -0.1245984  -0.06084511 -0.05513652  0.05936774
#   0.14353316  0.07135953  0.16818817 -0.20423593]
# Vector magnitude: 0.3873
# Min value: -1.7554
# Max value: 1.8389
# Mean absolute value: 0.4057
#
# Test Vector Statistics:
# Average vector: [ 0.10964964  0.13262573 -0.11185385 -0.05873971 -0.05393034  0.06134798
#   0.13849644  0.077085    0.16232455 -0.21561003]
# Vector magnitude: 0.3876
# Min value: -1.7149
# Max value: 1.6865
# Mean absolute value: 0.4056
# Saved train/test data for dataset_dim_10.txt
# Processing dataset_dim_12.txt with dimension 12
#
# Training Vector Statistics:
# Average vector: [-0.04286517  0.11257035  0.03624848 -0.08162502 -0.06614693 -0.14173414
#   0.07183545 -0.02736077 -0.11164959 -0.01715603 -0.05449459  0.06492066]
# Vector magnitude: 0.2698
# Min value: -1.3516
# Max value: 1.1992
# Mean absolute value: 0.2720
#
# Test Vector Statistics:
# Average vector: [-0.04539793  0.11748436  0.03769253 -0.08238757 -0.06809564 -0.1373099
#   0.07822712 -0.03303962 -0.11292548 -0.01794628 -0.06047056  0.062693  ]
# Vector magnitude: 0.2747
# Min value: -1.2249
# Max value: 1.1978
# Mean absolute value: 0.2713
# Saved train/test data for dataset_dim_12.txt
# Processing dataset_dim_15.txt with dimension 15
#
# Training Vector Statistics:
# Average vector: [-0.04351671  0.05304642 -0.05869486 -0.01973655  0.01001099  0.06882945
#   0.01576035  0.01070785 -0.08699493 -0.01444866 -0.07304765 -0.00356976
#  -0.01043127  0.01426921  0.00287801]
# Vector magnitude: 0.1649
# Min value: -0.8546
# Max value: 0.7365
# Mean absolute value: 0.1324
#
# Test Vector Statistics:
# Average vector: [-0.04450134  0.05143585 -0.05593343 -0.01981     0.00836666  0.06764265
#   0.01613397  0.01586725 -0.08752277 -0.01448447 -0.0735486  -0.00310861
#  -0.01164744  0.01498971  0.00511478]
# Vector magnitude: 0.1643
# Min value: -0.7615
# Max value: 0.7142
# Mean absolute value: 0.1324
# Saved train/test data for dataset_dim_15.txt
# Processing dataset_dim_18.txt with dimension 18
#
# Training Vector Statistics:
# Average vector: [ 0.00577698 -0.0462125   0.04091144  0.01689284 -0.03163904  0.01216234
#   0.01241976 -0.00811168 -0.00270263  0.0517132  -0.00126442 -0.0017491
#   0.0107054   0.07095246 -0.00191434 -0.0455946  -0.02876795 -0.00375933]
# Vector magnitude: 0.1275
# Min value: -0.4926
# Max value: 0.4663
# Mean absolute value: 0.0881
#
# Test Vector Statistics:
# Average vector: [ 0.0038182  -0.04565584  0.03936354  0.01642266 -0.03122465  0.01557265
#   0.01357226 -0.00792876 -0.00193942  0.05305905 -0.00280793 -0.00147505
#   0.01039078  0.0695993  -0.00390926 -0.04524928 -0.03024265 -0.00629586]
# Vector magnitude: 0.1272
# Min value: -0.4912
# Max value: 0.5304
# Mean absolute value: 0.0884
# Saved train/test data for dataset_dim_18.txt
# Processing dataset_dim_2.txt with dimension 2
#
# Training Vector Statistics:
# Average vector: [ 0.82515645 -1.2525672 ]
# Vector magnitude: 1.4999
# Min value: -5.2487
# Max value: 4.6068
# Mean absolute value: 2.6890
#
# Test Vector Statistics:
# Average vector: [ 0.76512706 -1.2127305 ]
# Vector magnitude: 1.4339
# Min value: -5.2508
# Max value: 4.6067
# Mean absolute value: 2.6894
# Saved train/test data for dataset_dim_2.txt
# Processing dataset_dim_20.txt with dimension 20
#
# Training Vector Statistics:
# Average vector: [ 0.01007683  0.00918121  0.00788795  0.00395596  0.0514164  -0.03955125
#   0.00780334  0.00628197 -0.01778043 -0.033048   -0.02570177 -0.03018675
#   0.00318628  0.04313939 -0.01865614  0.0123482  -0.01463255  0.02883326
#  -0.00731289 -0.00443189]
# Vector magnitude: 0.1051
# Min value: -0.5275
# Max value: 0.5016
# Mean absolute value: 0.0743
#
# Test Vector Statistics:
# Average vector: [ 0.01126813  0.00889237  0.00641641  0.00186243  0.05116184 -0.04015508
#   0.00745857  0.00562541 -0.01971406 -0.03120727 -0.02611255 -0.03030103
#   0.0032815   0.04362463 -0.01644715  0.01260649 -0.01234105  0.02854682
#  -0.00843336 -0.00484079]
# Vector magnitude: 0.1046
# Min value: -0.4673
# Max value: 0.4639
# Mean absolute value: 0.0744
# Saved train/test data for dataset_dim_20.txt
# Processing dataset_dim_3.txt with dimension 3
#
# Training Vector Statistics:
# Average vector: [-0.65256786 -0.3985541  -0.5674972 ]
# Vector magnitude: 0.9522
# Min value: -4.6737
# Max value: 5.6848
# Mean absolute value: 1.9983
#
# Test Vector Statistics:
# Average vector: [-0.6669137  -0.38243786 -0.5129736 ]
# Vector magnitude: 0.9242
# Min value: -4.6674
# Max value: 5.6859
# Mean absolute value: 1.9997
# Saved train/test data for dataset_dim_3.txt
# Processing dataset_dim_5.txt with dimension 5
#
# Training Vector Statistics:
# Average vector: [-0.51245075  0.27774662 -0.02455159 -0.44654682 -0.20198616]
# Vector magnitude: 0.7619
# Min value: -3.8805
# Max value: 3.4181
# Mean absolute value: 1.2625
#
# Test Vector Statistics:
# Average vector: [-0.5377283   0.26185548 -0.0126601  -0.4264531  -0.21122551]
# Vector magnitude: 0.7644
# Min value: -3.7759
# Max value: 3.4018
# Mean absolute value: 1.2618
# Saved train/test data for dataset_dim_5.txt
# Processing dataset_dim_8.txt with dimension 8
#
# Training Vector Statistics:
# Average vector: [ 0.09718815  0.08259146 -0.08030885  0.00572629  0.3439915   0.26254588
#  -0.11135969 -0.10207421]
# Vector magnitude: 0.4825
# Min value: -1.9106
# Max value: 1.9586
# Mean absolute value: 0.4524
#
# Test Vector Statistics:
# Average vector: [ 0.09900049  0.08011907 -0.07287739  0.01531809  0.34399453  0.26215348
#  -0.11286929 -0.108963  ]
# Vector magnitude: 0.4832
# Min value: -1.8424
# Max value: 1.9190
# Mean absolute value: 0.4513
# Saved train/test data for dataset_dim_8.txt
# Processing folder: dataset_7
# Processing dataset_dim_10.txt with dimension 10
#
# Training Vector Statistics:
# Average vector: [ 0.04366262 -0.00199408 -0.20151988  0.25771266  0.01462764 -0.14232881
#  -0.12351267 -0.09626476  0.14369042 -0.07646812]
# Vector magnitude: 0.4248
# Min value: -1.5217
# Max value: 1.5854
# Mean absolute value: 0.3720
#
# Test Vector Statistics:
# Average vector: [ 0.04283158  0.00313505 -0.1909242   0.2591949   0.01759281 -0.14120075
#  -0.12389866 -0.0883546   0.14238456 -0.08568095]
# Vector magnitude: 0.4201
# Min value: -1.5344
# Max value: 1.4180
# Mean absolute value: 0.3725
# Saved train/test data for dataset_dim_10.txt
# Processing dataset_dim_12.txt with dimension 12
#
# Training Vector Statistics:
# Average vector: [-0.10939042 -0.02095219  0.10526974  0.02084628 -0.03265829 -0.04672622
#  -0.00024966  0.06138274 -0.0593393  -0.07784338 -0.04197191  0.06013401]
# Vector magnitude: 0.2142
# Min value: -1.0537
# Max value: 1.0717
# Mean absolute value: 0.2402
#
# Test Vector Statistics:
# Average vector: [-0.11407229 -0.01567431  0.10648956  0.02006265 -0.03749462 -0.04549114
#   0.00482357  0.05576773 -0.06201379 -0.0781528  -0.04662809  0.05916961]
# Vector magnitude: 0.2173
# Min value: -1.0351
# Max value: 1.0945
# Mean absolute value: 0.2403
# Saved train/test data for dataset_dim_12.txt
# Processing dataset_dim_15.txt with dimension 15
#
# Training Vector Statistics:
# Average vector: [ 0.03840265 -0.07915442 -0.08212922 -0.04136626 -0.00360147 -0.00150019
#   0.04788607 -0.02489715  0.05078968 -0.03133139  0.01544564 -0.0032082
#   0.020576   -0.01704743 -0.09606075]
# Vector magnitude: 0.1813
# Min value: -0.8290
# Max value: 0.8216
# Mean absolute value: 0.1795
#
# Test Vector Statistics:
# Average vector: [ 0.03673857 -0.08002765 -0.08026545 -0.04145917 -0.00402841 -0.00455905
#   0.04907737 -0.01825016  0.05064095 -0.03128174  0.01561672 -0.00314941
#   0.01923325 -0.01782179 -0.09454216]
# Vector magnitude: 0.1792
# Min value: -0.8043
# Max value: 0.7984
# Mean absolute value: 0.1793
# Saved train/test data for dataset_dim_15.txt
# Processing dataset_dim_18.txt with dimension 18
#
# Training Vector Statistics:
# Average vector: [ 0.02732449  0.01151005 -0.0766304   0.01698146 -0.07123583 -0.00204409
#  -0.05769094 -0.04564688  0.05282986  0.00098882 -0.07096683  0.02594958
#   0.08254219  0.01265905 -0.02850404 -0.0379353  -0.01514177 -0.02351846]
# Vector magnitude: 0.1898
# Min value: -0.5518
# Max value: 0.5828
# Mean absolute value: 0.0867
#
# Test Vector Statistics:
# Average vector: [ 0.02579063  0.01146387 -0.07803603  0.01649925 -0.07132138  0.00100984
#  -0.05614479 -0.04615508  0.05464887  0.00167106 -0.07185702  0.02617859
#   0.08195522  0.01084565 -0.03083419 -0.03695438 -0.01624682 -0.0244984 ]
# Vector magnitude: 0.1907
# Min value: -0.5634
# Max value: 0.5461
# Mean absolute value: 0.0862
# Saved train/test data for dataset_dim_18.txt
# Processing dataset_dim_2.txt with dimension 2
#
# Training Vector Statistics:
# Average vector: [ 1.1301277  -0.39752907]
# Vector magnitude: 1.1980
# Min value: -6.2718
# Max value: 6.0534
# Mean absolute value: 3.2538
#
# Test Vector Statistics:
# Average vector: [ 1.0566615  -0.34998235]
# Vector magnitude: 1.1131
# Min value: -6.2710
# Max value: 6.0692
# Mean absolute value: 3.2615
# Saved train/test data for dataset_dim_2.txt
# Processing dataset_dim_20.txt with dimension 20
#
# Training Vector Statistics:
# Average vector: [ 0.00538232 -0.00215327  0.01911821 -0.04523341 -0.01039416 -0.00943183
#  -0.00302507  0.01441423  0.05113649  0.0278978  -0.01632166 -0.04398929
#   0.00904252 -0.01768168  0.01652322  0.02215713 -0.0094394  -0.04921129
#   0.01814584 -0.02642815]
# Vector magnitude: 0.1147
# Min value: -0.4760
# Max value: 0.4506
# Mean absolute value: 0.0740
#
# Test Vector Statistics:
# Average vector: [ 0.00713893 -0.00151901  0.01817222 -0.04745004 -0.01060158 -0.01083088
#  -0.00301351  0.01417447  0.04980637  0.02960303 -0.01670218 -0.0429365
#   0.00937788 -0.01793694  0.01932654  0.023427   -0.00619351 -0.05040886
#   0.01839726 -0.02620401]
# Vector magnitude: 0.1161
# Min value: -0.4567
# Max value: 0.4642
# Mean absolute value: 0.0740
# Saved train/test data for dataset_dim_20.txt
# Processing dataset_dim_3.txt with dimension 3
#
# Training Vector Statistics:
# Average vector: [ 0.2744141   0.1765222  -0.63074476]
# Vector magnitude: 0.7101
# Min value: -4.6728
# Max value: 4.8696
# Mean absolute value: 1.9947
#
# Test Vector Statistics:
# Average vector: [ 0.2820639   0.21825027 -0.5952767 ]
# Vector magnitude: 0.6939
# Min value: -4.6781
# Max value: 4.8905
# Mean absolute value: 1.9959
# Saved train/test data for dataset_dim_3.txt
# Processing dataset_dim_5.txt with dimension 5
#
# Training Vector Statistics:
# Average vector: [ 0.04026555 -0.39396164 -0.09150461  0.30804932 -0.4888051 ]
# Vector magnitude: 0.7064
# Min value: -3.9469
# Max value: 4.0460
# Mean absolute value: 1.3487
#
# Test Vector Statistics:
# Average vector: [ 0.01827795 -0.41373444 -0.08407817  0.3247703  -0.49901405]
# Vector magnitude: 0.7301
# Min value: -4.0083
# Max value: 4.1100
# Mean absolute value: 1.3530
# Saved train/test data for dataset_dim_5.txt
# Processing dataset_dim_8.txt with dimension 8
#
# Training Vector Statistics:
# Average vector: [-0.35653666  0.17634033  0.08841323  0.16805834 -0.03753106 -0.38069928
#   0.14465056  0.03383294]
# Vector magnitude: 0.6022
# Min value: -2.0764
# Max value: 2.2684
# Mean absolute value: 0.5951
#
# Test Vector Statistics:
# Average vector: [-0.35759288  0.17161377  0.10239306  0.18470997 -0.03420534 -0.38136205
#   0.13438913  0.0266348 ]
# Vector magnitude: 0.6061
# Min value: -2.0845
# Max value: 2.2469
# Mean absolute value: 0.5946
# Saved train/test data for dataset_dim_8.txt
# Processing folder: dataset_8
# Processing dataset_dim_10.txt with dimension 10
#
# Training Vector Statistics:
# Average vector: [ 0.05352154 -0.06816987 -0.20201162  0.15591714 -0.0396507   0.24295701
#  -0.16873293  0.08347014  0.0953349   0.05953617]
# Vector magnitude: 0.4258
# Min value: -1.5351
# Max value: 1.6527
# Mean absolute value: 0.3374
#
# Test Vector Statistics:
# Average vector: [ 0.05207529 -0.06380796 -0.19068013  0.15918262 -0.04303687  0.25151944
#  -0.16951284  0.09194449  0.09181914  0.04945994]
# Vector magnitude: 0.4262
# Min value: -1.5557
# Max value: 1.6702
# Mean absolute value: 0.3381
# Saved train/test data for dataset_dim_10.txt
# Processing dataset_dim_12.txt with dimension 12
#
# Training Vector Statistics:
# Average vector: [ 0.02692964  0.0134229  -0.05670334 -0.05253602  0.04535877 -0.12068756
#   0.0116786  -0.11621542  0.02572324  0.03969337  0.07211336  0.07494931]
# Vector magnitude: 0.2241
# Min value: -1.2103
# Max value: 1.1691
# Mean absolute value: 0.2337
#
# Test Vector Statistics:
# Average vector: [ 0.02387117  0.01766904 -0.0515962  -0.05102867  0.04289078 -0.11731684
#   0.01788232 -0.12216296  0.0223169   0.04039352  0.06739107  0.07264767]
# Vector magnitude: 0.2212
# Min value: -1.2244
# Max value: 1.0995
# Mean absolute value: 0.2338
# Saved train/test data for dataset_dim_12.txt
# Processing dataset_dim_15.txt with dimension 15
#
# Training Vector Statistics:
# Average vector: [-0.00016621 -0.05571528 -0.0042348   0.001258   -0.00257151 -0.04156887
#  -0.07116043  0.01828224  0.08276808 -0.05020976 -0.06343918  0.04005931
#   0.09219702 -0.05090973 -0.02203896]
# Vector magnitude: 0.1919
# Min value: -0.8221
# Max value: 0.7783
# Mean absolute value: 0.1483
#
# Test Vector Statistics:
# Average vector: [-0.00321801 -0.0561812  -0.0014971   0.00048267 -0.00412436 -0.04314699
#  -0.06956431  0.02393281  0.08246627 -0.05004851 -0.06392904  0.04154915
#   0.09100893 -0.05158383 -0.01889358]
# Vector magnitude: 0.1920
# Min value: -0.8950
# Max value: 0.8286
# Mean absolute value: 0.1482
# Saved train/test data for dataset_dim_15.txt
# Processing dataset_dim_18.txt with dimension 18
#
# Training Vector Statistics:
# Average vector: [ 0.04743747 -0.01501768  0.09345335 -0.03096461 -0.01614907  0.04618065
#  -0.04423093  0.03102474  0.03602176 -0.01803889 -0.06252888  0.05505147
#   0.01925997 -0.02419725  0.0358541  -0.00355689 -0.021417    0.12552425]
# Vector magnitude: 0.2110
# Min value: -0.8846
# Max value: 0.7968
# Mean absolute value: 0.1611
#
# Test Vector Statistics:
# Average vector: [ 0.044767   -0.01514767  0.08758526 -0.03177053 -0.01548981  0.05241771
#  -0.04413797  0.03026919  0.03941497 -0.01784549 -0.06591199  0.05535083
#   0.01783697 -0.02537512  0.03242355 -0.00165684 -0.02195787  0.12416339]
# Vector magnitude: 0.2097
# Min value: -0.8658
# Max value: 0.8417
# Mean absolute value: 0.1616
# Saved train/test data for dataset_dim_18.txt
# Processing dataset_dim_2.txt with dimension 2
#
# Training Vector Statistics:
# Average vector: [-0.9311085 -0.503043 ]
# Vector magnitude: 1.0583
# Min value: -6.1001
# Max value: 6.0305
# Mean absolute value: 3.1153
#
# Test Vector Statistics:
# Average vector: [-0.99774915 -0.4590545 ]
# Vector magnitude: 1.0983
# Min value: -6.0945
# Max value: 6.0385
# Mean absolute value: 3.1180
# Saved train/test data for dataset_dim_2.txt
# Processing dataset_dim_20.txt with dimension 20
#
# Training Vector Statistics:
# Average vector: [-3.3901304e-02 -8.0235973e-03  6.0396437e-02 -2.3691325e-02
#  -5.0941739e-02  3.5496373e-02  3.0140134e-02  4.8664488e-02
#  -2.0436013e-02 -1.5345363e-02  1.6778432e-02 -3.7215725e-02
#  -9.3922922e-03 -9.8650837e-03  3.9987280e-03 -1.9013632e-02
#  -2.9153722e-05 -2.0749459e-02  1.6873877e-02 -6.1116815e-02]
# Vector magnitude: 0.1410
# Min value: -0.5785
# Max value: 0.6117
# Mean absolute value: 0.0865
#
# Test Vector Statistics:
# Average vector: [-0.03251627 -0.00826939  0.0591879  -0.02730578 -0.04996436  0.03490601
#   0.02972356  0.04811088 -0.02155866 -0.01467558  0.01562794 -0.03683864
#  -0.00998885 -0.0090109   0.0066054  -0.0174059   0.00314699 -0.02181245
#   0.01745004 -0.06213406]
# Vector magnitude: 0.1405
# Min value: -0.5128
# Max value: 0.5611
# Mean absolute value: 0.0866
# Saved train/test data for dataset_dim_20.txt
# Processing dataset_dim_3.txt with dimension 3
#
# Training Vector Statistics:
# Average vector: [ 0.86829805  0.17113982 -0.8071884 ]
# Vector magnitude: 1.1978
# Min value: -5.9608
# Max value: 5.5668
# Mean absolute value: 2.4648
#
# Test Vector Statistics:
# Average vector: [ 0.87335265  0.22201419 -0.74607366]
# Vector magnitude: 1.1699
# Min value: -6.0179
# Max value: 5.5774
# Mean absolute value: 2.4717
# Saved train/test data for dataset_dim_3.txt
# Processing dataset_dim_5.txt with dimension 5
#
# Training Vector Statistics:
# Average vector: [-0.63781357 -0.04157482  0.2425083   0.01641657 -0.2022788 ]
# Vector magnitude: 0.7131
# Min value: -3.3807
# Max value: 3.2346
# Mean absolute value: 1.0526
#
# Test Vector Statistics:
# Average vector: [-0.6543044  -0.05305564  0.25224328  0.03356825 -0.21249029]
# Vector magnitude: 0.7354
# Min value: -3.3921
# Max value: 3.2263
# Mean absolute value: 1.0560
# Saved train/test data for dataset_dim_5.txt
# Processing dataset_dim_8.txt with dimension 8
#
# Training Vector Statistics:
# Average vector: [-0.10853449  0.06188643  0.28570652  0.13675027  0.25855646 -0.23755056
#   0.13575697  0.1811593 ]
# Vector magnitude: 0.5390
# Min value: -2.0798
# Max value: 2.4000
# Mean absolute value: 0.6183
#
# Test Vector Statistics:
# Average vector: [-0.11359929  0.05631597  0.29582512  0.15099406  0.26028815 -0.2395447
#   0.13023159  0.17253393]
# Vector magnitude: 0.5461
# Min value: -2.0794
# Max value: 2.3061
# Mean absolute value: 0.6192
# Saved train/test data for dataset_dim_8.txt
# Processing folder: dataset_9
# Processing dataset_dim_10.txt with dimension 10
#
# Training Vector Statistics:
# Average vector: [-0.00667052  0.02952893 -0.0205578   0.28003302 -0.21341214 -0.00504955
#   0.05144713 -0.14410828 -0.17108746  0.05814423]
# Vector magnitude: 0.4259
# Min value: -1.3501
# Max value: 1.3072
# Mean absolute value: 0.3432
#
# Test Vector Statistics:
# Average vector: [-0.0098121   0.03244359 -0.00737077  0.27984995 -0.21003558 -0.00269712
#   0.04952085 -0.13378063 -0.17226054  0.04886245]
# Vector magnitude: 0.4196
# Min value: -1.3915
# Max value: 1.3369
# Mean absolute value: 0.3431
# Saved train/test data for dataset_dim_10.txt
# Processing dataset_dim_12.txt with dimension 12
#
# Training Vector Statistics:
# Average vector: [-0.01262615  0.02681774  0.01294435  0.14509921 -0.10778849 -0.08538077
#  -0.02172772  0.12282775 -0.00499407 -0.07795784 -0.08675379  0.09307249]
# Vector magnitude: 0.2808
# Min value: -1.0808
# Max value: 1.1105
# Mean absolute value: 0.2593
#
# Test Vector Statistics:
# Average vector: [-0.01407477  0.03210577  0.01585737  0.14704227 -0.10964488 -0.08346384
#  -0.0174071   0.11711971 -0.00689    -0.07953447 -0.0903562   0.09145983]
# Vector magnitude: 0.2811
# Min value: -1.0116
# Max value: 1.0526
# Mean absolute value: 0.2592
# Saved train/test data for dataset_dim_12.txt
# Processing dataset_dim_15.txt with dimension 15
#
# Training Vector Statistics:
# Average vector: [ 0.00802875  0.06958557 -0.06555596 -0.02081685 -0.11135557  0.03402587
#  -0.04638254 -0.017095   -0.03216305  0.00569083 -0.06320459 -0.05465363
#   0.00501603  0.0028117  -0.00859225]
# Vector magnitude: 0.1838
# Min value: -0.5471
# Max value: 0.6253
# Mean absolute value: 0.0974
#
# Test Vector Statistics:
# Average vector: [ 0.00682643  0.06830984 -0.06352679 -0.02168231 -0.11301743  0.03389228
#  -0.04665856 -0.01331805 -0.03278939  0.00618622 -0.06358708 -0.0545474
#   0.00370964  0.00291753 -0.00712294]
# Vector magnitude: 0.1836
# Min value: -0.5778
# Max value: 0.5560
# Mean absolute value: 0.0975
# Saved train/test data for dataset_dim_15.txt
# Processing dataset_dim_18.txt with dimension 18
#
# Training Vector Statistics:
# Average vector: [-0.04016332 -0.01835281  0.05523028 -0.04198666  0.04684058 -0.06377765
#  -0.01691658  0.00157288 -0.02931869  0.00353979 -0.04424207  0.06014955
#   0.02446463 -0.04737178  0.00245784 -0.00137195 -0.04538915 -0.08686229]
# Vector magnitude: 0.1795
# Min value: -0.7952
# Max value: 0.6463
# Mean absolute value: 0.1191
#
# Test Vector Statistics:
# Average vector: [-0.04326941 -0.0178103   0.05234063 -0.04281873  0.04675269 -0.05791123
#  -0.01480553 -0.00030216 -0.02622961  0.00317997 -0.04665413  0.06083532
#   0.0225696  -0.04836261  0.00092018 -0.00011002 -0.04692321 -0.0884571 ]
# Vector magnitude: 0.1788
# Min value: -0.6748
# Max value: 0.6248
# Mean absolute value: 0.1190
# Saved train/test data for dataset_dim_18.txt
# Processing dataset_dim_2.txt with dimension 2
#
# Training Vector Statistics:
# Average vector: [-0.0859312 -1.0581768]
# Vector magnitude: 1.0617
# Min value: -6.4945
# Max value: 4.9276
# Mean absolute value: 2.8668
#
# Test Vector Statistics:
# Average vector: [-0.15261604 -1.0218303 ]
# Vector magnitude: 1.0332
# Min value: -6.4987
# Max value: 4.9532
# Mean absolute value: 2.8718
# Saved train/test data for dataset_dim_2.txt
# Processing dataset_dim_20.txt with dimension 20
#
# Training Vector Statistics:
# Average vector: [ 0.01357515 -0.06378656 -0.03375831  0.01922268  0.01057577  0.00503148
#  -0.00645653  0.00573377 -0.0182406   0.00021748  0.01517418  0.01907721
#  -0.01972627  0.00736114  0.02436439 -0.01774995 -0.00821101  0.01418327
#   0.02553972  0.00438978]
# Vector magnitude: 0.0959
# Min value: -0.3946
# Max value: 0.3268
# Mean absolute value: 0.0535
#
# Test Vector Statistics:
# Average vector: [ 0.0139942  -0.06398854 -0.03421873  0.01746175  0.01027842  0.00484123
#  -0.00664831  0.00494745 -0.01917132  0.00044487  0.01455542  0.01916197
#  -0.01962145  0.00800563  0.02603513 -0.01671394 -0.00640175  0.01426684
#   0.02576858  0.00455269]
# Vector magnitude: 0.0962
# Min value: -0.4213
# Max value: 0.3687
# Mean absolute value: 0.0536
# Saved train/test data for dataset_dim_20.txt
# Processing dataset_dim_3.txt with dimension 3
#
# Training Vector Statistics:
# Average vector: [-0.35160545 -0.12457953  1.2920492 ]
# Vector magnitude: 1.3448
# Min value: -6.2853
# Max value: 5.5562
# Mean absolute value: 2.4284
#
# Test Vector Statistics:
# Average vector: [-0.3538585  -0.08280156  1.3198208 ]
# Vector magnitude: 1.3689
# Min value: -6.2841
# Max value: 5.5782
# Mean absolute value: 2.4307
# Saved train/test data for dataset_dim_3.txt
# Processing dataset_dim_5.txt with dimension 5
#
# Training Vector Statistics:
# Average vector: [-0.41517797  0.24228916  0.2104508  -0.36208883 -0.4004085 ]
# Vector magnitude: 0.7529
# Min value: -3.2799
# Max value: 2.9932
# Mean absolute value: 1.1852
#
# Test Vector Statistics:
# Average vector: [-0.4349669   0.22893721  0.22130354 -0.3424102  -0.40711853]
# Vector magnitude: 0.7573
# Min value: -3.2527
# Max value: 2.9975
# Mean absolute value: 1.1863
# Saved train/test data for dataset_dim_5.txt
# Processing dataset_dim_8.txt with dimension 8
#
# Training Vector Statistics:
# Average vector: [ 0.30020303 -0.2374899   0.35741428 -0.12794991 -0.0849681   0.18934438
#  -0.12033515  0.1630094 ]
# Vector magnitude: 0.6122
# Min value: -2.4674
# Max value: 2.7460
# Mean absolute value: 0.7381
#
# Test Vector Statistics:
# Average vector: [ 0.29808378 -0.24672054  0.372598   -0.11359518 -0.08376618  0.18503165
#  -0.12559745  0.14939876]
# Vector magnitude: 0.6171
# Min value: -2.3979
# Max value: 2.6891
# Mean absolute value: 0.7396
# Saved train/test data for dataset_dim_8.txt
# Done!
