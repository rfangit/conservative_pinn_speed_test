# %% [markdown]
# # Imports

# %%
import torch
import sys
import numpy as np
import os
import shutil
from pathlib import Path
# Add parent directory to sys.path
parent_dir = Path.cwd().parent
sys.path.append(str(parent_dir))
# Import modules
from train import train_test_multiple_networks, train_network_with_test_loss, train_grad_network_with_test_loss, save_plot_test_train

# %% [markdown]
# # Network Parameters

# %%
# Training hyperparameters
num_trials = 10
neurons = [256, 256, 256]
num_epochs = 200

# %% [markdown]
# # Running Experiments

# %%
# Folder containing datasets
dataset_folder = "datasets"

# Output folder for plots
output_folder = "loss_plots"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

for subfolder in os.listdir(dataset_folder):
    subfolder_path = os.path.join(dataset_folder, subfolder)
    
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")

        output_subfolder = os.path.join(output_folder, subfolder)
        os.makedirs(output_subfolder, exist_ok=True)
        
        train_folder = os.path.join(subfolder_path, "train")
        test_folder = os.path.join(subfolder_path, "test")
        
        for filename in os.listdir(train_folder):
            if filename.endswith("_train.txt"):
                base_name = filename.replace("_train.txt", "")
                
                # Load train data
                train_filepath = os.path.join(train_folder, filename)
                train_data = np.loadtxt(train_filepath)

                dimension = (int)(train_data.shape[1]/2)

                train_points = torch.tensor(train_data[:, :dimension], dtype=torch.float32)
                train_values = torch.tensor(train_data[:, dimension:], dtype=torch.float32)

                
                # Load test data
                test_filename = f"{base_name}_test.txt"
                test_filepath = os.path.join(test_folder, test_filename)
                test_data = np.loadtxt(test_filepath)
                test_points = torch.tensor(test_data[:, :dimension], dtype=torch.float32)
                test_values = torch.tensor(test_data[:, dimension:], dtype=torch.float32)
                
                print(f"Loaded preprocessed data for dimension {dimension}")
                
                # Train the normal network
                mean_loss, variance_loss, mean_test_loss, variance_test_loss = train_test_multiple_networks(
                    train_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the normal network!")
        
                # Train the conservative network
                mean_loss_grad, variance_loss_grad, mean_test_loss_grad, variance_test_loss_grad = train_test_multiple_networks(
                    train_grad_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the conservative network!")

                # Calculate standard deviations for the normal network
                std_loss = np.sqrt(variance_loss)
                std_test_loss = np.sqrt(variance_test_loss)
                std_loss_grad = np.sqrt(variance_loss_grad)
                std_test_loss_grad = np.sqrt(variance_test_loss_grad)
        
                # Print the minimum loss
                print(f"The minimum loss was {mean_loss[-1]}, conservative {mean_loss_grad[-1]}")
                print(f"The minimum test loss was {mean_test_loss[-1]}, conservative {mean_test_loss_grad[-1]}")
                # Comparison Plot
                epochs = np.arange(num_epochs)
                save_plot_test_train(epochs, mean_loss, std_loss, mean_loss_grad, std_loss_grad,
                      mean_test_loss, std_test_loss, mean_test_loss_grad, std_test_loss_grad,
                      dimension, neurons, num_epochs, output_subfolder)

                # Save the losses to .txt files
                losses_filename = os.path.join(output_subfolder, f"{dimension}D_losses.txt")
                np.savetxt(
                    losses_filename,
                    np.column_stack((
                        epochs,
                        mean_loss, std_loss,  # Training loss and std for normal network
                        mean_test_loss, std_test_loss,  # Test loss and std for normal network
                        mean_loss_grad, std_loss_grad,  # Training loss and std for conservative network
                        mean_test_loss_grad, std_test_loss_grad  # Test loss and std for conservative network
                    )),
                    fmt='%.6f',
                    header='epochs mean_loss std_loss mean_test_loss std_test_loss mean_loss_grad std_loss_grad mean_test_loss_grad std_test_loss_grad'
                )
                print(f"Losses saved to {losses_filename}")
        
print ("Done!!!")
# Out:
# Using device: cuda
# Processing folder: dataset_1
# Loaded preprocessed data for dimension 10
# The network training took 7.33 seconds.
# Done training the normal network!
# The network training took 10.39 seconds.
# Done training the conservative network!
# The minimum loss was 0.00037780630809720607, conservative 0.0004006807299447246
# The minimum test loss was 0.0004767853417433798, conservative 0.00042630741227185355
# Plot saved to loss_plots\dataset_1\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.64 seconds.
# Done training the normal network!
# The network training took 10.57 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001794515919755213, conservative 0.0002345451503060758
# The minimum test loss was 0.00021913211239734664, conservative 0.000254479433351662
# Plot saved to loss_plots\dataset_1\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.51 seconds.
# Done training the normal network!
# The network training took 10.42 seconds.
# Done training the conservative network!
# The minimum loss was 0.00012788979074684903, conservative 0.00011452634134911932
# The minimum test loss was 0.00014803881495026872, conservative 0.00012106398717151023
# Plot saved to loss_plots\dataset_1\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.02 seconds.
# Done training the normal network!
# The network training took 11.35 seconds.
# Done training the conservative network!
# The minimum loss was 8.517735841451213e-05, conservative 4.684960949816741e-05
# The minimum test loss was 9.91187735053245e-05, conservative 5.202397478569765e-05
# Plot saved to loss_plots\dataset_1\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.60 seconds.
# Done training the normal network!
# The network training took 10.54 seconds.
# Done training the conservative network!
# The minimum loss was 8.413716168433893e-05, conservative 5.311206241458422e-05
# The minimum test loss was 8.610516633780207e-05, conservative 5.2021560986759144e-05
# Plot saved to loss_plots\dataset_1\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.69 seconds.
# Done training the normal network!
# The network training took 12.20 seconds.
# Done training the conservative network!
# The minimum loss was 0.003495122236199677, conservative 0.0002337122379685752
# The minimum test loss was 0.0035634166619274766, conservative 0.00022438505293393974
# Plot saved to loss_plots\dataset_1\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.51 seconds.
# Done training the normal network!
# The network training took 12.16 seconds.
# Done training the conservative network!
# The minimum loss was 0.00021383124840212986, conservative 0.00020993355428799987
# The minimum test loss was 0.0002139635296771303, conservative 0.00020979713954147883
# Plot saved to loss_plots\dataset_1\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.26 seconds.
# Done training the normal network!
# The network training took 10.52 seconds.
# Done training the conservative network!
# The minimum loss was 0.0013394218345638364, conservative 0.0004945211418089457
# The minimum test loss was 0.00136483438545838, conservative 0.0004916292251436971
# Plot saved to loss_plots\dataset_1\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.64 seconds.
# Done training the normal network!
# The network training took 10.47 seconds.
# Done training the conservative network!
# The minimum loss was 0.000471735475002788, conservative 0.00028685380748356694
# The minimum test loss was 0.0004973031114786864, conservative 0.0002858568499505054
# Plot saved to loss_plots\dataset_1\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\8D_losses.txt
# Processing folder: dataset_10
# Loaded preprocessed data for dimension 10
# The network training took 5.36 seconds.
# Done training the normal network!
# The network training took 11.06 seconds.
# Done training the conservative network!
# The minimum loss was 0.0003160707768984139, conservative 0.0003571196415578015
# The minimum test loss was 0.00035490261507220566, conservative 0.0003586452745366842
# Plot saved to loss_plots\dataset_10\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.76 seconds.
# Done training the normal network!
# The network training took 10.90 seconds.
# Done training the conservative network!
# The minimum loss was 0.00027564079355215656, conservative 0.00026172139041591436
# The minimum test loss was 0.00031287479505408554, conservative 0.0002691027533728629
# Plot saved to loss_plots\dataset_10\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.61 seconds.
# Done training the normal network!
# The network training took 10.56 seconds.
# Done training the conservative network!
# The minimum loss was 0.00013677464230568148, conservative 0.00010961054504150524
# The minimum test loss was 0.00015184370713541284, conservative 0.00011177642154507339
# Plot saved to loss_plots\dataset_10\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.79 seconds.
# Done training the normal network!
# The network training took 10.40 seconds.
# Done training the conservative network!
# The minimum loss was 9.784276626305655e-05, conservative 0.00011965536759817041
# The minimum test loss was 0.00010468172986293212, conservative 0.00011472414807940367
# Plot saved to loss_plots\dataset_10\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.82 seconds.
# Done training the normal network!
# The network training took 10.85 seconds.
# Done training the conservative network!
# The minimum loss was 4.5576303818961605e-05, conservative 5.8792847630684265e-05
# The minimum test loss was 5.066895864729304e-05, conservative 6.0311981542326976e-05
# Plot saved to loss_plots\dataset_10\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.61 seconds.
# Done training the normal network!
# The network training took 10.50 seconds.
# Done training the conservative network!
# The minimum loss was 0.0012184512976091354, conservative 0.00010261495626764371
# The minimum test loss was 0.0012505154722020962, conservative 0.00011217639148526359
# Plot saved to loss_plots\dataset_10\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.66 seconds.
# Done training the normal network!
# The network training took 10.52 seconds.
# Done training the conservative network!
# The minimum loss was 0.0024377893540076913, conservative 0.0003804887106525712
# The minimum test loss was 0.0024507935100700705, conservative 0.00037485490320250393
# Plot saved to loss_plots\dataset_10\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.56 seconds.
# Done training the normal network!
# The network training took 10.47 seconds.
# Done training the conservative network!
# The minimum loss was 0.0008453159884084016, conservative 0.0006451188281062059
# The minimum test loss was 0.0008604590024333447, conservative 0.0006515510802273638
# Plot saved to loss_plots\dataset_10\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.73 seconds.
# Done training the normal network!
# The network training took 10.78 seconds.
# Done training the conservative network!
# The minimum loss was 0.0008776296221185475, conservative 0.0005465018912218511
# The minimum test loss was 0.0010073207202367484, conservative 0.000560302275698632
# Plot saved to loss_plots\dataset_10\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\8D_losses.txt
# Processing folder: dataset_2
# Loaded preprocessed data for dimension 10
# The network training took 5.72 seconds.
# Done training the normal network!
# The network training took 10.86 seconds.
# Done training the conservative network!
# The minimum loss was 0.0006193769397214055, conservative 0.0006071939045796171
# The minimum test loss was 0.00071331468061544, conservative 0.0006310157303232699
# Plot saved to loss_plots\dataset_2\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.64 seconds.
# Done training the normal network!
# The network training took 10.63 seconds.
# Done training the conservative network!
# The minimum loss was 0.00024371940380660818, conservative 0.0003219303471269086
# The minimum test loss was 0.0002755730209173635, conservative 0.0003233514667954296
# Plot saved to loss_plots\dataset_2\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.63 seconds.
# Done training the normal network!
# The network training took 10.98 seconds.
# Done training the conservative network!
# The minimum loss was 0.00012421781502780505, conservative 9.979760070564226e-05
# The minimum test loss was 0.00013841933832736686, conservative 0.0001025732941343449
# Plot saved to loss_plots\dataset_2\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.60 seconds.
# Done training the normal network!
# The network training took 10.14 seconds.
# Done training the conservative network!
# The minimum loss was 0.00010725914180511608, conservative 6.002049376547802e-05
# The minimum test loss was 0.00011784416710725054, conservative 6.117560442362447e-05
# Plot saved to loss_plots\dataset_2\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.59 seconds.
# Done training the normal network!
# The network training took 10.76 seconds.
# Done training the conservative network!
# The minimum loss was 4.5848336958442816e-05, conservative 2.4932298219937366e-05
# The minimum test loss was 5.076025045127608e-05, conservative 2.5634898702264763e-05
# Plot saved to loss_plots\dataset_2\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.31 seconds.
# Done training the normal network!
# The network training took 9.92 seconds.
# Done training the conservative network!
# The minimum loss was 0.002489721344318241, conservative 0.00022591988126805518
# The minimum test loss was 0.002529610246710945, conservative 0.00022453787460108288
# Plot saved to loss_plots\dataset_2\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.55 seconds.
# Done training the normal network!
# The network training took 10.30 seconds.
# Done training the conservative network!
# The minimum loss was 0.0017782677139621228, conservative 0.0003806080138019752
# The minimum test loss was 0.0017512556019937619, conservative 0.00038079221558291466
# Plot saved to loss_plots\dataset_2\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.31 seconds.
# Done training the normal network!
# The network training took 9.92 seconds.
# Done training the conservative network!
# The minimum loss was 0.002491301216650754, conservative 0.0004958429140970111
# The minimum test loss was 0.0024690823862329125, conservative 0.0004982478378224187
# Plot saved to loss_plots\dataset_2\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.53 seconds.
# Done training the normal network!
# The network training took 10.14 seconds.
# Done training the conservative network!
# The minimum loss was 0.0004549420438706875, conservative 0.000447108356456738
# The minimum test loss was 0.0004957965778885409, conservative 0.00045078222901793195
# Plot saved to loss_plots\dataset_2\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\8D_losses.txt
# Processing folder: dataset_3
# Loaded preprocessed data for dimension 10
# The network training took 5.31 seconds.
# Done training the normal network!
# The network training took 10.14 seconds.
# Done training the conservative network!
# The minimum loss was 0.000488554552430287, conservative 0.0005245537147857248
# The minimum test loss was 0.000615200912579894, conservative 0.0006059719715267419
# Plot saved to loss_plots\dataset_3\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.86 seconds.
# Done training the normal network!
# The network training took 10.31 seconds.
# Done training the conservative network!
# The minimum loss was 0.000255626295984257, conservative 0.00043984198855469004
# The minimum test loss was 0.0002977415599161759, conservative 0.0004426605781191029
# Plot saved to loss_plots\dataset_3\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.47 seconds.
# Done training the normal network!
# The network training took 10.76 seconds.
# Done training the conservative network!
# The minimum loss was 0.00013245006994111463, conservative 0.00018059694702969863
# The minimum test loss was 0.00016185595886781813, conservative 0.0001880067604361102
# Plot saved to loss_plots\dataset_3\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.72 seconds.
# Done training the normal network!
# The network training took 10.05 seconds.
# Done training the conservative network!
# The minimum loss was 5.6097912238328715e-05, conservative 4.32110158726573e-05
# The minimum test loss was 5.605469632428139e-05, conservative 3.966133335779887e-05
# Plot saved to loss_plots\dataset_3\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.43 seconds.
# Done training the normal network!
# The network training took 10.55 seconds.
# Done training the conservative network!
# The minimum loss was 5.138478918524925e-05, conservative 3.012241704709595e-05
# The minimum test loss was 6.111171096563339e-05, conservative 3.270660072303144e-05
# Plot saved to loss_plots\dataset_3\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.48 seconds.
# Done training the normal network!
# The network training took 9.93 seconds.
# Done training the conservative network!
# The minimum loss was 0.002282604924403131, conservative 0.004646352539566578
# The minimum test loss was 0.0022780455656175036, conservative 0.00464376794952841
# Plot saved to loss_plots\dataset_3\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.49 seconds.
# Done training the normal network!
# The network training took 10.44 seconds.
# Done training the conservative network!
# The minimum loss was 0.0023486910795327276, conservative 0.00021825488656759262
# The minimum test loss was 0.002332062827190384, conservative 0.0002213367581134662
# Plot saved to loss_plots\dataset_3\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.54 seconds.
# Done training the normal network!
# The network training took 10.54 seconds.
# Done training the conservative network!
# The minimum loss was 0.0010575868072919548, conservative 0.0004799447022378445
# The minimum test loss was 0.0010573195992037653, conservative 0.0004777260051923804
# Plot saved to loss_plots\dataset_3\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.96 seconds.
# Done training the normal network!
# The network training took 12.29 seconds.
# Done training the conservative network!
# The minimum loss was 0.000521151177235879, conservative 0.0002559558328357525
# The minimum test loss was 0.0005813819821923971, conservative 0.00027445069135865194
# Plot saved to loss_plots\dataset_3\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\8D_losses.txt
# Processing folder: dataset_4
# Loaded preprocessed data for dimension 10
# The network training took 5.58 seconds.
# Done training the normal network!
# The network training took 11.29 seconds.
# Done training the conservative network!
# The minimum loss was 0.0003148794756270945, conservative 0.0003343512464198284
# The minimum test loss was 0.0003610375744756311, conservative 0.0003465621208306402
# Plot saved to loss_plots\dataset_4\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.38 seconds.
# Done training the normal network!
# The network training took 10.37 seconds.
# Done training the conservative network!
# The minimum loss was 0.00031038508168421684, conservative 0.00031155912729445844
# The minimum test loss was 0.00035268376232124867, conservative 0.0003288565465481952
# Plot saved to loss_plots\dataset_4\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.51 seconds.
# Done training the normal network!
# The network training took 11.98 seconds.
# Done training the conservative network!
# The minimum loss was 0.00011779066553572193, conservative 0.00025720632838783787
# The minimum test loss was 0.00012452303344616665, conservative 0.00025215610148734415
# Plot saved to loss_plots\dataset_4\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.99 seconds.
# Done training the normal network!
# The network training took 11.04 seconds.
# Done training the conservative network!
# The minimum loss was 9.026994302985258e-05, conservative 9.223929737345316e-05
# The minimum test loss was 0.00010524702884140424, conservative 9.530850729788654e-05
# Plot saved to loss_plots\dataset_4\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.99 seconds.
# Done training the normal network!
# The network training took 11.59 seconds.
# Done training the conservative network!
# The minimum loss was 6.0450433738878925e-05, conservative 5.3824262795387765e-05
# The minimum test loss was 7.074637687765062e-05, conservative 5.7072512208833356e-05
# Plot saved to loss_plots\dataset_4\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.59 seconds.
# Done training the normal network!
# The network training took 10.59 seconds.
# Done training the conservative network!
# The minimum loss was 0.0036289254581788554, conservative 0.00019184446755389218
# The minimum test loss was 0.003659352203249, conservative 0.0002039573446381837
# Plot saved to loss_plots\dataset_4\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.27 seconds.
# Done training the normal network!
# The network training took 10.93 seconds.
# Done training the conservative network!
# The minimum loss was 0.009168285675696098, conservative 0.0003096569766057655
# The minimum test loss was 0.009030111294123344, conservative 0.00030751207887078633
# Plot saved to loss_plots\dataset_4\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.64 seconds.
# Done training the normal network!
# The network training took 10.59 seconds.
# Done training the conservative network!
# The minimum loss was 0.0016476034186780452, conservative 0.000486141954024788
# The minimum test loss was 0.0016104024893138559, conservative 0.0004866493145527784
# Plot saved to loss_plots\dataset_4\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.34 seconds.
# Done training the normal network!
# The network training took 10.42 seconds.
# Done training the conservative network!
# The minimum loss was 0.0007455484999809414, conservative 0.0005715781269827857
# The minimum test loss was 0.0007815711316652596, conservative 0.0005511761788511649
# Plot saved to loss_plots\dataset_4\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\8D_losses.txt
# Processing folder: dataset_5
# Loaded preprocessed data for dimension 10
# The network training took 5.44 seconds.
# Done training the normal network!
# The network training took 11.21 seconds.
# Done training the conservative network!
# The minimum loss was 0.00031881551840342583, conservative 0.00048293823056155816
# The minimum test loss was 0.0003900251816958189, conservative 0.0005148634198121726
# Plot saved to loss_plots\dataset_5\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.65 seconds.
# Done training the normal network!
# The network training took 10.31 seconds.
# Done training the conservative network!
# The minimum loss was 0.00021173691638978198, conservative 0.0002270547585794702
# The minimum test loss was 0.00025650906609371306, conservative 0.00025429349625483155
# Plot saved to loss_plots\dataset_5\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.65 seconds.
# Done training the normal network!
# The network training took 11.41 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001440340325643774, conservative 0.00011891604954143986
# The minimum test loss was 0.00016381090608774684, conservative 0.000123199825611664
# Plot saved to loss_plots\dataset_5\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.56 seconds.
# Done training the normal network!
# The network training took 10.22 seconds.
# Done training the conservative network!
# The minimum loss was 8.818023779895156e-05, conservative 5.2872560627292844e-05
# The minimum test loss was 0.00010045282324426808, conservative 5.828761823067907e-05
# Plot saved to loss_plots\dataset_5\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.25 seconds.
# Done training the normal network!
# The network training took 11.03 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001314847049798118, conservative 2.764588916761568e-05
# The minimum test loss was 0.00013095918475301005, conservative 2.7023911570722703e-05
# Plot saved to loss_plots\dataset_5\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.74 seconds.
# Done training the normal network!
# The network training took 10.69 seconds.
# Done training the conservative network!
# The minimum loss was 0.00047835197110543957, conservative 0.00030900023048161527
# The minimum test loss was 0.0004980379570042714, conservative 0.0003495866025332361
# Plot saved to loss_plots\dataset_5\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.53 seconds.
# Done training the normal network!
# The network training took 10.62 seconds.
# Done training the conservative network!
# The minimum loss was 0.003179760734201409, conservative 0.003344178570114309
# The minimum test loss was 0.003192936963750981, conservative 0.0033402096218196676
# Plot saved to loss_plots\dataset_5\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.60 seconds.
# Done training the normal network!
# The network training took 11.52 seconds.
# Done training the conservative network!
# The minimum loss was 0.002247569989413023, conservative 0.00034466044598957524
# The minimum test loss was 0.0022851521731354295, conservative 0.00035128611634718256
# Plot saved to loss_plots\dataset_5\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.70 seconds.
# Done training the normal network!
# The network training took 10.56 seconds.
# Done training the conservative network!
# The minimum loss was 0.0007792517659254372, conservative 0.00036489376798272134
# The minimum test loss was 0.0008228520804550499, conservative 0.0003715937229571864
# Plot saved to loss_plots\dataset_5\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\8D_losses.txt
# Processing folder: dataset_6
# Loaded preprocessed data for dimension 10
# The network training took 5.65 seconds.
# Done training the normal network!
# The network training took 11.76 seconds.
# Done training the conservative network!
# The minimum loss was 0.0003616278147092089, conservative 0.00024003448634175585
# The minimum test loss was 0.00046421781298704444, conservative 0.0002916832789196633
# Plot saved to loss_plots\dataset_6\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.52 seconds.
# Done training the normal network!
# The network training took 10.62 seconds.
# Done training the conservative network!
# The minimum loss was 0.0002383086350164376, conservative 0.00027593499835347756
# The minimum test loss was 0.000267598194477614, conservative 0.0002789950027363375
# Plot saved to loss_plots\dataset_6\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.63 seconds.
# Done training the normal network!
# The network training took 10.96 seconds.
# Done training the conservative network!
# The minimum loss was 0.00013177347573218868, conservative 0.00010379035084042698
# The minimum test loss was 0.00016976071638055145, conservative 0.00012154575815657154
# Plot saved to loss_plots\dataset_6\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.88 seconds.
# Done training the normal network!
# The network training took 11.37 seconds.
# Done training the conservative network!
# The minimum loss was 8.467383522656747e-05, conservative 5.40008710231632e-05
# The minimum test loss was 9.49257388128899e-05, conservative 5.723053836845793e-05
# Plot saved to loss_plots\dataset_6\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 6.26 seconds.
# Done training the normal network!
# The network training took 10.54 seconds.
# Done training the conservative network!
# The minimum loss was 5.8803605497814715e-05, conservative 4.8230988613795486e-05
# The minimum test loss was 6.620554377150256e-05, conservative 4.956904449500143e-05
# Plot saved to loss_plots\dataset_6\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.63 seconds.
# Done training the normal network!
# The network training took 11.74 seconds.
# Done training the conservative network!
# The minimum loss was 0.00026637888804543764, conservative 0.005866543700540206
# The minimum test loss was 0.00026427153788972647, conservative 0.005873112834160565
# Plot saved to loss_plots\dataset_6\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.57 seconds.
# Done training the normal network!
# The network training took 10.65 seconds.
# Done training the conservative network!
# The minimum loss was 0.00408318109693937, conservative 0.002461583771946607
# The minimum test loss was 0.0041278173332102595, conservative 0.0024720938425161878
# Plot saved to loss_plots\dataset_6\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.02 seconds.
# Done training the normal network!
# The network training took 11.18 seconds.
# Done training the conservative network!
# The minimum loss was 0.0032422162592411043, conservative 0.00041490806033834816
# The minimum test loss was 0.0032308820518665016, conservative 0.00041474034514976665
# Plot saved to loss_plots\dataset_6\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.61 seconds.
# Done training the normal network!
# The network training took 10.58 seconds.
# Done training the conservative network!
# The minimum loss was 0.0007204317196737974, conservative 0.0006285053474130109
# The minimum test loss was 0.0008066894661169499, conservative 0.0006424098915886134
# Plot saved to loss_plots\dataset_6\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\8D_losses.txt
# Processing folder: dataset_7
# Loaded preprocessed data for dimension 10
# The network training took 6.56 seconds.
# Done training the normal network!
# The network training took 10.55 seconds.
# Done training the conservative network!
# The minimum loss was 0.0003715315222507343, conservative 0.00042585198243614284
# The minimum test loss was 0.0004145049373619258, conservative 0.0004226863864460029
# Plot saved to loss_plots\dataset_7\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.64 seconds.
# Done training the normal network!
# The network training took 11.49 seconds.
# Done training the conservative network!
# The minimum loss was 0.00019879675237461926, conservative 0.00022955614113016055
# The minimum test loss was 0.0002354468306293711, conservative 0.0002432748122373596
# Plot saved to loss_plots\dataset_7\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 6.00 seconds.
# Done training the normal network!
# The network training took 10.60 seconds.
# Done training the conservative network!
# The minimum loss was 0.00011216446728212759, conservative 0.00014621549198636785
# The minimum test loss was 0.00012690310832113026, conservative 0.00014544881851179524
# Plot saved to loss_plots\dataset_7\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.83 seconds.
# Done training the normal network!
# The network training took 11.69 seconds.
# Done training the conservative network!
# The minimum loss was 5.223599255259615e-05, conservative 6.761137665307615e-05
# The minimum test loss was 5.9063159278593956e-05, conservative 6.884159884066321e-05
# Plot saved to loss_plots\dataset_7\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.62 seconds.
# Done training the normal network!
# The network training took 10.53 seconds.
# Done training the conservative network!
# The minimum loss was 6.952595322218258e-05, conservative 5.8233063464285804e-05
# The minimum test loss was 7.965437180246226e-05, conservative 6.0973993822699415e-05
# Plot saved to loss_plots\dataset_7\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.46 seconds.
# Done training the normal network!
# The network training took 11.03 seconds.
# Done training the conservative network!
# The minimum loss was 0.0007385941338725388, conservative 0.0030099110314040444
# The minimum test loss was 0.0007563135761301965, conservative 0.0030484427930787205
# Plot saved to loss_plots\dataset_7\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.70 seconds.
# Done training the normal network!
# The network training took 11.33 seconds.
# Done training the conservative network!
# The minimum loss was 0.0013592221104772762, conservative 0.0002977299605845474
# The minimum test loss was 0.0013465857511619106, conservative 0.00029693074757233264
# Plot saved to loss_plots\dataset_7\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.88 seconds.
# Done training the normal network!
# The network training took 10.96 seconds.
# Done training the conservative network!
# The minimum loss was 0.0005340035859262571, conservative 0.0002046716763288714
# The minimum test loss was 0.0005528152716578916, conservative 0.00020613998640328646
# Plot saved to loss_plots\dataset_7\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.60 seconds.
# Done training the normal network!
# The network training took 11.36 seconds.
# Done training the conservative network!
# The minimum loss was 0.0005593937879893929, conservative 0.00044086516427341846
# The minimum test loss was 0.0006132047332357615, conservative 0.00046960573818068954
# Plot saved to loss_plots\dataset_7\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\8D_losses.txt
# Processing folder: dataset_8
# Loaded preprocessed data for dimension 10
# The network training took 5.63 seconds.
# Done training the normal network!
# The network training took 10.14 seconds.
# Done training the conservative network!
# The minimum loss was 0.0003874294721754268, conservative 0.0005163179099326954
# The minimum test loss was 0.00043322637211531403, conservative 0.0005124553543282672
# Plot saved to loss_plots\dataset_8\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.81 seconds.
# Done training the normal network!
# The network training took 11.16 seconds.
# Done training the conservative network!
# The minimum loss was 0.00022619201336055995, conservative 0.0002400023760856129
# The minimum test loss was 0.00028004076157230886, conservative 0.00025994547177106143
# Plot saved to loss_plots\dataset_8\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.51 seconds.
# Done training the normal network!
# The network training took 11.03 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001353157655103132, conservative 0.000125962160382187
# The minimum test loss was 0.00016552226879866793, conservative 0.00013721252034883946
# Plot saved to loss_plots\dataset_8\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 6.54 seconds.
# Done training the normal network!
# The network training took 10.55 seconds.
# Done training the conservative network!
# The minimum loss was 5.5770140897948294e-05, conservative 7.519265418522991e-05
# The minimum test loss was 6.575962543138303e-05, conservative 7.707197873969562e-05
# Plot saved to loss_plots\dataset_8\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.70 seconds.
# Done training the normal network!
# The network training took 11.29 seconds.
# Done training the conservative network!
# The minimum loss was 8.57510920468485e-05, conservative 6.901095548528247e-05
# The minimum test loss was 9.377883434353862e-05, conservative 7.151651225285604e-05
# Plot saved to loss_plots\dataset_8\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.89 seconds.
# Done training the normal network!
# The network training took 10.12 seconds.
# Done training the conservative network!
# The minimum loss was 0.00018823298669303767, conservative 0.0002525323616282549
# The minimum test loss was 0.00020010542866657488, conservative 0.00026542589766904713
# Plot saved to loss_plots\dataset_8\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.61 seconds.
# Done training the normal network!
# The network training took 11.74 seconds.
# Done training the conservative network!
# The minimum loss was 0.0003552178561221808, conservative 0.0002927855690359138
# The minimum test loss was 0.0003674520005006343, conservative 0.0002916642974014394
# Plot saved to loss_plots\dataset_8\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.63 seconds.
# Done training the normal network!
# The network training took 10.50 seconds.
# Done training the conservative network!
# The minimum loss was 0.0014048549404833467, conservative 0.00020295039867050945
# The minimum test loss was 0.001419590099249035, conservative 0.00020508270972641185
# Plot saved to loss_plots\dataset_8\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.42 seconds.
# Done training the normal network!
# The network training took 11.73 seconds.
# Done training the conservative network!
# The minimum loss was 0.0006554054270964116, conservative 0.0005677765322616324
# The minimum test loss was 0.0007337976654525846, conservative 0.0005840892408741638
# Plot saved to loss_plots\dataset_8\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\8D_losses.txt
# Processing folder: dataset_9
# Loaded preprocessed data for dimension 10
# The network training took 5.56 seconds.
# Done training the normal network!
# The network training took 11.08 seconds.
# Done training the conservative network!
# The minimum loss was 0.0007588364183902741, conservative 0.000592580161173828
# The minimum test loss was 0.0007406499760691076, conservative 0.0005324665835360065
# Plot saved to loss_plots\dataset_9\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.45 seconds.
# Done training the normal network!
# The network training took 10.23 seconds.
# Done training the conservative network!
# The minimum loss was 0.0002135653965524398, conservative 0.0002927051013102755
# The minimum test loss was 0.00022896137379575522, conservative 0.0002734809895628132
# Plot saved to loss_plots\dataset_9\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\12D_losses.txt
# Loaded preprocessed data for dimension 15
# The network training took 5.51 seconds.
# Done training the normal network!
# The network training took 11.18 seconds.
# Done training the conservative network!
# The minimum loss was 0.00011521740234456956, conservative 7.648036989849061e-05
# The minimum test loss was 0.0001221580387209542, conservative 7.511924377467949e-05
# Plot saved to loss_plots\dataset_9\15D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\15D_losses.txt
# Loaded preprocessed data for dimension 18
# The network training took 5.70 seconds.
# Done training the normal network!
# The network training took 10.19 seconds.
# Done training the conservative network!
# The minimum loss was 8.108509064186364e-05, conservative 7.942089869175106e-05
# The minimum test loss was 8.825811673887073e-05, conservative 7.666419951419811e-05
# Plot saved to loss_plots\dataset_9\18D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\18D_losses.txt
# Loaded preprocessed data for dimension 20
# The network training took 5.62 seconds.
# Done training the normal network!
# The network training took 12.36 seconds.
# Done training the conservative network!
# The minimum loss was 6.009825447108597e-05, conservative 3.9889809886517466e-05
# The minimum test loss was 6.815694941906259e-05, conservative 4.1329623309138695e-05
# Plot saved to loss_plots\dataset_9\20D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\20D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.56 seconds.
# Done training the normal network!
# The network training took 10.31 seconds.
# Done training the conservative network!
# The minimum loss was 0.00021928264468442648, conservative 0.00010792357570608147
# The minimum test loss was 0.0002326358364371117, conservative 0.00011064276113756933
# Plot saved to loss_plots\dataset_9\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 7.08 seconds.
# Done training the normal network!
# The network training took 10.87 seconds.
# Done training the conservative network!
# The minimum loss was 0.00047900896752253177, conservative 0.00028324818194960246
# The minimum test loss was 0.00049754498177208, conservative 0.0002829050958098378
# Plot saved to loss_plots\dataset_9\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\3D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.56 seconds.
# Done training the normal network!
# The network training took 10.80 seconds.
# Done training the conservative network!
# The minimum loss was 0.0005412221507867798, conservative 0.0002611958247143775
# The minimum test loss was 0.0005559453449677676, conservative 0.0002642632622155361
# Plot saved to loss_plots\dataset_9\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.25 seconds.
# Done training the normal network!
# The network training took 10.07 seconds.
# Done training the conservative network!
# The minimum loss was 0.0004675250733271241, conservative 0.0003724444832187146
# The minimum test loss was 0.0005441569606773555, conservative 0.0004075076489243656
# Plot saved to loss_plots\dataset_9\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\8D_losses.txt
# Done!!!

# %% [markdown]
# # Organizing Data

# %%
# Folder containing the loss plots and text files
loss_folder = "loss_plots"

# Output folders for consolidated images and text files
output_image_folder = "consolidated_images"
output_text_folder = "consolidated_text_files"

# Create output folders if they don't exist
os.makedirs(output_image_folder, exist_ok=True)
os.makedirs(output_text_folder, exist_ok=True)

# Iterate through all subfolders in the loss_folder
for subfolder in os.listdir(loss_folder):
    subfolder_path = os.path.join(loss_folder, subfolder)
    
    # Check if it's a directory (e.g., dataset_1, dataset_2, etc.)
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")
        
        # Extract the dataset number (e.g., "1" from "dataset_1")
        dataset_number = subfolder.split("_")[-1]
        
        # Process images
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".png"):  # Process only .png files
                # Construct the new filename (e.g., 2D_Conservative_NN_1.png)
                new_filename = filename.replace(".png", f"_{dataset_number}.png")
                
                # Copy the image to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_image_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied image: {src_path} -> {dest_path}")
        
        # Process text files
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".txt"):  # Process only .txt files
                # Construct the new filename (e.g., 8D_losses_1.txt)
                new_filename = filename.replace(".txt", f"_{dataset_number}.txt")
                
                # Copy the text file to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_text_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied text file: {src_path} -> {dest_path}")

print("All files have been consolidated.")
# Out:
# Processing folder: dataset_1
# Processing folder: dataset_10
# Processing folder: dataset_2
# Processing folder: dataset_3
# Processing folder: dataset_4
# Processing folder: dataset_5
# Processing folder: dataset_6
# Processing folder: dataset_7
# Processing folder: dataset_8
# Processing folder: dataset_9
# All files have been consolidated.
