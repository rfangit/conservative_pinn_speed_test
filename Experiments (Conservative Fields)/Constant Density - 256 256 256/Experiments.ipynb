# %% [markdown]
# # Imports

# %%
import torch
import sys
import numpy as np
import os
import shutil
from pathlib import Path
# Add parent directory to sys.path
parent_dir = Path.cwd().parent.parent
sys.path.append(str(parent_dir))
# Import modules
from train import train_test_multiple_networks, train_network_with_test_loss, train_grad_network_with_test_loss, save_plot_test_train

# %% [markdown]
# # Network Parameters

# %%
# Training hyperparameters
num_trials = 10
neurons = [256, 256, 256]
num_epochs = 200

# %% [markdown]
# # Running Experiments

# %%
# Folder containing datasets
dataset_folder = "datasets"

# Output folder for plots
output_folder = "loss_plots"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

for subfolder in os.listdir(dataset_folder):
    subfolder_path = os.path.join(dataset_folder, subfolder)
    
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")

        output_subfolder = os.path.join(output_folder, subfolder)
        os.makedirs(output_subfolder, exist_ok=True)
        
        train_folder = os.path.join(subfolder_path, "train")
        test_folder = os.path.join(subfolder_path, "test")
        
        for filename in os.listdir(train_folder):
            if filename.endswith("_train.txt"):
                base_name = filename.replace("_train.txt", "")
                
                # Load train data
                train_filepath = os.path.join(train_folder, filename)
                train_data = np.loadtxt(train_filepath)

                dimension = (int)(train_data.shape[1]/2)

                train_points = torch.tensor(train_data[:, :dimension], dtype=torch.float32)
                train_values = torch.tensor(train_data[:, dimension:], dtype=torch.float32)

                
                # Load test data
                test_filename = f"{base_name}_test.txt"
                test_filepath = os.path.join(test_folder, test_filename)
                test_data = np.loadtxt(test_filepath)
                test_points = torch.tensor(test_data[:, :dimension], dtype=torch.float32)
                test_values = torch.tensor(test_data[:, dimension:], dtype=torch.float32)
                
                print(f"Loaded preprocessed data for dimension {dimension}")
                
                # Train the normal network
                mean_loss, variance_loss, mean_test_loss, variance_test_loss = train_test_multiple_networks(
                    train_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the normal network!")
        
                # Train the conservative network
                mean_loss_grad, variance_loss_grad, mean_test_loss_grad, variance_test_loss_grad = train_test_multiple_networks(
                    train_grad_network_with_test_loss, dimension, train_points, neurons, 
                    num_epochs, train_values, test_points, test_values, num_trials)
                print("Done training the conservative network!")

                # Calculate standard deviations for the normal network
                std_loss = np.sqrt(variance_loss)
                std_test_loss = np.sqrt(variance_test_loss)
                std_loss_grad = np.sqrt(variance_loss_grad)
                std_test_loss_grad = np.sqrt(variance_test_loss_grad)
        
                # Print the minimum loss
                print(f"The minimum loss was {mean_loss[-1]}, conservative {mean_loss_grad[-1]}")
                print(f"The minimum test loss was {mean_test_loss[-1]}, conservative {mean_test_loss_grad[-1]}")
                # Comparison Plot
                epochs = np.arange(num_epochs)
                save_plot_test_train(epochs, mean_loss, std_loss, mean_loss_grad, std_loss_grad,
                      mean_test_loss, std_test_loss, mean_test_loss_grad, std_test_loss_grad,
                      dimension, neurons, num_epochs, output_subfolder)

                # Save the losses to .txt files
                losses_filename = os.path.join(output_subfolder, f"{dimension}D_losses.txt")
                np.savetxt(
                    losses_filename,
                    np.column_stack((
                        epochs,
                        mean_loss, std_loss,  # Training loss and std for normal network
                        mean_test_loss, std_test_loss,  # Test loss and std for normal network
                        mean_loss_grad, std_loss_grad,  # Training loss and std for conservative network
                        mean_test_loss_grad, std_test_loss_grad  # Test loss and std for conservative network
                    )),
                    fmt='%.6f',
                    header='epochs mean_loss std_loss mean_test_loss std_test_loss mean_loss_grad std_loss_grad mean_test_loss_grad std_test_loss_grad'
                )
                print(f"Losses saved to {losses_filename}")
        
print ("Done!!!")
# Out:
# Using device: cuda
# Processing folder: dataset_1
# Loaded preprocessed data for dimension 10
# The network training took 7.95 seconds.
# Done training the normal network!
# The network training took 11.17 seconds.
# Done training the conservative network!
# The minimum loss was 16.19585485458374, conservative 7.542507362365723
# The minimum test loss was 18.115475845336913, conservative 7.757508778572083
# Plot saved to loss_plots\dataset_1\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.00 seconds.
# Done training the normal network!
# The network training took 10.44 seconds.
# Done training the conservative network!
# The minimum loss was 1503.8199584960937, conservative 332.12855529785156
# The minimum test loss was 1732.0102294921876, conservative 357.6321105957031
# Plot saved to loss_plots\dataset_1\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.57 seconds.
# Done training the normal network!
# The network training took 11.11 seconds.
# Done training the conservative network!
# The minimum loss was 7.109311109161353e-05, conservative 1.2869725469499827e-05
# The minimum test loss was 7.085618253768188e-05, conservative 1.2870998625658104e-05
# Plot saved to loss_plots\dataset_1\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.58 seconds.
# Done training the normal network!
# The network training took 10.20 seconds.
# Done training the conservative network!
# The minimum loss was 0.001437909048399888, conservative 0.0008988332054286729
# The minimum test loss was 0.001425990251300391, conservative 0.0009037473151693121
# Plot saved to loss_plots\dataset_1\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 5.47 seconds.
# Done training the normal network!
# The network training took 10.76 seconds.
# Done training the conservative network!
# The minimum loss was 0.002348040894139558, conservative 0.0002674029077752493
# The minimum test loss was 0.0023288924508960917, conservative 0.0002609041417599656
# Plot saved to loss_plots\dataset_1\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.82 seconds.
# Done training the normal network!
# The network training took 10.52 seconds.
# Done training the conservative network!
# The minimum loss was 0.0029466283973306417, conservative 0.0026114472770132125
# The minimum test loss was 0.0029639369342476128, conservative 0.0025825132383033634
# Plot saved to loss_plots\dataset_1\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.70 seconds.
# Done training the normal network!
# The network training took 10.43 seconds.
# Done training the conservative network!
# The minimum loss was 0.2438335284590721, conservative 0.10845588073134423
# The minimum test loss was 0.2613783195614815, conservative 0.11217549219727516
# Plot saved to loss_plots\dataset_1\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_1\8D_losses.txt
# Processing folder: dataset_10
# Loaded preprocessed data for dimension 10
# The network training took 5.64 seconds.
# Done training the normal network!
# The network training took 10.48 seconds.
# Done training the conservative network!
# The minimum loss was 15.888918113708495, conservative 7.267440605163574
# The minimum test loss was 17.726236629486085, conservative 7.485220861434937
# Plot saved to loss_plots\dataset_10\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.59 seconds.
# Done training the normal network!
# The network training took 10.54 seconds.
# Done training the conservative network!
# The minimum loss was 1447.08857421875, conservative 325.5720581054687
# The minimum test loss was 1668.555859375, conservative 352.4081176757812
# Plot saved to loss_plots\dataset_10\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 6.11 seconds.
# Done training the normal network!
# The network training took 10.89 seconds.
# Done training the conservative network!
# The minimum loss was 1.5025302218418801e-05, conservative 0.0003301750394030023
# The minimum test loss was 1.4843941789877135e-05, conservative 0.000330565484341605
# Plot saved to loss_plots\dataset_10\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.80 seconds.
# Done training the normal network!
# The network training took 10.62 seconds.
# Done training the conservative network!
# The minimum loss was 0.0001815432100556791, conservative 8.003949915291741e-05
# The minimum test loss was 0.00017887198919197544, conservative 8.011112731765024e-05
# Plot saved to loss_plots\dataset_10\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 5.59 seconds.
# Done training the normal network!
# The network training took 10.63 seconds.
# Done training the conservative network!
# The minimum loss was 0.001294920640066266, conservative 0.00046226676931837574
# The minimum test loss was 0.0012834115070290864, conservative 0.0004632982352632098
# Plot saved to loss_plots\dataset_10\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.64 seconds.
# Done training the normal network!
# The network training took 10.75 seconds.
# Done training the conservative network!
# The minimum loss was 0.002833828190341592, conservative 0.004676223883870989
# The minimum test loss was 0.002857438591308892, conservative 0.004669384052976966
# Plot saved to loss_plots\dataset_10\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.01 seconds.
# Done training the normal network!
# The network training took 11.05 seconds.
# Done training the conservative network!
# The minimum loss was 0.2676948428153992, conservative 0.11430090218782425
# The minimum test loss was 0.2890933156013489, conservative 0.11768140941858292
# Plot saved to loss_plots\dataset_10\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_10\8D_losses.txt
# Processing folder: dataset_2
# Loaded preprocessed data for dimension 10
# The network training took 5.94 seconds.
# Done training the normal network!
# The network training took 10.63 seconds.
# Done training the conservative network!
# The minimum loss was 15.500084018707275, conservative 6.934902143478394
# The minimum test loss was 17.27175979614258, conservative 7.064802074432373
# Plot saved to loss_plots\dataset_2\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.65 seconds.
# Done training the normal network!
# The network training took 10.57 seconds.
# Done training the conservative network!
# The minimum loss was 1486.4689331054688, conservative 327.3810516357422
# The minimum test loss was 1707.891259765625, conservative 356.61623229980466
# Plot saved to loss_plots\dataset_2\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.71 seconds.
# Done training the normal network!
# The network training took 11.31 seconds.
# Done training the conservative network!
# The minimum loss was 0.00023509647999162553, conservative 1.0536174841035972e-05
# The minimum test loss was 0.0002388495444392902, conservative 1.0885166739171837e-05
# Plot saved to loss_plots\dataset_2\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.59 seconds.
# Done training the normal network!
# The network training took 11.07 seconds.
# Done training the conservative network!
# The minimum loss was 0.0002370460621023085, conservative 0.000519685434846906
# The minimum test loss was 0.00023598605548613705, conservative 0.000522372668638127
# Plot saved to loss_plots\dataset_2\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.17 seconds.
# Done training the normal network!
# The network training took 10.48 seconds.
# Done training the conservative network!
# The minimum loss was 0.00048148800851777196, conservative 0.0003346899975440465
# The minimum test loss was 0.00048035356448963287, conservative 0.0003297369883512147
# Plot saved to loss_plots\dataset_2\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.66 seconds.
# Done training the normal network!
# The network training took 10.64 seconds.
# Done training the conservative network!
# The minimum loss was 0.0019977737218141558, conservative 0.0040644211578182874
# The minimum test loss was 0.0020894860150292515, conservative 0.0041001897770911455
# Plot saved to loss_plots\dataset_2\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.80 seconds.
# Done training the normal network!
# The network training took 11.34 seconds.
# Done training the conservative network!
# The minimum loss was 0.22694580852985383, conservative 0.10217526108026505
# The minimum test loss was 0.2450508415699005, conservative 0.10947640463709832
# Plot saved to loss_plots\dataset_2\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_2\8D_losses.txt
# Processing folder: dataset_3
# Loaded preprocessed data for dimension 10
# The network training took 6.17 seconds.
# Done training the normal network!
# The network training took 11.42 seconds.
# Done training the conservative network!
# The minimum loss was 16.08187961578369, conservative 7.009744119644165
# The minimum test loss was 17.969747829437257, conservative 7.184412240982056
# Plot saved to loss_plots\dataset_3\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.76 seconds.
# Done training the normal network!
# The network training took 10.64 seconds.
# Done training the conservative network!
# The minimum loss was 1528.06318359375, conservative 334.537939453125
# The minimum test loss was 1758.1436157226562, conservative 362.8163665771484
# Plot saved to loss_plots\dataset_3\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.66 seconds.
# Done training the normal network!
# The network training took 10.77 seconds.
# Done training the conservative network!
# The minimum loss was 5.91594071011059e-05, conservative 0.0002308516016910289
# The minimum test loss was 5.812639883515658e-05, conservative 0.00023067157617333577
# Plot saved to loss_plots\dataset_3\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.20 seconds.
# Done training the normal network!
# The network training took 10.96 seconds.
# Done training the conservative network!
# The minimum loss was 0.0006062361673684791, conservative 0.000994272599928081
# The minimum test loss was 0.0006170161796035245, conservative 0.000998639540921431
# Plot saved to loss_plots\dataset_3\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 5.67 seconds.
# Done training the normal network!
# The network training took 11.53 seconds.
# Done training the conservative network!
# The minimum loss was 0.0034769196005072444, conservative 0.000871457825996913
# The minimum test loss was 0.003506919741630554, conservative 0.0008791121013928205
# Plot saved to loss_plots\dataset_3\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.68 seconds.
# Done training the normal network!
# The network training took 10.90 seconds.
# Done training the conservative network!
# The minimum loss was 0.0024643767392262816, conservative 0.002376876259222627
# The minimum test loss was 0.0025197676150128245, conservative 0.0023709079367108645
# Plot saved to loss_plots\dataset_3\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.76 seconds.
# Done training the normal network!
# The network training took 10.78 seconds.
# Done training the conservative network!
# The minimum loss was 0.2385832190513611, conservative 0.10467556044459343
# The minimum test loss was 0.25750148147344587, conservative 0.10931000933051109
# Plot saved to loss_plots\dataset_3\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_3\8D_losses.txt
# Processing folder: dataset_4
# Loaded preprocessed data for dimension 10
# The network training took 6.05 seconds.
# Done training the normal network!
# The network training took 12.22 seconds.
# Done training the conservative network!
# The minimum loss was 16.931153869628908, conservative 7.500669384002686
# The minimum test loss was 18.943914794921874, conservative 7.75761833190918
# Plot saved to loss_plots\dataset_4\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.78 seconds.
# Done training the normal network!
# The network training took 11.33 seconds.
# Done training the conservative network!
# The minimum loss was 1484.0935668945312, conservative 330.321044921875
# The minimum test loss was 1710.8691772460938, conservative 355.98125
# Plot saved to loss_plots\dataset_4\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.67 seconds.
# Done training the normal network!
# The network training took 11.10 seconds.
# Done training the conservative network!
# The minimum loss was 0.00023129182100092293, conservative 2.2423449081543367e-05
# The minimum test loss was 0.0002336996962185367, conservative 2.3265822892426514e-05
# Plot saved to loss_plots\dataset_4\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.72 seconds.
# Done training the normal network!
# The network training took 11.36 seconds.
# Done training the conservative network!
# The minimum loss was 0.0015918223332846537, conservative 0.00018615688750287518
# The minimum test loss was 0.0015977686736732722, conservative 0.0001855233422247693
# Plot saved to loss_plots\dataset_4\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.20 seconds.
# Done training the normal network!
# The network training took 11.46 seconds.
# Done training the conservative network!
# The minimum loss was 0.0023889895353931935, conservative 0.00047007899411255494
# The minimum test loss was 0.0024081443902105094, conservative 0.00047280793223762884
# Plot saved to loss_plots\dataset_4\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.63 seconds.
# Done training the normal network!
# The network training took 11.64 seconds.
# Done training the conservative network!
# The minimum loss was 0.002039866254199296, conservative 0.0025001409696415065
# The minimum test loss was 0.0021199471550062297, conservative 0.0025343202869407833
# Plot saved to loss_plots\dataset_4\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.76 seconds.
# Done training the normal network!
# The network training took 10.51 seconds.
# Done training the conservative network!
# The minimum loss was 0.24724124372005463, conservative 0.11328983679413795
# The minimum test loss was 0.27058436870574953, conservative 0.11871499046683312
# Plot saved to loss_plots\dataset_4\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_4\8D_losses.txt
# Processing folder: dataset_5
# Loaded preprocessed data for dimension 10
# The network training took 5.48 seconds.
# Done training the normal network!
# The network training took 10.78 seconds.
# Done training the conservative network!
# The minimum loss was 16.408218574523925, conservative 6.9731873035430905
# The minimum test loss was 18.37014808654785, conservative 7.207896757125854
# Plot saved to loss_plots\dataset_5\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.03 seconds.
# Done training the normal network!
# The network training took 10.55 seconds.
# Done training the conservative network!
# The minimum loss was 1495.6339233398437, conservative 333.2224975585938
# The minimum test loss was 1721.0376831054687, conservative 359.1468109130859
# Plot saved to loss_plots\dataset_5\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.66 seconds.
# Done training the normal network!
# The network training took 10.70 seconds.
# Done training the conservative network!
# The minimum loss was 2.8324757477093953e-05, conservative 1.5329954931075917e-05
# The minimum test loss was 3.158187937515322e-05, conservative 1.62128843840037e-05
# Plot saved to loss_plots\dataset_5\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.96 seconds.
# Done training the normal network!
# The network training took 10.29 seconds.
# Done training the conservative network!
# The minimum loss was 0.00019185098790330812, conservative 0.0006400627804396209
# The minimum test loss was 0.00019054005679208785, conservative 0.0006358415503200376
# Plot saved to loss_plots\dataset_5\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 5.92 seconds.
# Done training the normal network!
# The network training took 10.59 seconds.
# Done training the conservative network!
# The minimum loss was 0.0011680656927637756, conservative 0.0004342473592259921
# The minimum test loss was 0.001177962659858167, conservative 0.0004318742896430194
# Plot saved to loss_plots\dataset_5\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 6.06 seconds.
# Done training the normal network!
# The network training took 10.83 seconds.
# Done training the conservative network!
# The minimum loss was 0.0033644309965893625, conservative 0.001902966946363449
# The minimum test loss was 0.0034915835596621035, conservative 0.0019193688291124999
# Plot saved to loss_plots\dataset_5\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.63 seconds.
# Done training the normal network!
# The network training took 11.00 seconds.
# Done training the conservative network!
# The minimum loss was 0.24741019457578659, conservative 0.11209933534264564
# The minimum test loss was 0.26858987510204313, conservative 0.11578122973442077
# Plot saved to loss_plots\dataset_5\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_5\8D_losses.txt
# Processing folder: dataset_6
# Loaded preprocessed data for dimension 10
# The network training took 6.02 seconds.
# Done training the normal network!
# The network training took 10.64 seconds.
# Done training the conservative network!
# The minimum loss was 16.24643850326538, conservative 7.168881940841675
# The minimum test loss was 18.16762008666992, conservative 7.338009309768677
# Plot saved to loss_plots\dataset_6\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.61 seconds.
# Done training the normal network!
# The network training took 10.49 seconds.
# Done training the conservative network!
# The minimum loss was 1523.526806640625, conservative 329.6890808105469
# The minimum test loss was 1744.0553344726563, conservative 357.373681640625
# Plot saved to loss_plots\dataset_6\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.58 seconds.
# Done training the normal network!
# The network training took 10.47 seconds.
# Done training the conservative network!
# The minimum loss was 6.36457366454124e-05, conservative 0.0005003952092920372
# The minimum test loss was 6.324705818769872e-05, conservative 0.0005039282010102398
# Plot saved to loss_plots\dataset_6\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.67 seconds.
# Done training the normal network!
# The network training took 10.52 seconds.
# Done training the conservative network!
# The minimum loss was 0.001569904676580336, conservative 0.0003504592568788212
# The minimum test loss was 0.0015759132409584708, conservative 0.00035739393497351556
# Plot saved to loss_plots\dataset_6\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 5.84 seconds.
# Done training the normal network!
# The network training took 10.84 seconds.
# Done training the conservative network!
# The minimum loss was 0.0020731937198434024, conservative 0.0005773590877652168
# The minimum test loss was 0.002087066095555201, conservative 0.0005857675161678344
# Plot saved to loss_plots\dataset_6\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.61 seconds.
# Done training the normal network!
# The network training took 10.48 seconds.
# Done training the conservative network!
# The minimum loss was 0.0015069293905980885, conservative 0.002228858578018844
# The minimum test loss was 0.0015303012100048364, conservative 0.0021685211337171494
# Plot saved to loss_plots\dataset_6\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.63 seconds.
# Done training the normal network!
# The network training took 10.82 seconds.
# Done training the conservative network!
# The minimum loss was 0.23121686577796935, conservative 0.10637432038784027
# The minimum test loss was 0.2480573445558548, conservative 0.11105818673968315
# Plot saved to loss_plots\dataset_6\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_6\8D_losses.txt
# Processing folder: dataset_7
# Loaded preprocessed data for dimension 10
# The network training took 5.94 seconds.
# Done training the normal network!
# The network training took 10.75 seconds.
# Done training the conservative network!
# The minimum loss was 16.351713180541992, conservative 7.666334247589111
# The minimum test loss was 18.2441725730896, conservative 7.946478939056396
# Plot saved to loss_plots\dataset_7\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 6.12 seconds.
# Done training the normal network!
# The network training took 11.23 seconds.
# Done training the conservative network!
# The minimum loss was 1479.0965209960937, conservative 330.41612854003904
# The minimum test loss was 1702.979736328125, conservative 358.8763763427734
# Plot saved to loss_plots\dataset_7\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.67 seconds.
# Done training the normal network!
# The network training took 10.84 seconds.
# Done training the conservative network!
# The minimum loss was 5.0760500744218004e-05, conservative 0.0002946250506283832
# The minimum test loss was 5.029988897149451e-05, conservative 0.0002942717218502366
# Plot saved to loss_plots\dataset_7\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.79 seconds.
# Done training the normal network!
# The network training took 10.93 seconds.
# Done training the conservative network!
# The minimum loss was 0.00024868848558980974, conservative 0.0005324553618265782
# The minimum test loss was 0.0002482344381860457, conservative 0.0005315683654771419
# Plot saved to loss_plots\dataset_7\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 5.69 seconds.
# Done training the normal network!
# The network training took 10.54 seconds.
# Done training the conservative network!
# The minimum loss was 0.0023561241454444827, conservative 0.0005400095527875237
# The minimum test loss was 0.002372705563902855, conservative 0.0005408330485806801
# Plot saved to loss_plots\dataset_7\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.99 seconds.
# Done training the normal network!
# The network training took 11.03 seconds.
# Done training the conservative network!
# The minimum loss was 0.0018003382021561265, conservative 0.002425566216697916
# The minimum test loss was 0.0019028008566237987, conservative 0.0025031832745298745
# Plot saved to loss_plots\dataset_7\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.14 seconds.
# Done training the normal network!
# The network training took 10.41 seconds.
# Done training the conservative network!
# The minimum loss was 0.25879648625850676, conservative 0.1166523426771164
# The minimum test loss was 0.28097143620252607, conservative 0.11959053948521614
# Plot saved to loss_plots\dataset_7\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_7\8D_losses.txt
# Processing folder: dataset_8
# Loaded preprocessed data for dimension 10
# The network training took 5.73 seconds.
# Done training the normal network!
# The network training took 10.54 seconds.
# Done training the conservative network!
# The minimum loss was 15.896753406524658, conservative 6.998573970794678
# The minimum test loss was 17.79429636001587, conservative 7.203197431564331
# Plot saved to loss_plots\dataset_8\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.69 seconds.
# Done training the normal network!
# The network training took 10.38 seconds.
# Done training the conservative network!
# The minimum loss was 1490.5698974609375, conservative 329.2473449707031
# The minimum test loss was 1717.7953125, conservative 348.5592529296875
# Plot saved to loss_plots\dataset_8\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.88 seconds.
# Done training the normal network!
# The network training took 11.99 seconds.
# Done training the conservative network!
# The minimum loss was 8.387869420403148e-05, conservative 0.00020154909061602665
# The minimum test loss was 8.292741222248878e-05, conservative 0.00020288032455937355
# Plot saved to loss_plots\dataset_8\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 6.21 seconds.
# Done training the normal network!
# The network training took 10.55 seconds.
# Done training the conservative network!
# The minimum loss was 0.0012357441635685972, conservative 4.620006366167218e-05
# The minimum test loss was 0.001238762582943309, conservative 4.7326087951660156e-05
# Plot saved to loss_plots\dataset_8\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 5.71 seconds.
# Done training the normal network!
# The network training took 11.86 seconds.
# Done training the conservative network!
# The minimum loss was 0.0005525357351871208, conservative 0.003522353427251801
# The minimum test loss was 0.0005835948541061953, conservative 0.003530986279656645
# Plot saved to loss_plots\dataset_8\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.86 seconds.
# Done training the normal network!
# The network training took 10.85 seconds.
# Done training the conservative network!
# The minimum loss was 0.0021151479799300433, conservative 0.0031680584768764676
# The minimum test loss was 0.0021462677628733217, conservative 0.0031547625025268645
# Plot saved to loss_plots\dataset_8\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 6.88 seconds.
# Done training the normal network!
# The network training took 11.49 seconds.
# Done training the conservative network!
# The minimum loss was 0.23805690109729766, conservative 0.10588107854127884
# The minimum test loss was 0.25806888192892075, conservative 0.11004064902663231
# Plot saved to loss_plots\dataset_8\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_8\8D_losses.txt
# Processing folder: dataset_9
# Loaded preprocessed data for dimension 10
# The network training took 5.90 seconds.
# Done training the normal network!
# The network training took 11.13 seconds.
# Done training the conservative network!
# The minimum loss was 16.847700977325438, conservative 7.532326889038086
# The minimum test loss was 18.840160942077638, conservative 7.781787300109864
# Plot saved to loss_plots\dataset_9\10D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\10D_losses.txt
# Loaded preprocessed data for dimension 12
# The network training took 5.73 seconds.
# Done training the normal network!
# The network training took 10.68 seconds.
# Done training the conservative network!
# The minimum loss was 1524.9104858398437, conservative 328.0939880371094
# The minimum test loss was 1749.9861572265625, conservative 347.28692932128905
# Plot saved to loss_plots\dataset_9\12D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\12D_losses.txt
# Loaded preprocessed data for dimension 2
# The network training took 5.74 seconds.
# Done training the normal network!
# The network training took 10.66 seconds.
# Done training the conservative network!
# The minimum loss was 3.167156428389717e-05, conservative 1.5690781128796517e-05
# The minimum test loss was 3.126489264104748e-05, conservative 1.5829231779207474e-05
# Plot saved to loss_plots\dataset_9\2D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\2D_losses.txt
# Loaded preprocessed data for dimension 3
# The network training took 5.77 seconds.
# Done training the normal network!
# The network training took 11.81 seconds.
# Done training the conservative network!
# The minimum loss was 0.0002691990346647799, conservative 0.0002114366721798433
# The minimum test loss was 0.0002730347288888879, conservative 0.00021247797849355265
# Plot saved to loss_plots\dataset_9\3D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\3D_losses.txt
# Loaded preprocessed data for dimension 4
# The network training took 6.24 seconds.
# Done training the normal network!
# The network training took 10.85 seconds.
# Done training the conservative network!
# The minimum loss was 0.0019600812112912534, conservative 0.0008295433319290169
# The minimum test loss was 0.0019727236533071844, conservative 0.0008203045028494671
# Plot saved to loss_plots\dataset_9\4D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\4D_losses.txt
# Loaded preprocessed data for dimension 5
# The network training took 5.84 seconds.
# Done training the normal network!
# The network training took 10.83 seconds.
# Done training the conservative network!
# The minimum loss was 0.0020253834198229017, conservative 0.004579573660157621
# The minimum test loss was 0.0021143432008102537, conservative 0.004588221898302436
# Plot saved to loss_plots\dataset_9\5D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\5D_losses.txt
# Loaded preprocessed data for dimension 8
# The network training took 5.89 seconds.
# Done training the normal network!
# The network training took 11.17 seconds.
# Done training the conservative network!
# The minimum loss was 0.23225688487291335, conservative 0.10630712509155274
# The minimum test loss was 0.2507219210267067, conservative 0.11046918109059334
# Plot saved to loss_plots\dataset_9\8D_Conservative_NN.png
# Losses saved to loss_plots\dataset_9\8D_losses.txt
# Done!!!

# %% [markdown]
# # Organizing Data

# %%
# Folder containing the loss plots and text files
loss_folder = "loss_plots"

# Output folders for consolidated images and text files
output_image_folder = "consolidated_images"
output_text_folder = "consolidated_text_files"

# Create output folders if they don't exist
os.makedirs(output_image_folder, exist_ok=True)
os.makedirs(output_text_folder, exist_ok=True)

# Iterate through all subfolders in the loss_folder
for subfolder in os.listdir(loss_folder):
    subfolder_path = os.path.join(loss_folder, subfolder)
    
    # Check if it's a directory (e.g., dataset_1, dataset_2, etc.)
    if os.path.isdir(subfolder_path):
        print(f"Processing folder: {subfolder}")
        
        # Extract the dataset number (e.g., "1" from "dataset_1")
        dataset_number = subfolder.split("_")[-1]
        
        # Process images
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".png"):  # Process only .png files
                # Construct the new filename (e.g., 2D_Conservative_NN_1.png)
                new_filename = filename.replace(".png", f"_{dataset_number}.png")
                
                # Copy the image to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_image_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied image: {src_path} -> {dest_path}")
        
        # Process text files
        for filename in os.listdir(subfolder_path):
            if filename.endswith(".txt"):  # Process only .txt files
                # Construct the new filename (e.g., 8D_losses_1.txt)
                new_filename = filename.replace(".txt", f"_{dataset_number}.txt")
                
                # Copy the text file to the consolidated folder
                src_path = os.path.join(subfolder_path, filename)
                dest_path = os.path.join(output_text_folder, new_filename)
                shutil.copy(src_path, dest_path)
                #print(f"Copied text file: {src_path} -> {dest_path}")

print("All files have been consolidated.")
# Out:
# Processing folder: dataset_1
# Processing folder: dataset_10
# Processing folder: dataset_2
# Processing folder: dataset_3
# Processing folder: dataset_4
# Processing folder: dataset_5
# Processing folder: dataset_6
# Processing folder: dataset_7
# Processing folder: dataset_8
# Processing folder: dataset_9
# All files have been consolidated.
